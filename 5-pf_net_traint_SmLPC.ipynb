# %% [markdown]
# ## Train the PF-Controller Neural Network
#
# For each performance metric, train the corresponding particle-filter (PF) controller neural network.

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from matplotlib import pyplot as plt

from experiment_config import (
    AVERSION,
    DATA_NAME,
    DEGR_MODEL_DIR,
    DROPOUT,
    ESTIMATION_DIR,
    HIDDEN_DIMS,
    LEAKY_SLOPE,
    LOSS_TAIL_SIZE,
    LOSS_WINDOW,
    MAX_LIFE,
    N_PARTICLES,
    PFNET_DIR,
    SEED,
    DegModel,
)
from src.helpers.seed import set_global_seed
from src.models.networks.pf_mlp import ParticleFilterMLP
from src.models.particle_filter.core import ParticleFilter

DATA_NAME
# Out:
# 'DS06'

# %% [markdown]
# ## Task

# %%
perform_name = "SmLPC"

# %% [markdown]
# ## Hyper-Parameters

# %%
# Training parameters#
# optimization
lr = 5e-4

# Early stopping
max_epochs = 300
min_epochs = 100
patience = 40  # how many eval steps to wait
min_delta = 0.01  # minimum improvement to count

# %%
activation = nn.LeakyReLU(LEAKY_SLOPE)

set_global_seed(SEED)
PERFORM_DIR = PFNET_DIR / perform_name

checkpoint_best_path = PERFORM_DIR / "checkpoint_best.pt"
checkpoint_last_path = PERFORM_DIR / "checkpoint_last.pt"
checkpoint_best_path.parent.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Import training data

# %%
hi_df = pd.read_csv(ESTIMATION_DIR / "data_dev.csv")
units = hi_df["unit"].astype(int).unique().tolist()
units
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Extract degradation onset

# %%
onsets = {
    unit: hi_df[(hi_df["unit"] == unit) & (hi_df["hs"] == 0)]["cycle"].values[0]
    for unit in units
}
del hi_df["hs"]

# %%
perform_names = [col for col in hi_df.columns if col not in ["unit", "cycle"]]

performs = {
    name: {unit: hi_df[hi_df["unit"] == unit][name].values for unit in units}
    for name in perform_names
}

init_ss = {
    name: {unit: perform[unit].max() for unit in units}
    for name, perform in performs.items()
}
time = {unit: hi_df[hi_df["unit"] == unit]["cycle"].values for unit in units}

# %% [markdown]
# ## Create component (base) models

# %%
dev_data = {}
dev_eol = {}
for unit in units:
    t = time[unit]
    s = performs[perform_name][unit]
    dev_data[unit] = torch.tensor(np.stack([t, s], axis=1), dtype=torch.float32)
    dev_eol[unit] = torch.tensor(t[-1], dtype=torch.float32)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 5
#       1 dev_data = {}
#       2 dev_eol = {}
#       3 for unit in units:
#       4     t = time[unit]
# ----> 5     s = performs[perform_name][unit]
#       6     dev_data[unit] = torch.tensor(np.stack([t, s], axis=1), dtype=torch.float32)
#       7     dev_eol[unit] = torch.tensor(t[-1], dtype=torch.float32)
#
# KeyError: 'SmLPC'

# %%
dev_degmodels = {}
for unit, perform in performs[perform_name].items():
    best_model = DegModel(onset=onsets[unit], init_s=init_ss[perform_name][unit])
    best_model.load_state_dict(
        torch.load(
            DEGR_MODEL_DIR / "states" / perform_name / f"unit_{unit}" / "best_model.pt"
        )
    )
    dev_degmodels[unit] = best_model

# %% [markdown]
# ## Train Particle Filter controller Net

# %%
net = ParticleFilterMLP(
    state_dim=DegModel.state_dim(),
    hidden_dims=HIDDEN_DIMS,
    activation=lambda: nn.LeakyReLU(LEAKY_SLOPE),
    dropout_p=DROPOUT,
)

optimizer = torch.optim.Adam(net.parameters(), lr)
optimizer.zero_grad()

# %%
best_score = float("inf")
train_epoch_losses = []
eval_epoch_losses = []
scores = []
window_means = []
window_stds = []
wait = 0
start_epoch = 0

if checkpoint_last_path.exists():
    ckpt = torch.load(checkpoint_last_path, weights_only=False)

    net.load_state_dict(ckpt["model_state"])
    optimizer.load_state_dict(ckpt["optimizer_state"])

    start_epoch = ckpt["epoch"] + 1
    best_score = ckpt["best_score"]
    scores = ckpt.get("scores", [])
    train_epoch_losses = ckpt.get("train_losses", [])
    eval_epoch_losses = ckpt.get("eval_losses", [])
    window_means = ckpt.get("window_means", [])
    window_stds = ckpt.get("window_stds", [])

    torch.random.set_rng_state(ckpt["rng_torch"])
    np.random.set_state(ckpt["rng_numpy"])

    print(f"✓ Resumed from epoch {start_epoch}, best_score={best_score:.3f}")

# %%
for epoch in range(start_epoch, max_epochs):
    eval_fold_losses = []
    train_fold_losses = []

    for eval_unit in np.random.permutation(units):
        train_unit_losses = []

        # --------------------------
        # TRAINING
        # --------------------------
        for train_unit in np.random.permutation(units):
            if train_unit == eval_unit:
                continue

            train_offline_units = [u for u in units if u not in (train_unit, eval_unit)]

            train_offline_degmodels = [dev_degmodels[u] for u in train_offline_units]

            train_t_data = dev_data[train_unit][:, 0]
            train_s_data = dev_data[train_unit][:, 1]

            optimizer.zero_grad()

            train_pf = ParticleFilter(
                base_models=train_offline_degmodels,
                net=net,
                n_particles=N_PARTICLES,
                max_life=MAX_LIFE,
            ).train()

            train_step_losses = []
            for k in range(len(train_t_data)):
                train_mixture_dist = train_pf.step(
                    t_obs=train_t_data[[k]],
                    s_obs=train_s_data[[k]],
                )

                start_loss = -LOSS_TAIL_SIZE if LOSS_TAIL_SIZE else k
                train_last_dist = train_mixture_dist.distribution(
                    s=train_s_data[start_loss:]
                )
                train_step_nll = -train_last_dist.log_prob(
                    train_t_data[start_loss:]
                ).mean()

                train_step_losses.append(train_step_nll)

            train_unit_loss = torch.stack(train_step_losses).mean()

            train_unit_loss.backward()

            optimizer.step()

            train_unit_losses.append(train_unit_loss.item())

        train_fold_loss = np.mean(train_unit_losses)
        train_fold_losses.append(train_fold_loss)

        # --------------------------
        # EVALUATION
        # --------------------------

        eval_offline_units = [u for u in units if u != eval_unit]

        eval_offline_degmodels = [dev_degmodels[u] for u in eval_offline_units]

        eval_t_data = dev_data[eval_unit][:, 0]
        eval_s_data = dev_data[eval_unit][:, 1]

        eval_pf = ParticleFilter(
            base_models=eval_offline_degmodels,
            net=net,
            n_particles=N_PARTICLES,
            max_life=MAX_LIFE,
        ).eval()

        eval_step_losses = []
        for k in range(len(eval_t_data)):
            eval_mixture_dist = eval_pf.step(
                t_obs=eval_t_data[[k]],
                s_obs=eval_s_data[[k]],
            )

            start_loss = -LOSS_TAIL_SIZE if LOSS_TAIL_SIZE else k

            eval_last_dist = eval_mixture_dist.distribution(s=eval_s_data[start_loss:])

            eval_step_nll = -eval_last_dist.log_prob(eval_t_data[start_loss:]).mean()

            eval_step_losses.append(eval_step_nll.item())

        eval_fold_loss = np.mean(eval_step_losses)
        eval_fold_losses.append(eval_fold_loss)

    # --------------------------
    # epoch statistics
    # --------------------------

    train_epoch_loss = np.mean(train_fold_losses)
    eval_epoch_loss = np.mean(eval_fold_losses)

    train_epoch_losses.append(train_epoch_loss)
    eval_epoch_losses.append(eval_epoch_loss)

    # --------------------------
    # VARIANCE-AWARE SELECTION
    # --------------------------

    window = eval_epoch_losses[-LOSS_WINDOW:]
    mean_loss = np.mean(window)
    std_loss = np.std(window)
    window_means.append(mean_loss)
    window_stds.append(std_loss)

    score = mean_loss + AVERSION * std_loss
    scores.append(score)

    print(
        f"[Epoch {epoch:03d}] "
        f"train={train_epoch_loss:.3f} | "
        f"eval={eval_epoch_loss:.3f} | "
        f"score={score:.3f} "
        f"(μ={mean_loss:.3f}, σ={std_loss:.3f})"
    )

    # --------------------------
    # CHECKPOINT SELECTION
    # --------------------------

    if epoch + 1 >= LOSS_WINDOW:
        if score < best_score - min_delta:
            best_score = score
            wait = 0

            best_checkpoint = {
                "epoch": epoch,
                "model_state": net.state_dict(),
                "best_score": best_score,
            }

            torch.save(best_checkpoint, checkpoint_best_path)

            last_checkpoint = {
                "epoch": epoch,
                "model_state": net.state_dict(),
                "optimizer_state": optimizer.state_dict(),
                "best_score": best_score,
                "scores": scores,
                "train_losses": train_epoch_losses,
                "eval_losses": eval_epoch_losses,
                "window_means": window_means,
                "window_stds": window_stds,
                "rng_torch": torch.random.get_rng_state(),
                "rng_numpy": np.random.get_state(),
            }

            torch.save(last_checkpoint, checkpoint_last_path)

            print(f"  + saved (score={score:.3f})")
        else:
            wait += 1

            if epoch >= max(min_epochs, LOSS_WINDOW) and wait >= patience:
                print("🛑 Early stopping triggered")
                break
# Out:
# [Epoch 000] train=4.736 | eval=3.925 | score=3.925 (μ=3.925, σ=0.000)
# [Epoch 001] train=4.369 | eval=3.735 | score=3.877 (μ=3.830, σ=0.095)
# [Epoch 002] train=3.907 | eval=3.349 | score=3.789 (μ=3.670, σ=0.239)
# [Epoch 003] train=3.746 | eval=3.696 | score=3.780 (μ=3.676, σ=0.208)
# [Epoch 004] train=3.668 | eval=3.556 | score=3.748 (μ=3.652, σ=0.192)
# [Epoch 005] train=3.679 | eval=3.577 | score=3.728 (μ=3.640, σ=0.177)
# [Epoch 006] train=3.633 | eval=3.548 | score=3.710 (μ=3.626, σ=0.167)
# [Epoch 007] train=3.640 | eval=3.584 | score=3.700 (μ=3.621, σ=0.157)
# [Epoch 008] train=3.594 | eval=3.565 | score=3.689 (μ=3.615, σ=0.149)
# [Epoch 009] train=3.590 | eval=3.580 | score=3.682 (μ=3.611, σ=0.142)
#   + saved (score=3.682)
# [Epoch 010] train=3.586 | eval=3.580 | score=3.625 (μ=3.577, σ=0.096)
#   + saved (score=3.625)
# [Epoch 011] train=3.573 | eval=3.533 | score=3.597 (μ=3.557, σ=0.081)
#   + saved (score=3.597)
# [Epoch 012] train=3.561 | eval=3.536 | score=3.597 (μ=3.575, σ=0.044)
# [Epoch 013] train=3.561 | eval=3.528 | score=3.569 (μ=3.559, σ=0.020)
#   + saved (score=3.569)
# [Epoch 014] train=3.563 | eval=3.551 | score=3.568 (μ=3.558, σ=0.021)
# [Epoch 015] train=3.557 | eval=3.516 | score=3.564 (μ=3.552, σ=0.023)
# [Epoch 016] train=3.558 | eval=3.530 | score=3.562 (μ=3.550, σ=0.024)
# [Epoch 017] train=3.530 | eval=3.530 | score=3.556 (μ=3.545, σ=0.022)
#   + saved (score=3.556)
# [Epoch 018] train=3.550 | eval=3.521 | score=3.551 (μ=3.541, σ=0.022)
# [Epoch 019] train=3.548 | eval=3.510 | score=3.543 (μ=3.534, σ=0.019)
#   + saved (score=3.543)
# [Epoch 020] train=3.541 | eval=3.513 | score=3.533 (μ=3.527, σ=0.012)
#   + saved (score=3.533)
# [Epoch 021] train=3.532 | eval=3.505 | score=3.531 (μ=3.524, σ=0.013)
# [Epoch 022] train=3.538 | eval=3.509 | score=3.528 (μ=3.521, σ=0.013)
# [Epoch 023] train=3.539 | eval=3.490 | score=3.525 (μ=3.517, σ=0.016)
# [Epoch 024] train=3.534 | eval=3.505 | score=3.519 (μ=3.513, σ=0.012)
#   + saved (score=3.519)
# [Epoch 025] train=3.529 | eval=3.506 | score=3.518 (μ=3.512, σ=0.012)
# [Epoch 026] train=3.517 | eval=3.495 | score=3.514 (μ=3.508, σ=0.011)
# [Epoch 027] train=3.506 | eval=3.504 | score=3.510 (μ=3.506, σ=0.008)
# [Epoch 028] train=3.525 | eval=3.482 | score=3.506 (μ=3.502, σ=0.009)
#   + saved (score=3.506)
# [Epoch 029] train=3.511 | eval=3.491 | score=3.505 (μ=3.500, σ=0.009)
# [Epoch 030] train=3.512 | eval=3.495 | score=3.502 (μ=3.498, σ=0.008)
# [Epoch 031] train=3.499 | eval=3.488 | score=3.501 (μ=3.496, σ=0.009)
# [Epoch 032] train=3.497 | eval=3.471 | score=3.498 (μ=3.493, σ=0.010)
# [Epoch 033] train=3.506 | eval=3.476 | score=3.497 (μ=3.491, σ=0.012)
# [Epoch 034] train=3.496 | eval=3.474 | score=3.494 (μ=3.488, σ=0.012)
#   + saved (score=3.494)
# [Epoch 035] train=3.514 | eval=3.470 | score=3.490 (μ=3.485, σ=0.011)
# [Epoch 036] train=3.496 | eval=3.466 | score=3.488 (μ=3.482, σ=0.012)
# [Epoch 037] train=3.497 | eval=3.475 | score=3.483 (μ=3.479, σ=0.009)
#   + saved (score=3.483)
# [Epoch 038] train=3.487 | eval=3.454 | score=3.482 (μ=3.476, σ=0.012)
# [Epoch 039] train=3.508 | eval=3.474 | score=3.480 (μ=3.474, σ=0.010)
# [Epoch 040] train=3.482 | eval=3.450 | score=3.475 (μ=3.470, σ=0.010)
# [Epoch 041] train=3.474 | eval=3.465 | score=3.472 (μ=3.468, σ=0.008)
#   + saved (score=3.472)
# [Epoch 042] train=3.486 | eval=3.434 | score=3.470 (μ=3.464, σ=0.013)
# [Epoch 043] train=3.487 | eval=3.453 | score=3.468 (μ=3.462, σ=0.013)
# [Epoch 044] train=3.487 | eval=3.435 | score=3.465 (μ=3.458, σ=0.014)
# [Epoch 045] train=3.473 | eval=3.443 | score=3.462 (μ=3.455, σ=0.014)
# [Epoch 046] train=3.465 | eval=3.449 | score=3.460 (μ=3.453, σ=0.014)
#   + saved (score=3.460)
# [Epoch 047] train=3.461 | eval=3.424 | score=3.455 (μ=3.448, σ=0.014)
# [Epoch 048] train=3.458 | eval=3.413 | score=3.453 (μ=3.444, σ=0.017)
# [Epoch 049] train=3.452 | eval=3.427 | score=3.447 (μ=3.439, σ=0.015)
#   + saved (score=3.447)
# [Epoch 050] train=3.441 | eval=3.416 | score=3.444 (μ=3.436, σ=0.016)
# [Epoch 051] train=3.443 | eval=3.409 | score=3.437 (μ=3.430, σ=0.014)
# [Epoch 052] train=3.436 | eval=3.411 | score=3.435 (μ=3.428, σ=0.015)
#   + saved (score=3.435)
# [Epoch 053] train=3.456 | eval=3.397 | score=3.430 (μ=3.422, σ=0.015)
# [Epoch 054] train=3.443 | eval=3.391 | score=3.427 (μ=3.418, σ=0.017)
# [Epoch 055] train=3.431 | eval=3.392 | score=3.421 (μ=3.413, σ=0.017)
#   + saved (score=3.421)
# [Epoch 056] train=3.426 | eval=3.411 | score=3.415 (μ=3.409, σ=0.012)
# [Epoch 057] train=3.397 | eval=3.391 | score=3.412 (μ=3.406, σ=0.012)
# [Epoch 058] train=3.414 | eval=3.380 | score=3.409 (μ=3.403, σ=0.014)
#   + saved (score=3.409)
# [Epoch 059] train=3.409 | eval=3.374 | score=3.404 (μ=3.397, σ=0.013)
# [Epoch 060] train=3.395 | eval=3.373 | score=3.400 (μ=3.393, σ=0.014)
# [Epoch 061] train=3.396 | eval=3.377 | score=3.396 (μ=3.390, σ=0.013)
#   + saved (score=3.396)
# [Epoch 062] train=3.428 | eval=3.349 | score=3.392 (μ=3.384, σ=0.016)
# [Epoch 063] train=3.444 | eval=3.398 | score=3.392 (μ=3.384, σ=0.016)
# [Epoch 064] train=3.422 | eval=3.352 | score=3.389 (μ=3.380, σ=0.018)
# [Epoch 065] train=3.422 | eval=3.373 | score=3.387 (μ=3.378, σ=0.018)
# [Epoch 066] train=3.393 | eval=3.373 | score=3.381 (μ=3.374, σ=0.014)
#   + saved (score=3.381)
# [Epoch 067] train=3.431 | eval=3.387 | score=3.381 (μ=3.374, σ=0.014)
# [Epoch 068] train=3.421 | eval=3.368 | score=3.379 (μ=3.372, σ=0.014)
# [Epoch 069] train=3.412 | eval=3.411 | score=3.385 (μ=3.376, σ=0.018)
# [Epoch 070] train=3.409 | eval=3.359 | score=3.384 (μ=3.375, σ=0.019)
# [Epoch 071] train=3.429 | eval=3.397 | score=3.387 (μ=3.377, σ=0.020)
# [Epoch 072] train=3.395 | eval=3.337 | score=3.386 (μ=3.375, σ=0.022)
# [Epoch 073] train=3.394 | eval=3.364 | score=3.382 (μ=3.372, σ=0.021)
# [Epoch 074] train=3.403 | eval=3.359 | score=3.383 (μ=3.373, σ=0.020)
# [Epoch 075] train=3.410 | eval=3.347 | score=3.381 (μ=3.370, σ=0.022)
# [Epoch 076] train=3.408 | eval=3.352 | score=3.379 (μ=3.368, σ=0.022)
# [Epoch 077] train=3.396 | eval=3.372 | score=3.377 (μ=3.366, σ=0.021)
# [Epoch 078] train=3.409 | eval=3.335 | score=3.375 (μ=3.363, σ=0.023)
# [Epoch 079] train=3.404 | eval=3.382 | score=3.370 (μ=3.360, σ=0.019)
#   + saved (score=3.370)
# [Epoch 080] train=3.410 | eval=3.365 | score=3.370 (μ=3.361, σ=0.019)
# [Epoch 081] train=3.405 | eval=3.378 | score=3.367 (μ=3.359, σ=0.015)
# [Epoch 082] train=3.399 | eval=3.372 | score=3.370 (μ=3.363, σ=0.014)
# [Epoch 083] train=3.388 | eval=3.380 | score=3.372 (μ=3.364, σ=0.015)
# [Epoch 084] train=3.371 | eval=3.357 | score=3.371 (μ=3.364, σ=0.015)
# [Epoch 085] train=3.382 | eval=3.388 | score=3.376 (μ=3.368, σ=0.015)
# [Epoch 086] train=3.396 | eval=3.370 | score=3.377 (μ=3.370, σ=0.014)
# [Epoch 087] train=3.394 | eval=3.352 | score=3.376 (μ=3.368, σ=0.015)
# [Epoch 088] train=3.368 | eval=3.361 | score=3.376 (μ=3.371, σ=0.011)
# [Epoch 089] train=3.390 | eval=3.355 | score=3.373 (μ=3.368, σ=0.011)
# [Epoch 090] train=3.380 | eval=3.368 | score=3.374 (μ=3.368, σ=0.011)
# [Epoch 091] train=3.405 | eval=3.348 | score=3.371 (μ=3.365, σ=0.012)
# [Epoch 092] train=3.390 | eval=3.318 | score=3.369 (μ=3.360, σ=0.018)
# [Epoch 093] train=3.402 | eval=3.359 | score=3.366 (μ=3.358, σ=0.017)
# [Epoch 094] train=3.379 | eval=3.384 | score=3.370 (μ=3.360, σ=0.019)
# [Epoch 095] train=3.373 | eval=3.350 | score=3.365 (μ=3.357, σ=0.017)
# [Epoch 096] train=3.389 | eval=3.347 | score=3.362 (μ=3.354, σ=0.016)
# [Epoch 097] train=3.368 | eval=3.343 | score=3.362 (μ=3.353, σ=0.017)
# [Epoch 098] train=3.376 | eval=3.327 | score=3.359 (μ=3.350, σ=0.018)
#   + saved (score=3.359)
# [Epoch 099] train=3.385 | eval=3.379 | score=3.362 (μ=3.352, σ=0.020)
# [Epoch 100] train=3.386 | eval=3.319 | score=3.358 (μ=3.347, σ=0.022)
# [Epoch 101] train=3.377 | eval=3.335 | score=3.357 (μ=3.346, σ=0.022)
# [Epoch 102] train=3.361 | eval=3.337 | score=3.358 (μ=3.348, σ=0.020)
# [Epoch 103] train=3.398 | eval=3.317 | score=3.355 (μ=3.344, σ=0.022)
# [Epoch 104] train=3.377 | eval=3.313 | score=3.346 (μ=3.337, σ=0.019)
#   + saved (score=3.346)
# [Epoch 105] train=3.403 | eval=3.335 | score=3.344 (μ=3.335, σ=0.018)
# [Epoch 106] train=3.379 | eval=3.337 | score=3.343 (μ=3.334, σ=0.018)
# [Epoch 107] train=3.361 | eval=3.300 | score=3.340 (μ=3.330, σ=0.020)
# [Epoch 108] train=3.388 | eval=3.390 | score=3.350 (μ=3.336, σ=0.027)
# [Epoch 109] train=3.385 | eval=3.330 | score=3.343 (μ=3.331, σ=0.023)
# [Epoch 110] train=3.408 | eval=3.349 | score=3.346 (μ=3.334, σ=0.023)
# [Epoch 111] train=3.377 | eval=3.366 | score=3.350 (μ=3.337, σ=0.025)
# [Epoch 112] train=3.388 | eval=3.330 | score=3.349 (μ=3.337, σ=0.025)
# [Epoch 113] train=3.353 | eval=3.378 | score=3.356 (μ=3.343, σ=0.027)
# [Epoch 114] train=3.367 | eval=3.339 | score=3.358 (μ=3.345, σ=0.025)
# [Epoch 115] train=3.347 | eval=3.346 | score=3.359 (μ=3.346, σ=0.025)
# [Epoch 116] train=3.364 | eval=3.350 | score=3.360 (μ=3.348, σ=0.025)
# [Epoch 117] train=3.375 | eval=3.358 | score=3.363 (μ=3.354, σ=0.019)
# [Epoch 118] train=3.343 | eval=3.337 | score=3.356 (μ=3.348, σ=0.015)
# [Epoch 119] train=3.352 | eval=3.345 | score=3.357 (μ=3.350, σ=0.014)
# [Epoch 120] train=3.365 | eval=3.305 | score=3.355 (μ=3.345, σ=0.019)
# [Epoch 121] train=3.373 | eval=3.307 | score=3.350 (μ=3.339, σ=0.021)
# [Epoch 122] train=3.365 | eval=3.348 | score=3.352 (μ=3.341, σ=0.021)
# [Epoch 123] train=3.360 | eval=3.319 | score=3.344 (μ=3.335, σ=0.018)
# [Epoch 124] train=3.364 | eval=3.313 | score=3.342 (μ=3.333, σ=0.019)
# [Epoch 125] train=3.387 | eval=3.324 | score=3.340 (μ=3.331, σ=0.018)
# [Epoch 126] train=3.350 | eval=3.316 | score=3.336 (μ=3.327, σ=0.018)
# [Epoch 127] train=3.346 | eval=3.293 | score=3.329 (μ=3.321, σ=0.017)
#   + saved (score=3.329)
# [Epoch 128] train=3.347 | eval=3.363 | score=3.334 (μ=3.323, σ=0.021)
# [Epoch 129] train=3.333 | eval=3.303 | score=3.329 (μ=3.319, σ=0.020)
# [Epoch 130] train=3.338 | eval=3.367 | score=3.337 (μ=3.325, σ=0.024)
# [Epoch 131] train=3.374 | eval=3.326 | score=3.339 (μ=3.327, σ=0.023)
# [Epoch 132] train=3.333 | eval=3.318 | score=3.335 (μ=3.324, σ=0.022)
# [Epoch 133] train=3.350 | eval=3.331 | score=3.337 (μ=3.325, σ=0.022)
# [Epoch 134] train=3.365 | eval=3.317 | score=3.337 (μ=3.326, σ=0.022)
# [Epoch 135] train=3.378 | eval=3.298 | score=3.335 (μ=3.323, σ=0.024)
# [Epoch 136] train=3.433 | eval=3.322 | score=3.336 (μ=3.324, σ=0.024)
# [Epoch 137] train=3.356 | eval=3.328 | score=3.338 (μ=3.327, σ=0.021)
# [Epoch 138] train=3.347 | eval=3.322 | score=3.332 (μ=3.323, σ=0.018)
# [Epoch 139] train=3.349 | eval=3.302 | score=3.332 (μ=3.323, σ=0.018)
# [Epoch 140] train=3.345 | eval=3.355 | score=3.330 (μ=3.322, σ=0.015)
# [Epoch 141] train=3.340 | eval=3.312 | score=3.328 (μ=3.321, σ=0.015)
# [Epoch 142] train=3.337 | eval=3.305 | score=3.327 (μ=3.319, σ=0.016)
# [Epoch 143] train=3.345 | eval=3.310 | score=3.325 (μ=3.317, σ=0.016)
# [Epoch 144] train=3.354 | eval=3.330 | score=3.326 (μ=3.318, σ=0.016)
# [Epoch 145] train=3.358 | eval=3.296 | score=3.326 (μ=3.318, σ=0.016)
# [Epoch 146] train=3.350 | eval=3.386 | score=3.338 (μ=3.325, σ=0.026)
# [Epoch 147] train=3.341 | eval=3.309 | score=3.336 (μ=3.323, σ=0.027)
# [Epoch 148] train=3.332 | eval=3.308 | score=3.335 (μ=3.321, σ=0.027)
# [Epoch 149] train=3.344 | eval=3.306 | score=3.335 (μ=3.322, σ=0.027)
# [Epoch 150] train=3.365 | eval=3.302 | score=3.329 (μ=3.316, σ=0.025)
# [Epoch 151] train=3.343 | eval=3.352 | score=3.334 (μ=3.320, σ=0.027)
# [Epoch 152] train=3.355 | eval=3.304 | score=3.334 (μ=3.320, σ=0.027)
# [Epoch 153] train=3.367 | eval=3.314 | score=3.334 (μ=3.321, σ=0.027)
# [Epoch 154] train=3.341 | eval=3.333 | score=3.334 (μ=3.321, σ=0.027)
# [Epoch 155] train=3.347 | eval=3.296 | score=3.334 (μ=3.321, σ=0.027)
# [Epoch 156] train=3.361 | eval=3.307 | score=3.321 (μ=3.313, σ=0.016)
# [Epoch 157] train=3.340 | eval=3.331 | score=3.323 (μ=3.315, σ=0.017)
# [Epoch 158] train=3.342 | eval=3.306 | score=3.323 (μ=3.315, σ=0.017)
# [Epoch 159] train=3.372 | eval=3.317 | score=3.324 (μ=3.316, σ=0.016)
# [Epoch 160] train=3.361 | eval=3.291 | score=3.324 (μ=3.315, σ=0.018)
# [Epoch 161] train=3.335 | eval=3.292 | score=3.316 (μ=3.309, σ=0.014)
#   + saved (score=3.316)
# [Epoch 162] train=3.356 | eval=3.325 | score=3.318 (μ=3.311, σ=0.015)
# [Epoch 163] train=3.350 | eval=3.268 | score=3.316 (μ=3.306, σ=0.019)
# [Epoch 164] train=3.335 | eval=3.305 | score=3.312 (μ=3.304, σ=0.017)
# [Epoch 165] train=3.339 | eval=3.318 | score=3.315 (μ=3.306, σ=0.018)
# [Epoch 166] train=3.333 | eval=3.304 | score=3.314 (μ=3.306, σ=0.018)
# [Epoch 167] train=3.332 | eval=3.266 | score=3.309 (μ=3.299, σ=0.019)
# [Epoch 168] train=3.339 | eval=3.308 | score=3.309 (μ=3.299, σ=0.019)
# [Epoch 169] train=3.349 | eval=3.290 | score=3.306 (μ=3.297, σ=0.018)
#   + saved (score=3.306)
# [Epoch 170] train=3.346 | eval=3.306 | score=3.307 (μ=3.298, σ=0.018)
# [Epoch 171] train=3.358 | eval=3.322 | score=3.311 (μ=3.301, σ=0.020)
# [Epoch 172] train=3.340 | eval=3.275 | score=3.306 (μ=3.296, σ=0.019)
# [Epoch 173] train=3.337 | eval=3.299 | score=3.308 (μ=3.299, σ=0.017)
# [Epoch 174] train=3.343 | eval=3.340 | score=3.313 (μ=3.303, σ=0.021)
# [Epoch 175] train=3.344 | eval=3.278 | score=3.309 (μ=3.299, σ=0.021)
# [Epoch 176] train=3.331 | eval=3.302 | score=3.309 (μ=3.299, σ=0.021)
# [Epoch 177] train=3.319 | eval=3.309 | score=3.312 (μ=3.303, σ=0.018)
# [Epoch 178] train=3.394 | eval=3.307 | score=3.312 (μ=3.303, σ=0.018)
# [Epoch 179] train=3.331 | eval=3.323 | score=3.316 (μ=3.306, σ=0.019)
# [Epoch 180] train=3.342 | eval=3.303 | score=3.315 (μ=3.306, σ=0.019)
# [Epoch 181] train=3.341 | eval=3.288 | score=3.312 (μ=3.303, σ=0.019)
# [Epoch 182] train=3.356 | eval=3.285 | score=3.312 (μ=3.303, σ=0.017)
# [Epoch 183] train=3.356 | eval=3.300 | score=3.312 (μ=3.304, σ=0.017)
# [Epoch 184] train=3.358 | eval=3.294 | score=3.305 (μ=3.299, σ=0.013)
# [Epoch 185] train=3.331 | eval=3.295 | score=3.306 (μ=3.301, σ=0.011)
# [Epoch 186] train=3.362 | eval=3.299 | score=3.306 (μ=3.300, σ=0.011)
# [Epoch 187] train=3.330 | eval=3.288 | score=3.304 (μ=3.298, σ=0.011)
# [Epoch 188] train=3.328 | eval=3.273 | score=3.301 (μ=3.295, σ=0.013)
# [Epoch 189] train=3.329 | eval=3.279 | score=3.295 (μ=3.290, σ=0.009)
#   + saved (score=3.295)
# [Epoch 190] train=3.327 | eval=3.301 | score=3.295 (μ=3.290, σ=0.009)
# [Epoch 191] train=3.355 | eval=3.350 | score=3.307 (μ=3.297, σ=0.020)
# [Epoch 192] train=3.349 | eval=3.256 | score=3.305 (μ=3.294, σ=0.023)
# [Epoch 193] train=3.314 | eval=3.272 | score=3.303 (μ=3.291, σ=0.024)
# [Epoch 194] train=3.344 | eval=3.320 | score=3.306 (μ=3.294, σ=0.026)
# [Epoch 195] train=3.322 | eval=3.282 | score=3.305 (μ=3.292, σ=0.026)
# [Epoch 196] train=3.341 | eval=3.280 | score=3.303 (μ=3.290, σ=0.026)
# [Epoch 197] train=3.392 | eval=3.319 | score=3.307 (μ=3.293, σ=0.027)
# [Epoch 198] train=3.316 | eval=3.316 | score=3.311 (μ=3.298, σ=0.027)
# [Epoch 199] train=3.311 | eval=3.286 | score=3.312 (μ=3.298, σ=0.027)
# [Epoch 200] train=3.358 | eval=3.272 | score=3.309 (μ=3.295, σ=0.028)
# [Epoch 201] train=3.358 | eval=3.350 | score=3.309 (μ=3.295, σ=0.028)
# [Epoch 202] train=3.349 | eval=3.297 | score=3.312 (μ=3.299, σ=0.024)
# [Epoch 203] train=3.303 | eval=3.277 | score=3.312 (μ=3.300, σ=0.024)
# [Epoch 204] train=3.362 | eval=3.296 | score=3.309 (μ=3.298, σ=0.023)
# [Epoch 205] train=3.332 | eval=3.298 | score=3.310 (μ=3.299, σ=0.022)
# [Epoch 206] train=3.338 | eval=3.269 | score=3.310 (μ=3.298, σ=0.024)
# [Epoch 207] train=3.324 | eval=3.347 | score=3.315 (μ=3.301, σ=0.027)
# [Epoch 208] train=3.349 | eval=3.269 | score=3.310 (μ=3.296, σ=0.028)
# [Epoch 209] train=3.332 | eval=3.261 | score=3.309 (μ=3.294, σ=0.030)
# [Epoch 210] train=3.371 | eval=3.251 | score=3.308 (μ=3.292, σ=0.032)
# [Epoch 211] train=3.304 | eval=3.292 | score=3.299 (μ=3.286, σ=0.026)
# [Epoch 212] train=3.344 | eval=3.266 | score=3.296 (μ=3.283, σ=0.026)
# [Epoch 213] train=3.349 | eval=3.325 | score=3.302 (μ=3.287, σ=0.029)
# [Epoch 214] train=3.328 | eval=3.290 | score=3.301 (μ=3.287, σ=0.029)
# [Epoch 215] train=3.330 | eval=3.290 | score=3.300 (μ=3.286, σ=0.029)
# [Epoch 216] train=3.309 | eval=3.338 | score=3.309 (μ=3.293, σ=0.032)
# [Epoch 217] train=3.316 | eval=3.276 | score=3.299 (μ=3.286, σ=0.026)
# [Epoch 218] train=3.354 | eval=3.276 | score=3.299 (μ=3.287, σ=0.026)
# [Epoch 219] train=3.306 | eval=3.318 | score=3.305 (μ=3.292, σ=0.026)
# [Epoch 220] train=3.347 | eval=3.281 | score=3.306 (μ=3.295, σ=0.022)
# [Epoch 221] train=3.323 | eval=3.263 | score=3.305 (μ=3.292, σ=0.025)
# [Epoch 222] train=3.307 | eval=3.316 | score=3.309 (μ=3.297, σ=0.024)
# [Epoch 223] train=3.318 | eval=3.298 | score=3.306 (μ=3.295, σ=0.022)
# [Epoch 224] train=3.331 | eval=3.287 | score=3.305 (μ=3.294, σ=0.022)
# [Epoch 225] train=3.327 | eval=3.281 | score=3.304 (μ=3.293, σ=0.022)
# [Epoch 226] train=3.330 | eval=3.351 | score=3.307 (μ=3.295, σ=0.025)
# [Epoch 227] train=3.365 | eval=3.257 | score=3.306 (μ=3.293, σ=0.027)
# [Epoch 228] train=3.315 | eval=3.291 | score=3.307 (μ=3.294, σ=0.027)
# [Epoch 229] train=3.324 | eval=3.314 | score=3.307 (μ=3.294, σ=0.026)
# 🛑 Early stopping triggered

# %% [markdown]
# # Save last results

# %%
if start_epoch < max_epochs:
    last_checkpoint = {
        "epoch": epoch,
        "model_state": net.state_dict(),
        "optimizer_state": optimizer.state_dict(),
        "best_score": best_score,
        "scores": scores,
        "train_losses": train_epoch_losses,
        "eval_losses": eval_epoch_losses,
        "window_means": window_means,
        "window_stds": window_stds,
        "rng_torch": torch.random.get_rng_state(),
        "rng_numpy": np.random.get_state(),
    }

    torch.save(last_checkpoint, checkpoint_last_path)

    print("✓ Final LAST checkpoint saved.")

else:
    epoch = start_epoch
# Out:
# ✓ Final LAST checkpoint saved.

# %% [markdown]
# ## Plot

# %%
train_loss_arr = np.array(train_epoch_losses)
eval_loss_arr = np.array(eval_epoch_losses)
score_arr = np.array(scores)
best_epoch = best_checkpoint["epoch"]

epochs = np.arange(len(train_loss_arr))

# best epoch based on score

best_score = score_arr[best_epoch]
best_eval_loss = eval_loss_arr[best_epoch]

plt.figure(figsize=(8, 5))

# Main curves
plt.plot(epochs, train_loss_arr, linewidth=2, label="train loss")
plt.plot(epochs, eval_loss_arr, linewidth=2, label="eval loss")
plt.plot(epochs, score_arr, linewidth=2, linestyle="--", label="score")

ymin, ymax = plt.ylim()
yrange = ymax - ymin

xmin, xmax = plt.xlim()
xrange = xmax - xmin

y_offset = 0.5 * yrange
x_offset = -0.05 * xrange

# Annotation of best score
plt.annotate(
    f"min score = {best_score:.3f}\nepoch = {best_epoch}",
    xy=(best_epoch, best_score),
    xytext=(best_epoch + x_offset, best_score + y_offset),
    textcoords="data",
    arrowprops=dict(arrowstyle="->", linewidth=1),
    fontsize=9,
    bbox=dict(boxstyle="round,pad=0.3", fc="white", alpha=0.8),
)

plt.xlabel("Epoch")
plt.ylabel("Loss / Score")
plt.title(f"{perform_name} PF network training")

plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save figure
fig_path = PERFORM_DIR / "net_training_loss.png"
plt.savefig(fig_path, dpi=300)

# Save raw arrays
np.save(PERFORM_DIR / "net_training.npy", train_loss_arr)
np.save(PERFORM_DIR / "net_eval.npy", eval_loss_arr)
np.save(PERFORM_DIR / "net_score.npy", score_arr)
np.save(PERFORM_DIR / "net_bestepoch.npy", best_epoch)

plt.show()

print(f"✓ Plot saved to {fig_path}")
print(f"✓ Best epoch: {best_epoch} (score={best_score:.4f})")
# Out:
# ✓ Plot saved to /lustre/diazgonz/deep-performance-rul/experiments/DS05/opcond_q0.001-0.999_corr0.6_range0.6/estimation_thr0.2/gamma/net128x64x32_leaky0.05_dropout0.1_npar2000_cv_aversion0.5_losswin10_losstail5/SmLPC/net_training_loss.png
# ✓ Best epoch: 189 (score=3.2951)
