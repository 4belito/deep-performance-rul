# %% [markdown]
# ## Train the PF-Controller Neural Network
#
# For each performance metric, train the corresponding particle-filter (PF) controller neural network.

# %%
import numpy as np
import pandas as pd
import torch
from matplotlib import pyplot as plt
import torch.nn as nn
from src.models.particle_filter.core import ParticleFilter
from src.models.networks.pf_mlp import ParticleFilterMLP
from src.helpers.seed import set_global_seed

from experiment_config import (
    DegModel,DATA_NAME,SEED,LEAKY_SLOPE,HIDDEN_DIMS,PREDICTION_START_IDX,LOSS_TAIL_SIZE,N_PARTICLES,GRADIENT_CLIP,WEIGHT_DECAY,AVERSION,PFNET_DIR,DEGR_MODEL_DIR,ESTIMATION_DIR,LOSS_WINDOW
)
    
DATA_NAME
# Out:
# 'DS05'

# %% [markdown]
# ## Task

# %%
perform_name = 'SmLPC'

# %% [markdown]
# ## Hyper-Parameters

# %%
# Training parameters#
# optimization
lr = 5e-4

# Early stopping
max_epochs = 5000
min_epochs = 500
patience = 100         # how many eval steps to wait
min_delta = 1e-4       # minimum improvement to count

assert min_epochs >= LOSS_WINDOW, "min_epochs must be greater than LOSS_WINDOW_SIZE for the scoring mechanism to work properly."

# %%
activation = nn.LeakyReLU(LEAKY_SLOPE)

set_global_seed(SEED)
PERFORM_DIR = PFNET_DIR/perform_name

checkpoint_best_path = PERFORM_DIR / "checkpoint_best.pt"
checkpoint_last_path = PERFORM_DIR / "checkpoint_last.pt"
checkpoint_best_path.parent.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Import training data

# %%
hi_df = pd.read_csv(ESTIMATION_DIR/"data_dev.csv")
units = hi_df['unit'].astype(int).unique().tolist()
units
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Extract degradation onset

# %%
onsets = {unit: hi_df[(hi_df['unit']==unit) & (hi_df['hs']==0)]['cycle'].values[0] for unit in units}
del hi_df['hs']

# %%
perform_names = [col for col in hi_df.columns if col not in ['unit','cycle']]

performs = {name: 
    {unit: hi_df[hi_df['unit']==unit][name].values for unit in units} 
    for name in perform_names
}

init_ss = {name: {unit: perform[unit].max() for unit in units} for name,perform in performs.items()}
time = {unit: hi_df[hi_df['unit']==unit]['cycle'].values for unit in units}

# %% [markdown]
# ## Create component (base) models

# %%
train_data = {}
train_eol = {}
for unit in units:
    t_data = time[unit]
    s_data = performs[perform_name][unit]
    train_data[unit]=torch.tensor(np.stack([t_data, s_data],axis=1),dtype=torch.float32)
    train_eol[unit]=torch.tensor(t_data[-1],dtype=torch.float32)

# %%
degmodels = {}
for train_unit in units:
    offline_degmodels=[]
    for unit, perform in performs[perform_name].items():
        if unit == train_unit:
            continue
        best_model = DegModel(onset=onsets[unit], init_s=init_ss[perform_name][unit])
        best_model.load_state_dict(
            torch.load(DEGR_MODEL_DIR/'states'/perform_name/f'unit_{unit}'/ "best_model.pt")
        )
        offline_degmodels.append(best_model)
    degmodels[train_unit] = offline_degmodels

# %% [markdown]
# ## Train Particle Filter controller Net

# %%
net = ParticleFilterMLP(state_dim=DegModel.state_dim(), hidden_dims=HIDDEN_DIMS,
                        activation=lambda : nn.LeakyReLU(LEAKY_SLOPE))

optimizer = torch.optim.Adam(net.parameters(), lr, weight_decay=WEIGHT_DECAY)
optimizer.zero_grad()

# %%
wait = 0
best_score = float("inf")

all_epoch_unit_losses = []
mean_losses = []
std_losses = []
scores = []
epochs = []

start_epoch = 0

if checkpoint_last_path.exists():
    ckpt = torch.load(checkpoint_last_path, weights_only=False)

    net.load_state_dict(ckpt["model_state"])
    optimizer.load_state_dict(ckpt["optimizer_state"])

    start_epoch = ckpt["epoch"] + 1
    best_score = ckpt["best_score"]

    mean_losses = ckpt["mean_losses"]
    std_losses = ckpt["std_losses"]
    scores = ckpt["scores"]
    epochs = ckpt["epochs"]
    all_epoch_unit_losses = ckpt["all_epoch_unit_losses"]

    torch.random.set_rng_state(ckpt["rng_torch"])
    np.random.set_state(ckpt["rng_numpy"])

    print(f"✓ Resumed from epoch {start_epoch}, best_score={best_score:.3f}")

# %%
for epoch in range(start_epoch, max_epochs):

    epoch_unit_losses = []

    for train_unit in np.random.permutation(units):

        optimizer.zero_grad()

        offline_degmodels = degmodels[train_unit]
        t_data = train_data[train_unit][:, 0]
        s_data = train_data[train_unit][:, 1]

        pf = ParticleFilter(
            base_models=offline_degmodels,
            net=net,
            n_particles=N_PARTICLES,
        ).train()

        unit_loss = 0.0
        n_loss = 0

        for k in range(PREDICTION_START_IDX, len(t_data)):

            mixture_dist = pf.step(
                t_obs=t_data[:k+1],
                s_obs=s_data[:k+1],
            )
            

            init_loss = -LOSS_TAIL_SIZE if LOSS_TAIL_SIZE else k
            last_dist = mixture_dist.distribution(s=s_data[init_loss:])
            nll = -last_dist.log_prob(t_data[init_loss:]).mean()

            unit_loss += nll
            n_loss += 1

        unit_loss = unit_loss / n_loss

        unit_loss.backward()
        if GRADIENT_CLIP is not None:
            torch.nn.utils.clip_grad_norm_(net.parameters(), GRADIENT_CLIP)
        optimizer.step()

        epoch_unit_losses.append(unit_loss.item())

    # ---- compute score ----
    
    epoch_losses = np.array(epoch_unit_losses)
    mean_loss = epoch_losses.mean()
    std_loss = epoch_losses.std()


    all_epoch_unit_losses.append(epoch_unit_losses)
    window_losses = np.array(all_epoch_unit_losses[-LOSS_WINDOW:])
    wmean_loss = window_losses.mean()
    wstd_loss = window_losses.std()
    score = wmean_loss + AVERSION * wstd_loss
    
    mean_losses.append(mean_loss)
    std_losses.append(std_loss)
    scores.append(score)
    epochs.append(epoch)
    
    print(
        f"[Epoch {epoch:04d}] "
        f"mean={mean_loss:.3f} | std={std_loss:.3f} | "
        f"wmean={wmean_loss:.3f} | wstd={wstd_loss:.3f} | "
        f"score={score:.3f}"
    )
    # ---- early stopping on score ----
    if score < best_score - min_delta and len(all_epoch_unit_losses) >= LOSS_WINDOW:
        best_score = score
        wait = 0

        # ---- BEST (minimal) ----
        best_checkpoint = {
            'epoch': epoch,
            'model_state': net.state_dict(),
            'best_score': best_score,
        }
        torch.save(best_checkpoint, checkpoint_best_path)
        

        # ---- LAST (full training state) ----
        last_checkpoint = {
            'epoch': epoch,
            'model_state': net.state_dict(),
            'optimizer_state': optimizer.state_dict(),
            'best_score': best_score,
            'mean_losses': mean_losses,
            'std_losses': std_losses,
            'scores': scores,
            'epochs': epochs,
            'all_epoch_unit_losses': all_epoch_unit_losses,
            "rng_torch": torch.random.get_rng_state(),
            "rng_numpy": np.random.get_state(),
        }
        torch.save(last_checkpoint, checkpoint_last_path)
        print("  + saved")
    else:
        wait += 1
        if epoch>=min_epochs and wait >= patience:
            print("🛑 Early stopping triggered")
            break
# Out:
# [Epoch 0000] mean=5.002 | std=2.339 | wmean=5.002 | wstd=2.339 | score=6.171
# [Epoch 0001] mean=5.033 | std=2.361 | wmean=5.017 | wstd=2.350 | score=6.192
# [Epoch 0002] mean=5.475 | std=3.008 | wmean=5.170 | wstd=2.597 | score=6.468
# [Epoch 0003] mean=4.854 | std=2.146 | wmean=5.091 | wstd=2.496 | score=6.339
# [Epoch 0004] mean=5.241 | std=2.809 | wmean=5.121 | wstd=2.562 | score=6.402
# [Epoch 0005] mean=5.005 | std=2.377 | wmean=5.102 | wstd=2.533 | score=6.368
# [Epoch 0006] mean=4.373 | std=1.299 | wmean=4.998 | wstd=2.409 | score=6.202
# [Epoch 0007] mean=4.135 | std=0.884 | wmean=4.890 | wstd=2.293 | score=6.036
# [Epoch 0008] mean=4.087 | std=0.474 | wmean=4.801 | wstd=2.182 | score=5.892
# [Epoch 0009] mean=4.048 | std=0.240 | wmean=4.725 | wstd=2.084 | score=5.767
# [Epoch 0010] mean=4.048 | std=0.213 | wmean=4.664 | wstd=1.997 | score=5.663
# [Epoch 0011] mean=3.997 | std=0.250 | wmean=4.608 | wstd=1.923 | score=5.570
# [Epoch 0012] mean=3.965 | std=0.317 | wmean=4.559 | wstd=1.857 | score=5.487
# [Epoch 0013] mean=3.987 | std=0.340 | wmean=4.518 | wstd=1.798 | score=5.417
# [Epoch 0014] mean=3.957 | std=0.385 | wmean=4.481 | wstd=1.745 | score=5.353
# [Epoch 0015] mean=3.943 | std=0.445 | wmean=4.447 | wstd=1.699 | score=5.296
# [Epoch 0016] mean=3.897 | std=0.427 | wmean=4.415 | wstd=1.656 | score=5.243
# [Epoch 0017] mean=3.841 | std=0.308 | wmean=4.383 | wstd=1.617 | score=5.191
# [Epoch 0018] mean=3.798 | std=0.300 | wmean=4.352 | wstd=1.580 | score=5.142
# [Epoch 0019] mean=3.835 | std=0.336 | wmean=4.326 | wstd=1.546 | score=5.099
# [Epoch 0020] mean=3.793 | std=0.305 | wmean=4.301 | wstd=1.515 | score=5.058
# [Epoch 0021] mean=3.815 | std=0.341 | wmean=4.279 | wstd=1.485 | score=5.021
# [Epoch 0022] mean=3.739 | std=0.319 | wmean=4.255 | wstd=1.458 | score=4.984
# [Epoch 0023] mean=3.779 | std=0.331 | wmean=4.235 | wstd=1.432 | score=4.951
# [Epoch 0024] mean=3.724 | std=0.242 | wmean=4.215 | wstd=1.408 | score=4.919
# [Epoch 0025] mean=3.731 | std=0.222 | wmean=4.196 | wstd=1.384 | score=4.888
# [Epoch 0026] mean=3.702 | std=0.271 | wmean=4.178 | wstd=1.363 | score=4.859
# [Epoch 0027] mean=3.710 | std=0.324 | wmean=4.161 | wstd=1.342 | score=4.832
# [Epoch 0028] mean=3.715 | std=0.348 | wmean=4.146 | wstd=1.323 | score=4.807
# [Epoch 0029] mean=3.710 | std=0.323 | wmean=4.131 | wstd=1.304 | score=4.784
#   + saved
# [Epoch 0030] mean=3.813 | std=0.295 | wmean=4.092 | wstd=1.224 | score=4.704
#   + saved
# [Epoch 0031] mean=3.707 | std=0.277 | wmean=4.047 | wstd=1.135 | score=4.615
#   + saved
# [Epoch 0032] mean=3.709 | std=0.264 | wmean=3.989 | wstd=0.960 | score=4.469
#   + saved
# [Epoch 0033] mean=3.708 | std=0.290 | wmean=3.950 | wstd=0.865 | score=4.383
#   + saved
# [Epoch 0034] mean=3.713 | std=0.334 | wmean=3.899 | wstd=0.657 | score=4.228
#   + saved
# [Epoch 0035] mean=3.800 | std=0.313 | wmean=3.859 | wstd=0.453 | score=4.086
#   + saved
# [Epoch 0036] mean=3.753 | std=0.267 | wmean=3.839 | wstd=0.377 | score=4.027
#   + saved
# [Epoch 0037] mean=3.694 | std=0.312 | wmean=3.824 | wstd=0.342 | score=3.995
#   + saved
# [Epoch 0038] mean=3.718 | std=0.282 | wmean=3.812 | wstd=0.331 | score=3.977
#   + saved
# [Epoch 0039] mean=3.698 | std=0.243 | wmean=3.800 | wstd=0.329 | score=3.964
#   + saved
# [Epoch 0040] mean=3.779 | std=0.255 | wmean=3.791 | wstd=0.327 | score=3.954
#   + saved
# [Epoch 0041] mean=3.839 | std=0.556 | wmean=3.786 | wstd=0.337 | score=3.954
# [Epoch 0042] mean=3.664 | std=0.247 | wmean=3.776 | wstd=0.334 | score=3.943
#   + saved
# [Epoch 0043] mean=3.678 | std=0.283 | wmean=3.765 | wstd=0.331 | score=3.931
#   + saved
# [Epoch 0044] mean=3.680 | std=0.326 | wmean=3.756 | wstd=0.327 | score=3.920
#   + saved
# [Epoch 0045] mean=3.666 | std=0.309 | wmean=3.747 | wstd=0.320 | score=3.907
#   + saved
# [Epoch 0046] mean=3.681 | std=0.269 | wmean=3.740 | wstd=0.313 | score=3.896
#   + saved
# [Epoch 0047] mean=3.677 | std=0.300 | wmean=3.734 | wstd=0.313 | score=3.890
#   + saved
# [Epoch 0048] mean=3.771 | std=0.299 | wmean=3.733 | wstd=0.312 | score=3.889
#   + saved
# [Epoch 0049] mean=3.658 | std=0.268 | wmean=3.727 | wstd=0.310 | score=3.882
#   + saved
# [Epoch 0050] mean=3.728 | std=0.225 | wmean=3.725 | wstd=0.307 | score=3.879
#   + saved
# [Epoch 0051] mean=3.709 | std=0.266 | wmean=3.722 | wstd=0.304 | score=3.874
#   + saved
# [Epoch 0052] mean=3.675 | std=0.280 | wmean=3.720 | wstd=0.303 | score=3.871
#   + saved
# [Epoch 0053] mean=3.703 | std=0.273 | wmean=3.717 | wstd=0.301 | score=3.868
#   + saved
# [Epoch 0054] mean=3.686 | std=0.271 | wmean=3.716 | wstd=0.302 | score=3.867
#   + saved
# [Epoch 0055] mean=3.796 | std=0.242 | wmean=3.718 | wstd=0.303 | score=3.869
# [Epoch 0056] mean=3.676 | std=0.304 | wmean=3.717 | wstd=0.304 | score=3.869
# [Epoch 0057] mean=3.676 | std=0.259 | wmean=3.716 | wstd=0.302 | score=3.867
# [Epoch 0058] mean=3.650 | std=0.258 | wmean=3.714 | wstd=0.299 | score=3.863
#   + saved
# [Epoch 0059] mean=3.650 | std=0.273 | wmean=3.712 | wstd=0.298 | score=3.861
#   + saved
# [Epoch 0060] mean=3.676 | std=0.312 | wmean=3.707 | wstd=0.298 | score=3.856
#   + saved
# [Epoch 0061] mean=3.673 | std=0.339 | wmean=3.706 | wstd=0.300 | score=3.856
# [Epoch 0062] mean=3.646 | std=0.245 | wmean=3.704 | wstd=0.300 | score=3.854
#   + saved
# [Epoch 0063] mean=3.679 | std=0.289 | wmean=3.703 | wstd=0.299 | score=3.853
#   + saved
# [Epoch 0064] mean=3.676 | std=0.253 | wmean=3.702 | wstd=0.297 | score=3.850
#   + saved
# [Epoch 0065] mean=3.630 | std=0.241 | wmean=3.696 | wstd=0.294 | score=3.843
#   + saved
# [Epoch 0066] mean=3.632 | std=0.297 | wmean=3.692 | wstd=0.295 | score=3.840
#   + saved
# [Epoch 0067] mean=3.662 | std=0.307 | wmean=3.691 | wstd=0.295 | score=3.839
#   + saved
# [Epoch 0068] mean=3.632 | std=0.267 | wmean=3.688 | wstd=0.295 | score=3.836
#   + saved
# [Epoch 0069] mean=3.697 | std=0.293 | wmean=3.688 | wstd=0.296 | score=3.836
# [Epoch 0070] mean=3.668 | std=0.226 | wmean=3.684 | wstd=0.295 | score=3.832
#   + saved
# [Epoch 0071] mean=3.627 | std=0.247 | wmean=3.677 | wstd=0.279 | score=3.817
#   + saved
# [Epoch 0072] mean=3.699 | std=0.349 | wmean=3.679 | wstd=0.283 | score=3.820
# [Epoch 0073] mean=3.665 | std=0.359 | wmean=3.678 | wstd=0.286 | score=3.821
# [Epoch 0074] mean=3.652 | std=0.330 | wmean=3.677 | wstd=0.286 | score=3.820
# [Epoch 0075] mean=3.625 | std=0.276 | wmean=3.676 | wstd=0.285 | score=3.818
# [Epoch 0076] mean=3.653 | std=0.211 | wmean=3.675 | wstd=0.284 | score=3.817
#   + saved
# [Epoch 0077] mean=3.637 | std=0.238 | wmean=3.674 | wstd=0.282 | score=3.814
#   + saved
# [Epoch 0078] mean=3.659 | std=0.263 | wmean=3.670 | wstd=0.280 | score=3.810
#   + saved
# [Epoch 0079] mean=3.728 | std=0.365 | wmean=3.672 | wstd=0.284 | score=3.814
# [Epoch 0080] mean=3.764 | std=0.265 | wmean=3.673 | wstd=0.285 | score=3.816
# [Epoch 0081] mean=3.643 | std=0.230 | wmean=3.671 | wstd=0.284 | score=3.813
# [Epoch 0082] mean=3.679 | std=0.252 | wmean=3.671 | wstd=0.283 | score=3.813
# [Epoch 0083] mean=3.639 | std=0.229 | wmean=3.669 | wstd=0.282 | score=3.810
# [Epoch 0084] mean=3.650 | std=0.232 | wmean=3.668 | wstd=0.281 | score=3.808
#   + saved
# [Epoch 0085] mean=3.687 | std=0.290 | wmean=3.664 | wstd=0.281 | score=3.805
#   + saved
# [Epoch 0086] mean=3.606 | std=0.241 | wmean=3.662 | wstd=0.279 | score=3.802
#   + saved
# [Epoch 0087] mean=3.599 | std=0.227 | wmean=3.659 | wstd=0.279 | score=3.799
#   + saved
# [Epoch 0088] mean=3.673 | std=0.224 | wmean=3.660 | wstd=0.278 | score=3.799
# [Epoch 0089] mean=3.644 | std=0.220 | wmean=3.660 | wstd=0.276 | score=3.798
#   + saved
# [Epoch 0090] mean=3.641 | std=0.278 | wmean=3.659 | wstd=0.275 | score=3.796
#   + saved
# [Epoch 0091] mean=3.603 | std=0.232 | wmean=3.656 | wstd=0.271 | score=3.792
#   + saved
# [Epoch 0092] mean=3.644 | std=0.315 | wmean=3.656 | wstd=0.274 | score=3.793
# [Epoch 0093] mean=3.663 | std=0.371 | wmean=3.656 | wstd=0.277 | score=3.794
# [Epoch 0094] mean=3.598 | std=0.291 | wmean=3.653 | wstd=0.278 | score=3.793
# [Epoch 0095] mean=3.630 | std=0.265 | wmean=3.653 | wstd=0.279 | score=3.793
# [Epoch 0096] mean=3.653 | std=0.222 | wmean=3.654 | wstd=0.277 | score=3.792
# [Epoch 0097] mean=3.602 | std=0.191 | wmean=3.652 | wstd=0.274 | score=3.789
#   + saved
# [Epoch 0098] mean=3.614 | std=0.216 | wmean=3.651 | wstd=0.272 | score=3.787
#   + saved
# [Epoch 0099] mean=3.661 | std=0.203 | wmean=3.650 | wstd=0.269 | score=3.785
#   + saved
# [Epoch 0100] mean=3.652 | std=0.202 | wmean=3.650 | wstd=0.269 | score=3.784
#   + saved
# [Epoch 0101] mean=3.678 | std=0.408 | wmean=3.651 | wstd=0.275 | score=3.789
# [Epoch 0102] mean=4.010 | std=0.854 | wmean=3.662 | wstd=0.316 | score=3.820
# [Epoch 0103] mean=3.727 | std=0.360 | wmean=3.664 | wstd=0.316 | score=3.822
# [Epoch 0104] mean=3.813 | std=0.441 | wmean=3.669 | wstd=0.322 | score=3.830
# [Epoch 0105] mean=3.707 | std=0.364 | wmean=3.672 | wstd=0.325 | score=3.834
# [Epoch 0106] mean=3.800 | std=0.454 | wmean=3.677 | wstd=0.334 | score=3.844
# [Epoch 0107] mean=3.735 | std=0.371 | wmean=3.680 | wstd=0.338 | score=3.849
# [Epoch 0108] mean=3.788 | std=0.394 | wmean=3.684 | wstd=0.343 | score=3.856
# [Epoch 0109] mean=3.776 | std=0.265 | wmean=3.686 | wstd=0.340 | score=3.856
# [Epoch 0110] mean=3.753 | std=0.235 | wmean=3.686 | wstd=0.339 | score=3.855
# [Epoch 0111] mean=3.784 | std=0.371 | wmean=3.690 | wstd=0.344 | score=3.862
# [Epoch 0112] mean=3.773 | std=0.365 | wmean=3.693 | wstd=0.347 | score=3.867
# [Epoch 0113] mean=3.773 | std=0.350 | wmean=3.698 | wstd=0.351 | score=3.873
# [Epoch 0114] mean=3.767 | std=0.296 | wmean=3.702 | wstd=0.353 | score=3.878
# [Epoch 0115] mean=3.722 | std=0.285 | wmean=3.703 | wstd=0.352 | score=3.879
# [Epoch 0116] mean=3.718 | std=0.309 | wmean=3.707 | wstd=0.354 | score=3.884
# [Epoch 0117] mean=3.827 | std=0.439 | wmean=3.714 | wstd=0.360 | score=3.894
# [Epoch 0118] mean=3.731 | std=0.370 | wmean=3.716 | wstd=0.364 | score=3.898
# [Epoch 0119] mean=3.738 | std=0.340 | wmean=3.719 | wstd=0.367 | score=3.903
# [Epoch 0120] mean=3.742 | std=0.321 | wmean=3.723 | wstd=0.368 | score=3.907
# [Epoch 0121] mean=3.736 | std=0.334 | wmean=3.727 | wstd=0.370 | score=3.912
# [Epoch 0122] mean=3.727 | std=0.320 | wmean=3.730 | wstd=0.370 | score=3.915
# [Epoch 0123] mean=3.778 | std=0.351 | wmean=3.734 | wstd=0.369 | score=3.918
# [Epoch 0124] mean=3.711 | std=0.218 | wmean=3.737 | wstd=0.366 | score=3.921
# [Epoch 0125] mean=3.698 | std=0.283 | wmean=3.740 | wstd=0.366 | score=3.923
# [Epoch 0126] mean=3.724 | std=0.262 | wmean=3.742 | wstd=0.367 | score=3.926
# [Epoch 0127] mean=3.661 | std=0.267 | wmean=3.744 | wstd=0.368 | score=3.928
# [Epoch 0128] mean=3.705 | std=0.330 | wmean=3.747 | wstd=0.370 | score=3.932
# [Epoch 0129] mean=3.624 | std=0.265 | wmean=3.746 | wstd=0.372 | score=3.932
# [Epoch 0130] mean=3.658 | std=0.279 | wmean=3.746 | wstd=0.373 | score=3.933
# [Epoch 0131] mean=3.671 | std=0.291 | wmean=3.746 | wstd=0.370 | score=3.931
# [Epoch 0132] mean=3.650 | std=0.354 | wmean=3.734 | wstd=0.338 | score=3.903
# [Epoch 0133] mean=3.667 | std=0.305 | wmean=3.732 | wstd=0.337 | score=3.900
# [Epoch 0134] mean=3.644 | std=0.250 | wmean=3.726 | wstd=0.330 | score=3.891
# [Epoch 0135] mean=3.600 | std=0.308 | wmean=3.723 | wstd=0.329 | score=3.887
# [Epoch 0136] mean=3.598 | std=0.241 | wmean=3.716 | wstd=0.322 | score=3.877
# [Epoch 0137] mean=3.582 | std=0.324 | wmean=3.711 | wstd=0.321 | score=3.871
# [Epoch 0138] mean=3.564 | std=0.287 | wmean=3.703 | wstd=0.318 | score=3.862
# [Epoch 0139] mean=3.701 | std=0.385 | wmean=3.701 | wstd=0.322 | score=3.862
# [Epoch 0140] mean=3.567 | std=0.247 | wmean=3.695 | wstd=0.323 | score=3.856
# [Epoch 0141] mean=3.574 | std=0.221 | wmean=3.688 | wstd=0.318 | score=3.847
# [Epoch 0142] mean=3.592 | std=0.249 | wmean=3.682 | wstd=0.314 | score=3.839
# [Epoch 0143] mean=3.555 | std=0.261 | wmean=3.674 | wstd=0.312 | score=3.830
# [Epoch 0144] mean=3.531 | std=0.251 | wmean=3.666 | wstd=0.311 | score=3.822
# [Epoch 0145] mean=3.560 | std=0.217 | wmean=3.661 | wstd=0.310 | score=3.816
# [Epoch 0146] mean=3.557 | std=0.249 | wmean=3.656 | wstd=0.308 | score=3.810
# [Epoch 0147] mean=3.575 | std=0.248 | wmean=3.647 | wstd=0.300 | score=3.797
# [Epoch 0148] mean=3.534 | std=0.200 | wmean=3.641 | wstd=0.295 | score=3.788
# [Epoch 0149] mean=3.568 | std=0.251 | wmean=3.635 | wstd=0.291 | score=3.781
#   + saved
# [Epoch 0150] mean=3.531 | std=0.238 | wmean=3.628 | wstd=0.288 | score=3.772
#   + saved
# [Epoch 0151] mean=3.541 | std=0.265 | wmean=3.622 | wstd=0.286 | score=3.764
#   + saved
# [Epoch 0152] mean=3.540 | std=0.244 | wmean=3.615 | wstd=0.283 | score=3.757
#   + saved
# [Epoch 0153] mean=3.524 | std=0.231 | wmean=3.607 | wstd=0.278 | score=3.746
#   + saved
# [Epoch 0154] mean=3.568 | std=0.269 | wmean=3.602 | wstd=0.278 | score=3.741
#   + saved
# [Epoch 0155] mean=3.544 | std=0.235 | wmean=3.597 | wstd=0.277 | score=3.735
#   + saved
# [Epoch 0156] mean=3.524 | std=0.206 | wmean=3.590 | wstd=0.274 | score=3.727
#   + saved
# [Epoch 0157] mean=3.571 | std=0.271 | wmean=3.587 | wstd=0.274 | score=3.724
#   + saved
# [Epoch 0158] mean=3.507 | std=0.218 | wmean=3.581 | wstd=0.270 | score=3.716
#   + saved
# [Epoch 0159] mean=3.525 | std=0.257 | wmean=3.577 | wstd=0.270 | score=3.712
#   + saved
# [Epoch 0160] mean=3.516 | std=0.211 | wmean=3.573 | wstd=0.267 | score=3.706
#   + saved
# [Epoch 0161] mean=3.509 | std=0.210 | wmean=3.567 | wstd=0.264 | score=3.699
#   + saved
# [Epoch 0162] mean=3.521 | std=0.234 | wmean=3.563 | wstd=0.259 | score=3.693
#   + saved
# [Epoch 0163] mean=3.556 | std=0.279 | wmean=3.559 | wstd=0.258 | score=3.688
#   + saved
# [Epoch 0164] mean=3.555 | std=0.232 | wmean=3.556 | wstd=0.257 | score=3.685
#   + saved
# [Epoch 0165] mean=3.527 | std=0.200 | wmean=3.554 | wstd=0.253 | score=3.680
#   + saved
# [Epoch 0166] mean=3.514 | std=0.278 | wmean=3.551 | wstd=0.254 | score=3.678
#   + saved
# [Epoch 0167] mean=3.518 | std=0.276 | wmean=3.549 | wstd=0.252 | score=3.675
#   + saved
# [Epoch 0168] mean=3.482 | std=0.242 | wmean=3.546 | wstd=0.251 | score=3.672
#   + saved
# [Epoch 0169] mean=3.511 | std=0.287 | wmean=3.540 | wstd=0.245 | score=3.663
#   + saved
# [Epoch 0170] mean=3.584 | std=0.350 | wmean=3.541 | wstd=0.249 | score=3.665
# [Epoch 0171] mean=3.573 | std=0.323 | wmean=3.541 | wstd=0.253 | score=3.667
# [Epoch 0172] mean=3.493 | std=0.225 | wmean=3.537 | wstd=0.252 | score=3.663
# [Epoch 0173] mean=3.520 | std=0.261 | wmean=3.536 | wstd=0.252 | score=3.662
#   + saved
# [Epoch 0174] mean=3.530 | std=0.273 | wmean=3.536 | wstd=0.253 | score=3.663
# [Epoch 0175] mean=3.514 | std=0.232 | wmean=3.535 | wstd=0.253 | score=3.661
#   + saved
# [Epoch 0176] mean=3.566 | std=0.294 | wmean=3.535 | wstd=0.255 | score=3.662
# [Epoch 0177] mean=3.571 | std=0.271 | wmean=3.535 | wstd=0.256 | score=3.663
# [Epoch 0178] mean=3.555 | std=0.308 | wmean=3.535 | wstd=0.259 | score=3.665
# [Epoch 0179] mean=3.568 | std=0.268 | wmean=3.535 | wstd=0.260 | score=3.665
# [Epoch 0180] mean=3.531 | std=0.232 | wmean=3.535 | wstd=0.260 | score=3.665
# [Epoch 0181] mean=3.554 | std=0.282 | wmean=3.536 | wstd=0.260 | score=3.666
# [Epoch 0182] mean=3.519 | std=0.263 | wmean=3.535 | wstd=0.261 | score=3.666
# [Epoch 0183] mean=3.540 | std=0.246 | wmean=3.536 | wstd=0.261 | score=3.666
# [Epoch 0184] mean=3.535 | std=0.258 | wmean=3.535 | wstd=0.261 | score=3.665
# [Epoch 0185] mean=3.541 | std=0.243 | wmean=3.534 | wstd=0.261 | score=3.665
# [Epoch 0186] mean=3.562 | std=0.250 | wmean=3.536 | wstd=0.263 | score=3.667
# [Epoch 0187] mean=3.529 | std=0.247 | wmean=3.534 | wstd=0.262 | score=3.665
# [Epoch 0188] mean=3.484 | std=0.213 | wmean=3.534 | wstd=0.262 | score=3.664
# [Epoch 0189] mean=3.557 | std=0.257 | wmean=3.535 | wstd=0.262 | score=3.665
# [Epoch 0190] mean=3.548 | std=0.275 | wmean=3.536 | wstd=0.264 | score=3.667
# [Epoch 0191] mean=3.537 | std=0.252 | wmean=3.537 | wstd=0.265 | score=3.669
# [Epoch 0192] mean=3.527 | std=0.211 | wmean=3.537 | wstd=0.264 | score=3.669
# [Epoch 0193] mean=3.548 | std=0.269 | wmean=3.536 | wstd=0.264 | score=3.668
# [Epoch 0194] mean=3.539 | std=0.256 | wmean=3.536 | wstd=0.265 | score=3.668
# [Epoch 0195] mean=3.530 | std=0.211 | wmean=3.536 | wstd=0.265 | score=3.668
# [Epoch 0196] mean=3.481 | std=0.197 | wmean=3.535 | wstd=0.263 | score=3.666
# [Epoch 0197] mean=3.522 | std=0.242 | wmean=3.535 | wstd=0.261 | score=3.666
# [Epoch 0198] mean=3.544 | std=0.330 | wmean=3.537 | wstd=0.264 | score=3.669
# [Epoch 0199] mean=3.566 | std=0.322 | wmean=3.539 | wstd=0.266 | score=3.672
# [Epoch 0200] mean=3.534 | std=0.303 | wmean=3.537 | wstd=0.264 | score=3.669
# [Epoch 0201] mean=3.523 | std=0.246 | wmean=3.536 | wstd=0.261 | score=3.666
# [Epoch 0202] mean=3.543 | std=0.245 | wmean=3.537 | wstd=0.261 | score=3.668
# [Epoch 0203] mean=3.509 | std=0.227 | wmean=3.537 | wstd=0.260 | score=3.667
# [Epoch 0204] mean=3.545 | std=0.225 | wmean=3.537 | wstd=0.259 | score=3.667
# [Epoch 0205] mean=3.550 | std=0.289 | wmean=3.539 | wstd=0.261 | score=3.669
# [Epoch 0206] mean=3.517 | std=0.228 | wmean=3.537 | wstd=0.258 | score=3.666
# [Epoch 0207] mean=3.524 | std=0.197 | wmean=3.535 | wstd=0.256 | score=3.663
# [Epoch 0208] mean=3.501 | std=0.234 | wmean=3.534 | wstd=0.253 | score=3.660
#   + saved
# [Epoch 0209] mean=3.507 | std=0.338 | wmean=3.531 | wstd=0.256 | score=3.660
#   + saved
# [Epoch 0210] mean=3.532 | std=0.233 | wmean=3.532 | wstd=0.256 | score=3.660
# [Epoch 0211] mean=3.514 | std=0.231 | wmean=3.530 | wstd=0.255 | score=3.657
#   + saved
# [Epoch 0212] mean=3.547 | std=0.244 | wmean=3.531 | wstd=0.254 | score=3.658
# [Epoch 0213] mean=3.505 | std=0.183 | wmean=3.530 | wstd=0.252 | score=3.656
#   + saved
# [Epoch 0214] mean=3.490 | std=0.240 | wmean=3.528 | wstd=0.252 | score=3.654
#   + saved
# [Epoch 0215] mean=3.519 | std=0.266 | wmean=3.528 | wstd=0.252 | score=3.654
#   + saved
# [Epoch 0216] mean=3.508 | std=0.181 | wmean=3.526 | wstd=0.250 | score=3.651
#   + saved
# [Epoch 0217] mean=3.518 | std=0.254 | wmean=3.526 | wstd=0.251 | score=3.651
#   + saved
# [Epoch 0218] mean=3.505 | std=0.222 | wmean=3.526 | wstd=0.251 | score=3.652
# [Epoch 0219] mean=3.521 | std=0.271 | wmean=3.525 | wstd=0.251 | score=3.651
#   + saved
# [Epoch 0220] mean=3.534 | std=0.231 | wmean=3.525 | wstd=0.250 | score=3.650
#   + saved
# [Epoch 0221] mean=3.515 | std=0.246 | wmean=3.524 | wstd=0.250 | score=3.649
#   + saved
# [Epoch 0222] mean=3.510 | std=0.256 | wmean=3.523 | wstd=0.251 | score=3.649
# [Epoch 0223] mean=3.537 | std=0.298 | wmean=3.523 | wstd=0.252 | score=3.649
# [Epoch 0224] mean=3.508 | std=0.257 | wmean=3.522 | wstd=0.252 | score=3.648
#   + saved
# [Epoch 0225] mean=3.540 | std=0.277 | wmean=3.522 | wstd=0.254 | score=3.649
# [Epoch 0226] mean=3.535 | std=0.313 | wmean=3.524 | wstd=0.258 | score=3.653
# [Epoch 0227] mean=3.515 | std=0.267 | wmean=3.524 | wstd=0.259 | score=3.653
# [Epoch 0228] mean=3.495 | std=0.223 | wmean=3.522 | wstd=0.255 | score=3.650
# [Epoch 0229] mean=3.520 | std=0.250 | wmean=3.521 | wstd=0.252 | score=3.647
#   + saved
# [Epoch 0230] mean=3.519 | std=0.250 | wmean=3.520 | wstd=0.250 | score=3.645
#   + saved
# [Epoch 0231] mean=3.481 | std=0.242 | wmean=3.519 | wstd=0.250 | score=3.644
#   + saved
# [Epoch 0232] mean=3.528 | std=0.296 | wmean=3.518 | wstd=0.252 | score=3.644
# [Epoch 0233] mean=3.494 | std=0.243 | wmean=3.518 | wstd=0.253 | score=3.644
# [Epoch 0234] mean=3.493 | std=0.212 | wmean=3.516 | wstd=0.252 | score=3.642
#   + saved
# [Epoch 0235] mean=3.494 | std=0.241 | wmean=3.514 | wstd=0.250 | score=3.639
#   + saved
# [Epoch 0236] mean=3.525 | std=0.298 | wmean=3.515 | wstd=0.253 | score=3.641
# [Epoch 0237] mean=3.471 | std=0.224 | wmean=3.513 | wstd=0.254 | score=3.640
# [Epoch 0238] mean=3.502 | std=0.288 | wmean=3.513 | wstd=0.256 | score=3.641
# [Epoch 0239] mean=3.510 | std=0.265 | wmean=3.513 | wstd=0.253 | score=3.639
#   + saved
# [Epoch 0240] mean=3.517 | std=0.285 | wmean=3.512 | wstd=0.254 | score=3.640
# [Epoch 0241] mean=3.540 | std=0.263 | wmean=3.513 | wstd=0.256 | score=3.641
# [Epoch 0242] mean=3.531 | std=0.276 | wmean=3.513 | wstd=0.257 | score=3.641
# [Epoch 0243] mean=3.513 | std=0.267 | wmean=3.513 | wstd=0.259 | score=3.642
# [Epoch 0244] mean=3.504 | std=0.243 | wmean=3.513 | wstd=0.259 | score=3.643
# [Epoch 0245] mean=3.517 | std=0.241 | wmean=3.513 | wstd=0.258 | score=3.642
# [Epoch 0246] mean=3.505 | std=0.241 | wmean=3.513 | wstd=0.260 | score=3.643
# [Epoch 0247] mean=3.501 | std=0.265 | wmean=3.513 | wstd=0.260 | score=3.643
# [Epoch 0248] mean=3.506 | std=0.265 | wmean=3.513 | wstd=0.262 | score=3.644
# [Epoch 0249] mean=3.472 | std=0.219 | wmean=3.511 | wstd=0.260 | score=3.641
# [Epoch 0250] mean=3.485 | std=0.258 | wmean=3.509 | wstd=0.261 | score=3.640
# [Epoch 0251] mean=3.510 | std=0.282 | wmean=3.509 | wstd=0.262 | score=3.640
# [Epoch 0252] mean=3.496 | std=0.275 | wmean=3.509 | wstd=0.263 | score=3.640
# [Epoch 0253] mean=3.497 | std=0.236 | wmean=3.508 | wstd=0.261 | score=3.638
#   + saved
# [Epoch 0254] mean=3.525 | std=0.279 | wmean=3.508 | wstd=0.261 | score=3.639
# [Epoch 0255] mean=3.530 | std=0.253 | wmean=3.508 | wstd=0.260 | score=3.638
# [Epoch 0256] mean=3.524 | std=0.205 | wmean=3.507 | wstd=0.257 | score=3.636
#   + saved
# [Epoch 0257] mean=3.484 | std=0.197 | wmean=3.506 | wstd=0.255 | score=3.634
#   + saved
# [Epoch 0258] mean=3.518 | std=0.267 | wmean=3.507 | wstd=0.256 | score=3.635
# [Epoch 0259] mean=3.498 | std=0.257 | wmean=3.506 | wstd=0.256 | score=3.635
# [Epoch 0260] mean=3.508 | std=0.269 | wmean=3.506 | wstd=0.257 | score=3.635
# [Epoch 0261] mean=3.472 | std=0.235 | wmean=3.506 | wstd=0.257 | score=3.634
# [Epoch 0262] mean=3.505 | std=0.262 | wmean=3.505 | wstd=0.256 | score=3.633
#   + saved
# [Epoch 0263] mean=3.504 | std=0.253 | wmean=3.505 | wstd=0.256 | score=3.633
# [Epoch 0264] mean=3.494 | std=0.255 | wmean=3.505 | wstd=0.257 | score=3.634
# [Epoch 0265] mean=3.462 | std=0.180 | wmean=3.504 | wstd=0.256 | score=3.632
#   + saved
# [Epoch 0266] mean=3.498 | std=0.244 | wmean=3.503 | wstd=0.254 | score=3.630
#   + saved
# [Epoch 0267] mean=3.492 | std=0.252 | wmean=3.504 | wstd=0.254 | score=3.631
# [Epoch 0268] mean=3.504 | std=0.230 | wmean=3.504 | wstd=0.252 | score=3.630
# [Epoch 0269] mean=3.493 | std=0.242 | wmean=3.504 | wstd=0.252 | score=3.629
#   + saved
# [Epoch 0270] mean=3.544 | std=0.271 | wmean=3.504 | wstd=0.251 | score=3.630
# [Epoch 0271] mean=3.493 | std=0.224 | wmean=3.503 | wstd=0.250 | score=3.628
#   + saved
# [Epoch 0272] mean=3.503 | std=0.219 | wmean=3.502 | wstd=0.248 | score=3.626
#   + saved
# [Epoch 0273] mean=3.482 | std=0.199 | wmean=3.501 | wstd=0.246 | score=3.624
#   + saved
# [Epoch 0274] mean=3.492 | std=0.228 | wmean=3.501 | wstd=0.245 | score=3.623
#   + saved
# [Epoch 0275] mean=3.509 | std=0.281 | wmean=3.500 | wstd=0.247 | score=3.624
# [Epoch 0276] mean=3.492 | std=0.255 | wmean=3.500 | wstd=0.247 | score=3.623
# [Epoch 0277] mean=3.502 | std=0.239 | wmean=3.500 | wstd=0.246 | score=3.623
#   + saved
# [Epoch 0278] mean=3.508 | std=0.252 | wmean=3.500 | wstd=0.246 | score=3.623
#   + saved
# [Epoch 0279] mean=3.481 | std=0.199 | wmean=3.500 | wstd=0.245 | score=3.623
# [Epoch 0280] mean=3.482 | std=0.220 | wmean=3.500 | wstd=0.244 | score=3.622
#   + saved
# [Epoch 0281] mean=3.519 | std=0.278 | wmean=3.500 | wstd=0.244 | score=3.622
# [Epoch 0282] mean=3.493 | std=0.268 | wmean=3.500 | wstd=0.244 | score=3.622
# [Epoch 0283] mean=3.508 | std=0.234 | wmean=3.501 | wstd=0.244 | score=3.622
# [Epoch 0284] mean=3.502 | std=0.228 | wmean=3.500 | wstd=0.242 | score=3.621
#   + saved
# [Epoch 0285] mean=3.505 | std=0.280 | wmean=3.499 | wstd=0.243 | score=3.620
#   + saved
# [Epoch 0286] mean=3.503 | std=0.286 | wmean=3.498 | wstd=0.245 | score=3.621
# [Epoch 0287] mean=3.509 | std=0.287 | wmean=3.499 | wstd=0.248 | score=3.623
# [Epoch 0288] mean=3.494 | std=0.255 | wmean=3.498 | wstd=0.248 | score=3.622
# [Epoch 0289] mean=3.485 | std=0.233 | wmean=3.498 | wstd=0.247 | score=3.621
# [Epoch 0290] mean=3.499 | std=0.294 | wmean=3.498 | wstd=0.248 | score=3.622
# [Epoch 0291] mean=3.499 | std=0.305 | wmean=3.498 | wstd=0.250 | score=3.624
# [Epoch 0292] mean=3.481 | std=0.267 | wmean=3.498 | wstd=0.251 | score=3.623
# [Epoch 0293] mean=3.488 | std=0.285 | wmean=3.497 | wstd=0.252 | score=3.623
# [Epoch 0294] mean=3.500 | std=0.264 | wmean=3.497 | wstd=0.252 | score=3.623
# [Epoch 0295] mean=3.497 | std=0.248 | wmean=3.499 | wstd=0.254 | score=3.625
# [Epoch 0296] mean=3.465 | std=0.202 | wmean=3.497 | wstd=0.253 | score=3.624
# [Epoch 0297] mean=3.480 | std=0.241 | wmean=3.497 | wstd=0.252 | score=3.623
# [Epoch 0298] mean=3.478 | std=0.238 | wmean=3.496 | wstd=0.253 | score=3.622
# [Epoch 0299] mean=3.477 | std=0.223 | wmean=3.496 | wstd=0.252 | score=3.622
# [Epoch 0300] mean=3.491 | std=0.268 | wmean=3.494 | wstd=0.252 | score=3.620
#   + saved
# [Epoch 0301] mean=3.515 | std=0.306 | wmean=3.495 | wstd=0.255 | score=3.622
# [Epoch 0302] mean=3.459 | std=0.221 | wmean=3.493 | wstd=0.255 | score=3.621
# [Epoch 0303] mean=3.510 | std=0.283 | wmean=3.494 | wstd=0.258 | score=3.623
# [Epoch 0304] mean=3.511 | std=0.263 | wmean=3.495 | wstd=0.259 | score=3.624
# [Epoch 0305] mean=3.475 | std=0.231 | wmean=3.494 | wstd=0.257 | score=3.622
# [Epoch 0306] mean=3.521 | std=0.225 | wmean=3.494 | wstd=0.256 | score=3.623
# [Epoch 0307] mean=3.453 | std=0.186 | wmean=3.493 | wstd=0.255 | score=3.620
# [Epoch 0308] mean=3.519 | std=0.261 | wmean=3.493 | wstd=0.255 | score=3.621
# [Epoch 0309] mean=3.472 | std=0.201 | wmean=3.493 | wstd=0.255 | score=3.621
# [Epoch 0310] mean=3.505 | std=0.292 | wmean=3.494 | wstd=0.258 | score=3.623
# [Epoch 0311] mean=3.497 | std=0.264 | wmean=3.493 | wstd=0.257 | score=3.622
# [Epoch 0312] mean=3.533 | std=0.314 | wmean=3.494 | wstd=0.259 | score=3.624
# [Epoch 0313] mean=3.516 | std=0.286 | wmean=3.495 | wstd=0.261 | score=3.625
# [Epoch 0314] mean=3.495 | std=0.261 | wmean=3.494 | wstd=0.262 | score=3.625
# [Epoch 0315] mean=3.437 | std=0.175 | wmean=3.492 | wstd=0.259 | score=3.622
# [Epoch 0316] mean=3.492 | std=0.225 | wmean=3.492 | wstd=0.257 | score=3.620
# [Epoch 0317] mean=3.515 | std=0.252 | wmean=3.492 | wstd=0.256 | score=3.620
# [Epoch 0318] mean=3.473 | std=0.243 | wmean=3.491 | wstd=0.255 | score=3.619
#   + saved
# [Epoch 0319] mean=3.480 | std=0.216 | wmean=3.491 | wstd=0.255 | score=3.619
#   + saved
# [Epoch 0320] mean=3.509 | std=0.283 | wmean=3.492 | wstd=0.254 | score=3.619
# [Epoch 0321] mean=3.493 | std=0.272 | wmean=3.491 | wstd=0.253 | score=3.618
#   + saved
# [Epoch 0322] mean=3.456 | std=0.225 | wmean=3.490 | wstd=0.252 | score=3.616
#   + saved
# [Epoch 0323] mean=3.485 | std=0.283 | wmean=3.490 | wstd=0.252 | score=3.616
#   + saved
# [Epoch 0324] mean=3.538 | std=0.323 | wmean=3.492 | wstd=0.254 | score=3.619
# [Epoch 0325] mean=3.503 | std=0.276 | wmean=3.492 | wstd=0.255 | score=3.619
# [Epoch 0326] mean=3.471 | std=0.227 | wmean=3.492 | wstd=0.256 | score=3.620
# [Epoch 0327] mean=3.499 | std=0.261 | wmean=3.493 | wstd=0.256 | score=3.621
# [Epoch 0328] mean=3.472 | std=0.277 | wmean=3.492 | wstd=0.258 | score=3.621
# [Epoch 0329] mean=3.480 | std=0.255 | wmean=3.493 | wstd=0.259 | score=3.622
# [Epoch 0330] mean=3.482 | std=0.268 | wmean=3.492 | wstd=0.259 | score=3.622
# [Epoch 0331] mean=3.485 | std=0.248 | wmean=3.491 | wstd=0.257 | score=3.620
# [Epoch 0332] mean=3.454 | std=0.228 | wmean=3.491 | wstd=0.257 | score=3.620
# [Epoch 0333] mean=3.489 | std=0.243 | wmean=3.490 | wstd=0.255 | score=3.618
# [Epoch 0334] mean=3.449 | std=0.224 | wmean=3.488 | wstd=0.254 | score=3.616
#   + saved
# [Epoch 0335] mean=3.504 | std=0.323 | wmean=3.489 | wstd=0.258 | score=3.618
# [Epoch 0336] mean=3.524 | std=0.340 | wmean=3.489 | wstd=0.262 | score=3.620
# [Epoch 0337] mean=3.493 | std=0.294 | wmean=3.491 | wstd=0.265 | score=3.623
# [Epoch 0338] mean=3.469 | std=0.231 | wmean=3.489 | wstd=0.264 | score=3.621
# [Epoch 0339] mean=3.499 | std=0.267 | wmean=3.490 | wstd=0.266 | score=3.623
# [Epoch 0340] mean=3.478 | std=0.235 | wmean=3.489 | wstd=0.264 | score=3.621
# [Epoch 0341] mean=3.519 | std=0.294 | wmean=3.490 | wstd=0.265 | score=3.622
# [Epoch 0342] mean=3.499 | std=0.279 | wmean=3.489 | wstd=0.264 | score=3.620
# [Epoch 0343] mean=3.474 | std=0.279 | wmean=3.487 | wstd=0.263 | score=3.619
# [Epoch 0344] mean=3.486 | std=0.276 | wmean=3.487 | wstd=0.264 | score=3.619
# [Epoch 0345] mean=3.507 | std=0.282 | wmean=3.489 | wstd=0.267 | score=3.623
# [Epoch 0346] mean=3.464 | std=0.212 | wmean=3.488 | wstd=0.267 | score=3.622
# [Epoch 0347] mean=3.483 | std=0.228 | wmean=3.487 | wstd=0.266 | score=3.620
# [Epoch 0348] mean=3.495 | std=0.271 | wmean=3.488 | wstd=0.267 | score=3.621
# [Epoch 0349] mean=3.543 | std=0.298 | wmean=3.490 | wstd=0.269 | score=3.625
# [Epoch 0350] mean=3.496 | std=0.301 | wmean=3.490 | wstd=0.270 | score=3.625
# [Epoch 0351] mean=3.493 | std=0.282 | wmean=3.490 | wstd=0.270 | score=3.625
# [Epoch 0352] mean=3.501 | std=0.252 | wmean=3.491 | wstd=0.271 | score=3.627
# [Epoch 0353] mean=3.504 | std=0.248 | wmean=3.492 | wstd=0.270 | score=3.627
# [Epoch 0354] mean=3.491 | std=0.229 | wmean=3.490 | wstd=0.267 | score=3.624
# [Epoch 0355] mean=3.504 | std=0.251 | wmean=3.490 | wstd=0.266 | score=3.623
# [Epoch 0356] mean=3.491 | std=0.248 | wmean=3.491 | wstd=0.266 | score=3.624
# [Epoch 0357] mean=3.503 | std=0.248 | wmean=3.491 | wstd=0.266 | score=3.624
# [Epoch 0358] mean=3.494 | std=0.278 | wmean=3.492 | wstd=0.266 | score=3.625
# [Epoch 0359] mean=3.505 | std=0.285 | wmean=3.493 | wstd=0.267 | score=3.626
# [Epoch 0360] mean=3.466 | std=0.232 | wmean=3.492 | wstd=0.266 | score=3.625
# [Epoch 0361] mean=3.494 | std=0.229 | wmean=3.492 | wstd=0.265 | score=3.625
# [Epoch 0362] mean=3.500 | std=0.312 | wmean=3.494 | wstd=0.268 | score=3.628
# [Epoch 0363] mean=3.458 | std=0.263 | wmean=3.493 | wstd=0.269 | score=3.627
# [Epoch 0364] mean=3.454 | std=0.261 | wmean=3.493 | wstd=0.270 | score=3.628
# [Epoch 0365] mean=3.470 | std=0.279 | wmean=3.492 | wstd=0.268 | score=3.626
# [Epoch 0366] mean=3.457 | std=0.255 | wmean=3.490 | wstd=0.265 | score=3.622
# [Epoch 0367] mean=3.507 | std=0.318 | wmean=3.490 | wstd=0.266 | score=3.623
# [Epoch 0368] mean=3.518 | std=0.276 | wmean=3.492 | wstd=0.268 | score=3.625
# [Epoch 0369] mean=3.523 | std=0.265 | wmean=3.493 | wstd=0.267 | score=3.626
# [Epoch 0370] mean=3.479 | std=0.228 | wmean=3.493 | wstd=0.267 | score=3.626
# [Epoch 0371] mean=3.501 | std=0.270 | wmean=3.492 | wstd=0.266 | score=3.625
# [Epoch 0372] mean=3.489 | std=0.271 | wmean=3.492 | wstd=0.266 | score=3.625
# [Epoch 0373] mean=3.514 | std=0.321 | wmean=3.493 | wstd=0.268 | score=3.627
# [Epoch 0374] mean=3.488 | std=0.258 | wmean=3.493 | wstd=0.267 | score=3.627
# [Epoch 0375] mean=3.491 | std=0.254 | wmean=3.492 | wstd=0.266 | score=3.626
# [Epoch 0376] mean=3.496 | std=0.292 | wmean=3.494 | wstd=0.269 | score=3.628
# [Epoch 0377] mean=3.491 | std=0.281 | wmean=3.494 | wstd=0.270 | score=3.629
# [Epoch 0378] mean=3.484 | std=0.253 | wmean=3.493 | wstd=0.270 | score=3.628
# [Epoch 0379] mean=3.478 | std=0.299 | wmean=3.491 | wstd=0.270 | score=3.626
# [Epoch 0380] mean=3.496 | std=0.336 | wmean=3.491 | wstd=0.271 | score=3.627
# [Epoch 0381] mean=3.553 | std=0.330 | wmean=3.493 | wstd=0.273 | score=3.630
# [Epoch 0382] mean=3.462 | std=0.230 | wmean=3.492 | wstd=0.272 | score=3.628
# [Epoch 0383] mean=3.528 | std=0.324 | wmean=3.493 | wstd=0.275 | score=3.630
# [Epoch 0384] mean=3.476 | std=0.286 | wmean=3.492 | wstd=0.277 | score=3.631
# [Epoch 0385] mean=3.482 | std=0.344 | wmean=3.492 | wstd=0.280 | score=3.632
# [Epoch 0386] mean=3.497 | std=0.250 | wmean=3.492 | wstd=0.280 | score=3.632
# [Epoch 0387] mean=3.475 | std=0.255 | wmean=3.491 | wstd=0.280 | score=3.631
# [Epoch 0388] mean=3.461 | std=0.242 | wmean=3.490 | wstd=0.279 | score=3.629
# [Epoch 0389] mean=3.513 | std=0.341 | wmean=3.490 | wstd=0.281 | score=3.631
# [Epoch 0390] mean=3.470 | std=0.299 | wmean=3.490 | wstd=0.284 | score=3.632
# [Epoch 0391] mean=3.478 | std=0.315 | wmean=3.490 | wstd=0.286 | score=3.633
# [Epoch 0392] mean=3.449 | std=0.305 | wmean=3.488 | wstd=0.286 | score=3.631
# [Epoch 0393] mean=3.460 | std=0.317 | wmean=3.488 | wstd=0.288 | score=3.632
# [Epoch 0394] mean=3.473 | std=0.357 | wmean=3.489 | wstd=0.291 | score=3.634
# [Epoch 0395] mean=3.465 | std=0.415 | wmean=3.488 | wstd=0.297 | score=3.637
# [Epoch 0396] mean=3.420 | std=0.336 | wmean=3.487 | wstd=0.300 | score=3.637
# [Epoch 0397] mean=3.454 | std=0.376 | wmean=3.485 | wstd=0.302 | score=3.636
# [Epoch 0398] mean=3.347 | std=0.319 | wmean=3.480 | wstd=0.304 | score=3.632
# [Epoch 0399] mean=3.443 | std=0.419 | wmean=3.477 | wstd=0.310 | score=3.632
# [Epoch 0400] mean=3.409 | std=0.378 | wmean=3.475 | wstd=0.315 | score=3.632
# [Epoch 0401] mean=3.325 | std=0.305 | wmean=3.469 | wstd=0.317 | score=3.627
# [Epoch 0402] mean=3.324 | std=0.334 | wmean=3.463 | wstd=0.320 | score=3.623
# [Epoch 0403] mean=3.352 | std=0.375 | wmean=3.458 | wstd=0.323 | score=3.619
# [Epoch 0404] mean=3.394 | std=0.466 | wmean=3.455 | wstd=0.330 | score=3.620
# [Epoch 0405] mean=3.348 | std=0.410 | wmean=3.450 | wstd=0.336 | score=3.618
# [Epoch 0406] mean=3.377 | std=0.395 | wmean=3.446 | wstd=0.340 | score=3.616
# [Epoch 0407] mean=3.391 | std=0.407 | wmean=3.443 | wstd=0.344 | score=3.615
#   + saved
# [Epoch 0408] mean=3.411 | std=0.386 | wmean=3.440 | wstd=0.348 | score=3.614
#   + saved
# [Epoch 0409] mean=3.435 | std=0.438 | wmean=3.439 | wstd=0.353 | score=3.615
# [Epoch 0410] mean=3.370 | std=0.572 | wmean=3.435 | wstd=0.363 | score=3.616
# [Epoch 0411] mean=3.349 | std=0.433 | wmean=3.428 | wstd=0.366 | score=3.611
#   + saved
# [Epoch 0412] mean=3.361 | std=0.462 | wmean=3.425 | wstd=0.373 | score=3.611
# [Epoch 0413] mean=3.544 | std=0.616 | wmean=3.425 | wstd=0.386 | score=3.618
# [Epoch 0414] mean=3.332 | std=0.484 | wmean=3.420 | wstd=0.392 | score=3.617
# [Epoch 0415] mean=3.338 | std=0.499 | wmean=3.416 | wstd=0.398 | score=3.615
# [Epoch 0416] mean=3.337 | std=0.425 | wmean=3.410 | wstd=0.403 | score=3.612
# [Epoch 0417] mean=3.304 | std=0.358 | wmean=3.405 | wstd=0.406 | score=3.607
#   + saved
# [Epoch 0418] mean=3.260 | std=0.447 | wmean=3.398 | wstd=0.412 | score=3.604
#   + saved
# [Epoch 0419] mean=3.355 | std=0.562 | wmean=3.393 | wstd=0.420 | score=3.602
#   + saved
# [Epoch 0420] mean=3.416 | std=0.534 | wmean=3.391 | wstd=0.427 | score=3.604
# [Epoch 0421] mean=3.261 | std=0.471 | wmean=3.384 | wstd=0.432 | score=3.600
#   + saved
# [Epoch 0422] mean=3.338 | std=0.465 | wmean=3.380 | wstd=0.437 | score=3.598
#   + saved
# [Epoch 0423] mean=3.359 | std=0.451 | wmean=3.376 | wstd=0.441 | score=3.597
#   + saved
# [Epoch 0424] mean=3.448 | std=0.625 | wmean=3.376 | wstd=0.450 | score=3.601
# [Epoch 0425] mean=3.428 | std=0.494 | wmean=3.374 | wstd=0.453 | score=3.601
# [Epoch 0426] mean=3.404 | std=0.429 | wmean=3.374 | wstd=0.455 | score=3.601
# [Epoch 0427] mean=3.496 | std=0.559 | wmean=3.375 | wstd=0.462 | score=3.606
# [Epoch 0428] mean=3.272 | std=0.417 | wmean=3.373 | wstd=0.465 | score=3.605
# [Epoch 0429] mean=3.382 | std=0.402 | wmean=3.371 | wstd=0.464 | score=3.603
# [Epoch 0430] mean=3.544 | std=0.516 | wmean=3.375 | wstd=0.469 | score=3.610
# [Epoch 0431] mean=3.384 | std=0.425 | wmean=3.377 | wstd=0.472 | score=3.613
# [Epoch 0432] mean=3.514 | std=0.640 | wmean=3.383 | wstd=0.483 | score=3.625
# [Epoch 0433] mean=3.405 | std=0.576 | wmean=3.385 | wstd=0.490 | score=3.630
# [Epoch 0434] mean=3.268 | std=0.401 | wmean=3.381 | wstd=0.488 | score=3.625
# [Epoch 0435] mean=3.305 | std=0.488 | wmean=3.380 | wstd=0.491 | score=3.625
# [Epoch 0436] mean=3.365 | std=0.506 | wmean=3.379 | wstd=0.494 | score=3.626
# [Epoch 0437] mean=3.397 | std=0.515 | wmean=3.379 | wstd=0.498 | score=3.628
# [Epoch 0438] mean=3.371 | std=0.437 | wmean=3.378 | wstd=0.499 | score=3.628
# [Epoch 0439] mean=3.481 | std=0.444 | wmean=3.380 | wstd=0.500 | score=3.629
# [Epoch 0440] mean=3.327 | std=0.470 | wmean=3.378 | wstd=0.496 | score=3.626
# [Epoch 0441] mean=3.359 | std=0.444 | wmean=3.378 | wstd=0.496 | score=3.627
# [Epoch 0442] mean=3.446 | std=0.541 | wmean=3.381 | wstd=0.499 | score=3.631
# [Epoch 0443] mean=3.388 | std=0.509 | wmean=3.376 | wstd=0.494 | score=3.623
# [Epoch 0444] mean=3.407 | std=0.717 | wmean=3.379 | wstd=0.504 | score=3.630
# [Epoch 0445] mean=3.331 | std=0.439 | wmean=3.378 | wstd=0.502 | score=3.629
# [Epoch 0446] mean=3.471 | std=0.479 | wmean=3.383 | wstd=0.504 | score=3.635
# [Epoch 0447] mean=3.352 | std=0.476 | wmean=3.384 | wstd=0.507 | score=3.638
# [Epoch 0448] mean=3.428 | std=0.515 | wmean=3.390 | wstd=0.508 | score=3.644
# [Epoch 0449] mean=3.384 | std=0.559 | wmean=3.391 | wstd=0.508 | score=3.645
# [Epoch 0450] mean=3.345 | std=0.542 | wmean=3.389 | wstd=0.509 | score=3.643
# [Epoch 0451] mean=3.471 | std=0.438 | wmean=3.396 | wstd=0.507 | score=3.649
# [Epoch 0452] mean=3.411 | std=0.593 | wmean=3.398 | wstd=0.511 | score=3.654
# [Epoch 0453] mean=3.377 | std=0.633 | wmean=3.399 | wstd=0.518 | score=3.658
# [Epoch 0454] mean=3.379 | std=0.552 | wmean=3.396 | wstd=0.515 | score=3.654
# [Epoch 0455] mean=3.301 | std=0.400 | wmean=3.392 | wstd=0.512 | score=3.648
# [Epoch 0456] mean=3.298 | std=0.514 | wmean=3.389 | wstd=0.515 | score=3.646
# [Epoch 0457] mean=3.317 | std=0.527 | wmean=3.383 | wstd=0.514 | score=3.640
# [Epoch 0458] mean=3.558 | std=0.585 | wmean=3.392 | wstd=0.520 | score=3.652
# [Epoch 0459] mean=3.419 | std=0.605 | wmean=3.393 | wstd=0.526 | score=3.657
# [Epoch 0460] mean=3.276 | std=0.475 | wmean=3.384 | wstd=0.525 | score=3.647
# [Epoch 0461] mean=3.407 | std=0.414 | wmean=3.385 | wstd=0.524 | score=3.647
# [Epoch 0462] mean=3.316 | std=0.439 | wmean=3.379 | wstd=0.517 | score=3.637
# [Epoch 0463] mean=3.358 | std=0.480 | wmean=3.377 | wstd=0.514 | score=3.634
# [Epoch 0464] mean=3.478 | std=0.594 | wmean=3.384 | wstd=0.520 | score=3.644
# [Epoch 0465] mean=3.358 | std=0.417 | wmean=3.386 | wstd=0.518 | score=3.645
# [Epoch 0466] mean=3.426 | std=0.537 | wmean=3.388 | wstd=0.519 | score=3.647
# [Epoch 0467] mean=3.311 | std=0.451 | wmean=3.385 | wstd=0.517 | score=3.643
# [Epoch 0468] mean=3.359 | std=0.511 | wmean=3.385 | wstd=0.519 | score=3.644
# [Epoch 0469] mean=3.424 | std=0.452 | wmean=3.383 | wstd=0.519 | score=3.642
# [Epoch 0470] mean=3.313 | std=0.465 | wmean=3.382 | wstd=0.519 | score=3.642
# [Epoch 0471] mean=3.536 | std=0.467 | wmean=3.388 | wstd=0.520 | score=3.648
# [Epoch 0472] mean=3.397 | std=0.371 | wmean=3.386 | wstd=0.515 | score=3.644
# [Epoch 0473] mean=3.412 | std=0.518 | wmean=3.387 | wstd=0.516 | score=3.645
# [Epoch 0474] mean=3.397 | std=0.543 | wmean=3.387 | wstd=0.508 | score=3.641
# [Epoch 0475] mean=3.415 | std=0.579 | wmean=3.390 | wstd=0.513 | score=3.646
# [Epoch 0476] mean=3.382 | std=0.593 | wmean=3.387 | wstd=0.517 | score=3.645
# [Epoch 0477] mean=3.461 | std=0.467 | wmean=3.390 | wstd=0.517 | score=3.649
# [Epoch 0478] mean=3.525 | std=0.503 | wmean=3.394 | wstd=0.517 | score=3.652
# [Epoch 0479] mean=3.869 | std=1.113 | wmean=3.410 | wstd=0.552 | score=3.686
# [Epoch 0480] mean=3.393 | std=0.397 | wmean=3.411 | wstd=0.548 | score=3.686
# [Epoch 0481] mean=3.333 | std=0.400 | wmean=3.407 | wstd=0.547 | score=3.680
# [Epoch 0482] mean=3.479 | std=0.418 | wmean=3.409 | wstd=0.542 | score=3.680
# [Epoch 0483] mean=3.361 | std=0.387 | wmean=3.409 | wstd=0.534 | score=3.676
# [Epoch 0484] mean=3.319 | std=0.584 | wmean=3.407 | wstd=0.536 | score=3.674
# [Epoch 0485] mean=3.328 | std=0.457 | wmean=3.407 | wstd=0.537 | score=3.676
# [Epoch 0486] mean=3.335 | std=0.480 | wmean=3.409 | wstd=0.536 | score=3.677
# [Epoch 0487] mean=3.516 | std=0.543 | wmean=3.415 | wstd=0.536 | score=3.684
# [Epoch 0488] mean=3.503 | std=0.419 | wmean=3.414 | wstd=0.531 | score=3.679
# [Epoch 0489] mean=3.349 | std=0.440 | wmean=3.411 | wstd=0.525 | score=3.674
# [Epoch 0490] mean=3.371 | std=0.475 | wmean=3.414 | wstd=0.525 | score=3.677
# [Epoch 0491] mean=3.389 | std=0.380 | wmean=3.414 | wstd=0.524 | score=3.676
# [Epoch 0492] mean=3.404 | std=0.493 | wmean=3.417 | wstd=0.525 | score=3.679
# [Epoch 0493] mean=3.320 | std=0.472 | wmean=3.415 | wstd=0.525 | score=3.678
# [Epoch 0494] mean=3.279 | std=0.583 | wmean=3.409 | wstd=0.525 | score=3.671
# [Epoch 0495] mean=3.368 | std=0.476 | wmean=3.409 | wstd=0.527 | score=3.673
# [Epoch 0496] mean=3.458 | std=0.503 | wmean=3.410 | wstd=0.526 | score=3.673
# [Epoch 0497] mean=3.425 | std=0.559 | wmean=3.414 | wstd=0.529 | score=3.679
# [Epoch 0498] mean=3.391 | std=0.535 | wmean=3.415 | wstd=0.530 | score=3.680
# [Epoch 0499] mean=3.374 | std=0.490 | wmean=3.413 | wstd=0.531 | score=3.679
# [Epoch 0500] mean=3.402 | std=0.491 | wmean=3.416 | wstd=0.531 | score=3.682
# [Epoch 0501] mean=3.480 | std=0.543 | wmean=3.414 | wstd=0.533 | score=3.681
# [Epoch 0502] mean=3.392 | std=0.582 | wmean=3.414 | wstd=0.540 | score=3.684
# [Epoch 0503] mean=3.362 | std=0.401 | wmean=3.413 | wstd=0.536 | score=3.681
# [Epoch 0504] mean=3.264 | std=0.479 | wmean=3.408 | wstd=0.535 | score=3.676
# [Epoch 0505] mean=3.297 | std=0.600 | wmean=3.404 | wstd=0.536 | score=3.672
# [Epoch 0506] mean=3.505 | std=0.547 | wmean=3.408 | wstd=0.535 | score=3.676
# [Epoch 0507] mean=3.404 | std=0.615 | wmean=3.406 | wstd=0.540 | score=3.676
# [Epoch 0508] mean=3.441 | std=0.528 | wmean=3.404 | wstd=0.540 | score=3.674
# [Epoch 0509] mean=3.400 | std=0.487 | wmean=3.388 | wstd=0.501 | score=3.638
# [Epoch 0510] mean=3.494 | std=0.461 | wmean=3.391 | wstd=0.503 | score=3.643
# [Epoch 0511] mean=3.396 | std=0.527 | wmean=3.394 | wstd=0.507 | score=3.647
# [Epoch 0512] mean=3.425 | std=0.475 | wmean=3.392 | wstd=0.508 | score=3.646
# [Epoch 0513] mean=3.380 | std=0.536 | wmean=3.392 | wstd=0.513 | score=3.649
# [Epoch 0514] mean=3.340 | std=0.485 | wmean=3.393 | wstd=0.509 | score=3.648
# [Epoch 0515] mean=3.256 | std=0.510 | wmean=3.391 | wstd=0.511 | score=3.646
# [Epoch 0516] mean=3.415 | std=0.548 | wmean=3.393 | wstd=0.514 | score=3.650
# [Epoch 0517] mean=3.482 | std=0.430 | wmean=3.392 | wstd=0.510 | score=3.647
# [Epoch 0518] mean=3.398 | std=0.433 | wmean=3.389 | wstd=0.510 | score=3.644
# [Epoch 0519] mean=3.287 | std=0.418 | wmean=3.387 | wstd=0.509 | score=3.641
# [Epoch 0520] mean=3.402 | std=0.665 | wmean=3.388 | wstd=0.516 | score=3.646
# [Epoch 0521] mean=3.423 | std=0.521 | wmean=3.389 | wstd=0.521 | score=3.649
# [Epoch 0522] mean=3.390 | std=0.548 | wmean=3.388 | wstd=0.522 | score=3.650
# [Epoch 0523] mean=3.461 | std=0.478 | wmean=3.393 | wstd=0.523 | score=3.654
# 🛑 Early stopping triggered

# %% [markdown]
# # Save last results

# %%
# ---- Always save LAST at end of training ----
last_checkpoint = {
    'epoch': epoch,
    'model_state': net.state_dict(),
    'optimizer_state': optimizer.state_dict(),
    'best_score': best_score,
    'mean_losses': mean_losses,
    'std_losses': std_losses,
    'scores': scores,
    'epochs': epochs,
    'all_epoch_unit_losses': all_epoch_unit_losses,
    "rng_torch": torch.random.get_rng_state(),
    "rng_numpy": np.random.get_state(),
}

torch.save(last_checkpoint, checkpoint_last_path)
print("✓ Final LAST checkpoint saved.")
# Out:
# ✓ Final LAST checkpoint saved.

# %% [markdown]
# ## Plot

# %%
epochs_arr = np.array(epochs)
mean_arr = np.array(mean_losses)
std_arr = np.array(std_losses)
scores_arr = np.array(scores)


# ignore first epochs where score is not valid
best_idx = np.argmin(scores_arr[LOSS_WINDOW-1:]) + (LOSS_WINDOW-1)  
best_epoch = epochs_arr[best_idx]
best_score = scores_arr[best_idx]

plt.figure(figsize=(8, 5))

# Main curves
plt.plot(epochs_arr, mean_arr, linewidth=2, label='mean loss')
plt.plot(epochs_arr, mean_arr+AVERSION*std_arr, linewidth=2, label=f'mean+{AVERSION}std')
plt.plot(epochs_arr, scores_arr, linewidth=2, label='risk score')

ymin, ymax = plt.ylim()
yrange = ymax - ymin

y_offset = 0.5 * yrange      # 8% of axis height
x_offset = -0.05 * (epochs_arr.max() - epochs_arr.min())

# ---- Annotation instead of scatter ----
plt.annotate(
    f"min score = {best_score:.3f}\nepoch = {best_epoch}",
    xy=(best_epoch, best_score),
    xytext=(best_epoch + x_offset, best_score + y_offset),
    textcoords='data',
    arrowprops=dict(arrowstyle="->", linewidth=1),
    fontsize=9,
    bbox=dict(boxstyle="round,pad=0.3", fc="white", alpha=0.8),
)

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title(f'{perform_name} PF network training')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save figure
fig_path = PERFORM_DIR / "net_training_loss.png"
plt.savefig(fig_path, dpi=300)

# Save raw arrays
np.save(PERFORM_DIR/ "net_training_mean.npy", mean_arr)
np.save(PERFORM_DIR / "net_training_std.npy", std_arr)
np.save(PERFORM_DIR / "net_training_scores.npy", scores_arr)

plt.show()

print(f"✓ Plot saved to {fig_path}")
print(f"✓ Best epoch: {best_epoch} (score={best_score:.4f})")
# Out:
# ✓ Plot saved to experiments/DS05/opcond_q0-1/estimation/gamma/net256x256x128x64x32_leaky0.05_npar2000_aversion0.5_losswin30_losstail5/SmLPC/net_training_loss.png
# ✓ Best epoch: 423 (score=3.5967)
