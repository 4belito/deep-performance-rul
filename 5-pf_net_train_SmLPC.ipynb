# %% [markdown]
# ## Train the PF-Controller Neural Network
#
# For each performance metric, train the corresponding particle-filter (PF) controller neural network.

# %%
import numpy as np
from pathlib import Path
import pandas as pd
import torch
from matplotlib import pyplot as plt
import torch.nn as nn
from src.models.particle_filter.core import ParticleFilter
from src.models.networks.pf_mlp import ParticleFilterMLP
from src.helpers.seed import set_global_seed

from experiment_config import (
    DegModel,DATA_NAME,ESTIMATION_NAME,SEED,PFNET_NAME,LEAKY_SLOPE,HIDDEN_DIMS,PREDICTION_START_IDX,EMA_BETA,USE_LASTOBS_LOSS,N_PARTICLES
)

# %% [markdown]
# ## Task

# %%
perform_name = 'SmLPC'

# %% [markdown]
# ## Hyper-Parameters

# %%
# Training parameters#
# optimization
lr = 5e-4
weight_decay = 0
gradient_clip = 3.0
 


# Early stopping
n_epochs = 5000
patience = 100          # how many eval steps to wait
min_delta = 1e-4       # minimum improvement to count

# %%
degmodel_name = DegModel.name()
activation = nn.LeakyReLU(LEAKY_SLOPE)

set_global_seed(SEED)
experiment_dir = Path('experiments')/DATA_NAME

estimation_dir = experiment_dir/ESTIMATION_NAME
degmodel_dir = estimation_dir/degmodel_name
states_dir = degmodel_dir/'states'
pfnet_dir = degmodel_dir /'pf_performs'/PFNET_NAME
checkpoint_path = pfnet_dir / perform_name / "checkpoint.pt"
checkpoint_path.parent.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Import training data

# %%
hi_df = pd.read_csv(estimation_dir/"data_dev.csv")
units = hi_df['unit'].astype(int).unique().tolist()
units

# %% [markdown]
# ### Extract degradation onset

# %%
onsets = {unit: hi_df[(hi_df['unit']==unit) & (hi_df['hs']==0)]['cycle'].values[0] for unit in units}
del hi_df['hs']

# %%
perform_names = [col for col in hi_df.columns if col not in ['unit','cycle']]

performs = {name: 
    {unit: hi_df[hi_df['unit']==unit][name].values for unit in units} 
    for name in perform_names
}

init_ss = {name: {unit: perform[unit].max() for unit in units} for name,perform in performs.items()}
time = {unit: hi_df[hi_df['unit']==unit]['cycle'].values for unit in units}

# %% [markdown]
# ## Create component (base) models

# %%
eval_data = {}
eval_eol = {}
for unit in units:
    t_data = time[unit]
    s_data = performs[perform_name][unit]
    eval_data[unit]=torch.tensor(np.stack([t_data, s_data],axis=1),dtype=torch.float32)
    eval_eol[unit]=torch.tensor(t_data[-1],dtype=torch.float32)

# %%
train_degmodels = {}
for eval_unit in units:
    degmodels=[]
    for unit, perform in performs[perform_name].items():
        if unit == eval_unit:
            continue
        best_model = DegModel(onset=onsets[unit], init_s=init_ss[perform_name][unit])
        best_model.load_state_dict(
            torch.load(degmodel_dir/'states'/perform_name/f'unit_{unit}'/ "best_model.pt")
        )
        degmodels.append(best_model)
    train_degmodels[eval_unit] = degmodels

# %% [markdown]
# ## Train Particle Filter Net()

# %%
net = ParticleFilterMLP(state_dim=DegModel.state_dim(), hidden_dims=HIDDEN_DIMS,
                        activation=lambda : activation)

optimizer = torch.optim.Adam(net.parameters(), lr, weight_decay=weight_decay)
optimizer.zero_grad()

# %%
wait = 0             
early_stop = False
ema_loss = None


start_epoch = 0
best_loss = float("inf")
total_loss = 0.0
losses = []
epochs = []
if checkpoint_path.exists():
    ckpt = torch.load(checkpoint_path, weights_only=False)

    net.load_state_dict(ckpt["model_state"])
    optimizer.load_state_dict(ckpt["optimizer_state"])

    start_epoch = ckpt["epoch"] + 1
    best_loss = ckpt["best_loss"]
    losses = ckpt["losses"]
    epochs = ckpt["epochs"]

    ema_loss = ckpt.get("ema_loss", None)

    torch.random.set_rng_state(ckpt["rng_torch"])
    np.random.set_state(ckpt["rng_numpy"])

    print(f"✓ Resumed from epoch {start_epoch}, best_loss={best_loss:.3f}")

# %%
for epoch in range(start_epoch, n_epochs):

    epoch_losses = []

    for eval_unit in np.random.permutation(units):
        optimizer.zero_grad()
        degmodels = train_degmodels[eval_unit]
        t_data = eval_data[eval_unit][:, 0]
        s_data = eval_data[eval_unit][:, 1]

        pf = ParticleFilter(
            base_models=degmodels,
            net=net,
            n_particles=N_PARTICLES,
        ).train()

        unit_loss = 0.0
        n_loss = 0

        for k in range(PREDICTION_START_IDX, len(t_data)):
            
            mixture_dist = pf.step(
                t_obs=t_data[:k+1],
                s_obs=s_data[:k+1],
            )
            init_loss = -1 if USE_LASTOBS_LOSS else k
            last_dist = mixture_dist.distribution(s=s_data[init_loss:])
            nll = -last_dist.log_prob(t_data[init_loss:]).mean()
            unit_loss += nll
            n_loss += 1

        unit_loss = unit_loss / n_loss

        unit_loss.backward()
        torch.nn.utils.clip_grad_norm_(net.parameters(), gradient_clip)
        optimizer.step()

        epoch_losses.append(unit_loss.item())

    # ---- raw loss ----
    current_loss = float(sum(epoch_losses) / len(epoch_losses))

    # ---- EMA smoothing ----
    if ema_loss is None:
        ema_loss = current_loss
    else:
        ema_loss = EMA_BETA * ema_loss + (1 - EMA_BETA) * current_loss

    print(f"[Epoch {epoch:04d}] loss = {current_loss:.3f} | ema = {ema_loss:.3f}")

    losses.append(current_loss)
    epochs.append(epoch)

    # ---- early stopping on EMA ----
    if ema_loss < best_loss - min_delta:
        best_loss = ema_loss
        wait = 0

        checkpoint = {
            'epoch': epoch,
            'model_state': net.state_dict(),
            'optimizer_state': optimizer.state_dict(),
            'best_loss': best_loss,
            'losses': losses,
            'epochs': epochs,
            'ema_loss': ema_loss,
            "rng_torch": torch.random.get_rng_state(),
            "rng_numpy": np.random.get_state(),
        }

        torch.save(checkpoint, checkpoint_path)
        print("  + saved (best EMA)")

    else:
        wait += 1
        if wait >= patience:
            print("🛑 Early stopping triggered")
            break
# Out:
# [Epoch 0000] loss = 3.573 | ema = 3.573
#   + saved (best EMA)
# [Epoch 0001] loss = 3.477 | ema = 3.563
#   + saved (best EMA)
# [Epoch 0002] loss = 3.575 | ema = 3.565
# [Epoch 0003] loss = 3.579 | ema = 3.566
# [Epoch 0004] loss = 3.540 | ema = 3.563
# [Epoch 0005] loss = 3.472 | ema = 3.554
#   + saved (best EMA)
# [Epoch 0006] loss = 3.580 | ema = 3.557
# [Epoch 0007] loss = 3.446 | ema = 3.546
#   + saved (best EMA)
# [Epoch 0008] loss = 3.406 | ema = 3.532
#   + saved (best EMA)
# [Epoch 0009] loss = 3.698 | ema = 3.548
# [Epoch 0010] loss = 3.445 | ema = 3.538
# [Epoch 0011] loss = 3.436 | ema = 3.528
#   + saved (best EMA)
# [Epoch 0012] loss = 3.437 | ema = 3.519
#   + saved (best EMA)
# [Epoch 0013] loss = 3.404 | ema = 3.507
#   + saved (best EMA)
# [Epoch 0014] loss = 3.394 | ema = 3.496
#   + saved (best EMA)
# [Epoch 0015] loss = 3.428 | ema = 3.489
#   + saved (best EMA)
# [Epoch 0016] loss = 3.753 | ema = 3.516
# [Epoch 0017] loss = 3.386 | ema = 3.503
# [Epoch 0018] loss = 3.492 | ema = 3.501
# [Epoch 0019] loss = 3.486 | ema = 3.500
# [Epoch 0020] loss = 3.481 | ema = 3.498
# [Epoch 0021] loss = 3.489 | ema = 3.497
# [Epoch 0022] loss = 3.388 | ema = 3.486
#   + saved (best EMA)
# [Epoch 0023] loss = 3.445 | ema = 3.482
#   + saved (best EMA)
# [Epoch 0024] loss = 3.472 | ema = 3.481
#   + saved (best EMA)
# [Epoch 0025] loss = 3.451 | ema = 3.478
#   + saved (best EMA)
# [Epoch 0026] loss = 3.425 | ema = 3.473
#   + saved (best EMA)
# [Epoch 0027] loss = 3.413 | ema = 3.467
#   + saved (best EMA)
# [Epoch 0028] loss = 3.420 | ema = 3.462
#   + saved (best EMA)
# [Epoch 0029] loss = 3.428 | ema = 3.459
#   + saved (best EMA)
# [Epoch 0030] loss = 3.399 | ema = 3.453
#   + saved (best EMA)
# [Epoch 0031] loss = 3.421 | ema = 3.449
#   + saved (best EMA)
# [Epoch 0032] loss = 3.444 | ema = 3.449
#   + saved (best EMA)
# [Epoch 0033] loss = 3.456 | ema = 3.450
# [Epoch 0034] loss = 3.450 | ema = 3.450
# [Epoch 0035] loss = 3.337 | ema = 3.438
#   + saved (best EMA)
# [Epoch 0036] loss = 3.393 | ema = 3.434
#   + saved (best EMA)
# [Epoch 0037] loss = 3.501 | ema = 3.441
# [Epoch 0038] loss = 3.334 | ema = 3.430
#   + saved (best EMA)
# [Epoch 0039] loss = 4.031 | ema = 3.490
# [Epoch 0040] loss = 3.563 | ema = 3.497
# [Epoch 0041] loss = 3.636 | ema = 3.511
# [Epoch 0042] loss = 3.360 | ema = 3.496
# [Epoch 0043] loss = 3.413 | ema = 3.488
# [Epoch 0044] loss = 3.329 | ema = 3.472
# [Epoch 0045] loss = 3.303 | ema = 3.455
# [Epoch 0046] loss = 3.294 | ema = 3.439
# [Epoch 0047] loss = 3.346 | ema = 3.430
#   + saved (best EMA)
# [Epoch 0048] loss = 3.320 | ema = 3.419
#   + saved (best EMA)
# [Epoch 0049] loss = 3.316 | ema = 3.408
#   + saved (best EMA)
# [Epoch 0050] loss = 3.320 | ema = 3.400
#   + saved (best EMA)
# [Epoch 0051] loss = 3.442 | ema = 3.404
# [Epoch 0052] loss = 3.400 | ema = 3.403
# [Epoch 0053] loss = 3.411 | ema = 3.404
# [Epoch 0054] loss = 3.339 | ema = 3.398
#   + saved (best EMA)
# [Epoch 0055] loss = 3.347 | ema = 3.393
#   + saved (best EMA)
# [Epoch 0056] loss = 3.341 | ema = 3.387
#   + saved (best EMA)
# [Epoch 0057] loss = 3.315 | ema = 3.380
#   + saved (best EMA)
# [Epoch 0058] loss = 3.280 | ema = 3.370
#   + saved (best EMA)
# [Epoch 0059] loss = 3.291 | ema = 3.362
#   + saved (best EMA)
# [Epoch 0060] loss = 3.321 | ema = 3.358
#   + saved (best EMA)
# [Epoch 0061] loss = 3.350 | ema = 3.357
#   + saved (best EMA)
# [Epoch 0062] loss = 3.369 | ema = 3.359
# [Epoch 0063] loss = 3.351 | ema = 3.358
# [Epoch 0064] loss = 3.307 | ema = 3.353
#   + saved (best EMA)
# [Epoch 0065] loss = 3.391 | ema = 3.357
# [Epoch 0066] loss = 3.348 | ema = 3.356
# [Epoch 0067] loss = 3.219 | ema = 3.342
#   + saved (best EMA)
# [Epoch 0068] loss = 3.325 | ema = 3.340
#   + saved (best EMA)
# [Epoch 0069] loss = 3.232 | ema = 3.329
#   + saved (best EMA)
# [Epoch 0070] loss = 3.260 | ema = 3.323
#   + saved (best EMA)
# [Epoch 0071] loss = 3.276 | ema = 3.318
#   + saved (best EMA)
# [Epoch 0072] loss = 3.262 | ema = 3.312
#   + saved (best EMA)
# [Epoch 0073] loss = 3.291 | ema = 3.310
#   + saved (best EMA)
# [Epoch 0074] loss = 3.307 | ema = 3.310
#   + saved (best EMA)
# [Epoch 0075] loss = 3.295 | ema = 3.308
#   + saved (best EMA)
# [Epoch 0076] loss = 3.331 | ema = 3.311
# [Epoch 0077] loss = 3.297 | ema = 3.309
# [Epoch 0078] loss = 3.337 | ema = 3.312
# [Epoch 0079] loss = 3.357 | ema = 3.316
# [Epoch 0080] loss = 3.374 | ema = 3.322
# [Epoch 0081] loss = 3.212 | ema = 3.311
# [Epoch 0082] loss = 3.232 | ema = 3.303
#   + saved (best EMA)
# [Epoch 0083] loss = 3.286 | ema = 3.302
#   + saved (best EMA)
# [Epoch 0084] loss = 3.266 | ema = 3.298
#   + saved (best EMA)
# [Epoch 0085] loss = 3.311 | ema = 3.299
# [Epoch 0086] loss = 3.328 | ema = 3.302
# [Epoch 0087] loss = 3.305 | ema = 3.303
# [Epoch 0088] loss = 3.311 | ema = 3.303
# [Epoch 0089] loss = 3.227 | ema = 3.296
#   + saved (best EMA)
# [Epoch 0090] loss = 3.304 | ema = 3.297
# [Epoch 0091] loss = 3.292 | ema = 3.296
# [Epoch 0092] loss = 3.301 | ema = 3.297
# [Epoch 0093] loss = 3.255 | ema = 3.292
#   + saved (best EMA)
# [Epoch 0094] loss = 3.327 | ema = 3.296
# [Epoch 0095] loss = 3.245 | ema = 3.291
#   + saved (best EMA)
# [Epoch 0096] loss = 3.286 | ema = 3.290
#   + saved (best EMA)
# [Epoch 0097] loss = 3.263 | ema = 3.288
#   + saved (best EMA)
# [Epoch 0098] loss = 3.238 | ema = 3.283
#   + saved (best EMA)
# [Epoch 0099] loss = 3.283 | ema = 3.283
# [Epoch 0100] loss = 3.236 | ema = 3.278
#   + saved (best EMA)
# [Epoch 0101] loss = 3.234 | ema = 3.274
#   + saved (best EMA)
# [Epoch 0102] loss = 3.235 | ema = 3.270
#   + saved (best EMA)
# [Epoch 0103] loss = 3.246 | ema = 3.267
# [Epoch 0437] loss = 3.300 | ema = 3.224
# [Epoch 0438] loss = 3.208 | ema = 3.222
# [Epoch 0439] loss = 3.205 | ema = 3.221
# [Epoch 0440] loss = 3.225 | ema = 3.221
# [Epoch 0441] loss = 3.189 | ema = 3.218
# [Epoch 0442] loss = 3.163 | ema = 3.212
# [Epoch 0443] loss = 3.178 | ema = 3.209
# [Epoch 0444] loss = 3.140 | ema = 3.202
# [Epoch 0445] loss = 3.229 | ema = 3.205
# [Epoch 0446] loss = 3.174 | ema = 3.202
# [Epoch 0447] loss = 3.231 | ema = 3.205
# [Epoch 0448] loss = 3.229 | ema = 3.207
# [Epoch 0449] loss = 3.142 | ema = 3.201
# [Epoch 0450] loss = 3.165 | ema = 3.197
# [Epoch 0451] loss = 3.190 | ema = 3.196
# [Epoch 0452] loss = 3.225 | ema = 3.199
# [Epoch 0453] loss = 3.161 | ema = 3.195
# [Epoch 0454] loss = 3.232 | ema = 3.199
# [Epoch 0455] loss = 3.234 | ema = 3.202
# [Epoch 0456] loss = 3.260 | ema = 3.208
# [Epoch 0457] loss = 3.205 | ema = 3.208
# [Epoch 0458] loss = 3.225 | ema = 3.210
# [Epoch 0459] loss = 3.188 | ema = 3.207
# [Epoch 0460] loss = 3.233 | ema = 3.210
# [Epoch 0461] loss = 3.220 | ema = 3.211
# [Epoch 0462] loss = 3.342 | ema = 3.224
# [Epoch 0463] loss = 3.173 | ema = 3.219
# [Epoch 0464] loss = 3.187 | ema = 3.216
# [Epoch 0465] loss = 3.222 | ema = 3.216
# [Epoch 0466] loss = 3.194 | ema = 3.214
# [Epoch 0467] loss = 3.194 | ema = 3.212
# [Epoch 0468] loss = 3.250 | ema = 3.216
# [Epoch 0469] loss = 3.270 | ema = 3.221
# [Epoch 0470] loss = 3.280 | ema = 3.227
# [Epoch 0471] loss = 3.319 | ema = 3.236
# [Epoch 0472] loss = 3.237 | ema = 3.236
# 🛑 Early stopping triggered

# %% [markdown]
# # Save last results

# %%
if checkpoint_path.exists():
    ckpt:dict = torch.load(checkpoint_path, weights_only=False)
    ckpt.update({
        'epoch': epoch,
        'model_state':net.state_dict(),
        'optimizer_state': optimizer.state_dict(),
        'losses': losses,
        'epochs': epochs,
        "rng_torch": torch.random.get_rng_state(),
    	"rng_numpy": np.random.get_state(),
    })
    torch.save(ckpt,checkpoint_path)

    print(f"✓ Resumed from epoch {start_epoch}, best_loss={best_loss:.3f}")
# Out:
# ✓ Resumed from epoch 0, best_loss=3.187

# %%
str(checkpoint_path)
# Out:
# 'experiments/DS05/estimation_thr0.1_q0.01-0.99_filtered_n0.01_s20.0/gamma_onset0.2-0.2/pf_performs/net256x256x128x64x32leaky0.05_emaloss0.9_init0/SmLPC/checkpoint.pt'

# %% [markdown]
# ## Plot

# %%
likelihood = np.exp(-np.array(losses))

plt.figure(figsize=(8, 5))
plt.plot(epochs, likelihood)
plt.xlabel('epochs')
plt.ylabel('last obs prob')
plt.title(f'{perform_name} PF network loss')
plt.grid(True)

plt.tight_layout()
plt.savefig(pfnet_dir /perform_name/"net_training_loss.png", dpi=300) 
np.save(pfnet_dir /perform_name/"net_training_loss.npy", np.array(losses))
plt.show()
