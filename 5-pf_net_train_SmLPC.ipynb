# %% [markdown]
# ## Train the PF-Controller Neural Network
#
# For each performance metric, train the corresponding particle-filter (PF) controller neural network.

# %%
import numpy as np
import pandas as pd
import torch
from matplotlib import pyplot as plt
import torch.nn as nn
from src.models.particle_filter.core import ParticleFilter
from src.models.networks.pf_mlp import ParticleFilterMLP
from src.helpers.seed import set_global_seed

from experiment_config import (
    DegModel,DATA_NAME,SEED,LEAKY_SLOPE,HIDDEN_DIMS,PREDICTION_START_IDX,LOSS_WINDOW_SIZE,N_PARTICLES,GRADIENT_CLIP,WEIGHT_DECAY,AVERSION,PFNET_DIR,DEGR_MODEL_DIR,ESTIMATION_DIR
)
    
DATA_NAME
# Out:
# 'DS01'

# %% [markdown]
# ## Task

# %%
perform_name = 'SmLPC'

# %% [markdown]
# ## Hyper-Parameters

# %%
# Training parameters#
# optimization
lr = 5e-4

# Early stopping
n_epochs = 5000
patience = 100         # how many eval steps to wait
min_delta = 1e-4       # minimum improvement to count

# %%
set_global_seed(SEED)
PERFORM_DIR = PFNET_DIR/perform_name

checkpoint_best_path = PERFORM_DIR / "checkpoint_best.pt"
checkpoint_last_path = PERFORM_DIR / "checkpoint_last.pt"
checkpoint_best_path.parent.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Import training data

# %%
hi_df = pd.read_csv(ESTIMATION_DIR/"data_dev.csv")
units = hi_df['unit'].astype(int).unique().tolist()
units
# Out:
# [1, 2, 4, 5, 6]

# %% [markdown]
# ### Extract degradation onset

# %%
onsets = {unit: hi_df[(hi_df['unit']==unit) & (hi_df['hs']==0)]['cycle'].values[0] for unit in units}
del hi_df['hs']

# %%
perform_names = [col for col in hi_df.columns if col not in ['unit','cycle']]

performs = {name: 
    {unit: hi_df[hi_df['unit']==unit][name].values for unit in units} 
    for name in perform_names
}

init_ss = {name: {unit: perform[unit].max() for unit in units} for name,perform in performs.items()}
time = {unit: hi_df[hi_df['unit']==unit]['cycle'].values for unit in units}

# %% [markdown]
# ## Create component (base) models

# %%
train_data = {}
train_eol = {}
for unit in units:
    t_data = time[unit]
    s_data = performs[perform_name][unit]
    train_data[unit]=torch.tensor(np.stack([t_data, s_data],axis=1),dtype=torch.float32)
    train_eol[unit]=torch.tensor(t_data[-1],dtype=torch.float32)

# %%
degmodels = {}
for train_unit in units:
    offline_degmodels=[]
    for unit, perform in performs[perform_name].items():
        if unit == train_unit:
            continue
        best_model = DegModel(onset=onsets[unit], init_s=init_ss[perform_name][unit])
        best_model.load_state_dict(
            torch.load(DEGR_MODEL_DIR/'states'/perform_name/f'unit_{unit}'/ "best_model.pt")
        )
        offline_degmodels.append(best_model)
    degmodels[train_unit] = offline_degmodels

# %% [markdown]
# ## Train Particle Filter Net()

# %%
net = ParticleFilterMLP(state_dim=DegModel.state_dim(), hidden_dims=HIDDEN_DIMS,
                        activation=lambda : nn.LeakyReLU(LEAKY_SLOPE))

optimizer = torch.optim.Adam(net.parameters(), lr, weight_decay=WEIGHT_DECAY)
optimizer.zero_grad()

# %%
wait = 0
best_score = float("inf")

all_epoch_unit_losses = []
mean_losses = []
std_losses = []
scores = []
epochs = []

start_epoch = 0

if checkpoint_last_path.exists():
    ckpt = torch.load(checkpoint_last_path, weights_only=False)

    net.load_state_dict(ckpt["model_state"])
    optimizer.load_state_dict(ckpt["optimizer_state"])

    start_epoch = ckpt["epoch"] + 1
    best_score = ckpt["best_score"]

    mean_losses = ckpt["mean_losses"]
    std_losses = ckpt["std_losses"]
    scores = ckpt["scores"]
    epochs = ckpt["epochs"]
    all_epoch_unit_losses = ckpt["all_epoch_unit_losses"]

    torch.random.set_rng_state(ckpt["rng_torch"])
    np.random.set_state(ckpt["rng_numpy"])

    print(f"✓ Resumed from epoch {start_epoch}, best_score={best_score:.3f}")

# %%
for epoch in range(start_epoch, n_epochs):

    epoch_unit_losses = {}

    for train_unit in np.random.permutation(units):

        optimizer.zero_grad()

        offline_degmodels = degmodels[train_unit]
        t_data = train_data[train_unit][:, 0]
        s_data = train_data[train_unit][:, 1]

        pf = ParticleFilter(
            base_models=offline_degmodels,
            net=net,
            n_particles=N_PARTICLES,
        ).train()

        unit_loss = 0.0
        n_loss = 0

        for k in range(PREDICTION_START_IDX, len(t_data)):

            mixture_dist = pf.step(
                t_obs=t_data[:k+1],
                s_obs=s_data[:k+1],
            )
            

            init_loss = -LOSS_WINDOW_SIZE if LOSS_WINDOW_SIZE else k
            last_dist = mixture_dist.distribution(s=s_data[init_loss:])
            nll = -last_dist.log_prob(t_data[init_loss:]).mean()

            unit_loss += nll
            n_loss += 1

        unit_loss = unit_loss / n_loss

        unit_loss.backward()
        if GRADIENT_CLIP is not None:
            torch.nn.utils.clip_grad_norm_(net.parameters(), GRADIENT_CLIP)
        optimizer.step()

        epoch_unit_losses[train_unit] = unit_loss.item()

    # ---- compute score ----
    unit_values = np.array(list(epoch_unit_losses.values()))
    mean_loss = unit_values.mean()
    std_loss = unit_values.std()

    score = mean_loss + AVERSION * std_loss

    print(
        f"[Epoch {epoch:04d}] "
        f"mean={mean_loss:.3f} | std={std_loss:.3f} | score={score:.3f}"
    )

    all_epoch_unit_losses.append(epoch_unit_losses)
    mean_losses.append(mean_loss)
    std_losses.append(std_loss)
    scores.append(score)
    epochs.append(epoch)

    # ---- early stopping on score ----
    if score < best_score - min_delta:
        best_score = score
        wait = 0

        # ---- BEST (minimal) ----
        best_checkpoint = {
            'epoch': epoch,
            'model_state': net.state_dict(),
            'best_score': best_score,
        }
        torch.save(best_checkpoint, checkpoint_best_path)
        

        # ---- LAST (full training state) ----
        last_checkpoint = {
            'epoch': epoch,
            'model_state': net.state_dict(),
            'optimizer_state': optimizer.state_dict(),
            'best_score': best_score,
            'mean_losses': mean_losses,
            'std_losses': std_losses,
            'scores': scores,
            'epochs': epochs,
            'all_epoch_unit_losses': all_epoch_unit_losses,
            "rng_torch": torch.random.get_rng_state(),
            "rng_numpy": np.random.get_state(),
        }
        torch.save(last_checkpoint, checkpoint_last_path)
        print("  + saved")
    else:
        wait += 1
        if wait >= patience:
            print("🛑 Early stopping triggered")
            break
# Out:
# [Epoch 0000] mean=7.237 | std=3.601 | score=7.237
#   + saved
# [Epoch 0001] mean=7.199 | std=3.500 | score=7.199
#   + saved
# [Epoch 0002] mean=7.078 | std=3.298 | score=7.078
#   + saved
# [Epoch 0003] mean=6.933 | std=2.809 | score=6.933
#   + saved
# [Epoch 0004] mean=6.910 | std=2.468 | score=6.910
#   + saved
# [Epoch 0005] mean=5.215 | std=1.632 | score=5.215
#   + saved
# [Epoch 0006] mean=4.721 | std=0.934 | score=4.721
#   + saved
# [Epoch 0007] mean=4.003 | std=0.297 | score=4.003
#   + saved
# [Epoch 0008] mean=3.922 | std=0.154 | score=3.922
#   + saved
# [Epoch 0009] mean=4.089 | std=0.212 | score=4.089
# [Epoch 0010] mean=4.058 | std=0.222 | score=4.058
# [Epoch 0011] mean=3.935 | std=0.198 | score=3.935
# [Epoch 0012] mean=3.828 | std=0.155 | score=3.828
#   + saved
# [Epoch 0013] mean=3.769 | std=0.135 | score=3.769
#   + saved
# [Epoch 0014] mean=3.695 | std=0.151 | score=3.695
#   + saved
# [Epoch 0015] mean=3.674 | std=0.138 | score=3.674
#   + saved
# [Epoch 0016] mean=3.693 | std=0.184 | score=3.693
# [Epoch 0017] mean=3.700 | std=0.207 | score=3.700
# [Epoch 0018] mean=3.640 | std=0.172 | score=3.640
#   + saved
# [Epoch 0019] mean=3.633 | std=0.148 | score=3.633
#   + saved
# [Epoch 0020] mean=3.591 | std=0.163 | score=3.591
#   + saved
# [Epoch 0021] mean=3.589 | std=0.131 | score=3.589
#   + saved
# [Epoch 0022] mean=3.607 | std=0.186 | score=3.607
# [Epoch 0023] mean=3.606 | std=0.122 | score=3.606
# [Epoch 0024] mean=3.570 | std=0.111 | score=3.570
#   + saved
# [Epoch 0025] mean=3.599 | std=0.111 | score=3.599
# [Epoch 0026] mean=3.562 | std=0.122 | score=3.562
#   + saved
# [Epoch 0027] mean=3.531 | std=0.135 | score=3.531
#   + saved
# [Epoch 0028] mean=3.588 | std=0.099 | score=3.588
# [Epoch 0029] mean=3.612 | std=0.147 | score=3.612
# [Epoch 0030] mean=3.645 | std=0.153 | score=3.645
# [Epoch 0031] mean=3.564 | std=0.152 | score=3.564
# [Epoch 0032] mean=3.552 | std=0.120 | score=3.552
# [Epoch 0033] mean=3.621 | std=0.150 | score=3.621
# [Epoch 0034] mean=3.626 | std=0.112 | score=3.626
# [Epoch 0035] mean=3.665 | std=0.117 | score=3.665
# [Epoch 0036] mean=3.586 | std=0.107 | score=3.586
# [Epoch 0037] mean=3.532 | std=0.133 | score=3.532
# [Epoch 0038] mean=3.540 | std=0.127 | score=3.540
# [Epoch 0039] mean=3.631 | std=0.158 | score=3.631
# [Epoch 0040] mean=3.532 | std=0.082 | score=3.532
# [Epoch 0041] mean=3.544 | std=0.124 | score=3.544
# [Epoch 0042] mean=3.563 | std=0.152 | score=3.563
# [Epoch 0043] mean=3.593 | std=0.128 | score=3.593
# [Epoch 0044] mean=3.583 | std=0.152 | score=3.583
# [Epoch 0045] mean=3.640 | std=0.224 | score=3.640
# [Epoch 0046] mean=3.559 | std=0.145 | score=3.559
# [Epoch 0047] mean=3.564 | std=0.113 | score=3.564
# [Epoch 0048] mean=3.484 | std=0.102 | score=3.484
#   + saved
# [Epoch 0049] mean=3.523 | std=0.118 | score=3.523
# [Epoch 0050] mean=3.528 | std=0.113 | score=3.528
# [Epoch 0051] mean=3.669 | std=0.109 | score=3.669
# [Epoch 0052] mean=3.481 | std=0.120 | score=3.481
#   + saved
# [Epoch 0053] mean=3.472 | std=0.115 | score=3.472
#   + saved
# [Epoch 0054] mean=3.523 | std=0.067 | score=3.523
# [Epoch 0055] mean=3.533 | std=0.130 | score=3.533
# [Epoch 0056] mean=3.603 | std=0.165 | score=3.603
# [Epoch 0057] mean=3.523 | std=0.080 | score=3.523
# [Epoch 0058] mean=3.553 | std=0.123 | score=3.553
# [Epoch 0059] mean=3.507 | std=0.118 | score=3.507
# [Epoch 0060] mean=3.503 | std=0.085 | score=3.503
# [Epoch 0061] mean=3.513 | std=0.128 | score=3.513
# [Epoch 0062] mean=3.545 | std=0.083 | score=3.545
# [Epoch 0063] mean=3.487 | std=0.143 | score=3.487
# [Epoch 0064] mean=3.515 | std=0.103 | score=3.515
# [Epoch 0065] mean=3.497 | std=0.164 | score=3.497
# [Epoch 0066] mean=3.592 | std=0.093 | score=3.592
# [Epoch 0067] mean=3.534 | std=0.109 | score=3.534
# [Epoch 0068] mean=3.533 | std=0.127 | score=3.533
# [Epoch 0069] mean=3.581 | std=0.172 | score=3.581
# [Epoch 0070] mean=3.463 | std=0.118 | score=3.463
#   + saved
# [Epoch 0071] mean=3.524 | std=0.091 | score=3.524
# [Epoch 0072] mean=3.470 | std=0.133 | score=3.470
# [Epoch 0073] mean=3.607 | std=0.185 | score=3.607
# [Epoch 0074] mean=3.582 | std=0.135 | score=3.582
# [Epoch 0075] mean=3.529 | std=0.139 | score=3.529
# [Epoch 0076] mean=3.615 | std=0.136 | score=3.615
# [Epoch 0077] mean=3.583 | std=0.122 | score=3.583
# [Epoch 0078] mean=3.510 | std=0.137 | score=3.510
# [Epoch 0079] mean=3.505 | std=0.147 | score=3.505
# [Epoch 0080] mean=3.581 | std=0.132 | score=3.581
# [Epoch 0081] mean=3.496 | std=0.118 | score=3.496
# [Epoch 0082] mean=3.552 | std=0.076 | score=3.552
# [Epoch 0083] mean=3.471 | std=0.095 | score=3.471
# [Epoch 0084] mean=3.496 | std=0.110 | score=3.496
# [Epoch 0085] mean=3.510 | std=0.122 | score=3.510
# [Epoch 0086] mean=3.587 | std=0.068 | score=3.587
# [Epoch 0087] mean=3.472 | std=0.129 | score=3.472
# [Epoch 0088] mean=3.489 | std=0.090 | score=3.489
# [Epoch 0089] mean=3.539 | std=0.139 | score=3.539
# [Epoch 0090] mean=3.579 | std=0.130 | score=3.579
# [Epoch 0091] mean=3.646 | std=0.222 | score=3.646
# [Epoch 0092] mean=3.485 | std=0.118 | score=3.485
# [Epoch 0093] mean=3.484 | std=0.080 | score=3.484
# [Epoch 0094] mean=3.457 | std=0.105 | score=3.457
#   + saved
# [Epoch 0095] mean=3.629 | std=0.167 | score=3.629
# [Epoch 0096] mean=3.595 | std=0.164 | score=3.595
# [Epoch 0097] mean=3.491 | std=0.129 | score=3.491
# [Epoch 0098] mean=3.531 | std=0.105 | score=3.531
# [Epoch 0099] mean=3.556 | std=0.117 | score=3.556
# [Epoch 0100] mean=3.514 | std=0.104 | score=3.514
# [Epoch 0101] mean=3.512 | std=0.151 | score=3.512
# [Epoch 0102] mean=3.438 | std=0.111 | score=3.438
#   + saved
# [Epoch 0103] mean=3.538 | std=0.072 | score=3.538
# [Epoch 0104] mean=3.471 | std=0.145 | score=3.471
# [Epoch 0105] mean=3.508 | std=0.083 | score=3.508
# [Epoch 0106] mean=3.548 | std=0.163 | score=3.548
# [Epoch 0107] mean=3.490 | std=0.137 | score=3.490
# [Epoch 0108] mean=3.528 | std=0.153 | score=3.528
# [Epoch 0109] mean=3.558 | std=0.154 | score=3.558
# [Epoch 0110] mean=3.623 | std=0.231 | score=3.623
# [Epoch 0111] mean=3.631 | std=0.144 | score=3.631
# [Epoch 0112] mean=3.485 | std=0.163 | score=3.485
# [Epoch 0113] mean=3.528 | std=0.098 | score=3.528
# [Epoch 0114] mean=3.626 | std=0.225 | score=3.626
# [Epoch 0115] mean=3.861 | std=0.309 | score=3.861
# [Epoch 0116] mean=3.474 | std=0.131 | score=3.474
# [Epoch 0117] mean=3.533 | std=0.169 | score=3.533
# [Epoch 0118] mean=3.540 | std=0.159 | score=3.540
# [Epoch 0119] mean=3.494 | std=0.089 | score=3.494
# [Epoch 0120] mean=3.584 | std=0.173 | score=3.584
# [Epoch 0121] mean=3.450 | std=0.166 | score=3.450
# [Epoch 0122] mean=3.560 | std=0.124 | score=3.560
# [Epoch 0123] mean=3.530 | std=0.154 | score=3.530
# [Epoch 0124] mean=3.530 | std=0.210 | score=3.530
# [Epoch 0125] mean=3.461 | std=0.109 | score=3.461
# [Epoch 0126] mean=3.538 | std=0.112 | score=3.538
# [Epoch 0127] mean=3.479 | std=0.108 | score=3.479
# [Epoch 0128] mean=3.482 | std=0.125 | score=3.482
# [Epoch 0129] mean=3.502 | std=0.112 | score=3.502
# [Epoch 0130] mean=3.500 | std=0.188 | score=3.500
# [Epoch 0131] mean=3.449 | std=0.128 | score=3.449
# [Epoch 0132] mean=3.485 | std=0.141 | score=3.485
# [Epoch 0133] mean=3.649 | std=0.196 | score=3.649
# [Epoch 0134] mean=3.495 | std=0.095 | score=3.495
# [Epoch 0135] mean=3.508 | std=0.190 | score=3.508
# [Epoch 0136] mean=3.517 | std=0.121 | score=3.517
# [Epoch 0137] mean=3.507 | std=0.158 | score=3.507
# [Epoch 0138] mean=3.439 | std=0.097 | score=3.439
# [Epoch 0139] mean=3.468 | std=0.120 | score=3.468
# [Epoch 0140] mean=3.525 | std=0.199 | score=3.525
# [Epoch 0141] mean=3.567 | std=0.224 | score=3.567
# [Epoch 0142] mean=3.474 | std=0.119 | score=3.474
# [Epoch 0143] mean=3.523 | std=0.135 | score=3.523
# [Epoch 0144] mean=3.459 | std=0.079 | score=3.459
# [Epoch 0145] mean=3.429 | std=0.083 | score=3.429
#   + saved
# [Epoch 0146] mean=3.459 | std=0.127 | score=3.459
# [Epoch 0147] mean=3.543 | std=0.120 | score=3.543
# [Epoch 0148] mean=3.392 | std=0.098 | score=3.392
#   + saved
# [Epoch 0149] mean=3.528 | std=0.110 | score=3.528
# [Epoch 0150] mean=3.494 | std=0.073 | score=3.494
# [Epoch 0151] mean=3.445 | std=0.120 | score=3.445
# [Epoch 0152] mean=3.386 | std=0.106 | score=3.386
#   + saved
# [Epoch 0153] mean=3.482 | std=0.153 | score=3.482
# [Epoch 0154] mean=3.468 | std=0.150 | score=3.468
# [Epoch 0155] mean=3.474 | std=0.159 | score=3.474
# [Epoch 0156] mean=3.406 | std=0.090 | score=3.406
# [Epoch 0157] mean=3.371 | std=0.122 | score=3.371
#   + saved
# [Epoch 0158] mean=3.467 | std=0.212 | score=3.467
# [Epoch 0159] mean=3.454 | std=0.115 | score=3.454
# [Epoch 0160] mean=3.410 | std=0.106 | score=3.410
# [Epoch 0161] mean=3.368 | std=0.079 | score=3.368
#   + saved
# [Epoch 0162] mean=3.411 | std=0.057 | score=3.411
# [Epoch 0163] mean=3.467 | std=0.167 | score=3.467
# [Epoch 0164] mean=3.378 | std=0.158 | score=3.378
# [Epoch 0165] mean=3.514 | std=0.204 | score=3.514
# [Epoch 0166] mean=3.415 | std=0.199 | score=3.415
# [Epoch 0167] mean=3.415 | std=0.162 | score=3.415
# [Epoch 0168] mean=3.497 | std=0.078 | score=3.497
# [Epoch 0169] mean=3.396 | std=0.091 | score=3.396
# [Epoch 0170] mean=3.455 | std=0.134 | score=3.455
# [Epoch 0171] mean=3.448 | std=0.111 | score=3.448
# [Epoch 0172] mean=3.483 | std=0.139 | score=3.483
# [Epoch 0173] mean=3.494 | std=0.163 | score=3.494
# [Epoch 0174] mean=3.432 | std=0.066 | score=3.432
# [Epoch 0175] mean=3.479 | std=0.092 | score=3.479
# [Epoch 0176] mean=3.481 | std=0.144 | score=3.481
# [Epoch 0177] mean=3.463 | std=0.140 | score=3.463
# [Epoch 0178] mean=3.440 | std=0.105 | score=3.440
# [Epoch 0179] mean=3.490 | std=0.224 | score=3.490
# [Epoch 0180] mean=3.474 | std=0.154 | score=3.474
# [Epoch 0181] mean=3.511 | std=0.229 | score=3.511
# [Epoch 0182] mean=3.396 | std=0.127 | score=3.396
# [Epoch 0183] mean=3.507 | std=0.276 | score=3.507
# [Epoch 0184] mean=3.413 | std=0.176 | score=3.413
# [Epoch 0185] mean=3.360 | std=0.086 | score=3.360
#   + saved
# [Epoch 0186] mean=3.415 | std=0.198 | score=3.415
# [Epoch 0187] mean=3.429 | std=0.170 | score=3.429
# [Epoch 0188] mean=3.430 | std=0.205 | score=3.430
# [Epoch 0189] mean=3.449 | std=0.231 | score=3.449
# [Epoch 0190] mean=3.411 | std=0.209 | score=3.411
# [Epoch 0191] mean=3.412 | std=0.194 | score=3.412
# [Epoch 0192] mean=3.332 | std=0.125 | score=3.332
#   + saved
# [Epoch 0193] mean=3.403 | std=0.220 | score=3.403
# [Epoch 0194] mean=3.380 | std=0.181 | score=3.380
# [Epoch 0195] mean=3.418 | std=0.238 | score=3.418
# [Epoch 0196] mean=3.402 | std=0.166 | score=3.402
# [Epoch 0197] mean=3.351 | std=0.160 | score=3.351
# [Epoch 0198] mean=3.434 | std=0.213 | score=3.434
# [Epoch 0199] mean=3.408 | std=0.190 | score=3.408
# [Epoch 0200] mean=3.398 | std=0.186 | score=3.398
# [Epoch 0201] mean=3.381 | std=0.212 | score=3.381
# [Epoch 0202] mean=3.423 | std=0.259 | score=3.423
# [Epoch 0203] mean=3.354 | std=0.193 | score=3.354
# [Epoch 0204] mean=3.406 | std=0.234 | score=3.406
# [Epoch 0205] mean=3.414 | std=0.191 | score=3.414
# [Epoch 0206] mean=3.438 | std=0.239 | score=3.438
# [Epoch 0207] mean=3.418 | std=0.193 | score=3.418
# [Epoch 0208] mean=3.519 | std=0.210 | score=3.519
# [Epoch 0209] mean=3.502 | std=0.196 | score=3.502
# [Epoch 0210] mean=3.509 | std=0.221 | score=3.509
# [Epoch 0211] mean=3.480 | std=0.159 | score=3.480
# [Epoch 0212] mean=3.423 | std=0.195 | score=3.423
# [Epoch 0213] mean=3.399 | std=0.205 | score=3.399
# [Epoch 0214] mean=3.436 | std=0.209 | score=3.436
# [Epoch 0215] mean=3.431 | std=0.231 | score=3.431
# [Epoch 0216] mean=3.399 | std=0.183 | score=3.399
# [Epoch 0217] mean=3.445 | std=0.160 | score=3.445
# [Epoch 0218] mean=3.472 | std=0.197 | score=3.472
# [Epoch 0219] mean=3.471 | std=0.185 | score=3.471
# [Epoch 0220] mean=3.482 | std=0.171 | score=3.482
# [Epoch 0221] mean=3.438 | std=0.157 | score=3.438
# [Epoch 0222] mean=3.386 | std=0.162 | score=3.386
# [Epoch 0223] mean=3.394 | std=0.215 | score=3.394
# [Epoch 0224] mean=3.414 | std=0.227 | score=3.414
# [Epoch 0225] mean=3.380 | std=0.173 | score=3.380
# [Epoch 0226] mean=3.369 | std=0.178 | score=3.369
# [Epoch 0227] mean=3.280 | std=0.109 | score=3.280
#   + saved
# [Epoch 0228] mean=3.373 | std=0.206 | score=3.373
# [Epoch 0229] mean=3.360 | std=0.212 | score=3.360
# [Epoch 0230] mean=3.378 | std=0.159 | score=3.378
# [Epoch 0231] mean=3.360 | std=0.179 | score=3.360
# [Epoch 0232] mean=3.488 | std=0.286 | score=3.488
# [Epoch 0233] mean=3.446 | std=0.250 | score=3.446
# [Epoch 0234] mean=3.499 | std=0.338 | score=3.499
# [Epoch 0235] mean=3.475 | std=0.284 | score=3.475
# [Epoch 0236] mean=3.429 | std=0.170 | score=3.429
# [Epoch 0237] mean=3.361 | std=0.191 | score=3.361
# [Epoch 0238] mean=3.321 | std=0.201 | score=3.321
# [Epoch 0239] mean=3.330 | std=0.192 | score=3.330
# [Epoch 0240] mean=3.327 | std=0.214 | score=3.327
# [Epoch 0241] mean=3.329 | std=0.191 | score=3.329
# [Epoch 0242] mean=3.408 | std=0.248 | score=3.408
# [Epoch 0243] mean=3.450 | std=0.320 | score=3.450
# [Epoch 0244] mean=3.422 | std=0.263 | score=3.422
# [Epoch 0245] mean=3.456 | std=0.197 | score=3.456
# [Epoch 0246] mean=3.425 | std=0.191 | score=3.425
# [Epoch 0247] mean=3.423 | std=0.316 | score=3.423
# [Epoch 0248] mean=3.389 | std=0.212 | score=3.389
# [Epoch 0249] mean=3.442 | std=0.304 | score=3.442
# [Epoch 0250] mean=3.424 | std=0.217 | score=3.424
# [Epoch 0251] mean=3.391 | std=0.210 | score=3.391
# [Epoch 0252] mean=3.494 | std=0.422 | score=3.494
# [Epoch 0253] mean=3.460 | std=0.248 | score=3.460
# [Epoch 0254] mean=3.528 | std=0.144 | score=3.528
# [Epoch 0255] mean=3.502 | std=0.131 | score=3.502
# [Epoch 0256] mean=3.432 | std=0.202 | score=3.432
# [Epoch 0257] mean=3.410 | std=0.252 | score=3.410
# [Epoch 0258] mean=3.416 | std=0.256 | score=3.416
# [Epoch 0259] mean=3.393 | std=0.239 | score=3.393
# [Epoch 0260] mean=3.422 | std=0.251 | score=3.422
# [Epoch 0261] mean=3.453 | std=0.229 | score=3.453
# [Epoch 0262] mean=3.422 | std=0.224 | score=3.422
# [Epoch 0263] mean=3.428 | std=0.241 | score=3.428
# [Epoch 0264] mean=3.420 | std=0.249 | score=3.420
# [Epoch 0265] mean=3.401 | std=0.262 | score=3.401
# [Epoch 0266] mean=3.369 | std=0.201 | score=3.369
# [Epoch 0267] mean=3.394 | std=0.225 | score=3.394
# [Epoch 0268] mean=3.393 | std=0.225 | score=3.393
# [Epoch 0269] mean=3.405 | std=0.220 | score=3.405
# [Epoch 0270] mean=3.418 | std=0.243 | score=3.418
# [Epoch 0271] mean=3.387 | std=0.224 | score=3.387
# [Epoch 0272] mean=3.398 | std=0.241 | score=3.398
# [Epoch 0273] mean=3.416 | std=0.209 | score=3.416
# [Epoch 0274] mean=3.399 | std=0.226 | score=3.399
# [Epoch 0275] mean=3.457 | std=0.293 | score=3.457
# [Epoch 0276] mean=3.389 | std=0.244 | score=3.389
# [Epoch 0277] mean=3.382 | std=0.193 | score=3.382
# [Epoch 0278] mean=3.400 | std=0.229 | score=3.400
# [Epoch 0279] mean=3.396 | std=0.229 | score=3.396
# [Epoch 0280] mean=3.312 | std=0.196 | score=3.312
# [Epoch 0281] mean=3.440 | std=0.282 | score=3.440
# [Epoch 0282] mean=3.403 | std=0.243 | score=3.403
# [Epoch 0283] mean=3.427 | std=0.242 | score=3.427
# [Epoch 0284] mean=3.397 | std=0.193 | score=3.397
# [Epoch 0285] mean=3.416 | std=0.254 | score=3.416
# [Epoch 0286] mean=3.407 | std=0.252 | score=3.407
# [Epoch 0287] mean=3.386 | std=0.219 | score=3.386
# [Epoch 0288] mean=3.471 | std=0.296 | score=3.471
# [Epoch 0289] mean=3.404 | std=0.215 | score=3.404
# [Epoch 0290] mean=3.401 | std=0.264 | score=3.401
# [Epoch 0291] mean=3.412 | std=0.262 | score=3.412
# [Epoch 0292] mean=3.437 | std=0.238 | score=3.437
# [Epoch 0293] mean=3.426 | std=0.231 | score=3.426
# [Epoch 0294] mean=3.414 | std=0.208 | score=3.414
# [Epoch 0295] mean=3.403 | std=0.240 | score=3.403
# [Epoch 0296] mean=3.386 | std=0.209 | score=3.386
# [Epoch 0297] mean=3.402 | std=0.245 | score=3.402
# [Epoch 0298] mean=3.423 | std=0.240 | score=3.423
# [Epoch 0299] mean=3.389 | std=0.221 | score=3.389
# [Epoch 0300] mean=3.399 | std=0.233 | score=3.399
# [Epoch 0301] mean=3.374 | std=0.215 | score=3.374
# [Epoch 0302] mean=3.417 | std=0.235 | score=3.417
# [Epoch 0303] mean=3.389 | std=0.235 | score=3.389
# [Epoch 0304] mean=3.402 | std=0.223 | score=3.402
# [Epoch 0305] mean=3.389 | std=0.223 | score=3.389
# [Epoch 0306] mean=3.426 | std=0.275 | score=3.426
# [Epoch 0307] mean=3.399 | std=0.234 | score=3.399
# [Epoch 0308] mean=3.375 | std=0.194 | score=3.375
# [Epoch 0309] mean=3.394 | std=0.220 | score=3.394
# [Epoch 0310] mean=3.346 | std=0.219 | score=3.346
# [Epoch 0311] mean=3.419 | std=0.283 | score=3.419
# [Epoch 0312] mean=3.410 | std=0.215 | score=3.410
# [Epoch 0313] mean=3.425 | std=0.181 | score=3.425
# [Epoch 0314] mean=3.375 | std=0.189 | score=3.375
# [Epoch 0315] mean=3.308 | std=0.213 | score=3.308
# [Epoch 0316] mean=3.354 | std=0.253 | score=3.354
# [Epoch 0317] mean=3.313 | std=0.170 | score=3.313
# [Epoch 0318] mean=3.433 | std=0.303 | score=3.433
# [Epoch 0319] mean=3.409 | std=0.261 | score=3.409
# [Epoch 0320] mean=3.355 | std=0.232 | score=3.355
# [Epoch 0321] mean=3.350 | std=0.209 | score=3.350
# [Epoch 0322] mean=3.389 | std=0.202 | score=3.389
# [Epoch 0323] mean=3.378 | std=0.210 | score=3.378
# [Epoch 0324] mean=3.355 | std=0.214 | score=3.355
# [Epoch 0325] mean=3.381 | std=0.212 | score=3.381
# [Epoch 0326] mean=3.344 | std=0.232 | score=3.344
# [Epoch 0327] mean=3.355 | std=0.204 | score=3.355
# 🛑 Early stopping triggered

# %% [markdown]
# # Save last results

# %%
# ---- Always save LAST at end of training ----
last_checkpoint = {
    'epoch': epoch,
    'model_state': net.state_dict(),
    'optimizer_state': optimizer.state_dict(),
    'best_score': best_score,
    'mean_losses': mean_losses,
    'std_losses': std_losses,
    'scores': scores,
    'epochs': epochs,
    'all_epoch_unit_losses': all_epoch_unit_losses,
    "rng_torch": torch.random.get_rng_state(),
    "rng_numpy": np.random.get_state(),
}

torch.save(last_checkpoint, checkpoint_last_path)
print("✓ Final LAST checkpoint saved.")
# Out:
# ✓ Final LAST checkpoint saved.

# %% [markdown]
# ## Plot

# %%
epochs_arr = np.array(epochs)
mean_arr = np.array(mean_losses)
std_arr = np.array(std_losses)
scores_arr = np.array(scores)

best_idx = np.argmin(scores_arr)
best_epoch = epochs_arr[best_idx]
best_score = scores_arr[best_idx]

plt.figure(figsize=(8, 5))

# Main curves
plt.plot(epochs_arr, mean_arr, linewidth=2, label='mean loss')
plt.plot(epochs_arr, scores_arr, linewidth=2, label='risk score')
plt.plot(epochs_arr, mean_arr+std_arr, linewidth=2, label='mean+std')


ymin, ymax = plt.ylim()
yrange = ymax - ymin

y_offset = 0.5 * yrange      # 8% of axis height
x_offset = -0.05 * (epochs_arr.max() - epochs_arr.min())

# ---- Annotation instead of scatter ----
plt.annotate(
    f"min score = {best_score:.3f}\nepoch = {best_epoch}",
    xy=(best_epoch, best_score),
    xytext=(best_epoch + x_offset, best_score + y_offset),
    textcoords='data',
    arrowprops=dict(arrowstyle="->", linewidth=1),
    fontsize=9,
    bbox=dict(boxstyle="round,pad=0.3", fc="white", alpha=0.8),
)

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title(f'{perform_name} PF network training')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save figure
fig_path = PERFORM_DIR / "net_training_loss.png"
plt.savefig(fig_path, dpi=300)

# Save raw arrays
np.save(PERFORM_DIR/ "net_training_mean.npy", mean_arr)
np.save(PERFORM_DIR / "net_training_std.npy", std_arr)
np.save(PERFORM_DIR / "net_training_scores.npy", scores_arr)

plt.show()

print(f"✓ Plot saved to {fig_path}")
print(f"✓ Best epoch: {best_epoch} (score={best_score:.4f})")
# Out:
# ✓ Plot saved to experiments/DS01/opcond_q0-1/estimation_thr0.1/gamma/net256x256x128x64x32_leaky0.05_npar2000_losswin5/SmLPC/net_training_loss.png
# ✓ Best epoch: 227 (score=3.2802)
