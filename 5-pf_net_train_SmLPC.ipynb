# %% [markdown]
# ## Train the PF-Controller Neural Network
#
# For each performance metric, train the corresponding particle-filter (PF) controller neural network.

# %%
import numpy as np
import pandas as pd
import torch
from matplotlib import pyplot as plt

from experiment_config import (
    SEED,
    DegModel,
    dataset_paths,
)
from src.helpers.seed import set_global_seed
from src.models.networks.pf_mlp import ParticleFilterMLP
from src.training.pfnet_hparams import PFNET_ARGS
from src.training.pfnet_training import train_pf_controller_cv

# %% [markdown]
# ## Task

# %%
DATA_NAME = "DS05"
perform_name = "SmLPC"
ARGS_ID = 5

# %% [markdown]
# ## Hyper-Parameters

# %%
args = PFNET_ARGS[ARGS_ID]

net_args = args["NETWORK"]

if net_args is None:
    raise SystemExit(
        "This ARGS_ID is a no-network baseline (NETWORK=None): there is no "
        "network to train. Use it only in the test/ablation notebooks."
    )
pf_args = args["PARTICLE_FILTER"]
train_args = args["TRAINING"]
eval_args = args["EVALUATION"]

# %%
set_global_seed(SEED)

ESTIMATION_DIR, DEGR_MODEL_DIR = dataset_paths(
    DATA_NAME, fields=["estimation", "degr_model"]
)

PFNET_ARGS_DIR = DEGR_MODEL_DIR / f"net_arg{ARGS_ID}"
PERFORM_DIR = PFNET_ARGS_DIR / perform_name

checkpoint_best_path = PERFORM_DIR / "checkpoint_best.pt"
checkpoint_last_path = PERFORM_DIR / "checkpoint_last.pt"
checkpoint_best_path.parent.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Import training data

# %%
hi_df = pd.read_csv(ESTIMATION_DIR / "data_dev.csv")
units = hi_df["unit"].astype(int).unique().tolist()
units
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Extract degradation onset

# %%
onsets = {
    unit: hi_df[(hi_df["unit"] == unit) & (hi_df["hs"] == 0)]["cycle"].values[0]
    for unit in units
}
del hi_df["hs"]

# %%
perform_names = [col for col in hi_df.columns if col not in ["unit", "cycle"]]

performs = {
    name: {unit: hi_df[hi_df["unit"] == unit][name].values for unit in units}
    for name in perform_names
}

init_ss = {
    name: {unit: perform[unit].max() for unit in units}
    for name, perform in performs.items()
}
time = {unit: hi_df[hi_df["unit"] == unit]["cycle"].values for unit in units}

# %% [markdown]
# ## Create component (base) models

# %%
dev_data = {}
dev_eol = {}
for unit in units:
    t = time[unit]
    s = performs[perform_name][unit]
    dev_data[unit] = torch.tensor(np.stack([t, s], axis=1), dtype=torch.float32)
    dev_eol[unit] = torch.tensor(t[-1], dtype=torch.float32)

# %%
dev_degmodels = {}
for unit in performs[perform_name]:
    best_model = DegModel(onset=onsets[unit], init_s=init_ss[perform_name][unit])
    best_model.load_state_dict(
        torch.load(
            DEGR_MODEL_DIR / "states" / perform_name / f"unit_{unit}" / "best_model.pt"
        )
    )
    dev_degmodels[unit] = best_model

# %% [markdown]
# ## Train Particle Filter controller Net

# %%
from src.models.networks.pf_mlp import build_activation

net = ParticleFilterMLP(
    state_dim=DegModel.state_dim(),
    hidden_dims=list(net_args["HIDDEN_DIMS"]),
    activation=build_activation(net_args),
    dropout_p=float(net_args["DROPOUT"]),
)

optimizer = torch.optim.Adam(net.parameters(), float(train_args["LR"]))
optimizer.zero_grad()

# %%
best_score = float("inf")
train_epoch_losses = []
eval_epoch_losses = []
scores = []
start_epoch = 0

if checkpoint_last_path.exists():
    ckpt = torch.load(checkpoint_last_path, weights_only=False)

    net.load_state_dict(ckpt["model_state"])
    optimizer.load_state_dict(ckpt["optimizer_state"])

    start_epoch = ckpt["epoch"] + 1
    best_score = ckpt["best_score"]
    scores = ckpt.get("scores", [])
    train_epoch_losses = ckpt.get("train_losses", [])
    eval_epoch_losses = ckpt.get("eval_losses", [])

    torch.random.set_rng_state(ckpt["rng_torch"])
    np.random.set_state(ckpt["rng_numpy"])

    print(f"✓ Resumed from epoch {start_epoch}, best_score={best_score:.3f}")
# Out:
# ✓ Resumed from epoch 53, best_score=3.491

# %%
train_state = train_pf_controller_cv(
    net=net,
    optimizer=optimizer,
    units=units,
    dev_data=dev_data,
    dev_degmodels=dev_degmodels,
    n_particles=int(pf_args["N_PARTICLES"]),
    max_life=int(pf_args["MAX_LIFE"]),
    loss_tail_steps=int(train_args["LOSS_TAIL_STEPS"]),
    n_epochs=int(train_args["N_EPOCHS"]),
    checkpoint_best_path=checkpoint_best_path,
    checkpoint_last_path=checkpoint_last_path,
    start_epoch=start_epoch,
    best_score=best_score,
    scores=scores,
    train_epoch_losses=train_epoch_losses,
    eval_epoch_losses=eval_epoch_losses,
    seed=SEED,
    eval_repetitions=int(eval_args["REPETITIONS"]),
    eval_seed_stride=int(eval_args["SEED_STRIDE"]),
    eval_initial_interval_epochs=int(eval_args["INITIAL_INTERVAL_EPOCHS"]),
    eval_final_interval_epochs=int(eval_args["FINAL_INTERVAL_EPOCHS"]),
    match_train_eval_prior=bool(train_args.get("MATCH_TRAIN_EVAL_PRIOR", False)),
    verbose=True,
)

best_score = train_state["best_score"]
scores = train_state["scores"]
train_epoch_losses = train_state["train_epoch_losses"]
eval_epoch_losses = train_state["eval_epoch_losses"]
epoch = train_state["epoch"]
best_checkpoint = train_state["best_checkpoint"]

if best_checkpoint is None and checkpoint_best_path.exists():
    best_checkpoint = torch.load(checkpoint_best_path, weights_only=False)
# Out:
# [Epoch 053] train=3.521 | eval=3.497 | score=3.497 (eval_every~12)
# [Epoch 054] train=3.556 | eval=skipped (eval_every~12)
# [Epoch 055] train=3.544 | eval=skipped (eval_every~12)
# [Epoch 056] train=3.542 | eval=skipped (eval_every~12)
# [Epoch 057] train=3.531 | eval=skipped (eval_every~12)
# [Epoch 058] train=3.529 | eval=skipped (eval_every~12)
# [Epoch 059] train=3.529 | eval=skipped (eval_every~12)
# [Epoch 060] train=3.533 | eval=skipped (eval_every~12)
# [Epoch 061] train=3.502 | eval=skipped (eval_every~12)
# [Epoch 062] train=3.537 | eval=skipped (eval_every~12)
# [Epoch 063] train=3.530 | eval=skipped (eval_every~12)
# [Epoch 064] train=3.521 | eval=skipped (eval_every~12)
# [Epoch 065] train=3.539 | eval=3.500 | score=3.500 (eval_every~11)
# [Epoch 066] train=3.528 | eval=skipped (eval_every~11)
# [Epoch 067] train=3.528 | eval=skipped (eval_every~11)
# [Epoch 068] train=3.523 | eval=skipped (eval_every~11)
# [Epoch 069] train=3.536 | eval=skipped (eval_every~11)
# [Epoch 070] train=3.518 | eval=skipped (eval_every~11)
# [Epoch 071] train=3.542 | eval=skipped (eval_every~11)
# [Epoch 072] train=3.535 | eval=skipped (eval_every~11)
# [Epoch 073] train=3.524 | eval=skipped (eval_every~11)
# [Epoch 074] train=3.519 | eval=skipped (eval_every~11)
# [Epoch 075] train=3.524 | eval=skipped (eval_every~11)
# [Epoch 076] train=3.527 | eval=3.503 | score=3.503 (eval_every~11)
# [Epoch 077] train=3.519 | eval=skipped (eval_every~11)
# [Epoch 078] train=3.512 | eval=skipped (eval_every~11)
# [Epoch 079] train=3.518 | eval=skipped (eval_every~11)
# [Epoch 080] train=3.512 | eval=skipped (eval_every~11)
# [Epoch 081] train=3.519 | eval=skipped (eval_every~11)
# [Epoch 082] train=3.522 | eval=skipped (eval_every~11)
# [Epoch 083] train=3.518 | eval=skipped (eval_every~11)
# [Epoch 084] train=3.518 | eval=skipped (eval_every~11)
# [Epoch 085] train=3.516 | eval=skipped (eval_every~11)
# [Epoch 086] train=3.523 | eval=skipped (eval_every~11)
# [Epoch 087] train=3.522 | eval=3.497 | score=3.497 (eval_every~10)
# [Epoch 088] train=3.518 | eval=skipped (eval_every~10)
# [Epoch 089] train=3.525 | eval=skipped (eval_every~10)
# [Epoch 090] train=3.521 | eval=skipped (eval_every~10)
# [Epoch 091] train=3.506 | eval=skipped (eval_every~10)
# [Epoch 092] train=3.519 | eval=skipped (eval_every~10)
# [Epoch 093] train=3.514 | eval=skipped (eval_every~10)
# [Epoch 094] train=3.505 | eval=skipped (eval_every~10)
# [Epoch 095] train=3.514 | eval=skipped (eval_every~10)
# [Epoch 096] train=3.508 | eval=skipped (eval_every~10)
# [Epoch 097] train=3.509 | eval=3.497 | score=3.497 (eval_every~10)
# [Epoch 098] train=3.506 | eval=skipped (eval_every~10)
# [Epoch 099] train=3.512 | eval=skipped (eval_every~10)
# [Epoch 100] train=3.503 | eval=skipped (eval_every~10)
# [Epoch 101] train=3.508 | eval=skipped (eval_every~10)
# [Epoch 102] train=3.513 | eval=skipped (eval_every~10)
# [Epoch 103] train=3.499 | eval=skipped (eval_every~10)
# [Epoch 104] train=3.508 | eval=skipped (eval_every~10)
# [Epoch 105] train=3.506 | eval=skipped (eval_every~10)
# [Epoch 106] train=3.508 | eval=skipped (eval_every~10)
# [Epoch 107] train=3.501 | eval=3.487 | score=3.487 (eval_every~10)
#   + saved (score=3.487)
# [Epoch 108] train=3.511 | eval=skipped (eval_every~10)
# [Epoch 109] train=3.502 | eval=skipped (eval_every~9)
# [Epoch 110] train=3.505 | eval=skipped (eval_every~9)
# [Epoch 111] train=3.504 | eval=skipped (eval_every~9)
# [Epoch 112] train=3.500 | eval=skipped (eval_every~9)
# [Epoch 113] train=3.503 | eval=skipped (eval_every~9)
# [Epoch 114] train=3.500 | eval=skipped (eval_every~9)
# [Epoch 115] train=3.505 | eval=skipped (eval_every~9)
# [Epoch 116] train=3.506 | eval=skipped (eval_every~9)
# [Epoch 117] train=3.493 | eval=3.480 | score=3.480 (eval_every~9)
#   + saved (score=3.480)
# [Epoch 118] train=3.499 | eval=skipped (eval_every~9)
# [Epoch 119] train=3.497 | eval=skipped (eval_every~9)
# [Epoch 120] train=3.497 | eval=skipped (eval_every~9)
# [Epoch 121] train=3.488 | eval=skipped (eval_every~9)
# [Epoch 122] train=3.490 | eval=skipped (eval_every~9)
# [Epoch 123] train=3.483 | eval=skipped (eval_every~9)
# [Epoch 124] train=3.495 | eval=skipped (eval_every~9)
# [Epoch 125] train=3.505 | eval=skipped (eval_every~9)
# [Epoch 126] train=3.478 | eval=3.460 | score=3.460 (eval_every~9)
#   + saved (score=3.460)
# [Epoch 127] train=3.498 | eval=skipped (eval_every~9)
# [Epoch 128] train=3.499 | eval=skipped (eval_every~9)
# [Epoch 129] train=3.488 | eval=skipped (eval_every~9)
# [Epoch 130] train=3.484 | eval=skipped (eval_every~9)
# [Epoch 131] train=3.479 | eval=skipped (eval_every~9)
# [Epoch 132] train=3.489 | eval=skipped (eval_every~8)
# [Epoch 133] train=3.480 | eval=skipped (eval_every~8)
# [Epoch 134] train=3.485 | eval=skipped (eval_every~8)
# [Epoch 135] train=3.486 | eval=3.456 | score=3.456 (eval_every~8)
#   + saved (score=3.456)
# [Epoch 136] train=3.487 | eval=skipped (eval_every~8)
# [Epoch 137] train=3.489 | eval=skipped (eval_every~8)
# [Epoch 138] train=3.487 | eval=skipped (eval_every~8)
# [Epoch 139] train=3.480 | eval=skipped (eval_every~8)
# [Epoch 140] train=3.475 | eval=skipped (eval_every~8)
# [Epoch 141] train=3.464 | eval=skipped (eval_every~8)
# [Epoch 142] train=3.466 | eval=skipped (eval_every~8)
# [Epoch 143] train=3.474 | eval=3.431 | score=3.431 (eval_every~8)
#   + saved (score=3.431)
# [Epoch 144] train=3.454 | eval=skipped (eval_every~8)
# [Epoch 145] train=3.447 | eval=skipped (eval_every~8)
# [Epoch 146] train=3.466 | eval=skipped (eval_every~8)
# [Epoch 147] train=3.472 | eval=skipped (eval_every~8)
# [Epoch 148] train=3.473 | eval=skipped (eval_every~8)
# [Epoch 149] train=3.454 | eval=skipped (eval_every~8)
# [Epoch 150] train=3.472 | eval=skipped (eval_every~8)
# [Epoch 151] train=3.469 | eval=3.429 | score=3.429 (eval_every~8)
#   + saved (score=3.429)
# [Epoch 152] train=3.471 | eval=skipped (eval_every~8)
# [Epoch 153] train=3.454 | eval=skipped (eval_every~8)
# [Epoch 154] train=3.450 | eval=skipped (eval_every~7)
# [Epoch 155] train=3.457 | eval=skipped (eval_every~7)
# [Epoch 156] train=3.450 | eval=skipped (eval_every~7)
# [Epoch 157] train=3.445 | eval=skipped (eval_every~7)
# [Epoch 158] train=3.455 | eval=skipped (eval_every~7)
# [Epoch 159] train=3.453 | eval=3.412 | score=3.412 (eval_every~7)
#   + saved (score=3.412)
# [Epoch 160] train=3.436 | eval=skipped (eval_every~7)
# [Epoch 161] train=3.450 | eval=skipped (eval_every~7)
# [Epoch 162] train=3.448 | eval=skipped (eval_every~7)
# [Epoch 163] train=3.443 | eval=skipped (eval_every~7)
# [Epoch 164] train=3.438 | eval=skipped (eval_every~7)
# [Epoch 165] train=3.455 | eval=skipped (eval_every~7)
# [Epoch 166] train=3.453 | eval=3.408 | score=3.408 (eval_every~7)
#   + saved (score=3.408)
# [Epoch 167] train=3.445 | eval=skipped (eval_every~7)
# [Epoch 168] train=3.433 | eval=skipped (eval_every~7)
# [Epoch 169] train=3.436 | eval=skipped (eval_every~7)
# [Epoch 170] train=3.443 | eval=skipped (eval_every~7)
# [Epoch 171] train=3.439 | eval=skipped (eval_every~7)
# [Epoch 172] train=3.441 | eval=skipped (eval_every~7)
# [Epoch 173] train=3.440 | eval=3.395 | score=3.395 (eval_every~7)
#   + saved (score=3.395)
# [Epoch 174] train=3.444 | eval=skipped (eval_every~7)
# [Epoch 175] train=3.434 | eval=skipped (eval_every~7)
# [Epoch 176] train=3.453 | eval=skipped (eval_every~6)
# [Epoch 177] train=3.431 | eval=skipped (eval_every~6)
# [Epoch 178] train=3.428 | eval=skipped (eval_every~6)
# [Epoch 179] train=3.457 | eval=skipped (eval_every~6)
# [Epoch 180] train=3.439 | eval=3.396 | score=3.396 (eval_every~6)
# [Epoch 181] train=3.438 | eval=skipped (eval_every~6)
# [Epoch 182] train=3.428 | eval=skipped (eval_every~6)
# [Epoch 183] train=3.442 | eval=skipped (eval_every~6)
# [Epoch 184] train=3.452 | eval=skipped (eval_every~6)
# [Epoch 185] train=3.429 | eval=skipped (eval_every~6)
# [Epoch 186] train=3.416 | eval=3.395 | score=3.395 (eval_every~6)
# [Epoch 187] train=3.428 | eval=skipped (eval_every~6)
# [Epoch 188] train=3.418 | eval=skipped (eval_every~6)
# [Epoch 189] train=3.435 | eval=skipped (eval_every~6)
# [Epoch 190] train=3.410 | eval=skipped (eval_every~6)
# [Epoch 191] train=3.420 | eval=skipped (eval_every~6)
# [Epoch 192] train=3.418 | eval=3.391 | score=3.391 (eval_every~6)
#   + saved (score=3.391)
# [Epoch 193] train=3.418 | eval=skipped (eval_every~6)
# [Epoch 194] train=3.433 | eval=skipped (eval_every~6)
# [Epoch 195] train=3.421 | eval=skipped (eval_every~6)
# [Epoch 196] train=3.427 | eval=skipped (eval_every~6)
# [Epoch 197] train=3.433 | eval=skipped (eval_every~6)
# [Epoch 198] train=3.423 | eval=3.375 | score=3.375 (eval_every~6)
#   + saved (score=3.375)
# [Epoch 199] train=3.421 | eval=skipped (eval_every~5)
# [Epoch 200] train=3.417 | eval=skipped (eval_every~5)
# [Epoch 201] train=3.433 | eval=skipped (eval_every~5)
# [Epoch 202] train=3.416 | eval=skipped (eval_every~5)
# [Epoch 203] train=3.416 | eval=skipped (eval_every~5)
# [Epoch 204] train=3.438 | eval=3.376 | score=3.376 (eval_every~5)
# [Epoch 205] train=3.427 | eval=skipped (eval_every~5)
# [Epoch 206] train=3.433 | eval=skipped (eval_every~5)
# [Epoch 207] train=3.424 | eval=skipped (eval_every~5)
# [Epoch 208] train=3.413 | eval=skipped (eval_every~5)
# [Epoch 209] train=3.441 | eval=3.376 | score=3.376 (eval_every~5)
# [Epoch 210] train=3.411 | eval=skipped (eval_every~5)
# [Epoch 211] train=3.414 | eval=skipped (eval_every~5)
# [Epoch 212] train=3.411 | eval=skipped (eval_every~5)
# [Epoch 213] train=3.411 | eval=skipped (eval_every~5)
# [Epoch 214] train=3.425 | eval=3.374 | score=3.374 (eval_every~5)
#   + saved (score=3.374)
# [Epoch 215] train=3.401 | eval=skipped (eval_every~5)
# [Epoch 216] train=3.423 | eval=skipped (eval_every~5)
# [Epoch 217] train=3.421 | eval=skipped (eval_every~5)
# [Epoch 218] train=3.419 | eval=skipped (eval_every~5)
# [Epoch 219] train=3.430 | eval=3.380 | score=3.380 (eval_every~5)
# [Epoch 220] train=3.431 | eval=skipped (eval_every~5)
# [Epoch 221] train=3.414 | eval=skipped (eval_every~4)
# [Epoch 222] train=3.431 | eval=skipped (eval_every~4)
# [Epoch 223] train=3.420 | eval=skipped (eval_every~4)
# [Epoch 224] train=3.423 | eval=3.378 | score=3.378 (eval_every~4)
# [Epoch 225] train=3.405 | eval=skipped (eval_every~4)
# [Epoch 226] train=3.403 | eval=skipped (eval_every~4)
# [Epoch 227] train=3.414 | eval=skipped (eval_every~4)
# [Epoch 228] train=3.410 | eval=3.372 | score=3.372 (eval_every~4)
#   + saved (score=3.372)
# [Epoch 229] train=3.410 | eval=skipped (eval_every~4)
# [Epoch 230] train=3.420 | eval=skipped (eval_every~4)
# [Epoch 231] train=3.406 | eval=skipped (eval_every~4)
# [Epoch 232] train=3.424 | eval=3.364 | score=3.364 (eval_every~4)
#   + saved (score=3.364)
# [Epoch 233] train=3.388 | eval=skipped (eval_every~4)
# [Epoch 234] train=3.413 | eval=skipped (eval_every~4)
# [Epoch 235] train=3.409 | eval=skipped (eval_every~4)
# [Epoch 236] train=3.405 | eval=3.364 | score=3.364 (eval_every~4)
# [Epoch 237] train=3.408 | eval=skipped (eval_every~4)
# [Epoch 238] train=3.401 | eval=skipped (eval_every~4)
# [Epoch 239] train=3.404 | eval=skipped (eval_every~4)
# [Epoch 240] train=3.399 | eval=3.366 | score=3.366 (eval_every~4)
# [Epoch 241] train=3.417 | eval=skipped (eval_every~4)
# [Epoch 242] train=3.411 | eval=skipped (eval_every~4)
# [Epoch 243] train=3.415 | eval=skipped (eval_every~4)
# [Epoch 244] train=3.391 | eval=3.361 | score=3.361 (eval_every~3)
#   + saved (score=3.361)
# [Epoch 245] train=3.421 | eval=skipped (eval_every~3)
# [Epoch 246] train=3.393 | eval=skipped (eval_every~3)
# [Epoch 247] train=3.405 | eval=3.363 | score=3.363 (eval_every~3)
# [Epoch 248] train=3.422 | eval=skipped (eval_every~3)
# [Epoch 249] train=3.415 | eval=skipped (eval_every~3)
# [Epoch 250] train=3.399 | eval=3.356 | score=3.356 (eval_every~3)
#   + saved (score=3.356)
# [Epoch 251] train=3.407 | eval=skipped (eval_every~3)
# [Epoch 252] train=3.412 | eval=skipped (eval_every~3)
# [Epoch 253] train=3.415 | eval=3.356 | score=3.356 (eval_every~3)
# [Epoch 254] train=3.398 | eval=skipped (eval_every~3)
# [Epoch 255] train=3.401 | eval=skipped (eval_every~3)
# [Epoch 256] train=3.411 | eval=3.360 | score=3.360 (eval_every~3)
# [Epoch 257] train=3.389 | eval=skipped (eval_every~3)
# [Epoch 258] train=3.410 | eval=skipped (eval_every~3)
# [Epoch 259] train=3.377 | eval=3.343 | score=3.343 (eval_every~3)
#   + saved (score=3.343)
# [Epoch 260] train=3.398 | eval=skipped (eval_every~3)
# [Epoch 261] train=3.393 | eval=skipped (eval_every~3)
# [Epoch 262] train=3.402 | eval=3.344 | score=3.344 (eval_every~3)
# [Epoch 263] train=3.393 | eval=skipped (eval_every~3)
# [Epoch 264] train=3.379 | eval=skipped (eval_every~3)
# [Epoch 265] train=3.388 | eval=3.343 | score=3.343 (eval_every~3)
#   + saved (score=3.343)
# [Epoch 266] train=3.371 | eval=skipped (eval_every~2)
# [Epoch 267] train=3.397 | eval=skipped (eval_every~2)
# [Epoch 268] train=3.387 | eval=3.336 | score=3.336 (eval_every~2)
#   + saved (score=3.336)
# [Epoch 269] train=3.403 | eval=skipped (eval_every~2)
# [Epoch 270] train=3.389 | eval=3.342 | score=3.342 (eval_every~2)
# [Epoch 271] train=3.368 | eval=skipped (eval_every~2)
# [Epoch 272] train=3.379 | eval=3.340 | score=3.340 (eval_every~2)
# [Epoch 273] train=3.404 | eval=skipped (eval_every~2)
# [Epoch 274] train=3.374 | eval=3.341 | score=3.341 (eval_every~2)
# [Epoch 275] train=3.366 | eval=skipped (eval_every~2)
# [Epoch 276] train=3.382 | eval=3.331 | score=3.331 (eval_every~2)
#   + saved (score=3.331)
# [Epoch 277] train=3.388 | eval=skipped (eval_every~2)
# [Epoch 278] train=3.362 | eval=3.327 | score=3.327 (eval_every~2)
#   + saved (score=3.327)
# [Epoch 279] train=3.370 | eval=skipped (eval_every~2)
# [Epoch 280] train=3.369 | eval=3.323 | score=3.323 (eval_every~2)
#   + saved (score=3.323)
# [Epoch 281] train=3.372 | eval=skipped (eval_every~2)
# [Epoch 282] train=3.358 | eval=3.331 | score=3.331 (eval_every~2)
# [Epoch 283] train=3.377 | eval=skipped (eval_every~2)
# [Epoch 284] train=3.384 | eval=3.330 | score=3.330 (eval_every~2)
# [Epoch 285] train=3.358 | eval=skipped (eval_every~2)
# [Epoch 286] train=3.349 | eval=3.329 | score=3.329 (eval_every~2)
# [Epoch 287] train=3.359 | eval=skipped (eval_every~2)
# [Epoch 288] train=3.361 | eval=3.326 | score=3.326 (eval_every~1)
# [Epoch 289] train=3.344 | eval=3.324 | score=3.324 (eval_every~1)
# [Epoch 290] train=3.353 | eval=3.329 | score=3.329 (eval_every~1)
# [Epoch 291] train=3.357 | eval=3.323 | score=3.323 (eval_every~1)
# [Epoch 292] train=3.370 | eval=3.325 | score=3.325 (eval_every~1)
# [Epoch 293] train=3.381 | eval=3.319 | score=3.319 (eval_every~1)
#   + saved (score=3.319)
# [Epoch 294] train=3.363 | eval=3.331 | score=3.331 (eval_every~1)
# [Epoch 295] train=3.365 | eval=3.322 | score=3.322 (eval_every~1)
# [Epoch 296] train=3.351 | eval=3.316 | score=3.316 (eval_every~1)
#   + saved (score=3.316)
# [Epoch 297] train=3.354 | eval=3.326 | score=3.326 (eval_every~1)
# [Epoch 298] train=3.361 | eval=3.316 | score=3.316 (eval_every~1)
# [Epoch 299] train=3.356 | eval=3.320 | score=3.320 (eval_every~1)

# %% [markdown]
# ## Plot

# %%
train_loss_arr = np.array(train_epoch_losses)
eval_loss_arr = np.array(eval_epoch_losses)
score_arr = np.array(scores)
best_epoch = best_checkpoint["epoch"]

epochs = np.arange(len(train_loss_arr))

# best epoch based on score

best_score = score_arr[best_epoch]
best_eval_loss = eval_loss_arr[best_epoch]

plt.figure(figsize=(8, 5))

# Main curves
plt.plot(epochs, train_loss_arr, linewidth=2, label="train loss")
plt.plot(epochs, eval_loss_arr, linewidth=2, label="eval loss")
plt.plot(epochs, score_arr, linewidth=2, linestyle="--", label="score")

ymin, ymax = plt.ylim()
yrange = ymax - ymin

xmin, xmax = plt.xlim()
xrange = xmax - xmin

y_offset = 0.5 * yrange
x_offset = -0.05 * xrange

# Annotation of best score
plt.annotate(
    f"min score = {best_score:.3f}\nepoch = {best_epoch}",
    xy=(best_epoch, best_score),
    xytext=(best_epoch + x_offset, best_score + y_offset),
    textcoords="data",
    arrowprops={"arrowstyle": "->", "linewidth": 1},
    fontsize=9,
    bbox={"boxstyle": "round,pad=0.3", "fc": "white", "alpha": 0.8},
)

plt.xlabel("Epoch")
plt.ylabel("Loss / Score")
plt.title(f"{perform_name} PF network training")

plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save figure
fig_path = PERFORM_DIR / "net_training_loss.png"
plt.savefig(fig_path, dpi=300)

# Save raw arrays
np.save(PERFORM_DIR / "net_training.npy", train_loss_arr)
np.save(PERFORM_DIR / "net_eval.npy", eval_loss_arr)
np.save(PERFORM_DIR / "net_score.npy", score_arr)
np.save(PERFORM_DIR / "net_bestepoch.npy", best_epoch)

plt.show()

print(f"✓ Plot saved to {fig_path}")
print(f"✓ Best epoch: {best_epoch} (score={best_score:.4f})")
# Out:
# ✓ Plot saved to /lustre/diazgonz/deep-performance-rul/experiments/DS03/opcond_q0.001-0.999_corr0.6_range0.6/estimation_thr0.2/gamma/net_arg5/SmLPC/net_training_loss.png
# ✓ Best epoch: 292 (score=3.4954)
