# %% [markdown]
# ## Train the PF-Controller Neural Network
#
# For each performance metric, train the corresponding particle-filter (PF) controller neural network.

# %%
import numpy as np
import pandas as pd
import torch
from matplotlib import pyplot as plt
import torch.nn as nn
from src.models.particle_filter.core import ParticleFilter
from src.models.networks.pf_mlp import ParticleFilterMLP
from src.helpers.seed import set_global_seed

from experiment_config import (
    DegModel,DATA_NAME,SEED,LEAKY_SLOPE,HIDDEN_DIMS,PREDICTION_START_IDX,LOSS_TAIL_SIZE,N_PARTICLES,GRADIENT_CLIP,WEIGHT_DECAY,PFNET_DIR,DEGR_MODEL_DIR,ESTIMATION_DIR,LOSS_WINDOW,AVERSION,CURRENT_OBS
)
    
DATA_NAME
# Out:
# 'DS05'

# %% [markdown]
# ## Task

# %%
perform_name = 'SmHPC'

# %% [markdown]
# ## Hyper-Parameters

# %%
# Training parameters#
# optimization
lr = 5e-4

# Early stopping
max_epochs = 300
min_epochs = 100
patience = 40     # how many eval steps to wait
min_delta = 0.01      # minimum improvement to count

# %%
activation = nn.LeakyReLU(LEAKY_SLOPE)

set_global_seed(SEED)
PERFORM_DIR = PFNET_DIR/perform_name

checkpoint_best_path = PERFORM_DIR / "checkpoint_best.pt"
checkpoint_last_path = PERFORM_DIR / "checkpoint_last.pt"
checkpoint_best_path.parent.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Import training data

# %%
hi_df = pd.read_csv(ESTIMATION_DIR/"data_dev.csv")
units = hi_df['unit'].astype(int).unique().tolist()
units
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Extract degradation onset

# %%
onsets = {unit: hi_df[(hi_df['unit']==unit) & (hi_df['hs']==0)]['cycle'].values[0] for unit in units}
del hi_df['hs']

# %%
perform_names = [col for col in hi_df.columns if col not in ['unit','cycle']]

performs = {name: 
    {unit: hi_df[hi_df['unit']==unit][name].values for unit in units} 
    for name in perform_names
}

init_ss = {name: {unit: perform[unit].max() for unit in units} for name,perform in performs.items()}
time = {unit: hi_df[hi_df['unit']==unit]['cycle'].values for unit in units}

# %% [markdown]
# ## Create component (base) models

# %%
dev_data = {}
dev_eol = {}
for unit in units:
    t = time[unit]
    s = performs[perform_name][unit]
    dev_data[unit]=torch.tensor(np.stack([t, s],axis=1),dtype=torch.float32)
    dev_eol[unit]=torch.tensor(t[-1],dtype=torch.float32)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 5
#       3 for unit in units:
#       4     t = time[unit]
# ----> 5     s = performs[perform_name][unit]
#       6     dev_data[unit]=torch.tensor(np.stack([t, s],axis=1),dtype=torch.float32)
#       7     dev_eol[unit]=torch.tensor(t[-1],dtype=torch.float32)
#
# KeyError: 'SmHPC'

# %%
dev_degmodels = {}
for unit, perform in performs[perform_name].items():
	best_model = DegModel(onset=onsets[unit], init_s=init_ss[perform_name][unit])
	best_model.load_state_dict(
		torch.load(DEGR_MODEL_DIR/'states'/perform_name/f'unit_{unit}'/ "best_model.pt")
	)
	dev_degmodels[unit] = best_model

# %% [markdown]
# ## Train Particle Filter controller Net

# %%
net = ParticleFilterMLP(state_dim=DegModel.state_dim(), hidden_dims=HIDDEN_DIMS,
                        activation=lambda : nn.LeakyReLU(LEAKY_SLOPE))

optimizer = torch.optim.Adam(net.parameters(), lr, weight_decay=WEIGHT_DECAY)
optimizer.zero_grad()

# %%
best_score = float("inf")
train_epoch_losses = []
eval_epoch_losses = []
scores = []
window_means = []
window_stds = []
wait = 0
start_epoch = 0

if checkpoint_last_path.exists():
    ckpt = torch.load(checkpoint_last_path, weights_only=False)

    net.load_state_dict(ckpt["model_state"])
    optimizer.load_state_dict(ckpt["optimizer_state"])

    start_epoch = ckpt["epoch"] + 1
    best_score = ckpt["best_score"]
    scores = ckpt.get("scores", [])
    train_epoch_losses = ckpt.get("train_losses", [])
    eval_epoch_losses = ckpt.get("eval_losses", [])
    window_means = ckpt.get("window_means", [])
    window_stds = ckpt.get("window_stds", [])

    torch.random.set_rng_state(ckpt["rng_torch"])
    np.random.set_state(ckpt["rng_numpy"])

    print(f"✓ Resumed from epoch {start_epoch}, best_score={best_score:.3f}")

# %%
for epoch in range(start_epoch, max_epochs):

    eval_fold_losses = []
    train_fold_losses = []

    for eval_unit in np.random.permutation(units):
        train_unit_losses = []

        # --------------------------
        # TRAINING
        # --------------------------
        for train_unit in np.random.permutation(units):

            if train_unit == eval_unit:
                continue

            train_offline_units = [
                u for u in units if u not in (train_unit, eval_unit)
            ]

            train_offline_degmodels = [
                dev_degmodels[u] for u in train_offline_units
            ]

            train_t_data = dev_data[train_unit][:, 0]
            train_s_data = dev_data[train_unit][:, 1]

            optimizer.zero_grad()

            train_pf = ParticleFilter(
                base_models=train_offline_degmodels,
                net=net,
                n_particles=N_PARTICLES,
            ).train()
            
            train_step_losses = []
            for k in range(PREDICTION_START_IDX, len(train_t_data)):
                start_obs = k if CURRENT_OBS else 0
                train_mixture_dist = train_pf.step(
                    t_obs=train_t_data[start_obs:k + 1],
                    s_obs=train_s_data[start_obs:k + 1],
                )

                start_loss = -LOSS_TAIL_SIZE if LOSS_TAIL_SIZE else k
                train_last_dist = train_mixture_dist.distribution(
                    s=train_s_data[start_loss:]
                )
                train_step_nll = -train_last_dist.log_prob(
                    train_t_data[start_loss:]
                ).mean()

                train_step_losses.append(train_step_nll)

            train_unit_loss = (1-train_s_data[-1])*torch.stack(train_step_losses).mean()

            train_unit_loss.backward()

            if GRADIENT_CLIP is not None:
                torch.nn.utils.clip_grad_norm_(
                    net.parameters(), GRADIENT_CLIP
                )

            optimizer.step()

            train_unit_losses.append(train_unit_loss.item())

        train_fold_loss = np.mean(train_unit_losses)
        train_fold_losses.append(train_fold_loss)

        # --------------------------
        # EVALUATION
        # --------------------------

        eval_offline_units = [u for u in units if u != eval_unit]

        eval_offline_degmodels = [
            dev_degmodels[u] for u in eval_offline_units
        ]

        eval_t_data = dev_data[eval_unit][:, 0]
        eval_s_data = dev_data[eval_unit][:, 1]

        eval_pf = ParticleFilter(
            base_models=eval_offline_degmodels,
            net=net,
            n_particles=N_PARTICLES,
        ).eval()

        eval_step_losses = []
        for k in range(PREDICTION_START_IDX, len(eval_t_data)):

            start_obs = k if CURRENT_OBS else 0
            eval_mixture_dist = eval_pf.step(
                t_obs=eval_t_data[start_obs:k + 1],
                s_obs=eval_s_data[start_obs:k + 1],
            )

            start_loss = -LOSS_TAIL_SIZE if LOSS_TAIL_SIZE else k

            eval_last_dist = eval_mixture_dist.distribution(
                s=eval_s_data[start_loss:]
            )

            eval_step_nll = -eval_last_dist.log_prob(
                eval_t_data[start_loss:]
            ).mean()

            eval_step_losses.append(eval_step_nll.item())

        eval_fold_loss = (1-eval_s_data[-1])*np.mean(eval_step_losses)
        eval_fold_losses.append(eval_fold_loss)

    # --------------------------
    # epoch statistics
    # --------------------------

    train_epoch_loss = np.mean(train_fold_losses)
    eval_epoch_loss = np.mean(eval_fold_losses)

    train_epoch_losses.append(train_epoch_loss)
    eval_epoch_losses.append(eval_epoch_loss)



    # --------------------------
    # Score computation
    # --------------------------
    window = eval_epoch_losses[-LOSS_WINDOW:]

    mean_loss = np.mean(window)
    range_loss = np.max(window) - np.min(window)

    score = mean_loss + AVERSION * range_loss
    scores.append(score)
    
    print(
        f"[Epoch {epoch:04d}] "
        f"train={train_epoch_loss:.3f} | "
        f"eval={eval_epoch_loss:.3f} | "
        f"score={score:.3f} "
    )


    # --------------------------
    # CHECKPOINT SELECTION
    # --------------------------

    if (epoch + 1 >= LOSS_WINDOW): 
        if (score < best_score - min_delta):

            best_score = score
            wait = 0

            best_checkpoint = {
                "epoch": epoch,
                "model_state": net.state_dict(),
                "best_score": best_score,
            }

            torch.save(best_checkpoint, checkpoint_best_path)

            last_checkpoint = {
                "epoch": epoch,
                "model_state": net.state_dict(),
                "optimizer_state": optimizer.state_dict(),
                "best_score": best_score,
                "scores": scores,
                "train_losses": train_epoch_losses,
                "eval_losses": eval_epoch_losses,
                "window_means": window_means,
                "window_stds": window_stds,
                "rng_torch": torch.random.get_rng_state(),
                "rng_numpy": np.random.get_state(),
            }

            torch.save(last_checkpoint, checkpoint_last_path)

            print(f"  + saved (score={score:.3f})")
        else:
            wait += 1

            if epoch >= max(min_epochs, LOSS_WINDOW) and wait >= patience:
                print("🛑 Early stopping triggered")
                break
# Out:
# [Epoch 0000] train=13.222 | eval=19.589 | score=19.589
# [Epoch 0001] train=7.407 | eval=12.952 | score=19.589
# [Epoch 0002] train=4.013 | eval=3.697 | score=20.025
# [Epoch 0003] train=3.717 | eval=3.707 | score=17.932
# [Epoch 0004] train=3.698 | eval=3.676 | score=16.680
# [Epoch 0005] train=3.671 | eval=3.649 | score=15.848
# [Epoch 0006] train=3.648 | eval=3.652 | score=15.244
# [Epoch 0007] train=3.638 | eval=3.620 | score=14.802
# [Epoch 0008] train=3.630 | eval=3.639 | score=14.449
# [Epoch 0009] train=3.607 | eval=3.557 | score=14.189
#   + saved (score=14.189)
# [Epoch 0010] train=3.601 | eval=3.594 | score=9.272
#   + saved (score=9.272)
# [Epoch 0011] train=3.607 | eval=3.610 | score=3.715
#   + saved (score=3.715)
# [Epoch 0012] train=3.588 | eval=3.658 | score=3.711
# [Epoch 0013] train=3.584 | eval=3.570 | score=3.682
#   + saved (score=3.682)
# [Epoch 0014] train=3.572 | eval=3.601 | score=3.665
#   + saved (score=3.665)
# [Epoch 0015] train=3.572 | eval=3.581 | score=3.659
# [Epoch 0016] train=3.549 | eval=3.534 | score=3.658
# [Epoch 0017] train=3.536 | eval=3.538 | score=3.650
#   + saved (score=3.650)
# [Epoch 0018] train=3.512 | eval=3.515 | score=3.648
# [Epoch 0019] train=3.496 | eval=3.536 | score=3.645
# [Epoch 0020] train=3.475 | eval=3.488 | score=3.648
# [Epoch 0021] train=3.462 | eval=3.487 | score=3.636
#   + saved (score=3.636)
# [Epoch 0022] train=3.460 | eval=3.481 | score=3.593
#   + saved (score=3.593)
# [Epoch 0023] train=3.456 | eval=3.464 | score=3.591
# [Epoch 0024] train=3.440 | eval=3.486 | score=3.569
#   + saved (score=3.569)
# [Epoch 0025] train=3.430 | eval=3.462 | score=3.537
#   + saved (score=3.537)
# [Epoch 0026] train=3.438 | eval=3.428 | score=3.543
# [Epoch 0027] train=3.443 | eval=3.445 | score=3.533
# [Epoch 0028] train=3.412 | eval=3.431 | score=3.525
#   + saved (score=3.525)
# [Epoch 0029] train=3.407 | eval=3.384 | score=3.508
#   + saved (score=3.508)
# [Epoch 0030] train=3.430 | eval=3.447 | score=3.503
# [Epoch 0031] train=3.411 | eval=3.400 | score=3.494
#   + saved (score=3.494)
# [Epoch 0032] train=3.407 | eval=3.424 | score=3.488
# [Epoch 0033] train=3.389 | eval=3.391 | score=3.481
#   + saved (score=3.481)
# [Epoch 0034] train=3.377 | eval=3.403 | score=3.461
#   + saved (score=3.461)
# [Epoch 0035] train=3.381 | eval=3.429 | score=3.450
#   + saved (score=3.450)
# [Epoch 0036] train=3.362 | eval=3.353 | score=3.458
# [Epoch 0037] train=3.371 | eval=3.359 | score=3.449
# [Epoch 0038] train=3.365 | eval=3.406 | score=3.447
# [Epoch 0039] train=3.376 | eval=3.525 | score=3.500
# [Epoch 0040] train=3.373 | eval=3.385 | score=3.493
# [Epoch 0041] train=3.346 | eval=3.341 | score=3.494
# [Epoch 0042] train=3.337 | eval=3.330 | score=3.489
# [Epoch 0043] train=3.346 | eval=3.358 | score=3.486
# [Epoch 0044] train=3.339 | eval=3.331 | score=3.479
# [Epoch 0045] train=3.328 | eval=3.338 | score=3.470
# [Epoch 0046] train=3.327 | eval=3.342 | score=3.469
# [Epoch 0047] train=3.310 | eval=3.308 | score=3.475
# [Epoch 0048] train=3.287 | eval=3.301 | score=3.468
# [Epoch 0049] train=3.282 | eval=3.275 | score=3.386
#   + saved (score=3.386)
# [Epoch 0050] train=3.275 | eval=3.262 | score=3.367
#   + saved (score=3.367)
# [Epoch 0051] train=3.348 | eval=3.368 | score=3.375
# [Epoch 0052] train=3.342 | eval=3.414 | score=3.406
# [Epoch 0053] train=3.353 | eval=3.318 | score=3.402
# [Epoch 0054] train=3.283 | eval=3.302 | score=3.399
# [Epoch 0055] train=3.252 | eval=3.342 | score=3.399
# [Epoch 0056] train=3.266 | eval=3.261 | score=3.391
# [Epoch 0057] train=3.255 | eval=3.283 | score=3.389
# [Epoch 0058] train=3.303 | eval=3.294 | score=3.388
# [Epoch 0059] train=3.303 | eval=3.235 | score=3.397
# [Epoch 0060] train=3.292 | eval=3.259 | score=3.397
# [Epoch 0061] train=3.259 | eval=3.287 | score=3.389
# [Epoch 0062] train=3.265 | eval=3.250 | score=3.336
#   + saved (score=3.336)
# [Epoch 0063] train=3.250 | eval=3.238 | score=3.328
# [Epoch 0064] train=3.268 | eval=3.247 | score=3.323
#   + saved (score=3.323)
# [Epoch 0065] train=3.249 | eval=3.234 | score=3.289
#   + saved (score=3.289)
# [Epoch 0066] train=3.280 | eval=3.312 | score=3.303
# [Epoch 0067] train=3.298 | eval=3.212 | score=3.307
# [Epoch 0068] train=3.253 | eval=3.225 | score=3.300
# [Epoch 0069] train=3.256 | eval=3.247 | score=3.301
# [Epoch 0070] train=3.265 | eval=3.288 | score=3.304
# [Epoch 0071] train=3.288 | eval=3.356 | score=3.333
# [Epoch 0072] train=3.311 | eval=3.259 | score=3.334
# [Epoch 0073] train=3.310 | eval=3.257 | score=3.336
# [Epoch 0074] train=3.248 | eval=3.247 | score=3.335
# [Epoch 0075] train=3.256 | eval=3.214 | score=3.333
# [Epoch 0076] train=3.271 | eval=3.249 | score=3.327
# [Epoch 0077] train=3.254 | eval=3.330 | score=3.338
# [Epoch 0078] train=3.266 | eval=3.285 | score=3.344
# [Epoch 0079] train=3.254 | eval=3.244 | score=3.343
# [Epoch 0080] train=3.249 | eval=3.268 | score=3.341
# [Epoch 0081] train=3.247 | eval=3.235 | score=3.316
# [Epoch 0082] train=3.249 | eval=3.289 | score=3.319
# [Epoch 0083] train=3.214 | eval=3.218 | score=3.315
# [Epoch 0084] train=3.241 | eval=3.318 | score=3.323
# [Epoch 0085] train=3.264 | eval=3.258 | score=3.325
# [Epoch 0086] train=3.262 | eval=3.360 | score=3.351
# [Epoch 0087] train=3.274 | eval=3.318 | score=3.350
# [Epoch 0088] train=3.233 | eval=3.316 | score=3.353
# [Epoch 0089] train=3.244 | eval=3.235 | score=3.352
# [Epoch 0090] train=3.282 | eval=3.259 | score=3.351
# [Epoch 0091] train=3.252 | eval=3.255 | score=3.353
# [Epoch 0092] train=3.251 | eval=3.242 | score=3.349
# [Epoch 0093] train=3.255 | eval=3.267 | score=3.345
# [Epoch 0094] train=3.248 | eval=3.282 | score=3.342
# [Epoch 0095] train=3.235 | eval=3.256 | score=3.342
# [Epoch 0096] train=3.255 | eval=3.247 | score=3.309
# [Epoch 0097] train=3.263 | eval=3.253 | score=3.302
# [Epoch 0098] train=3.257 | eval=3.240 | score=3.277
#   + saved (score=3.277)
# [Epoch 0099] train=3.255 | eval=3.258 | score=3.277
# [Epoch 0100] train=3.257 | eval=3.225 | score=3.281
# [Epoch 0101] train=3.237 | eval=3.233 | score=3.279
# [Epoch 0102] train=3.240 | eval=3.298 | score=3.293
# [Epoch 0103] train=3.239 | eval=3.235 | score=3.289
# [Epoch 0104] train=3.234 | eval=3.224 | score=3.284
# [Epoch 0105] train=3.230 | eval=3.227 | score=3.281
# [Epoch 0106] train=3.279 | eval=3.251 | score=3.282
# [Epoch 0107] train=3.229 | eval=3.192 | score=3.292
# [Epoch 0108] train=3.256 | eval=3.203 | score=3.288
# [Epoch 0109] train=3.235 | eval=3.253 | score=3.288
# [Epoch 0110] train=3.232 | eval=3.194 | score=3.284
# [Epoch 0111] train=3.219 | eval=3.217 | score=3.283
# [Epoch 0112] train=3.250 | eval=3.226 | score=3.253
#   + saved (score=3.253)
# [Epoch 0113] train=3.219 | eval=3.229 | score=3.252
# [Epoch 0114] train=3.218 | eval=3.257 | score=3.258
# [Epoch 0115] train=3.256 | eval=3.285 | score=3.277
# [Epoch 0116] train=3.219 | eval=3.259 | score=3.278
# [Epoch 0117] train=3.223 | eval=3.244 | score=3.282
# [Epoch 0118] train=3.210 | eval=3.197 | score=3.281
# [Epoch 0119] train=3.211 | eval=3.211 | score=3.277
# [Epoch 0120] train=3.217 | eval=3.195 | score=3.277
# [Epoch 0121] train=3.234 | eval=3.211 | score=3.276
# [Epoch 0122] train=3.217 | eval=3.214 | score=3.275
# [Epoch 0123] train=3.230 | eval=3.284 | score=3.281
# [Epoch 0124] train=3.238 | eval=3.250 | score=3.280
# [Epoch 0125] train=3.235 | eval=3.239 | score=3.275
# [Epoch 0126] train=3.236 | eval=3.216 | score=3.271
# [Epoch 0127] train=3.261 | eval=3.190 | score=3.268
# [Epoch 0128] train=3.268 | eval=3.336 | score=3.307
# [Epoch 0129] train=3.246 | eval=3.245 | score=3.311
# [Epoch 0130] train=3.236 | eval=3.240 | score=3.315
# [Epoch 0131] train=3.217 | eval=3.187 | score=3.315
# [Epoch 0132] train=3.218 | eval=3.219 | score=3.315
# [Epoch 0133] train=3.229 | eval=3.180 | score=3.308
# [Epoch 0134] train=3.215 | eval=3.207 | score=3.304
# [Epoch 0135] train=3.203 | eval=3.252 | score=3.305
# [Epoch 0136] train=3.235 | eval=3.213 | score=3.305
# [Epoch 0137] train=3.221 | eval=3.215 | score=3.307
# [Epoch 0138] train=3.230 | eval=3.229 | score=3.255
# [Epoch 0139] train=3.254 | eval=3.220 | score=3.252
# [Epoch 0140] train=3.218 | eval=3.188 | score=3.247
# [Epoch 0141] train=3.206 | eval=3.206 | score=3.249
# [Epoch 0142] train=3.228 | eval=3.231 | score=3.250
# [Epoch 0143] train=3.197 | eval=3.194 | score=3.248
# [Epoch 0144] train=3.295 | eval=3.403 | score=3.343
# [Epoch 0145] train=3.233 | eval=3.265 | score=3.344
# [Epoch 0146] train=3.212 | eval=3.284 | score=3.351
# [Epoch 0147] train=3.212 | eval=3.199 | score=3.349
# [Epoch 0148] train=3.202 | eval=3.202 | score=3.347
# [Epoch 0149] train=3.201 | eval=3.255 | score=3.350
# [Epoch 0150] train=3.290 | eval=3.256 | score=3.354
# [Epoch 0151] train=3.256 | eval=3.275 | score=3.361
# [Epoch 0152] train=3.225 | eval=3.321 | score=3.370
# 🛑 Early stopping triggered

# %% [markdown]
# # Save last results

# %%
if start_epoch < max_epochs:
    last_checkpoint = {
        "epoch": epoch,
        "model_state": net.state_dict(),
        "optimizer_state": optimizer.state_dict(),
        "best_score": best_score,
        "scores": scores,
        "train_losses": train_epoch_losses,
        "eval_losses": eval_epoch_losses,
        "window_means": window_means,
        "window_stds": window_stds,
        "rng_torch": torch.random.get_rng_state(),
        "rng_numpy": np.random.get_state(),
    }

    torch.save(last_checkpoint, checkpoint_last_path)

    print("✓ Final LAST checkpoint saved.")

else:
    epoch = start_epoch
# Out:
# ✓ Final LAST checkpoint saved.

# %% [markdown]
# ## Plot

# %%
train_loss_arr = np.array(train_epoch_losses)
eval_loss_arr = np.array(eval_epoch_losses)
score_arr = np.array(scores)
best_epoch = best_checkpoint['epoch']

epochs = np.arange(len(train_loss_arr))

# best epoch based on score

best_score = score_arr[best_epoch]
best_eval_loss = eval_loss_arr[best_epoch]

plt.figure(figsize=(8, 5))

# Main curves
plt.plot(epochs, train_loss_arr, linewidth=2, label="train loss")
plt.plot(epochs, eval_loss_arr, linewidth=2, label="eval loss")
plt.plot(epochs, score_arr, linewidth=2, linestyle="--", label="score")

ymin, ymax = plt.ylim()
yrange = ymax - ymin

xmin, xmax = plt.xlim()
xrange = xmax - xmin

y_offset = 0.5 * yrange
x_offset = -0.05 * xrange

# Annotation of best score
plt.annotate(
    f"min score = {best_score:.3f}\nepoch = {best_epoch}",
    xy=(best_epoch, best_score),
    xytext=(best_epoch + x_offset, best_score + y_offset),
    textcoords="data",
    arrowprops=dict(arrowstyle="->", linewidth=1),
    fontsize=9,
    bbox=dict(boxstyle="round,pad=0.3", fc="white", alpha=0.8),
)

plt.xlabel("Epoch")
plt.ylabel("Loss / Score")
plt.title(f"{perform_name} PF network training")

plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save figure
fig_path = PERFORM_DIR / "net_training_loss.png"
plt.savefig(fig_path, dpi=300)

# Save raw arrays
np.save(PERFORM_DIR / "net_training.npy", train_loss_arr)
np.save(PERFORM_DIR / "net_eval.npy", eval_loss_arr)
np.save(PERFORM_DIR / "net_score.npy", score_arr)
np.save(PERFORM_DIR / "net_bestepoch.npy", best_epoch)

plt.show()

print(f"✓ Plot saved to {fig_path}")
print(f"✓ Best epoch: {best_epoch} (score={best_score:.4f})")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 train_loss_arr = np.array(train_epoch_losses)
#       2 eval_loss_arr = np.array(eval_epoch_losses)
#       3 score_arr = np.array(scores)
#
# NameError: name 'np' is not defined
