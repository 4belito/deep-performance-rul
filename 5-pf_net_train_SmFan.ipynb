# %% [markdown]
# ## Train the PF-Controller Neural Network
#
# For each performance metric, train the corresponding particle-filter (PF) controller neural network.

# %%
import numpy as np
import pandas as pd
import torch
from matplotlib import pyplot as plt

from experiment_config import (
    SEED,
    DegModel,
    dataset_paths,
)
from src.helpers.seed import set_global_seed
from src.models.networks.pf_mlp import ParticleFilterMLP
from src.training.pfnet_hparams import PFNET_ARGS
from src.training.pfnet_training import train_pf_controller_cv

# %% [markdown]
# ## Task

# %%
DATA_NAME = "DS05"
perform_name = "SmFan"
ARGS_ID = 5

# %% [markdown]
# ## Hyper-Parameters

# %%
args = PFNET_ARGS[ARGS_ID]

net_args = args["NETWORK"]

if net_args is None:
    raise SystemExit(
        "This ARGS_ID is a no-network baseline (NETWORK=None): there is no "
        "network to train. Use it only in the test/ablation notebooks."
    )
pf_args = args["PARTICLE_FILTER"]
train_args = args["TRAINING"]
eval_args = args["EVALUATION"]

# %%
set_global_seed(SEED)

ESTIMATION_DIR, DEGR_MODEL_DIR = dataset_paths(
    DATA_NAME, fields=["estimation", "degr_model"]
)

PFNET_ARGS_DIR = DEGR_MODEL_DIR / f"net_arg{ARGS_ID}"
PERFORM_DIR = PFNET_ARGS_DIR / perform_name

checkpoint_best_path = PERFORM_DIR / "checkpoint_best.pt"
checkpoint_last_path = PERFORM_DIR / "checkpoint_last.pt"
checkpoint_best_path.parent.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Import training data

# %%
hi_df = pd.read_csv(ESTIMATION_DIR / "data_dev.csv")
units = hi_df["unit"].astype(int).unique().tolist()
units
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Extract degradation onset

# %%
onsets = {
    unit: hi_df[(hi_df["unit"] == unit) & (hi_df["hs"] == 0)]["cycle"].values[0]
    for unit in units
}
del hi_df["hs"]

# %%
perform_names = [col for col in hi_df.columns if col not in ["unit", "cycle"]]

performs = {
    name: {unit: hi_df[hi_df["unit"] == unit][name].values for unit in units}
    for name in perform_names
}

init_ss = {
    name: {unit: perform[unit].max() for unit in units}
    for name, perform in performs.items()
}
time = {unit: hi_df[hi_df["unit"] == unit]["cycle"].values for unit in units}

# %% [markdown]
# ## Create component (base) models

# %%
dev_data = {}
dev_eol = {}
for unit in units:
    t = time[unit]
    s = performs[perform_name][unit]
    dev_data[unit] = torch.tensor(np.stack([t, s], axis=1), dtype=torch.float32)
    dev_eol[unit] = torch.tensor(t[-1], dtype=torch.float32)

# %%
dev_degmodels = {}
for unit in performs[perform_name]:
    best_model = DegModel(onset=onsets[unit], init_s=init_ss[perform_name][unit])
    best_model.load_state_dict(
        torch.load(
            DEGR_MODEL_DIR / "states" / perform_name / f"unit_{unit}" / "best_model.pt"
        )
    )
    dev_degmodels[unit] = best_model

# %% [markdown]
# ## Train Particle Filter controller Net

# %%
from src.models.networks.pf_mlp import build_activation

net = ParticleFilterMLP(
    state_dim=DegModel.state_dim(),
    hidden_dims=list(net_args["HIDDEN_DIMS"]),
    activation=build_activation(net_args),
    dropout_p=float(net_args["DROPOUT"]),
)

optimizer = torch.optim.Adam(net.parameters(), float(train_args["LR"]))
optimizer.zero_grad()

# %%
best_score = float("inf")
train_epoch_losses = []
eval_epoch_losses = []
scores = []
start_epoch = 0

if checkpoint_last_path.exists():
    ckpt = torch.load(checkpoint_last_path, weights_only=False)

    net.load_state_dict(ckpt["model_state"])
    optimizer.load_state_dict(ckpt["optimizer_state"])

    start_epoch = ckpt["epoch"] + 1
    best_score = ckpt["best_score"]
    scores = ckpt.get("scores", [])
    train_epoch_losses = ckpt.get("train_losses", [])
    eval_epoch_losses = ckpt.get("eval_losses", [])

    torch.random.set_rng_state(ckpt["rng_torch"])
    np.random.set_state(ckpt["rng_numpy"])

    print(f"✓ Resumed from epoch {start_epoch}, best_score={best_score:.3f}")
# Out:
# ✓ Resumed from epoch 159, best_score=3.685

# %%
train_state = train_pf_controller_cv(
    net=net,
    optimizer=optimizer,
    units=units,
    dev_data=dev_data,
    dev_degmodels=dev_degmodels,
    n_particles=int(pf_args["N_PARTICLES"]),
    max_life=int(pf_args["MAX_LIFE"]),
    loss_tail_steps=int(train_args["LOSS_TAIL_STEPS"]),
    n_epochs=int(train_args["N_EPOCHS"]),
    checkpoint_best_path=checkpoint_best_path,
    checkpoint_last_path=checkpoint_last_path,
    start_epoch=start_epoch,
    best_score=best_score,
    scores=scores,
    train_epoch_losses=train_epoch_losses,
    eval_epoch_losses=eval_epoch_losses,
    seed=SEED,
    eval_repetitions=int(eval_args["REPETITIONS"]),
    eval_seed_stride=int(eval_args["SEED_STRIDE"]),
    eval_initial_interval_epochs=int(eval_args["INITIAL_INTERVAL_EPOCHS"]),
    eval_final_interval_epochs=int(eval_args["FINAL_INTERVAL_EPOCHS"]),
    match_train_eval_prior=bool(train_args.get("MATCH_TRAIN_EVAL_PRIOR", False)),
    verbose=True,
)

best_score = train_state["best_score"]
scores = train_state["scores"]
train_epoch_losses = train_state["train_epoch_losses"]
eval_epoch_losses = train_state["eval_epoch_losses"]
epoch = train_state["epoch"]
best_checkpoint = train_state["best_checkpoint"]

if best_checkpoint is None and checkpoint_best_path.exists():
    best_checkpoint = torch.load(checkpoint_best_path, weights_only=False)
# Out:
# [Epoch 159] train=3.757 | eval=3.678 | score=3.678 (eval_every~12)
#   + saved (score=3.678)
# [Epoch 160] train=3.731 | eval=skipped (eval_every~12)
# [Epoch 161] train=3.741 | eval=skipped (eval_every~12)
# [Epoch 162] train=3.747 | eval=skipped (eval_every~12)
# [Epoch 163] train=3.729 | eval=skipped (eval_every~12)
# [Epoch 164] train=3.730 | eval=skipped (eval_every~12)
# [Epoch 165] train=3.756 | eval=skipped (eval_every~12)
# [Epoch 166] train=3.732 | eval=skipped (eval_every~11)
# [Epoch 167] train=3.756 | eval=skipped (eval_every~11)
# [Epoch 168] train=3.724 | eval=skipped (eval_every~11)
# [Epoch 169] train=3.725 | eval=skipped (eval_every~11)
# [Epoch 170] train=3.718 | eval=skipped (eval_every~11)
# [Epoch 171] train=3.737 | eval=3.647 | score=3.647 (eval_every~11)
#   + saved (score=3.647)
# [Epoch 172] train=3.720 | eval=skipped (eval_every~11)
# [Epoch 173] train=3.715 | eval=skipped (eval_every~11)
# [Epoch 174] train=3.716 | eval=skipped (eval_every~11)
# [Epoch 175] train=3.732 | eval=skipped (eval_every~11)
# [Epoch 176] train=3.739 | eval=skipped (eval_every~11)
# [Epoch 177] train=3.721 | eval=skipped (eval_every~11)
# [Epoch 178] train=3.734 | eval=skipped (eval_every~11)
# [Epoch 179] train=3.719 | eval=skipped (eval_every~10)
# [Epoch 180] train=3.726 | eval=skipped (eval_every~10)
# [Epoch 181] train=3.719 | eval=skipped (eval_every~10)
# [Epoch 182] train=3.734 | eval=3.656 | score=3.656 (eval_every~10)
# [Epoch 183] train=3.719 | eval=skipped (eval_every~10)
# [Epoch 184] train=3.718 | eval=skipped (eval_every~10)
# [Epoch 185] train=3.715 | eval=skipped (eval_every~10)
# [Epoch 186] train=3.716 | eval=skipped (eval_every~10)
# [Epoch 187] train=3.703 | eval=skipped (eval_every~10)
# [Epoch 188] train=3.722 | eval=skipped (eval_every~10)
# [Epoch 189] train=3.714 | eval=skipped (eval_every~10)
# [Epoch 190] train=3.727 | eval=skipped (eval_every~10)
# [Epoch 191] train=3.712 | eval=skipped (eval_every~9)
# [Epoch 192] train=3.719 | eval=3.665 | score=3.665 (eval_every~9)
# [Epoch 193] train=3.730 | eval=skipped (eval_every~9)
# [Epoch 194] train=3.720 | eval=skipped (eval_every~9)
# [Epoch 195] train=3.707 | eval=skipped (eval_every~9)
# [Epoch 196] train=3.708 | eval=skipped (eval_every~9)
# [Epoch 197] train=3.706 | eval=skipped (eval_every~9)
# [Epoch 198] train=3.709 | eval=skipped (eval_every~9)
# [Epoch 199] train=3.723 | eval=skipped (eval_every~9)
# [Epoch 200] train=3.697 | eval=skipped (eval_every~9)
# [Epoch 201] train=3.715 | eval=3.649 | score=3.649 (eval_every~9)
# [Epoch 202] train=3.697 | eval=skipped (eval_every~9)
# [Epoch 203] train=3.722 | eval=skipped (eval_every~9)
# [Epoch 204] train=3.699 | eval=skipped (eval_every~8)
# [Epoch 205] train=3.723 | eval=skipped (eval_every~8)
# [Epoch 206] train=3.701 | eval=skipped (eval_every~8)
# [Epoch 207] train=3.708 | eval=skipped (eval_every~8)
# [Epoch 208] train=3.701 | eval=skipped (eval_every~8)
# [Epoch 209] train=3.705 | eval=skipped (eval_every~8)
# [Epoch 210] train=3.732 | eval=3.649 | score=3.649 (eval_every~8)
# [Epoch 211] train=3.715 | eval=skipped (eval_every~8)
# [Epoch 212] train=3.741 | eval=skipped (eval_every~8)
# [Epoch 213] train=3.711 | eval=skipped (eval_every~8)
# [Epoch 214] train=3.719 | eval=skipped (eval_every~8)
# [Epoch 215] train=3.720 | eval=skipped (eval_every~8)
# [Epoch 216] train=3.711 | eval=skipped (eval_every~8)
# [Epoch 217] train=3.692 | eval=skipped (eval_every~7)
# [Epoch 218] train=3.711 | eval=3.633 | score=3.633 (eval_every~7)
#   + saved (score=3.633)
# [Epoch 219] train=3.682 | eval=skipped (eval_every~7)
# [Epoch 220] train=3.716 | eval=skipped (eval_every~7)
# [Epoch 221] train=3.691 | eval=skipped (eval_every~7)
# [Epoch 222] train=3.709 | eval=skipped (eval_every~7)
# [Epoch 223] train=3.693 | eval=skipped (eval_every~7)
# [Epoch 224] train=3.720 | eval=skipped (eval_every~7)
# [Epoch 225] train=3.674 | eval=3.619 | score=3.619 (eval_every~7)
#   + saved (score=3.619)
# [Epoch 226] train=3.711 | eval=skipped (eval_every~7)
# [Epoch 227] train=3.744 | eval=skipped (eval_every~7)
# [Epoch 228] train=3.686 | eval=skipped (eval_every~7)
# [Epoch 229] train=3.703 | eval=skipped (eval_every~6)
# [Epoch 230] train=3.712 | eval=skipped (eval_every~6)
# [Epoch 231] train=3.692 | eval=skipped (eval_every~6)
# [Epoch 232] train=3.684 | eval=3.636 | score=3.636 (eval_every~6)
# [Epoch 233] train=3.713 | eval=skipped (eval_every~6)
# [Epoch 234] train=3.691 | eval=skipped (eval_every~6)
# [Epoch 235] train=3.693 | eval=skipped (eval_every~6)
# [Epoch 236] train=3.723 | eval=skipped (eval_every~6)
# [Epoch 237] train=3.711 | eval=skipped (eval_every~6)
# [Epoch 238] train=3.698 | eval=3.635 | score=3.635 (eval_every~6)
# [Epoch 239] train=3.679 | eval=skipped (eval_every~6)
# [Epoch 240] train=3.681 | eval=skipped (eval_every~6)
# [Epoch 241] train=3.691 | eval=skipped (eval_every~6)
# [Epoch 242] train=3.688 | eval=skipped (eval_every~5)
# [Epoch 243] train=3.675 | eval=skipped (eval_every~5)
# [Epoch 244] train=3.671 | eval=3.618 | score=3.618 (eval_every~5)
#   + saved (score=3.618)
# [Epoch 245] train=3.701 | eval=skipped (eval_every~5)
# [Epoch 246] train=3.675 | eval=skipped (eval_every~5)
# [Epoch 247] train=3.709 | eval=skipped (eval_every~5)
# [Epoch 248] train=3.700 | eval=skipped (eval_every~5)
# [Epoch 249] train=3.695 | eval=3.625 | score=3.625 (eval_every~5)
# [Epoch 250] train=3.714 | eval=skipped (eval_every~5)
# [Epoch 251] train=3.692 | eval=skipped (eval_every~5)
# [Epoch 252] train=3.683 | eval=skipped (eval_every~5)
# [Epoch 253] train=3.694 | eval=skipped (eval_every~5)
# [Epoch 254] train=3.705 | eval=3.617 | score=3.617 (eval_every~5)
#   + saved (score=3.617)
# [Epoch 255] train=3.696 | eval=skipped (eval_every~4)
# [Epoch 256] train=3.695 | eval=skipped (eval_every~4)
# [Epoch 257] train=3.682 | eval=skipped (eval_every~4)
# [Epoch 258] train=3.678 | eval=skipped (eval_every~4)
# [Epoch 259] train=3.674 | eval=3.618 | score=3.618 (eval_every~4)
# [Epoch 260] train=3.693 | eval=skipped (eval_every~4)
# [Epoch 261] train=3.690 | eval=skipped (eval_every~4)
# [Epoch 262] train=3.683 | eval=skipped (eval_every~4)
# [Epoch 263] train=3.672 | eval=3.601 | score=3.601 (eval_every~4)
#   + saved (score=3.601)
# [Epoch 264] train=3.695 | eval=skipped (eval_every~4)
# [Epoch 265] train=3.701 | eval=skipped (eval_every~4)
# [Epoch 266] train=3.675 | eval=skipped (eval_every~4)
# [Epoch 267] train=3.675 | eval=3.604 | score=3.604 (eval_every~4)
# [Epoch 268] train=3.673 | eval=skipped (eval_every~3)
# [Epoch 269] train=3.665 | eval=skipped (eval_every~3)
# [Epoch 270] train=3.705 | eval=skipped (eval_every~3)
# [Epoch 271] train=3.678 | eval=3.599 | score=3.599 (eval_every~3)
#   + saved (score=3.599)
# [Epoch 272] train=3.685 | eval=skipped (eval_every~3)
# [Epoch 273] train=3.667 | eval=skipped (eval_every~3)
# [Epoch 274] train=3.725 | eval=3.601 | score=3.601 (eval_every~3)
# [Epoch 275] train=3.672 | eval=skipped (eval_every~3)
# [Epoch 276] train=3.726 | eval=skipped (eval_every~3)
# [Epoch 277] train=3.675 | eval=3.597 | score=3.597 (eval_every~3)
#   + saved (score=3.597)
# [Epoch 278] train=3.689 | eval=skipped (eval_every~3)
# [Epoch 279] train=3.666 | eval=skipped (eval_every~3)
# [Epoch 280] train=3.681 | eval=3.603 | score=3.603 (eval_every~2)
# [Epoch 281] train=3.697 | eval=skipped (eval_every~2)
# [Epoch 282] train=3.684 | eval=3.590 | score=3.590 (eval_every~2)
#   + saved (score=3.590)
# [Epoch 283] train=3.683 | eval=skipped (eval_every~2)
# [Epoch 284] train=3.672 | eval=3.600 | score=3.600 (eval_every~2)
# [Epoch 285] train=3.684 | eval=skipped (eval_every~2)
# [Epoch 286] train=3.672 | eval=3.597 | score=3.597 (eval_every~2)
# [Epoch 287] train=3.664 | eval=skipped (eval_every~2)
# [Epoch 288] train=3.662 | eval=3.591 | score=3.591 (eval_every~2)
# [Epoch 289] train=3.677 | eval=skipped (eval_every~2)
# [Epoch 290] train=3.658 | eval=3.589 | score=3.589 (eval_every~2)
#   + saved (score=3.589)
# [Epoch 291] train=3.673 | eval=skipped (eval_every~2)
# [Epoch 292] train=3.671 | eval=3.583 | score=3.583 (eval_every~2)
#   + saved (score=3.583)
# [Epoch 293] train=3.666 | eval=skipped (eval_every~1)
# [Epoch 294] train=3.668 | eval=3.583 | score=3.583 (eval_every~1)
# [Epoch 295] train=3.675 | eval=3.588 | score=3.588 (eval_every~1)
# [Epoch 296] train=3.663 | eval=3.584 | score=3.584 (eval_every~1)
# [Epoch 297] train=3.703 | eval=3.613 | score=3.613 (eval_every~1)
# [Epoch 298] train=3.672 | eval=3.591 | score=3.591 (eval_every~1)
# [Epoch 299] train=3.651 | eval=3.599 | score=3.599 (eval_every~1)

# %% [markdown]
# ## Plot

# %%
train_loss_arr = np.array(train_epoch_losses)
eval_loss_arr = np.array(eval_epoch_losses)
score_arr = np.array(scores)
best_epoch = best_checkpoint["epoch"]

epochs = np.arange(len(train_loss_arr))

# best epoch based on score

best_score = score_arr[best_epoch]
best_eval_loss = eval_loss_arr[best_epoch]

plt.figure(figsize=(8, 5))

# Main curves
plt.plot(epochs, train_loss_arr, linewidth=2, label="train loss")
plt.plot(epochs, eval_loss_arr, linewidth=2, label="eval loss")
plt.plot(epochs, score_arr, linewidth=2, linestyle="--", label="score")

ymin, ymax = plt.ylim()
yrange = ymax - ymin

xmin, xmax = plt.xlim()
xrange = xmax - xmin

y_offset = 0.5 * yrange
x_offset = -0.05 * xrange

# Annotation of best score
plt.annotate(
    f"min score = {best_score:.3f}\nepoch = {best_epoch}",
    xy=(best_epoch, best_score),
    xytext=(best_epoch + x_offset, best_score + y_offset),
    textcoords="data",
    arrowprops={"arrowstyle": "->", "linewidth": 1},
    fontsize=9,
    bbox={"boxstyle": "round,pad=0.3", "fc": "white", "alpha": 0.8},
)

plt.xlabel("Epoch")
plt.ylabel("Loss / Score")
plt.title(f"{perform_name} PF network training")

plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save figure
fig_path = PERFORM_DIR / "net_training_loss.png"
plt.savefig(fig_path, dpi=300)

# Save raw arrays
np.save(PERFORM_DIR / "net_training.npy", train_loss_arr)
np.save(PERFORM_DIR / "net_eval.npy", eval_loss_arr)
np.save(PERFORM_DIR / "net_score.npy", score_arr)
np.save(PERFORM_DIR / "net_bestepoch.npy", best_epoch)

plt.show()

print(f"✓ Plot saved to {fig_path}")
print(f"✓ Best epoch: {best_epoch} (score={best_score:.4f})")
# Out:
# ✓ Plot saved to /lustre/diazgonz/deep-performance-rul/experiments/DS03/opcond_q0.001-0.999_corr0.6_range0.6/estimation_thr0.2/gamma/net_arg5/SmFan/net_training_loss.png
# ✓ Best epoch: 299 (score=3.7736)
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
