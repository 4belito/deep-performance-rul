# %% [markdown]
# ## Train the PF-Controller Neural Network
#
# For each performance metric, train the corresponding particle-filter (PF) controller neural network.

# %%
import os

# use the CPUs allocated by SLURM (fallback 4); set before numpy/torch import so
# the BLAS/OpenMP backend also honors the thread count
N_CPUS = int(os.environ.get("SLURM_CPUS_PER_TASK") or 4)
os.environ.setdefault("OMP_NUM_THREADS", str(N_CPUS))
os.environ.setdefault("MKL_NUM_THREADS", str(N_CPUS))

import numpy as np  # noqa: E402
import pandas as pd  # noqa: E402
import torch  # noqa: E402
from matplotlib import pyplot as plt  # noqa: E402

from experiment_config import (  # noqa: E402
    SEED,
    DegModel,
    dataset_paths,
)
from src.helpers.seed import set_global_seed  # noqa: E402
from src.models.networks.pf_mlp import ParticleFilterMLP  # noqa: E402
from src.training.pfnet_hparams import PFNET_ARGS  # noqa: E402
from src.training.pfnet_training import train_pf_controller_cv  # noqa: E402

torch.set_num_threads(N_CPUS)
print(f"CPU threads: {torch.get_num_threads()} (N_CPUS={N_CPUS})")
# Out:
# CPU threads: 4 (N_CPUS=4)

# %% [markdown]
# ## Task

# %%
DATA_NAME = "DS03"
perform_name = "SmHPC"
ARGS_ID = 6

# %% [markdown]
# ## Hyper-Parameters

# %%
args = PFNET_ARGS[ARGS_ID]

net_args = args["NETWORK"]

if net_args is None:
    raise SystemExit(
        "This ARGS_ID is a no-network baseline (NETWORK=None): there is no "
        "network to train. Use it only in the test/ablation notebooks."
    )
pf_args = args["PARTICLE_FILTER"]
train_args = args["TRAINING"]
eval_args = args["EVALUATION"]

# %%
set_global_seed(SEED)

ESTIMATION_DIR, DEGR_MODEL_DIR = dataset_paths(
    DATA_NAME, fields=["estimation", "degr_model"]
)

PFNET_ARGS_DIR = DEGR_MODEL_DIR / f"net_arg{ARGS_ID}"
PERFORM_DIR = PFNET_ARGS_DIR / perform_name

checkpoint_best_path = PERFORM_DIR / "checkpoint_best.pt"
checkpoint_last_path = PERFORM_DIR / "checkpoint_last.pt"
checkpoint_best_path.parent.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Import training data

# %%
hi_df = pd.read_csv(ESTIMATION_DIR / "data_dev.csv")
units = hi_df["unit"].astype(int).unique().tolist()
units
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ### Extract degradation onset

# %%
onsets = {
    unit: hi_df[(hi_df["unit"] == unit) & (hi_df["hs"] == 0)]["cycle"].values[0]
    for unit in units
}
del hi_df["hs"]

# %%
perform_names = [col for col in hi_df.columns if col not in ["unit", "cycle"]]

performs = {
    name: {unit: hi_df[hi_df["unit"] == unit][name].values for unit in units}
    for name in perform_names
}

init_ss = {
    name: {unit: perform[unit].max() for unit in units}
    for name, perform in performs.items()
}
time = {unit: hi_df[hi_df["unit"] == unit]["cycle"].values for unit in units}

# %% [markdown]
# ## Create component (base) models

# %%
dev_data = {}
dev_eol = {}
for unit in units:
    t = time[unit]
    s = performs[perform_name][unit]
    dev_data[unit] = torch.tensor(np.stack([t, s], axis=1), dtype=torch.float32)
    dev_eol[unit] = torch.tensor(t[-1], dtype=torch.float32)

# %%
dev_degmodels = {}
for unit in performs[perform_name]:
    best_model = DegModel(onset=onsets[unit], init_s=init_ss[perform_name][unit])
    best_model.load_state_dict(
        torch.load(
            DEGR_MODEL_DIR / "states" / perform_name / f"unit_{unit}" / "best_model.pt"
        )
    )
    dev_degmodels[unit] = best_model

# %% [markdown]
# ## Train Particle Filter controller Net

# %%
from src.models.networks.pf_mlp import build_activation

net = ParticleFilterMLP(
    state_dim=DegModel.state_dim(),
    hidden_dims=list(net_args["HIDDEN_DIMS"]),
    activation=build_activation(net_args),
    dropout_p=float(net_args["DROPOUT"]),
)

optimizer = torch.optim.Adam(net.parameters(), float(train_args["LR"]))
optimizer.zero_grad()

# %%
best_score = float("inf")
train_epoch_losses = []
eval_epoch_losses = []
scores = []
start_epoch = 0

if checkpoint_last_path.exists():
    ckpt = torch.load(checkpoint_last_path, weights_only=False)

    net.load_state_dict(ckpt["model_state"])
    optimizer.load_state_dict(ckpt["optimizer_state"])

    start_epoch = ckpt["epoch"] + 1
    best_score = ckpt["best_score"]
    scores = ckpt.get("scores", [])
    train_epoch_losses = ckpt.get("train_losses", [])
    eval_epoch_losses = ckpt.get("eval_losses", [])

    torch.random.set_rng_state(ckpt["rng_torch"])
    np.random.set_state(ckpt["rng_numpy"])

    print(f"✓ Resumed from epoch {start_epoch}, best_score={best_score:.3f}")
# Out:
# ✓ Resumed from epoch 91, best_score=3.015

# %%
train_state = train_pf_controller_cv(
    net=net,
    optimizer=optimizer,
    units=units,
    dev_data=dev_data,
    dev_degmodels=dev_degmodels,
    n_particles=int(pf_args["N_PARTICLES"]),
    max_life=int(pf_args["MAX_LIFE"]),
    loss_tail_steps=int(train_args["LOSS_TAIL_STEPS"]),
    n_epochs=int(train_args["N_EPOCHS"]),
    checkpoint_best_path=checkpoint_best_path,
    checkpoint_last_path=checkpoint_last_path,
    start_epoch=start_epoch,
    best_score=best_score,
    scores=scores,
    train_epoch_losses=train_epoch_losses,
    eval_epoch_losses=eval_epoch_losses,
    seed=SEED,
    eval_repetitions=int(eval_args["REPETITIONS"]),
    eval_seed_stride=int(eval_args["SEED_STRIDE"]),
    eval_initial_interval_epochs=int(eval_args["INITIAL_INTERVAL_EPOCHS"]),
    eval_final_interval_epochs=int(eval_args["FINAL_INTERVAL_EPOCHS"]),
    match_train_eval_prior=bool(train_args.get("MATCH_TRAIN_EVAL_PRIOR", False)),
    verbose=True,
)

best_score = train_state["best_score"]
scores = train_state["scores"]
train_epoch_losses = train_state["train_epoch_losses"]
eval_epoch_losses = train_state["eval_epoch_losses"]
epoch = train_state["epoch"]
best_checkpoint = train_state["best_checkpoint"]

if best_checkpoint is None and checkpoint_best_path.exists():
    best_checkpoint = torch.load(checkpoint_best_path, weights_only=False)
# Out:
# [Epoch 091] train=3.032 | eval=3.004 | score=3.004 (eval_every~12)
#   + saved (score=3.004)
# [Epoch 092] train=3.048 | eval=skipped (eval_every~12)
# [Epoch 093] train=3.031 | eval=skipped (eval_every~12)
# [Epoch 094] train=3.039 | eval=skipped (eval_every~12)
# [Epoch 095] train=3.030 | eval=skipped (eval_every~12)
# [Epoch 096] train=3.033 | eval=skipped (eval_every~12)
# [Epoch 097] train=3.020 | eval=skipped (eval_every~12)
# [Epoch 098] train=3.044 | eval=skipped (eval_every~12)
# [Epoch 099] train=3.046 | eval=skipped (eval_every~12)
# [Epoch 100] train=3.026 | eval=skipped (eval_every~12)
# [Epoch 101] train=3.051 | eval=skipped (eval_every~11)
# [Epoch 102] train=3.014 | eval=skipped (eval_every~11)
# [Epoch 103] train=3.025 | eval=3.009 | score=3.009 (eval_every~11)
# [Epoch 104] train=3.004 | eval=skipped (eval_every~11)
# [Epoch 105] train=3.032 | eval=skipped (eval_every~11)
# [Epoch 106] train=3.026 | eval=skipped (eval_every~11)
# [Epoch 107] train=3.033 | eval=skipped (eval_every~11)
# [Epoch 108] train=3.032 | eval=skipped (eval_every~11)
# [Epoch 109] train=3.023 | eval=skipped (eval_every~11)
# [Epoch 110] train=3.022 | eval=skipped (eval_every~11)
# [Epoch 111] train=3.012 | eval=skipped (eval_every~11)
# [Epoch 112] train=3.007 | eval=skipped (eval_every~11)
# [Epoch 113] train=3.026 | eval=skipped (eval_every~11)
# [Epoch 114] train=3.016 | eval=2.989 | score=2.989 (eval_every~11)
#   + saved (score=2.989)
# [Epoch 115] train=2.996 | eval=skipped (eval_every~11)
# [Epoch 116] train=3.009 | eval=skipped (eval_every~11)
# [Epoch 117] train=3.011 | eval=skipped (eval_every~11)
# [Epoch 118] train=3.023 | eval=skipped (eval_every~11)
# [Epoch 119] train=3.025 | eval=skipped (eval_every~11)
# [Epoch 120] train=3.001 | eval=skipped (eval_every~10)
# [Epoch 121] train=3.018 | eval=skipped (eval_every~10)
# [Epoch 122] train=3.011 | eval=skipped (eval_every~10)
# [Epoch 123] train=3.008 | eval=skipped (eval_every~10)
# [Epoch 124] train=3.004 | eval=skipped (eval_every~10)
# [Epoch 125] train=3.020 | eval=2.984 | score=2.984 (eval_every~10)
#   + saved (score=2.984)
# [Epoch 126] train=3.010 | eval=skipped (eval_every~10)
# [Epoch 127] train=3.022 | eval=skipped (eval_every~10)
# [Epoch 128] train=3.019 | eval=skipped (eval_every~10)
# [Epoch 129] train=3.009 | eval=skipped (eval_every~10)
# [Epoch 130] train=3.001 | eval=skipped (eval_every~10)
# [Epoch 131] train=2.985 | eval=skipped (eval_every~10)
# [Epoch 132] train=3.006 | eval=skipped (eval_every~10)
# [Epoch 133] train=3.006 | eval=skipped (eval_every~10)
# [Epoch 134] train=3.003 | eval=skipped (eval_every~10)
# [Epoch 135] train=3.020 | eval=2.972 | score=2.972 (eval_every~10)
#   + saved (score=2.972)
# [Epoch 136] train=3.003 | eval=skipped (eval_every~10)
# [Epoch 137] train=2.988 | eval=skipped (eval_every~10)
# [Epoch 138] train=2.997 | eval=skipped (eval_every~10)
# [Epoch 139] train=2.994 | eval=skipped (eval_every~9)
# [Epoch 140] train=3.005 | eval=skipped (eval_every~9)
# [Epoch 141] train=3.015 | eval=skipped (eval_every~9)
# [Epoch 142] train=3.012 | eval=skipped (eval_every~9)
# [Epoch 143] train=3.012 | eval=skipped (eval_every~9)
# [Epoch 144] train=3.004 | eval=skipped (eval_every~9)
# [Epoch 145] train=3.010 | eval=2.975 | score=2.975 (eval_every~9)
# [Epoch 146] train=2.996 | eval=skipped (eval_every~9)
# [Epoch 147] train=2.996 | eval=skipped (eval_every~9)
# [Epoch 148] train=2.985 | eval=skipped (eval_every~9)
# [Epoch 149] train=3.003 | eval=skipped (eval_every~9)
# [Epoch 150] train=2.979 | eval=skipped (eval_every~9)
# [Epoch 151] train=2.992 | eval=skipped (eval_every~9)
# [Epoch 152] train=2.993 | eval=skipped (eval_every~9)
# [Epoch 153] train=2.999 | eval=skipped (eval_every~9)
# [Epoch 154] train=3.003 | eval=2.967 | score=2.967 (eval_every~9)
#   + saved (score=2.967)
# [Epoch 155] train=2.987 | eval=skipped (eval_every~9)
# [Epoch 156] train=2.986 | eval=skipped (eval_every~9)
# [Epoch 157] train=2.999 | eval=skipped (eval_every~9)
# [Epoch 158] train=2.986 | eval=skipped (eval_every~8)
# [Epoch 159] train=2.982 | eval=skipped (eval_every~8)
# [Epoch 160] train=2.981 | eval=skipped (eval_every~8)
# [Epoch 161] train=2.984 | eval=skipped (eval_every~8)
# [Epoch 162] train=3.000 | eval=skipped (eval_every~8)
# [Epoch 163] train=2.979 | eval=2.966 | score=2.966 (eval_every~8)
#   + saved (score=2.966)
# [Epoch 164] train=2.987 | eval=skipped (eval_every~8)
# [Epoch 165] train=2.994 | eval=skipped (eval_every~8)
# [Epoch 166] train=2.977 | eval=skipped (eval_every~8)
# [Epoch 167] train=3.007 | eval=skipped (eval_every~8)
# [Epoch 168] train=2.985 | eval=skipped (eval_every~8)
# [Epoch 169] train=2.972 | eval=skipped (eval_every~8)
# [Epoch 170] train=3.014 | eval=skipped (eval_every~8)
# [Epoch 171] train=2.964 | eval=2.948 | score=2.948 (eval_every~8)
#   + saved (score=2.948)
# [Epoch 172] train=2.961 | eval=skipped (eval_every~8)
# [Epoch 173] train=2.986 | eval=skipped (eval_every~8)
# [Epoch 174] train=2.973 | eval=skipped (eval_every~8)
# [Epoch 175] train=2.939 | eval=skipped (eval_every~8)
# [Epoch 176] train=2.978 | eval=skipped (eval_every~8)
# [Epoch 177] train=2.951 | eval=skipped (eval_every~7)
# [Epoch 178] train=2.965 | eval=skipped (eval_every~7)
# [Epoch 179] train=3.005 | eval=2.958 | score=2.958 (eval_every~7)
# [Epoch 180] train=2.969 | eval=skipped (eval_every~7)
# [Epoch 181] train=2.955 | eval=skipped (eval_every~7)
# [Epoch 182] train=2.972 | eval=skipped (eval_every~7)
# [Epoch 183] train=2.979 | eval=skipped (eval_every~7)
# [Epoch 184] train=2.973 | eval=skipped (eval_every~7)
# [Epoch 185] train=2.988 | eval=skipped (eval_every~7)
# [Epoch 186] train=2.978 | eval=2.943 | score=2.943 (eval_every~7)
#   + saved (score=2.943)
# [Epoch 187] train=2.977 | eval=skipped (eval_every~7)
# [Epoch 188] train=2.985 | eval=skipped (eval_every~7)
# [Epoch 189] train=2.962 | eval=skipped (eval_every~7)
# [Epoch 190] train=2.960 | eval=skipped (eval_every~7)
# [Epoch 191] train=2.980 | eval=skipped (eval_every~7)
# [Epoch 192] train=2.953 | eval=skipped (eval_every~7)
# [Epoch 193] train=2.981 | eval=2.908 | score=2.908 (eval_every~7)
#   + saved (score=2.908)
# [Epoch 194] train=2.945 | eval=skipped (eval_every~7)
# [Epoch 195] train=2.953 | eval=skipped (eval_every~6)
# [Epoch 196] train=2.987 | eval=skipped (eval_every~6)
# [Epoch 197] train=2.986 | eval=skipped (eval_every~6)
# [Epoch 198] train=2.956 | eval=skipped (eval_every~6)
# [Epoch 199] train=2.965 | eval=skipped (eval_every~6)
# [Epoch 200] train=2.981 | eval=2.927 | score=2.927 (eval_every~6)
# [Epoch 201] train=2.947 | eval=skipped (eval_every~6)
# [Epoch 202] train=2.962 | eval=skipped (eval_every~6)
# [Epoch 203] train=2.951 | eval=skipped (eval_every~6)
# [Epoch 204] train=2.963 | eval=skipped (eval_every~6)

# %% [markdown]
# ## Plot

# %%
train_loss_arr = np.array(train_epoch_losses)
eval_loss_arr = np.array(eval_epoch_losses)
score_arr = np.array(scores)
best_epoch = best_checkpoint["epoch"]

epochs = np.arange(len(train_loss_arr))

# best epoch based on score

best_score = score_arr[best_epoch]
best_eval_loss = eval_loss_arr[best_epoch]

plt.figure(figsize=(8, 5))

# Main curves
plt.plot(epochs, train_loss_arr, linewidth=2, label="train loss")
plt.plot(epochs, eval_loss_arr, linewidth=2, label="eval loss")
plt.plot(epochs, score_arr, linewidth=2, linestyle="--", label="score")

ymin, ymax = plt.ylim()
yrange = ymax - ymin

xmin, xmax = plt.xlim()
xrange = xmax - xmin

y_offset = 0.5 * yrange
x_offset = -0.05 * xrange

# Annotation of best score
plt.annotate(
    f"min score = {best_score:.3f}\nepoch = {best_epoch}",
    xy=(best_epoch, best_score),
    xytext=(best_epoch + x_offset, best_score + y_offset),
    textcoords="data",
    arrowprops={"arrowstyle": "->", "linewidth": 1},
    fontsize=9,
    bbox={"boxstyle": "round,pad=0.3", "fc": "white", "alpha": 0.8},
)

plt.xlabel("Epoch")
plt.ylabel("Loss / Score")
plt.title(f"{perform_name} PF network training")

plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save figure
fig_path = PERFORM_DIR / "net_training_loss.png"
plt.savefig(fig_path, dpi=300)

# Save raw arrays
np.save(PERFORM_DIR / "net_training.npy", train_loss_arr)
np.save(PERFORM_DIR / "net_eval.npy", eval_loss_arr)
np.save(PERFORM_DIR / "net_score.npy", score_arr)
np.save(PERFORM_DIR / "net_bestepoch.npy", best_epoch)

plt.show()

print(f"✓ Plot saved to {fig_path}")
print(f"✓ Best epoch: {best_epoch} (score={best_score:.4f})")
# Out:
# ✓ Plot saved to /lustre/diazgonz/deep-performance-rul/experiments/DS01/opcond_q0.001-0.999_corr0.6_range0.6/estimation_thr0.2/gamma/net_arg6/SmHPC/net_training_loss.png
# ✓ Best epoch: 288 (score=3.0926)
