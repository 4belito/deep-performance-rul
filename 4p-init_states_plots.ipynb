# %% [markdown]
# ## Plot Learned Initial States
#
# This notebook visualizes the training results of the initial-state models by plotting the learned stochastic degradation processes and comparing them against the observed performance trajectories.

# %%
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt

from experiment_config import DegModel,DEGR_MODEL_DIR,ESTIMATION_DIR

# %% [markdown]
# ## Import training data

# %%
hi_df = pd.read_csv(ESTIMATION_DIR/'data_dev.csv')
units = hi_df['unit'].astype(int).unique().tolist()
units
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# ### Extract degradation onset

# %%
onsets = {unit: hi_df[(hi_df['unit']==unit) & (hi_df['hs']==0)]['cycle'].values[0] 
          for unit in units}
del hi_df['hs']

# %%
perform_names = [col for col in hi_df.columns if col not in ['unit','cycle']]

performs = {name: 
    {unit: hi_df[hi_df['unit']==unit][name].values for unit in units} 
    for name in perform_names
}
init_ss = {name: {unit: perform[unit].max() for unit in units} for name,perform in performs.items()}
time = {unit: hi_df[hi_df['unit']==unit]['cycle'].values for unit in units}

# %% [markdown]
# ## Load best model

# %%
import torch.nn.functional as F

def extract_parameters(model, onset, init_s):
    raw = dict(model.named_parameters())

    raw_so = raw["raw_so"].item()
    raw_dmx = raw["raw_dmx"].item()
    raw_dmc = raw["raw_dmc"].item()
    raw_dvx = raw["raw_dvx"].item()
    raw_dvs = raw["raw_dvs"].item()
    raw_nmy = raw["raw_nmy"].item()

    to = onset

    dmx = to + model.min_to_gab + F.softplus(torch.tensor(raw_dmx)).item()
    dmc = model.min_dmc + F.softplus(torch.tensor(raw_dmc)).item()

    ratio = to / dmx
    A = 1 - ratio ** (1 / dmc)

    so = min(init_s, A) * torch.sigmoid(torch.tensor(raw_so)).item()
    dmy = so / A

    dvx = F.softplus(torch.tensor(raw_dvx)).item()
    dvs = F.softplus(torch.tensor(raw_dvs)).item()

    nmy_min = so + model.min_so_gab
    nmy = nmy_min + (1 - nmy_min) * torch.sigmoid(torch.tensor(raw_nmy)).item()

    return {
        "s_on": so,
        "d_t": dmx,
        "d_c": dmc,
        "d_s": dmy,
        "v_t": dvx,
        "v_s": dvs,
        "n_s": nmy,
    }

# %%
t = np.linspace(0.1, 100, 400)  # Start from 0.1 instead of 0.0
s = np.linspace(0.0, 1.0, 300)


for name, units_perform in performs.items():
    print(f"Plotting for perform: {name}")
    for unit, perform in units_perform.items():
        print(f"  Unit: {unit}") 

        s_np:np.ndarray = perform
        t_np:np.ndarray = time[unit]

        best_model = DegModel(onset=onsets[unit], init_s=init_ss[name][unit])
        best_model.load_state_dict(
            torch.load(DEGR_MODEL_DIR/'states'/name/f'unit_{unit}'/ "best_model.pt")
        )
        best_model.eval()

        ax = best_model.plot_distribution(
            t=t,
            s=s,
            func="pdf",
            title="Performance Degradation model",#f"{DegModel.name().capitalize()} pdf ({name}: unit {unit})",
            plot_mode=True,
            plot_mean=True,
        )
  
        ax.vlines(onsets[unit], ymin=0, ymax=ax.get_ylim()[1], color='red', linestyle='--', label=f'$\\ t_{{on}}$')



        ax.set_xlim([t.min(), t.max()])
        ax.plot(t_np,s_np,'o-',
                color='white',alpha=0.3,markersize=4,markeredgecolor='black',markeredgewidth=0.8,
                label='data')
        ax.legend()
        
        params = extract_parameters(best_model, onsets[unit], init_ss[name][unit])

        text = (
            f"$\\phi_{{s_{{on}}}}$ = {params['s_on']:.3f}\n"
            f"$\\phi_{{n_s}}$ = {params['n_s']:.3f}\n"
            f"$\\phi_{{d_t}}$ = {params['d_t']:.2f}\n"
            f"$\\phi_{{d_c}}$ = {params['d_c']:.2f}\n"
            f"$\\phi_{{v_t}}$ = {params['v_t']:.3f}\n"
            f"$\\phi_{{v_s}}$ = {params['v_s']:.3f}\n"
            f"$d_s$ = {params['d_s']:.3f}"
        )

        ax.text(
            0.02,
            0.02,
            text,
            transform=ax.transAxes,
            fontsize=15,
            verticalalignment="bottom",
            bbox=dict(boxstyle="round", facecolor="white", alpha=0.8),
        )
        plt.show()
# Out:
# Plotting for perform: T48
#   Unit: 1
#   Unit: 2
#   Unit: 3
#   Unit: 4
#   Unit: 5
#   Unit: 6
#   Unit: 7
#   Unit: 8
#   Unit: 9
# Plotting for perform: SmFan
#   Unit: 1
#   Unit: 2
#   Unit: 3
#   Unit: 4
#   Unit: 5
#   Unit: 6
#   Unit: 7
#   Unit: 8
#   Unit: 9
# Plotting for perform: SmLPC
#   Unit: 1
#   Unit: 2
#   Unit: 3
#   Unit: 4
#   Unit: 5
#   Unit: 6
#   Unit: 7
#   Unit: 8
#   Unit: 9
# Plotting for perform: SmHPC
#   Unit: 1
#   Unit: 2
#   Unit: 3
#   Unit: 4
#   Unit: 5
#   Unit: 6
#   Unit: 7
#   Unit: 8
#   Unit: 9

# %% [markdown]
# ## Show parameters

# %%
for p in best_model.named_parameters():
    print(p)
# Out:
# ('raw_so', Parameter containing:
# tensor(2.4041, requires_grad=True))
# ('raw_dmx', Parameter containing:
# tensor(46.3675, requires_grad=True))
# ('raw_dmc', Parameter containing:
# tensor(-1.5483, requires_grad=True))
# ('raw_dvx', Parameter containing:
# tensor(-3.2137, requires_grad=True))
# ('raw_dvs', Parameter containing:
# tensor(3.4392, requires_grad=True))
# ('raw_nmy', Parameter containing:
# tensor(1.5422, requires_grad=True))
