# %% [markdown]
# ## Train the PF-Controller Neural Network
#
# For each performance metric, train the corresponding particle-filter (PF) controller neural network.

# %%
import numpy as np
import pandas as pd
import torch
from matplotlib import pyplot as plt
import torch.nn as nn
from src.models.particle_filter.core import ParticleFilter
from src.models.networks.pf_mlp import ParticleFilterMLP
from src.helpers.seed import set_global_seed

from experiment_config import (
    DegModel,DATA_NAME,SEED,LEAKY_SLOPE,HIDDEN_DIMS,PREDICTION_START_IDX,LOSS_TAIL_SIZE,N_PARTICLES,GRADIENT_CLIP,WEIGHT_DECAY,AVERSION,PFNET_DIR,DEGR_MODEL_DIR,ESTIMATION_DIR,LOSS_WINDOW
)
    
DATA_NAME
# Out:
# 'DS05'

# %% [markdown]
# ## Task

# %%
perform_name = 'SmHPC'

# %% [markdown]
# ## Hyper-Parameters

# %%
# Training parameters#
# optimization
lr = 5e-4

# Early stopping
max_epochs = 5000
min_epochs = 500
patience = 100         # how many eval steps to wait
min_delta = 1e-4       # minimum improvement to count

assert min_epochs >= LOSS_WINDOW, "min_epochs must be greater than LOSS_WINDOW_SIZE for the scoring mechanism to work properly."

# %%
activation = nn.LeakyReLU(LEAKY_SLOPE)

set_global_seed(SEED)
PERFORM_DIR = PFNET_DIR/perform_name

checkpoint_best_path = PERFORM_DIR / "checkpoint_best.pt"
checkpoint_last_path = PERFORM_DIR / "checkpoint_last.pt"
checkpoint_best_path.parent.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Import training data

# %%
hi_df = pd.read_csv(ESTIMATION_DIR/"data_dev.csv")
units = hi_df['unit'].astype(int).unique().tolist()
units
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Extract degradation onset

# %%
onsets = {unit: hi_df[(hi_df['unit']==unit) & (hi_df['hs']==0)]['cycle'].values[0] for unit in units}
del hi_df['hs']

# %%
perform_names = [col for col in hi_df.columns if col not in ['unit','cycle']]

performs = {name: 
    {unit: hi_df[hi_df['unit']==unit][name].values for unit in units} 
    for name in perform_names
}

init_ss = {name: {unit: perform[unit].max() for unit in units} for name,perform in performs.items()}
time = {unit: hi_df[hi_df['unit']==unit]['cycle'].values for unit in units}

# %% [markdown]
# ## Create component (base) models

# %%
train_data = {}
train_eol = {}
for unit in units:
    t_data = time[unit]
    s_data = performs[perform_name][unit]
    train_data[unit]=torch.tensor(np.stack([t_data, s_data],axis=1),dtype=torch.float32)
    train_eol[unit]=torch.tensor(t_data[-1],dtype=torch.float32)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 5
#       3 for unit in units:
#       4     t_data = time[unit]
# ----> 5     s_data = performs[perform_name][unit]
#       6     train_data[unit]=torch.tensor(np.stack([t_data, s_data],axis=1),dtype=torch.float32)
#       7     train_eol[unit]=torch.tensor(t_data[-1],dtype=torch.float32)
#
# KeyError: 'SmHPC'

# %%
degmodels = {}
for train_unit in units:
    offline_degmodels=[]
    for unit, perform in performs[perform_name].items():
        if unit == train_unit:
            continue
        best_model = DegModel(onset=onsets[unit], init_s=init_ss[perform_name][unit])
        best_model.load_state_dict(
            torch.load(DEGR_MODEL_DIR/'states'/perform_name/f'unit_{unit}'/ "best_model.pt")
        )
        offline_degmodels.append(best_model)
    degmodels[train_unit] = offline_degmodels

# %% [markdown]
# ## Train Particle Filter controller Net

# %%
net = ParticleFilterMLP(state_dim=DegModel.state_dim(), hidden_dims=HIDDEN_DIMS,
                        activation=lambda : nn.LeakyReLU(LEAKY_SLOPE))

optimizer = torch.optim.Adam(net.parameters(), lr, weight_decay=WEIGHT_DECAY)
optimizer.zero_grad()

# %%
wait = 0
best_score = float("inf")

all_epoch_unit_losses = []
mean_losses = []
std_losses = []
scores = []
epochs = []

start_epoch = 0

if checkpoint_last_path.exists():
    ckpt = torch.load(checkpoint_last_path, weights_only=False)

    net.load_state_dict(ckpt["model_state"])
    optimizer.load_state_dict(ckpt["optimizer_state"])

    start_epoch = ckpt["epoch"] + 1
    best_score = ckpt["best_score"]

    mean_losses = ckpt["mean_losses"]
    std_losses = ckpt["std_losses"]
    scores = ckpt["scores"]
    epochs = ckpt["epochs"]
    all_epoch_unit_losses = ckpt["all_epoch_unit_losses"]

    torch.random.set_rng_state(ckpt["rng_torch"])
    np.random.set_state(ckpt["rng_numpy"])

    print(f"✓ Resumed from epoch {start_epoch}, best_score={best_score:.3f}")
# Out:
# ✓ Resumed from epoch 423, best_score=3.335

# %%
for epoch in range(start_epoch, max_epochs):

    epoch_unit_losses = []

    for train_unit in np.random.permutation(units):

        optimizer.zero_grad()

        offline_degmodels = degmodels[train_unit]
        t_data = train_data[train_unit][:, 0]
        s_data = train_data[train_unit][:, 1]

        pf = ParticleFilter(
            base_models=offline_degmodels,
            net=net,
            n_particles=N_PARTICLES,
        ).train()

        unit_loss = 0.0
        n_loss = 0

        for k in range(PREDICTION_START_IDX, len(t_data)):

            mixture_dist = pf.step(
                t_obs=t_data[:k+1],
                s_obs=s_data[:k+1],
            )
            

            init_loss = -LOSS_TAIL_SIZE if LOSS_TAIL_SIZE else k
            last_dist = mixture_dist.distribution(s=s_data[init_loss:])
            nll = -last_dist.log_prob(t_data[init_loss:]).mean()

            unit_loss += nll
            n_loss += 1

        unit_loss = unit_loss / n_loss

        unit_loss.backward()
        if GRADIENT_CLIP is not None:
            torch.nn.utils.clip_grad_norm_(net.parameters(), GRADIENT_CLIP)
        optimizer.step()

        epoch_unit_losses.append(unit_loss.item())

    # ---- compute score ----
    
    epoch_losses = np.array(epoch_unit_losses)
    mean_loss = epoch_losses.mean()
    std_loss = epoch_losses.std()


    all_epoch_unit_losses.append(epoch_unit_losses)
    window_losses = np.array(all_epoch_unit_losses[-LOSS_WINDOW:])
    wmean_loss = window_losses.mean()
    wstd_loss = window_losses.std()
    score = wmean_loss + AVERSION * wstd_loss
    
    mean_losses.append(mean_loss)
    std_losses.append(std_loss)
    scores.append(score)
    epochs.append(epoch)
    
    print(
        f"[Epoch {epoch:04d}] "
        f"mean={mean_loss:.3f} | std={std_loss:.3f} | "
        f"wmean={wmean_loss:.3f} | wstd={wstd_loss:.3f} | "
        f"score={score:.3f}"
    )
    # ---- early stopping on score ----
    if score < best_score - min_delta and len(all_epoch_unit_losses) >= LOSS_WINDOW:
        best_score = score
        wait = 0

        # ---- BEST (minimal) ----
        best_checkpoint = {
            'epoch': epoch,
            'model_state': net.state_dict(),
            'best_score': best_score,
        }
        torch.save(best_checkpoint, checkpoint_best_path)
        

        # ---- LAST (full training state) ----
        last_checkpoint = {
            'epoch': epoch,
            'model_state': net.state_dict(),
            'optimizer_state': optimizer.state_dict(),
            'best_score': best_score,
            'mean_losses': mean_losses,
            'std_losses': std_losses,
            'scores': scores,
            'epochs': epochs,
            'all_epoch_unit_losses': all_epoch_unit_losses,
            "rng_torch": torch.random.get_rng_state(),
            "rng_numpy": np.random.get_state(),
        }
        torch.save(last_checkpoint, checkpoint_last_path)
        print("  + saved")
    else:
        wait += 1
        if epoch>=min_epochs and wait >= patience:
            print("🛑 Early stopping triggered")
            break
# Out:
# [Epoch 0423] mean=3.258 | std=0.149 | wmean=3.245 | wstd=0.181 | score=3.335
# [Epoch 0424] mean=3.280 | std=0.189 | wmean=3.246 | wstd=0.181 | score=3.336
# [Epoch 0425] mean=3.261 | std=0.230 | wmean=3.247 | wstd=0.183 | score=3.339
# [Epoch 0426] mean=3.220 | std=0.199 | wmean=3.247 | wstd=0.185 | score=3.339
# [Epoch 0427] mean=3.255 | std=0.186 | wmean=3.246 | wstd=0.185 | score=3.339
# [Epoch 0428] mean=3.289 | std=0.201 | wmean=3.246 | wstd=0.184 | score=3.338
# [Epoch 0429] mean=3.208 | std=0.143 | wmean=3.244 | wstd=0.183 | score=3.336
# [Epoch 0430] mean=3.251 | std=0.201 | wmean=3.245 | wstd=0.184 | score=3.338
# [Epoch 0431] mean=3.299 | std=0.207 | wmean=3.248 | wstd=0.185 | score=3.341
# [Epoch 0432] mean=3.270 | std=0.186 | wmean=3.249 | wstd=0.185 | score=3.341
# [Epoch 0433] mean=3.240 | std=0.123 | wmean=3.249 | wstd=0.183 | score=3.340
# [Epoch 0434] mean=3.312 | std=0.206 | wmean=3.249 | wstd=0.184 | score=3.341
# [Epoch 0435] mean=3.231 | std=0.171 | wmean=3.249 | wstd=0.184 | score=3.342
# [Epoch 0436] mean=3.245 | std=0.198 | wmean=3.250 | wstd=0.185 | score=3.343
# [Epoch 0437] mean=3.303 | std=0.235 | wmean=3.252 | wstd=0.187 | score=3.345
# [Epoch 0438] mean=3.242 | std=0.122 | wmean=3.253 | wstd=0.186 | score=3.346
# [Epoch 0439] mean=3.249 | std=0.178 | wmean=3.254 | wstd=0.186 | score=3.347
# [Epoch 0440] mean=3.234 | std=0.157 | wmean=3.252 | wstd=0.184 | score=3.344
# [Epoch 0441] mean=3.279 | std=0.210 | wmean=3.255 | wstd=0.186 | score=3.348
# [Epoch 0442] mean=3.229 | std=0.179 | wmean=3.254 | wstd=0.184 | score=3.346
# [Epoch 0443] mean=3.294 | std=0.235 | wmean=3.256 | wstd=0.186 | score=3.349
# [Epoch 0444] mean=3.244 | std=0.146 | wmean=3.257 | wstd=0.185 | score=3.350
# [Epoch 0445] mean=3.238 | std=0.173 | wmean=3.258 | wstd=0.187 | score=3.351
# [Epoch 0446] mean=3.233 | std=0.155 | wmean=3.256 | wstd=0.186 | score=3.349
# [Epoch 0447] mean=3.258 | std=0.145 | wmean=3.255 | wstd=0.183 | score=3.347
# [Epoch 0448] mean=3.228 | std=0.169 | wmean=3.255 | wstd=0.184 | score=3.347
# [Epoch 0449] mean=3.196 | std=0.143 | wmean=3.254 | wstd=0.183 | score=3.346
# [Epoch 0450] mean=3.294 | std=0.201 | wmean=3.255 | wstd=0.185 | score=3.348
# [Epoch 0451] mean=3.244 | std=0.159 | wmean=3.254 | wstd=0.183 | score=3.346
# [Epoch 0452] mean=3.207 | std=0.197 | wmean=3.253 | wstd=0.185 | score=3.345
# [Epoch 0453] mean=3.289 | std=0.218 | wmean=3.254 | wstd=0.187 | score=3.348
# [Epoch 0454] mean=3.230 | std=0.144 | wmean=3.252 | wstd=0.186 | score=3.345
# [Epoch 0455] mean=3.194 | std=0.131 | wmean=3.250 | wstd=0.183 | score=3.342
# [Epoch 0456] mean=3.301 | std=0.209 | wmean=3.253 | wstd=0.183 | score=3.344
# [Epoch 0457] mean=3.208 | std=0.173 | wmean=3.251 | wstd=0.183 | score=3.343
# [Epoch 0458] mean=3.258 | std=0.213 | wmean=3.250 | wstd=0.183 | score=3.342
# [Epoch 0459] mean=3.229 | std=0.204 | wmean=3.251 | wstd=0.185 | score=3.344
# [Epoch 0460] mean=3.215 | std=0.143 | wmean=3.250 | wstd=0.184 | score=3.341
# [Epoch 0461] mean=3.308 | std=0.276 | wmean=3.250 | wstd=0.187 | score=3.343
# [Epoch 0462] mean=3.195 | std=0.134 | wmean=3.247 | wstd=0.185 | score=3.340
# [Epoch 0463] mean=3.222 | std=0.155 | wmean=3.247 | wstd=0.186 | score=3.340
# [Epoch 0464] mean=3.259 | std=0.202 | wmean=3.245 | wstd=0.186 | score=3.338
# [Epoch 0465] mean=3.219 | std=0.151 | wmean=3.245 | wstd=0.185 | score=3.337
# [Epoch 0466] mean=3.209 | std=0.216 | wmean=3.244 | wstd=0.186 | score=3.336
# [Epoch 0467] mean=3.229 | std=0.186 | wmean=3.241 | wstd=0.184 | score=3.333
#   + saved
# [Epoch 0468] mean=3.275 | std=0.231 | wmean=3.242 | wstd=0.187 | score=3.336
# [Epoch 0469] mean=3.216 | std=0.203 | wmean=3.241 | wstd=0.188 | score=3.335
# [Epoch 0470] mean=3.278 | std=0.189 | wmean=3.242 | wstd=0.189 | score=3.337
# [Epoch 0471] mean=3.236 | std=0.171 | wmean=3.241 | wstd=0.188 | score=3.335
# [Epoch 0472] mean=3.201 | std=0.147 | wmean=3.240 | wstd=0.187 | score=3.334
# [Epoch 0473] mean=3.199 | std=0.184 | wmean=3.237 | wstd=0.185 | score=3.329
#   + saved
# [Epoch 0474] mean=3.270 | std=0.231 | wmean=3.238 | wstd=0.188 | score=3.332
# [Epoch 0475] mean=3.219 | std=0.156 | wmean=3.237 | wstd=0.187 | score=3.331
# [Epoch 0476] mean=3.237 | std=0.194 | wmean=3.237 | wstd=0.189 | score=3.332
# [Epoch 0477] mean=3.204 | std=0.201 | wmean=3.236 | wstd=0.190 | score=3.331
# [Epoch 0478] mean=3.209 | std=0.209 | wmean=3.235 | wstd=0.192 | score=3.331
# [Epoch 0479] mean=3.273 | std=0.193 | wmean=3.238 | wstd=0.193 | score=3.334
# [Epoch 0480] mean=3.228 | std=0.154 | wmean=3.235 | wstd=0.191 | score=3.331
# [Epoch 0481] mean=3.261 | std=0.162 | wmean=3.236 | wstd=0.192 | score=3.332
# [Epoch 0482] mean=3.196 | std=0.174 | wmean=3.236 | wstd=0.191 | score=3.331
# [Epoch 0483] mean=3.196 | std=0.203 | wmean=3.232 | wstd=0.190 | score=3.328
#   + saved
# [Epoch 0484] mean=3.241 | std=0.172 | wmean=3.233 | wstd=0.191 | score=3.328
# [Epoch 0485] mean=3.214 | std=0.165 | wmean=3.233 | wstd=0.192 | score=3.329
# [Epoch 0486] mean=3.203 | std=0.167 | wmean=3.230 | wstd=0.190 | score=3.325
#   + saved
# [Epoch 0487] mean=3.268 | std=0.230 | wmean=3.232 | wstd=0.192 | score=3.328
# [Epoch 0488] mean=3.239 | std=0.215 | wmean=3.232 | wstd=0.192 | score=3.328
# [Epoch 0489] mean=3.192 | std=0.169 | wmean=3.230 | wstd=0.191 | score=3.326
# [Epoch 0490] mean=3.163 | std=0.149 | wmean=3.229 | wstd=0.192 | score=3.325
#   + saved
# [Epoch 0491] mean=3.315 | std=0.269 | wmean=3.229 | wstd=0.191 | score=3.325
# [Epoch 0492] mean=3.192 | std=0.164 | wmean=3.229 | wstd=0.192 | score=3.325
# [Epoch 0493] mean=3.265 | std=0.282 | wmean=3.230 | wstd=0.197 | score=3.329
# [Epoch 0494] mean=3.269 | std=0.203 | wmean=3.231 | wstd=0.197 | score=3.329
# [Epoch 0495] mean=3.246 | std=0.137 | wmean=3.231 | wstd=0.197 | score=3.330
# [Epoch 0496] mean=3.205 | std=0.141 | wmean=3.231 | wstd=0.195 | score=3.329
# [Epoch 0497] mean=3.170 | std=0.174 | wmean=3.229 | wstd=0.195 | score=3.327
# [Epoch 0498] mean=3.229 | std=0.309 | wmean=3.228 | wstd=0.198 | score=3.327
# [Epoch 0499] mean=3.194 | std=0.143 | wmean=3.227 | wstd=0.196 | score=3.325
# [Epoch 0500] mean=3.239 | std=0.157 | wmean=3.226 | wstd=0.195 | score=3.323
#   + saved
# [Epoch 0501] mean=3.251 | std=0.186 | wmean=3.226 | wstd=0.196 | score=3.324
# [Epoch 0502] mean=3.195 | std=0.131 | wmean=3.226 | wstd=0.195 | score=3.324
# [Epoch 0503] mean=3.249 | std=0.202 | wmean=3.228 | wstd=0.196 | score=3.326
# [Epoch 0504] mean=3.191 | std=0.146 | wmean=3.225 | wstd=0.193 | score=3.322
#   + saved
# [Epoch 0505] mean=3.256 | std=0.267 | wmean=3.226 | wstd=0.197 | score=3.325
# [Epoch 0506] mean=3.285 | std=0.187 | wmean=3.228 | wstd=0.197 | score=3.327
# [Epoch 0507] mean=3.212 | std=0.136 | wmean=3.228 | wstd=0.195 | score=3.326
# [Epoch 0508] mean=3.191 | std=0.185 | wmean=3.228 | wstd=0.194 | score=3.325
# [Epoch 0509] mean=3.211 | std=0.201 | wmean=3.226 | wstd=0.195 | score=3.323
# [Epoch 0510] mean=3.207 | std=0.176 | wmean=3.225 | wstd=0.195 | score=3.323
# [Epoch 0511] mean=3.245 | std=0.190 | wmean=3.224 | wstd=0.196 | score=3.322
# [Epoch 0512] mean=3.195 | std=0.207 | wmean=3.224 | wstd=0.197 | score=3.323
# [Epoch 0513] mean=3.171 | std=0.154 | wmean=3.223 | wstd=0.196 | score=3.321
#   + saved
# [Epoch 0514] mean=3.182 | std=0.173 | wmean=3.222 | wstd=0.196 | score=3.319
#   + saved
# [Epoch 0515] mean=3.171 | std=0.140 | wmean=3.220 | wstd=0.195 | score=3.318
#   + saved
# [Epoch 0516] mean=3.206 | std=0.158 | wmean=3.220 | wstd=0.195 | score=3.318
# [Epoch 0517] mean=3.264 | std=0.210 | wmean=3.220 | wstd=0.194 | score=3.317
#   + saved
# [Epoch 0518] mean=3.211 | std=0.116 | wmean=3.219 | wstd=0.192 | score=3.315
#   + saved
# [Epoch 0519] mean=3.227 | std=0.160 | wmean=3.220 | wstd=0.191 | score=3.316
# [Epoch 0520] mean=3.217 | std=0.143 | wmean=3.222 | wstd=0.191 | score=3.317
# [Epoch 0521] mean=3.272 | std=0.288 | wmean=3.221 | wstd=0.191 | score=3.316
# [Epoch 0522] mean=3.225 | std=0.156 | wmean=3.222 | wstd=0.191 | score=3.317
# [Epoch 0523] mean=3.212 | std=0.111 | wmean=3.220 | wstd=0.185 | score=3.312
#   + saved
# [Epoch 0524] mean=3.211 | std=0.137 | wmean=3.218 | wstd=0.183 | score=3.309
#   + saved
# [Epoch 0525] mean=3.301 | std=0.418 | wmean=3.220 | wstd=0.197 | score=3.318
# [Epoch 0526] mean=3.248 | std=0.168 | wmean=3.221 | wstd=0.197 | score=3.320
# [Epoch 0527] mean=3.326 | std=0.125 | wmean=3.227 | wstd=0.197 | score=3.325
# [Epoch 0528] mean=3.311 | std=0.140 | wmean=3.229 | wstd=0.191 | score=3.325
# [Epoch 0529] mean=3.325 | std=0.127 | wmean=3.234 | wstd=0.191 | score=3.329
# [Epoch 0530] mean=3.298 | std=0.135 | wmean=3.236 | wstd=0.191 | score=3.331
# [Epoch 0531] mean=3.209 | std=0.122 | wmean=3.234 | wstd=0.189 | score=3.329
# [Epoch 0532] mean=3.298 | std=0.274 | wmean=3.238 | wstd=0.195 | score=3.335
# [Epoch 0533] mean=3.261 | std=0.235 | wmean=3.238 | wstd=0.196 | score=3.336
# [Epoch 0534] mean=3.221 | std=0.140 | wmean=3.239 | wstd=0.196 | score=3.337
# [Epoch 0535] mean=3.234 | std=0.165 | wmean=3.238 | wstd=0.192 | score=3.334
# [Epoch 0536] mean=3.199 | std=0.147 | wmean=3.235 | wstd=0.191 | score=3.331
# [Epoch 0537] mean=3.267 | std=0.246 | wmean=3.237 | wstd=0.194 | score=3.334
# [Epoch 0538] mean=3.195 | std=0.204 | wmean=3.237 | wstd=0.195 | score=3.335
# [Epoch 0539] mean=3.161 | std=0.110 | wmean=3.236 | wstd=0.193 | score=3.332
# [Epoch 0540] mean=3.162 | std=0.172 | wmean=3.234 | wstd=0.193 | score=3.331
# [Epoch 0541] mean=3.168 | std=0.176 | wmean=3.232 | wstd=0.193 | score=3.328
# [Epoch 0542] mean=3.191 | std=0.220 | wmean=3.231 | wstd=0.193 | score=3.328
# [Epoch 0543] mean=3.276 | std=0.263 | wmean=3.235 | wstd=0.197 | score=3.334
# [Epoch 0544] mean=3.223 | std=0.138 | wmean=3.236 | wstd=0.196 | score=3.334
# [Epoch 0545] mean=3.242 | std=0.140 | wmean=3.239 | wstd=0.196 | score=3.337
# [Epoch 0546] mean=3.200 | std=0.120 | wmean=3.238 | wstd=0.195 | score=3.336
# [Epoch 0547] mean=3.235 | std=0.222 | wmean=3.237 | wstd=0.195 | score=3.335
# [Epoch 0548] mean=3.208 | std=0.171 | wmean=3.237 | wstd=0.197 | score=3.336
# [Epoch 0549] mean=3.207 | std=0.160 | wmean=3.237 | wstd=0.197 | score=3.335
# [Epoch 0550] mean=3.178 | std=0.145 | wmean=3.235 | wstd=0.197 | score=3.334
# [Epoch 0551] mean=3.241 | std=0.216 | wmean=3.234 | wstd=0.194 | score=3.331
# [Epoch 0552] mean=3.203 | std=0.173 | wmean=3.234 | wstd=0.194 | score=3.331
# [Epoch 0553] mean=3.232 | std=0.192 | wmean=3.234 | wstd=0.196 | score=3.332
# [Epoch 0554] mean=3.271 | std=0.256 | wmean=3.236 | wstd=0.200 | score=3.336
# [Epoch 0555] mean=3.282 | std=0.204 | wmean=3.236 | wstd=0.189 | score=3.330
# [Epoch 0556] mean=3.192 | std=0.147 | wmean=3.234 | wstd=0.188 | score=3.328
# [Epoch 0557] mean=3.180 | std=0.172 | wmean=3.229 | wstd=0.189 | score=3.323
# [Epoch 0558] mean=3.249 | std=0.222 | wmean=3.227 | wstd=0.191 | score=3.322
# [Epoch 0559] mean=3.178 | std=0.146 | wmean=3.222 | wstd=0.191 | score=3.317
# [Epoch 0560] mean=3.166 | std=0.112 | wmean=3.218 | wstd=0.190 | score=3.313
# [Epoch 0561] mean=3.192 | std=0.238 | wmean=3.217 | wstd=0.194 | score=3.314
# [Epoch 0562] mean=3.156 | std=0.149 | wmean=3.212 | wstd=0.189 | score=3.307
#   + saved
# [Epoch 0563] mean=3.167 | std=0.206 | wmean=3.209 | wstd=0.188 | score=3.303
#   + saved
# [Epoch 0564] mean=3.300 | std=0.251 | wmean=3.212 | wstd=0.192 | score=3.308
# [Epoch 0565] mean=3.267 | std=0.233 | wmean=3.213 | wstd=0.195 | score=3.310
# [Epoch 0566] mean=3.296 | std=0.156 | wmean=3.216 | wstd=0.195 | score=3.314
# [Epoch 0567] mean=3.251 | std=0.147 | wmean=3.216 | wstd=0.192 | score=3.312
# [Epoch 0568] mean=3.163 | std=0.138 | wmean=3.215 | wstd=0.190 | score=3.310
# [Epoch 0569] mean=3.248 | std=0.302 | wmean=3.217 | wstd=0.197 | score=3.316
# [Epoch 0570] mean=3.247 | std=0.201 | wmean=3.220 | wstd=0.197 | score=3.319
# [Epoch 0571] mean=3.294 | std=0.159 | wmean=3.224 | wstd=0.197 | score=3.323
# [Epoch 0572] mean=3.194 | std=0.175 | wmean=3.225 | wstd=0.196 | score=3.322
# [Epoch 0573] mean=3.204 | std=0.140 | wmean=3.222 | wstd=0.191 | score=3.318
# [Epoch 0574] mean=3.184 | std=0.147 | wmean=3.221 | wstd=0.192 | score=3.317
# [Epoch 0575] mean=3.208 | std=0.172 | wmean=3.220 | wstd=0.192 | score=3.316
# [Epoch 0576] mean=3.199 | std=0.105 | wmean=3.220 | wstd=0.192 | score=3.316
# [Epoch 0577] mean=3.171 | std=0.129 | wmean=3.218 | wstd=0.189 | score=3.312
# [Epoch 0578] mean=3.238 | std=0.228 | wmean=3.219 | wstd=0.191 | score=3.314
# [Epoch 0579] mean=3.144 | std=0.163 | wmean=3.216 | wstd=0.192 | score=3.312
# [Epoch 0580] mean=3.204 | std=0.188 | wmean=3.217 | wstd=0.193 | score=3.314
# [Epoch 0581] mean=3.231 | std=0.160 | wmean=3.217 | wstd=0.191 | score=3.313
# [Epoch 0582] mean=3.197 | std=0.176 | wmean=3.217 | wstd=0.191 | score=3.313
# [Epoch 0583] mean=3.165 | std=0.141 | wmean=3.215 | wstd=0.190 | score=3.310
# [Epoch 0584] mean=3.195 | std=0.198 | wmean=3.212 | wstd=0.187 | score=3.306
# [Epoch 0585] mean=3.237 | std=0.210 | wmean=3.211 | wstd=0.187 | score=3.304
# [Epoch 0586] mean=3.147 | std=0.153 | wmean=3.209 | wstd=0.188 | score=3.303
# [Epoch 0587] mean=3.169 | std=0.161 | wmean=3.209 | wstd=0.188 | score=3.302
#   + saved
# [Epoch 0588] mean=3.226 | std=0.179 | wmean=3.208 | wstd=0.186 | score=3.301
#   + saved
# [Epoch 0589] mean=3.309 | std=0.212 | wmean=3.212 | wstd=0.189 | score=3.307
# [Epoch 0590] mean=3.261 | std=0.147 | wmean=3.216 | wstd=0.190 | score=3.310
# [Epoch 0591] mean=3.234 | std=0.137 | wmean=3.217 | wstd=0.186 | score=3.310
# [Epoch 0592] mean=3.178 | std=0.151 | wmean=3.218 | wstd=0.186 | score=3.311
# [Epoch 0593] mean=3.244 | std=0.158 | wmean=3.220 | wstd=0.184 | score=3.312
# [Epoch 0594] mean=3.169 | std=0.180 | wmean=3.216 | wstd=0.181 | score=3.306
# [Epoch 0595] mean=3.220 | std=0.188 | wmean=3.214 | wstd=0.179 | score=3.304
# [Epoch 0596] mean=3.201 | std=0.190 | wmean=3.211 | wstd=0.179 | score=3.301
#   + saved
# [Epoch 0597] mean=3.157 | std=0.135 | wmean=3.208 | wstd=0.179 | score=3.298
#   + saved
# [Epoch 0598] mean=3.275 | std=0.239 | wmean=3.212 | wstd=0.183 | score=3.303
# [Epoch 0599] mean=3.199 | std=0.174 | wmean=3.210 | wstd=0.177 | score=3.299
# [Epoch 0600] mean=3.199 | std=0.186 | wmean=3.208 | wstd=0.176 | score=3.297
#   + saved
# [Epoch 0601] mean=3.133 | std=0.150 | wmean=3.203 | wstd=0.176 | score=3.291
#   + saved
# [Epoch 0602] mean=3.226 | std=0.252 | wmean=3.204 | wstd=0.179 | score=3.294
# [Epoch 0603] mean=3.160 | std=0.157 | wmean=3.203 | wstd=0.180 | score=3.293
# [Epoch 0604] mean=3.280 | std=0.214 | wmean=3.206 | wstd=0.182 | score=3.297
# [Epoch 0605] mean=3.223 | std=0.227 | wmean=3.206 | wstd=0.184 | score=3.299
# [Epoch 0606] mean=3.181 | std=0.223 | wmean=3.206 | wstd=0.188 | score=3.300
# [Epoch 0607] mean=3.187 | std=0.155 | wmean=3.206 | wstd=0.189 | score=3.301
# [Epoch 0608] mean=3.286 | std=0.231 | wmean=3.208 | wstd=0.189 | score=3.303
# [Epoch 0609] mean=3.183 | std=0.126 | wmean=3.209 | wstd=0.188 | score=3.303
# [Epoch 0610] mean=3.114 | std=0.152 | wmean=3.206 | wstd=0.188 | score=3.300
# [Epoch 0611] mean=3.163 | std=0.126 | wmean=3.204 | wstd=0.187 | score=3.297
# [Epoch 0612] mean=3.146 | std=0.153 | wmean=3.202 | wstd=0.186 | score=3.296
# [Epoch 0613] mean=3.224 | std=0.279 | wmean=3.204 | wstd=0.191 | score=3.300
# [Epoch 0614] mean=3.245 | std=0.216 | wmean=3.206 | wstd=0.192 | score=3.302
# [Epoch 0615] mean=3.156 | std=0.179 | wmean=3.203 | wstd=0.191 | score=3.299
# [Epoch 0616] mean=3.214 | std=0.351 | wmean=3.206 | wstd=0.200 | score=3.305
# [Epoch 0617] mean=3.255 | std=0.142 | wmean=3.208 | wstd=0.199 | score=3.308
# [Epoch 0618] mean=3.276 | std=0.100 | wmean=3.210 | wstd=0.198 | score=3.309
# [Epoch 0619] mean=3.159 | std=0.088 | wmean=3.205 | wstd=0.194 | score=3.302
# [Epoch 0620] mean=3.183 | std=0.177 | wmean=3.202 | wstd=0.194 | score=3.300
# [Epoch 0621] mean=3.153 | std=0.126 | wmean=3.200 | wstd=0.194 | score=3.297
# [Epoch 0622] mean=3.178 | std=0.151 | wmean=3.200 | wstd=0.194 | score=3.297
# [Epoch 0623] mean=3.240 | std=0.192 | wmean=3.200 | wstd=0.195 | score=3.297
# [Epoch 0624] mean=3.212 | std=0.150 | wmean=3.201 | wstd=0.194 | score=3.298
# [Epoch 0625] mean=3.165 | std=0.132 | wmean=3.199 | wstd=0.193 | score=3.296
# [Epoch 0626] mean=3.182 | std=0.192 | wmean=3.199 | wstd=0.193 | score=3.295
# [Epoch 0627] mean=3.138 | std=0.127 | wmean=3.198 | wstd=0.193 | score=3.294
# [Epoch 0628] mean=3.112 | std=0.151 | wmean=3.192 | wstd=0.190 | score=3.287
#   + saved
# [Epoch 0629] mean=3.131 | std=0.099 | wmean=3.190 | wstd=0.189 | score=3.284
#   + saved
# [Epoch 0630] mean=3.211 | std=0.158 | wmean=3.191 | wstd=0.188 | score=3.284
# [Epoch 0631] mean=3.182 | std=0.096 | wmean=3.192 | wstd=0.186 | score=3.285
# [Epoch 0632] mean=3.178 | std=0.167 | wmean=3.191 | wstd=0.183 | score=3.282
#   + saved
# [Epoch 0633] mean=3.128 | std=0.168 | wmean=3.189 | wstd=0.184 | score=3.281
#   + saved
# [Epoch 0634] mean=3.242 | std=0.292 | wmean=3.188 | wstd=0.187 | score=3.282
# [Epoch 0635] mean=3.204 | std=0.295 | wmean=3.188 | wstd=0.190 | score=3.282
# [Epoch 0636] mean=3.182 | std=0.195 | wmean=3.188 | wstd=0.189 | score=3.282
# [Epoch 0637] mean=3.183 | std=0.113 | wmean=3.187 | wstd=0.188 | score=3.281
# [Epoch 0638] mean=3.226 | std=0.201 | wmean=3.185 | wstd=0.186 | score=3.278
#   + saved
# [Epoch 0639] mean=3.135 | std=0.134 | wmean=3.184 | wstd=0.186 | score=3.277
#   + saved
# [Epoch 0640] mean=3.191 | std=0.194 | wmean=3.186 | wstd=0.187 | score=3.280
# [Epoch 0641] mean=3.169 | std=0.127 | wmean=3.187 | wstd=0.187 | score=3.280
# [Epoch 0642] mean=3.180 | std=0.143 | wmean=3.188 | wstd=0.187 | score=3.281
# [Epoch 0643] mean=3.247 | std=0.227 | wmean=3.189 | wstd=0.184 | score=3.281
# [Epoch 0644] mean=3.159 | std=0.100 | wmean=3.186 | wstd=0.181 | score=3.276
#   + saved
# [Epoch 0645] mean=3.120 | std=0.115 | wmean=3.184 | wstd=0.179 | score=3.274
#   + saved
# [Epoch 0646] mean=3.179 | std=0.144 | wmean=3.183 | wstd=0.170 | score=3.268
#   + saved
# [Epoch 0647] mean=3.171 | std=0.167 | wmean=3.180 | wstd=0.170 | score=3.265
#   + saved
# [Epoch 0648] mean=3.207 | std=0.150 | wmean=3.178 | wstd=0.170 | score=3.263
#   + saved
# [Epoch 0649] mean=3.192 | std=0.132 | wmean=3.179 | wstd=0.171 | score=3.265
# [Epoch 0650] mean=3.184 | std=0.258 | wmean=3.179 | wstd=0.175 | score=3.267
# [Epoch 0651] mean=3.153 | std=0.189 | wmean=3.179 | wstd=0.176 | score=3.267
# [Epoch 0652] mean=3.131 | std=0.151 | wmean=3.178 | wstd=0.177 | score=3.266
# [Epoch 0653] mean=3.201 | std=0.144 | wmean=3.176 | wstd=0.175 | score=3.264
# [Epoch 0654] mean=3.108 | std=0.142 | wmean=3.173 | wstd=0.175 | score=3.260
#   + saved
# [Epoch 0655] mean=3.140 | std=0.122 | wmean=3.172 | wstd=0.175 | score=3.259
#   + saved
# [Epoch 0656] mean=3.182 | std=0.152 | wmean=3.172 | wstd=0.173 | score=3.259
#   + saved
# [Epoch 0657] mean=3.128 | std=0.139 | wmean=3.172 | wstd=0.174 | score=3.259
#   + saved
# [Epoch 0658] mean=3.135 | std=0.157 | wmean=3.173 | wstd=0.174 | score=3.259
# [Epoch 0659] mean=3.109 | std=0.136 | wmean=3.172 | wstd=0.175 | score=3.259
# [Epoch 0660] mean=3.113 | std=0.165 | wmean=3.169 | wstd=0.175 | score=3.256
#   + saved
# [Epoch 0661] mean=3.144 | std=0.145 | wmean=3.167 | wstd=0.176 | score=3.255
#   + saved
# [Epoch 0662] mean=3.116 | std=0.150 | wmean=3.165 | wstd=0.176 | score=3.253
#   + saved
# [Epoch 0663] mean=3.105 | std=0.120 | wmean=3.164 | wstd=0.175 | score=3.252
#   + saved
# [Epoch 0664] mean=3.241 | std=0.253 | wmean=3.164 | wstd=0.173 | score=3.251
#   + saved
# [Epoch 0665] mean=3.145 | std=0.195 | wmean=3.162 | wstd=0.168 | score=3.246
#   + saved
# [Epoch 0666] mean=3.188 | std=0.201 | wmean=3.163 | wstd=0.168 | score=3.247
# [Epoch 0667] mean=3.210 | std=0.131 | wmean=3.164 | wstd=0.169 | score=3.248
# [Epoch 0668] mean=3.190 | std=0.163 | wmean=3.162 | wstd=0.167 | score=3.246
#   + saved
# [Epoch 0669] mean=3.119 | std=0.153 | wmean=3.162 | wstd=0.168 | score=3.246
#   + saved
# [Epoch 0670] mean=3.190 | std=0.196 | wmean=3.162 | wstd=0.168 | score=3.246
# [Epoch 0671] mean=3.161 | std=0.232 | wmean=3.162 | wstd=0.172 | score=3.247
# [Epoch 0672] mean=3.233 | std=0.243 | wmean=3.163 | wstd=0.176 | score=3.251
# [Epoch 0673] mean=3.132 | std=0.123 | wmean=3.159 | wstd=0.172 | score=3.245
#   + saved
# [Epoch 0674] mean=3.178 | std=0.148 | wmean=3.160 | wstd=0.173 | score=3.247
# [Epoch 0675] mean=3.116 | std=0.127 | wmean=3.160 | wstd=0.173 | score=3.247
# [Epoch 0676] mean=3.182 | std=0.184 | wmean=3.160 | wstd=0.174 | score=3.247
# [Epoch 0677] mean=3.064 | std=0.157 | wmean=3.157 | wstd=0.175 | score=3.244
#   + saved
# [Epoch 0678] mean=3.164 | std=0.160 | wmean=3.155 | wstd=0.175 | score=3.243
#   + saved
# [Epoch 0679] mean=3.120 | std=0.153 | wmean=3.153 | wstd=0.175 | score=3.240
#   + saved
# [Epoch 0680] mean=3.166 | std=0.231 | wmean=3.152 | wstd=0.174 | score=3.239
#   + saved
# [Epoch 0681] mean=3.144 | std=0.092 | wmean=3.152 | wstd=0.171 | score=3.238
#   + saved
# [Epoch 0682] mean=3.165 | std=0.252 | wmean=3.153 | wstd=0.175 | score=3.241
# [Epoch 0683] mean=3.107 | std=0.195 | wmean=3.150 | wstd=0.177 | score=3.238
# [Epoch 0684] mean=3.097 | std=0.166 | wmean=3.149 | wstd=0.178 | score=3.238
# [Epoch 0685] mean=3.152 | std=0.132 | wmean=3.150 | wstd=0.178 | score=3.239
# [Epoch 0686] mean=3.131 | std=0.144 | wmean=3.148 | wstd=0.178 | score=3.237
#   + saved
# [Epoch 0687] mean=3.160 | std=0.124 | wmean=3.149 | wstd=0.177 | score=3.238
# [Epoch 0688] mean=3.124 | std=0.082 | wmean=3.149 | wstd=0.176 | score=3.237
#   + saved
# [Epoch 0689] mean=3.083 | std=0.148 | wmean=3.148 | wstd=0.176 | score=3.236
#   + saved
# [Epoch 0690] mean=3.168 | std=0.192 | wmean=3.150 | wstd=0.177 | score=3.238
# [Epoch 0691] mean=3.145 | std=0.192 | wmean=3.150 | wstd=0.179 | score=3.239
# [Epoch 0692] mean=3.166 | std=0.187 | wmean=3.151 | wstd=0.180 | score=3.241
# [Epoch 0693] mean=3.150 | std=0.181 | wmean=3.153 | wstd=0.181 | score=3.244
# [Epoch 0694] mean=3.103 | std=0.135 | wmean=3.148 | wstd=0.176 | score=3.237
# [Epoch 0695] mean=3.250 | std=0.174 | wmean=3.152 | wstd=0.176 | score=3.240
# [Epoch 0696] mean=3.106 | std=0.134 | wmean=3.149 | wstd=0.174 | score=3.236
# [Epoch 0697] mean=3.145 | std=0.166 | wmean=3.147 | wstd=0.175 | score=3.235
#   + saved
# [Epoch 0698] mean=3.148 | std=0.133 | wmean=3.146 | wstd=0.174 | score=3.233
#   + saved
# [Epoch 0699] mean=3.184 | std=0.232 | wmean=3.148 | wstd=0.177 | score=3.236
# [Epoch 0700] mean=3.193 | std=0.216 | wmean=3.148 | wstd=0.178 | score=3.237
# [Epoch 0701] mean=3.418 | std=0.719 | wmean=3.156 | wstd=0.222 | score=3.268
# [Epoch 0702] mean=3.254 | std=0.092 | wmean=3.157 | wstd=0.219 | score=3.267
# [Epoch 0703] mean=3.183 | std=0.156 | wmean=3.159 | wstd=0.219 | score=3.269
# [Epoch 0704] mean=3.171 | std=0.158 | wmean=3.159 | wstd=0.220 | score=3.268
# [Epoch 0705] mean=3.148 | std=0.193 | wmean=3.160 | wstd=0.221 | score=3.270
# [Epoch 0706] mean=3.206 | std=0.255 | wmean=3.161 | wstd=0.224 | score=3.272
# [Epoch 0707] mean=3.162 | std=0.151 | wmean=3.164 | wstd=0.223 | score=3.275
# [Epoch 0708] mean=3.103 | std=0.139 | wmean=3.162 | wstd=0.222 | score=3.273
# [Epoch 0709] mean=3.141 | std=0.150 | wmean=3.162 | wstd=0.222 | score=3.274
# [Epoch 0710] mean=3.129 | std=0.166 | wmean=3.161 | wstd=0.220 | score=3.271
# [Epoch 0711] mean=3.139 | std=0.156 | wmean=3.161 | wstd=0.222 | score=3.272
# [Epoch 0712] mean=3.086 | std=0.098 | wmean=3.158 | wstd=0.218 | score=3.267
# [Epoch 0713] mean=3.066 | std=0.179 | wmean=3.157 | wstd=0.218 | score=3.266
# [Epoch 0714] mean=3.181 | std=0.318 | wmean=3.160 | wstd=0.223 | score=3.272
# [Epoch 0715] mean=3.198 | std=0.081 | wmean=3.161 | wstd=0.223 | score=3.273
# [Epoch 0716] mean=3.235 | std=0.164 | wmean=3.165 | wstd=0.223 | score=3.277
# [Epoch 0717] mean=3.126 | std=0.144 | wmean=3.164 | wstd=0.224 | score=3.276
# [Epoch 0718] mean=3.166 | std=0.166 | wmean=3.165 | wstd=0.225 | score=3.278
# [Epoch 0719] mean=3.178 | std=0.158 | wmean=3.168 | wstd=0.225 | score=3.281
# [Epoch 0720] mean=3.113 | std=0.132 | wmean=3.167 | wstd=0.224 | score=3.278
# [Epoch 0721] mean=3.114 | std=0.194 | wmean=3.165 | wstd=0.224 | score=3.277
# [Epoch 0722] mean=3.212 | std=0.098 | wmean=3.167 | wstd=0.222 | score=3.278
# [Epoch 0723] mean=3.194 | std=0.224 | wmean=3.168 | wstd=0.224 | score=3.280
# [Epoch 0724] mean=3.151 | std=0.135 | wmean=3.170 | wstd=0.223 | score=3.282
# [Epoch 0725] mean=3.116 | std=0.144 | wmean=3.166 | wstd=0.222 | score=3.277
# [Epoch 0726] mean=3.120 | std=0.158 | wmean=3.166 | wstd=0.223 | score=3.277
# [Epoch 0727] mean=3.269 | std=0.325 | wmean=3.170 | wstd=0.229 | score=3.285
# [Epoch 0728] mean=3.170 | std=0.169 | wmean=3.171 | wstd=0.230 | score=3.286
# [Epoch 0729] mean=3.180 | std=0.091 | wmean=3.171 | wstd=0.227 | score=3.284
# [Epoch 0730] mean=3.124 | std=0.110 | wmean=3.168 | wstd=0.224 | score=3.280
# [Epoch 0731] mean=3.128 | std=0.151 | wmean=3.159 | wstd=0.178 | score=3.248
# [Epoch 0732] mean=3.083 | std=0.173 | wmean=3.153 | wstd=0.179 | score=3.243
# [Epoch 0733] mean=3.154 | std=0.146 | wmean=3.152 | wstd=0.179 | score=3.242
# [Epoch 0734] mean=3.107 | std=0.116 | wmean=3.150 | wstd=0.178 | score=3.239
# [Epoch 0735] mean=3.095 | std=0.129 | wmean=3.148 | wstd=0.176 | score=3.236
# [Epoch 0736] mean=3.187 | std=0.302 | wmean=3.148 | wstd=0.179 | score=3.237
# [Epoch 0737] mean=3.176 | std=0.202 | wmean=3.148 | wstd=0.181 | score=3.238
# [Epoch 0738] mean=3.114 | std=0.123 | wmean=3.148 | wstd=0.180 | score=3.238
# [Epoch 0739] mean=3.110 | std=0.112 | wmean=3.147 | wstd=0.179 | score=3.237
# [Epoch 0740] mean=3.080 | std=0.134 | wmean=3.146 | wstd=0.179 | score=3.235
# [Epoch 0741] mean=3.192 | std=0.195 | wmean=3.147 | wstd=0.180 | score=3.238
# [Epoch 0742] mean=3.175 | std=0.169 | wmean=3.150 | wstd=0.182 | score=3.241
# [Epoch 0743] mean=3.112 | std=0.103 | wmean=3.152 | wstd=0.179 | score=3.242
# [Epoch 0744] mean=3.099 | std=0.129 | wmean=3.149 | wstd=0.171 | score=3.235
# [Epoch 0745] mean=3.098 | std=0.157 | wmean=3.146 | wstd=0.173 | score=3.232
#   + saved
# [Epoch 0746] mean=3.081 | std=0.146 | wmean=3.141 | wstd=0.172 | score=3.227
#   + saved
# [Epoch 0747] mean=3.141 | std=0.196 | wmean=3.141 | wstd=0.174 | score=3.228
# [Epoch 0748] mean=3.189 | std=0.215 | wmean=3.142 | wstd=0.176 | score=3.230
# [Epoch 0749] mean=3.152 | std=0.193 | wmean=3.141 | wstd=0.177 | score=3.229
# [Epoch 0750] mean=3.322 | std=0.411 | wmean=3.148 | wstd=0.193 | score=3.245
# [Epoch 0751] mean=3.123 | std=0.131 | wmean=3.148 | wstd=0.191 | score=3.244
# [Epoch 0752] mean=3.306 | std=0.394 | wmean=3.152 | wstd=0.205 | score=3.254
# [Epoch 0753] mean=3.269 | std=0.116 | wmean=3.154 | wstd=0.203 | score=3.256
# [Epoch 0754] mean=3.354 | std=0.123 | wmean=3.161 | wstd=0.206 | score=3.264
# [Epoch 0755] mean=3.314 | std=0.138 | wmean=3.167 | wstd=0.208 | score=3.271
# [Epoch 0756] mean=3.261 | std=0.258 | wmean=3.172 | wstd=0.211 | score=3.278
# [Epoch 0757] mean=3.148 | std=0.128 | wmean=3.168 | wstd=0.203 | score=3.270
# [Epoch 0758] mean=3.176 | std=0.289 | wmean=3.168 | wstd=0.208 | score=3.272
# [Epoch 0759] mean=3.194 | std=0.227 | wmean=3.169 | wstd=0.211 | score=3.274
# [Epoch 0760] mean=3.139 | std=0.127 | wmean=3.169 | wstd=0.212 | score=3.275
# [Epoch 0761] mean=3.047 | std=0.145 | wmean=3.167 | wstd=0.212 | score=3.273
# [Epoch 0762] mean=3.132 | std=0.142 | wmean=3.168 | wstd=0.211 | score=3.274
# [Epoch 0763] mean=3.119 | std=0.148 | wmean=3.167 | wstd=0.211 | score=3.273
# [Epoch 0764] mean=3.210 | std=0.392 | wmean=3.170 | wstd=0.222 | score=3.282
# [Epoch 0765] mean=3.087 | std=0.117 | wmean=3.170 | wstd=0.222 | score=3.281
# [Epoch 0766] mean=3.172 | std=0.142 | wmean=3.170 | wstd=0.217 | score=3.278
# [Epoch 0767] mean=3.090 | std=0.143 | wmean=3.167 | wstd=0.215 | score=3.275
# [Epoch 0768] mean=3.142 | std=0.156 | wmean=3.168 | wstd=0.216 | score=3.276
# [Epoch 0769] mean=3.095 | std=0.142 | wmean=3.167 | wstd=0.217 | score=3.276
# [Epoch 0770] mean=3.185 | std=0.256 | wmean=3.171 | wstd=0.220 | score=3.281
# [Epoch 0771] mean=3.037 | std=0.153 | wmean=3.166 | wstd=0.220 | score=3.276
# [Epoch 0772] mean=3.122 | std=0.154 | wmean=3.164 | wstd=0.220 | score=3.274
# [Epoch 0773] mean=3.050 | std=0.156 | wmean=3.162 | wstd=0.221 | score=3.272
# [Epoch 0774] mean=3.182 | std=0.292 | wmean=3.165 | wstd=0.226 | score=3.278
# [Epoch 0775] mean=3.114 | std=0.156 | wmean=3.165 | wstd=0.226 | score=3.278
# [Epoch 0776] mean=3.142 | std=0.162 | wmean=3.167 | wstd=0.226 | score=3.280
# [Epoch 0777] mean=3.185 | std=0.149 | wmean=3.169 | wstd=0.225 | score=3.281
# [Epoch 0778] mean=3.106 | std=0.128 | wmean=3.166 | wstd=0.223 | score=3.277
# [Epoch 0779] mean=3.111 | std=0.134 | wmean=3.164 | wstd=0.222 | score=3.275
# [Epoch 0780] mean=3.147 | std=0.161 | wmean=3.159 | wstd=0.208 | score=3.263
# [Epoch 0781] mean=3.140 | std=0.186 | wmean=3.159 | wstd=0.210 | score=3.264
# [Epoch 0782] mean=3.168 | std=0.130 | wmean=3.155 | wstd=0.197 | score=3.253
# [Epoch 0783] mean=3.124 | std=0.110 | wmean=3.150 | wstd=0.195 | score=3.247
# [Epoch 0784] mean=3.183 | std=0.224 | wmean=3.144 | wstd=0.195 | score=3.241
# [Epoch 0785] mean=3.127 | std=0.178 | wmean=3.138 | wstd=0.193 | score=3.235
# [Epoch 0786] mean=3.161 | std=0.251 | wmean=3.134 | wstd=0.192 | score=3.230
# [Epoch 0787] mean=3.137 | std=0.201 | wmean=3.134 | wstd=0.194 | score=3.231
# [Epoch 0788] mean=3.123 | std=0.126 | wmean=3.132 | wstd=0.188 | score=3.226
#   + saved
# [Epoch 0789] mean=3.095 | std=0.137 | wmean=3.129 | wstd=0.185 | score=3.221
#   + saved
# [Epoch 0790] mean=3.094 | std=0.192 | wmean=3.128 | wstd=0.187 | score=3.221
#   + saved
# [Epoch 0791] mean=3.086 | std=0.135 | wmean=3.129 | wstd=0.186 | score=3.222
# [Epoch 0792] mean=3.098 | std=0.170 | wmean=3.128 | wstd=0.187 | score=3.221
# [Epoch 0793] mean=3.146 | std=0.332 | wmean=3.129 | wstd=0.194 | score=3.226
# [Epoch 0794] mean=3.169 | std=0.223 | wmean=3.127 | wstd=0.185 | score=3.220
#   + saved
# [Epoch 0795] mean=3.251 | std=0.231 | wmean=3.133 | wstd=0.190 | score=3.227
# [Epoch 0796] mean=3.098 | std=0.141 | wmean=3.130 | wstd=0.190 | score=3.225
# [Epoch 0797] mean=3.129 | std=0.112 | wmean=3.132 | wstd=0.189 | score=3.226
# [Epoch 0798] mean=3.203 | std=0.423 | wmean=3.134 | wstd=0.202 | score=3.235
# [Epoch 0799] mean=3.115 | std=0.160 | wmean=3.134 | wstd=0.203 | score=3.236
# [Epoch 0800] mean=3.096 | std=0.122 | wmean=3.131 | wstd=0.198 | score=3.230
# [Epoch 0801] mean=3.144 | std=0.273 | wmean=3.135 | wstd=0.202 | score=3.236
# [Epoch 0802] mean=3.063 | std=0.149 | wmean=3.133 | wstd=0.202 | score=3.234
# [Epoch 0803] mean=3.078 | std=0.148 | wmean=3.134 | wstd=0.202 | score=3.235
# [Epoch 0804] mean=3.164 | std=0.270 | wmean=3.133 | wstd=0.200 | score=3.233
# [Epoch 0805] mean=3.173 | std=0.354 | wmean=3.135 | wstd=0.209 | score=3.240
# [Epoch 0806] mean=3.112 | std=0.136 | wmean=3.134 | wstd=0.208 | score=3.238
# [Epoch 0807] mean=3.076 | std=0.096 | wmean=3.131 | wstd=0.207 | score=3.234
# [Epoch 0808] mean=3.159 | std=0.278 | wmean=3.132 | wstd=0.212 | score=3.238
# [Epoch 0809] mean=3.219 | std=0.274 | wmean=3.136 | wstd=0.217 | score=3.244
# [Epoch 0810] mean=3.142 | std=0.230 | wmean=3.136 | wstd=0.219 | score=3.245
# [Epoch 0811] mean=3.040 | std=0.179 | wmean=3.132 | wstd=0.220 | score=3.242
# [Epoch 0812] mean=3.064 | std=0.166 | wmean=3.129 | wstd=0.221 | score=3.239
# [Epoch 0813] mean=3.135 | std=0.264 | wmean=3.129 | wstd=0.225 | score=3.242
# [Epoch 0814] mean=3.065 | std=0.199 | wmean=3.125 | wstd=0.224 | score=3.237
# [Epoch 0815] mean=3.039 | std=0.099 | wmean=3.122 | wstd=0.223 | score=3.234
# [Epoch 0816] mean=3.196 | std=0.294 | wmean=3.124 | wstd=0.225 | score=3.236
# [Epoch 0817] mean=3.089 | std=0.156 | wmean=3.122 | wstd=0.224 | score=3.234
# [Epoch 0818] mean=3.095 | std=0.119 | wmean=3.121 | wstd=0.224 | score=3.233
# [Epoch 0819] mean=3.149 | std=0.133 | wmean=3.123 | wstd=0.224 | score=3.235
# [Epoch 0820] mean=3.105 | std=0.147 | wmean=3.123 | wstd=0.223 | score=3.235
# [Epoch 0821] mean=3.073 | std=0.127 | wmean=3.123 | wstd=0.223 | score=3.234
# [Epoch 0822] mean=3.120 | std=0.316 | wmean=3.124 | wstd=0.228 | score=3.237
# [Epoch 0823] mean=3.139 | std=0.193 | wmean=3.123 | wstd=0.222 | score=3.235
# [Epoch 0824] mean=3.151 | std=0.258 | wmean=3.123 | wstd=0.224 | score=3.235
# [Epoch 0825] mean=3.073 | std=0.127 | wmean=3.117 | wstd=0.220 | score=3.227
# [Epoch 0826] mean=3.072 | std=0.132 | wmean=3.116 | wstd=0.220 | score=3.226
# [Epoch 0827] mean=3.096 | std=0.141 | wmean=3.115 | wstd=0.220 | score=3.225
# [Epoch 0828] mean=3.147 | std=0.191 | wmean=3.113 | wstd=0.208 | score=3.217
#   + saved
# [Epoch 0829] mean=3.066 | std=0.159 | wmean=3.111 | wstd=0.209 | score=3.216
#   + saved
# [Epoch 0830] mean=3.075 | std=0.169 | wmean=3.111 | wstd=0.210 | score=3.216
#   + saved
# [Epoch 0831] mean=3.140 | std=0.204 | wmean=3.111 | wstd=0.207 | score=3.214
#   + saved
# [Epoch 0832] mean=3.402 | std=0.743 | wmean=3.122 | wstd=0.251 | score=3.248
# [Epoch 0833] mean=3.078 | std=0.118 | wmean=3.122 | wstd=0.251 | score=3.247
# [Epoch 0834] mean=3.228 | std=0.318 | wmean=3.124 | wstd=0.253 | score=3.251
# [Epoch 0835] mean=3.416 | std=0.227 | wmean=3.132 | wstd=0.254 | score=3.259
# [Epoch 0836] mean=3.338 | std=0.197 | wmean=3.140 | wstd=0.258 | score=3.268
# [Epoch 0837] mean=3.383 | std=0.147 | wmean=3.150 | wstd=0.262 | score=3.281
# [Epoch 0838] mean=3.363 | std=0.155 | wmean=3.157 | wstd=0.261 | score=3.287
# [Epoch 0839] mean=3.311 | std=0.185 | wmean=3.160 | wstd=0.260 | score=3.290
# [Epoch 0840] mean=3.367 | std=0.283 | wmean=3.167 | wstd=0.264 | score=3.299
# [Epoch 0841] mean=3.402 | std=0.131 | wmean=3.179 | wstd=0.266 | score=3.312
# [Epoch 0842] mean=3.300 | std=0.163 | wmean=3.187 | wstd=0.265 | score=3.320
# [Epoch 0843] mean=3.363 | std=0.235 | wmean=3.195 | wstd=0.266 | score=3.328
# [Epoch 0844] mean=3.402 | std=0.114 | wmean=3.206 | wstd=0.266 | score=3.339
# [Epoch 0845] mean=3.354 | std=0.148 | wmean=3.216 | wstd=0.266 | score=3.349
# [Epoch 0846] mean=3.331 | std=0.201 | wmean=3.221 | wstd=0.264 | score=3.353
# [Epoch 0847] mean=3.347 | std=0.164 | wmean=3.230 | wstd=0.264 | score=3.361
# [Epoch 0848] mean=3.392 | std=0.180 | wmean=3.239 | wstd=0.265 | score=3.372
# [Epoch 0849] mean=3.381 | std=0.082 | wmean=3.247 | wstd=0.265 | score=3.380
# [Epoch 0850] mean=3.407 | std=0.315 | wmean=3.257 | wstd=0.270 | score=3.392
# [Epoch 0851] mean=3.399 | std=0.127 | wmean=3.268 | wstd=0.269 | score=3.403
# [Epoch 0852] mean=3.417 | std=0.147 | wmean=3.278 | wstd=0.264 | score=3.410
# [Epoch 0853] mean=3.372 | std=0.126 | wmean=3.286 | wstd=0.262 | score=3.417
# [Epoch 0854] mean=3.380 | std=0.205 | wmean=3.293 | wstd=0.260 | score=3.423
# [Epoch 0855] mean=3.337 | std=0.216 | wmean=3.302 | wstd=0.259 | score=3.432
# [Epoch 0856] mean=3.348 | std=0.223 | wmean=3.311 | wstd=0.257 | score=3.440
# [Epoch 0857] mean=3.395 | std=0.137 | wmean=3.321 | wstd=0.254 | score=3.449
# [Epoch 0858] mean=3.382 | std=0.127 | wmean=3.329 | wstd=0.251 | score=3.455
# [Epoch 0859] mean=3.389 | std=0.160 | wmean=3.340 | wstd=0.246 | score=3.463
# [Epoch 0860] mean=3.375 | std=0.195 | wmean=3.350 | wstd=0.242 | score=3.471
# [Epoch 0861] mean=3.386 | std=0.178 | wmean=3.358 | wstd=0.238 | score=3.477
# [Epoch 0862] mean=3.345 | std=0.133 | wmean=3.356 | wstd=0.197 | score=3.455
# [Epoch 0863] mean=3.363 | std=0.182 | wmean=3.366 | wstd=0.192 | score=3.462
# [Epoch 0864] mean=3.357 | std=0.184 | wmean=3.370 | wstd=0.184 | score=3.462
# [Epoch 0865] mean=3.363 | std=0.140 | wmean=3.368 | wstd=0.181 | score=3.459
# [Epoch 0866] mean=3.355 | std=0.234 | wmean=3.369 | wstd=0.183 | score=3.460
# [Epoch 0867] mean=3.352 | std=0.140 | wmean=3.368 | wstd=0.183 | score=3.459
# [Epoch 0868] mean=3.357 | std=0.128 | wmean=3.368 | wstd=0.182 | score=3.459
# [Epoch 0869] mean=3.357 | std=0.137 | wmean=3.369 | wstd=0.180 | score=3.459
# [Epoch 0870] mean=3.318 | std=0.212 | wmean=3.368 | wstd=0.177 | score=3.456
# [Epoch 0871] mean=3.359 | std=0.153 | wmean=3.366 | wstd=0.178 | score=3.455
# [Epoch 0872] mean=3.349 | std=0.167 | wmean=3.368 | wstd=0.177 | score=3.456
# [Epoch 0873] mean=3.332 | std=0.167 | wmean=3.367 | wstd=0.175 | score=3.454
# [Epoch 0874] mean=3.340 | std=0.180 | wmean=3.365 | wstd=0.177 | score=3.453
# [Epoch 0875] mean=3.340 | std=0.171 | wmean=3.364 | wstd=0.177 | score=3.453
# [Epoch 0876] mean=3.336 | std=0.188 | wmean=3.364 | wstd=0.177 | score=3.453
# [Epoch 0877] mean=3.323 | std=0.103 | wmean=3.364 | wstd=0.175 | score=3.451
# [Epoch 0878] mean=3.341 | std=0.153 | wmean=3.362 | wstd=0.175 | score=3.449
# [Epoch 0879] mean=3.347 | std=0.213 | wmean=3.361 | wstd=0.178 | score=3.450
# [Epoch 0880] mean=3.344 | std=0.124 | wmean=3.359 | wstd=0.170 | score=3.444
# [Epoch 0881] mean=3.323 | std=0.158 | wmean=3.356 | wstd=0.171 | score=3.441
# [Epoch 0882] mean=3.339 | std=0.178 | wmean=3.353 | wstd=0.171 | score=3.439
# [Epoch 0883] mean=3.315 | std=0.126 | wmean=3.352 | wstd=0.172 | score=3.437
# [Epoch 0884] mean=3.337 | std=0.209 | wmean=3.350 | wstd=0.172 | score=3.436
# [Epoch 0885] mean=3.353 | std=0.169 | wmean=3.351 | wstd=0.170 | score=3.436
# [Epoch 0886] mean=3.384 | std=0.171 | wmean=3.352 | wstd=0.168 | score=3.436
# [Epoch 0887] mean=3.398 | std=0.132 | wmean=3.352 | wstd=0.168 | score=3.436
# [Epoch 0888] mean=3.345 | std=0.180 | wmean=3.351 | wstd=0.169 | score=3.435
# [Epoch 0889] mean=3.315 | std=0.153 | wmean=3.348 | wstd=0.169 | score=3.433
# [Epoch 0890] mean=3.315 | std=0.194 | wmean=3.346 | wstd=0.169 | score=3.431
# [Epoch 0891] mean=3.332 | std=0.147 | wmean=3.344 | wstd=0.168 | score=3.428
# [Epoch 0892] mean=3.343 | std=0.137 | wmean=3.344 | wstd=0.168 | score=3.428
# [Epoch 0893] mean=3.332 | std=0.124 | wmean=3.343 | wstd=0.166 | score=3.426
# [Epoch 0894] mean=3.367 | std=0.223 | wmean=3.344 | wstd=0.168 | score=3.428
# [Epoch 0895] mean=3.336 | std=0.110 | wmean=3.343 | wstd=0.167 | score=3.426
# [Epoch 0896] mean=3.360 | std=0.168 | wmean=3.343 | wstd=0.164 | score=3.425
# [Epoch 0897] mean=3.361 | std=0.156 | wmean=3.343 | wstd=0.165 | score=3.426
# [Epoch 0898] mean=3.348 | std=0.165 | wmean=3.343 | wstd=0.166 | score=3.426
# [Epoch 0899] mean=3.330 | std=0.134 | wmean=3.342 | wstd=0.166 | score=3.425
# [Epoch 0900] mean=3.338 | std=0.191 | wmean=3.343 | wstd=0.165 | score=3.425
# [Epoch 0901] mean=3.350 | std=0.139 | wmean=3.342 | wstd=0.165 | score=3.425
# [Epoch 0902] mean=3.356 | std=0.170 | wmean=3.343 | wstd=0.165 | score=3.425
# [Epoch 0903] mean=3.377 | std=0.139 | wmean=3.344 | wstd=0.164 | score=3.426
# [Epoch 0904] mean=3.326 | std=0.127 | wmean=3.344 | wstd=0.162 | score=3.425
# [Epoch 0905] mean=3.374 | std=0.230 | wmean=3.345 | wstd=0.165 | score=3.427
# [Epoch 0906] mean=3.390 | std=0.169 | wmean=3.347 | wstd=0.164 | score=3.429
# [Epoch 0907] mean=3.375 | std=0.131 | wmean=3.348 | wstd=0.165 | score=3.431
# [Epoch 0908] mean=3.326 | std=0.120 | wmean=3.348 | wstd=0.164 | score=3.430
# [Epoch 0909] mean=3.327 | std=0.219 | wmean=3.347 | wstd=0.164 | score=3.429
# [Epoch 0910] mean=3.344 | std=0.209 | wmean=3.347 | wstd=0.167 | score=3.431
# [Epoch 0911] mean=3.329 | std=0.090 | wmean=3.347 | wstd=0.166 | score=3.430
# [Epoch 0912] mean=3.323 | std=0.118 | wmean=3.347 | wstd=0.164 | score=3.429
# [Epoch 0913] mean=3.332 | std=0.163 | wmean=3.347 | wstd=0.165 | score=3.430
# [Epoch 0914] mean=3.331 | std=0.174 | wmean=3.347 | wstd=0.164 | score=3.429
# [Epoch 0915] mean=3.281 | std=0.126 | wmean=3.345 | wstd=0.163 | score=3.426
# [Epoch 0916] mean=3.287 | std=0.116 | wmean=3.342 | wstd=0.161 | score=3.422
# [Epoch 0917] mean=3.343 | std=0.273 | wmean=3.340 | wstd=0.167 | score=3.423
# [Epoch 0918] mean=3.374 | std=0.205 | wmean=3.341 | wstd=0.168 | score=3.425
# [Epoch 0919] mean=3.319 | std=0.067 | wmean=3.341 | wstd=0.166 | score=3.424
# [Epoch 0920] mean=3.361 | std=0.166 | wmean=3.342 | wstd=0.165 | score=3.425
# [Epoch 0921] mean=3.341 | std=0.233 | wmean=3.343 | wstd=0.168 | score=3.427
# [Epoch 0922] mean=3.318 | std=0.210 | wmean=3.342 | wstd=0.171 | score=3.427
# [Epoch 0923] mean=3.300 | std=0.112 | wmean=3.341 | wstd=0.170 | score=3.426
# [Epoch 0924] mean=3.337 | std=0.206 | wmean=3.340 | wstd=0.170 | score=3.425
# [Epoch 0925] mean=3.369 | std=0.133 | wmean=3.341 | wstd=0.170 | score=3.426
# [Epoch 0926] mean=3.353 | std=0.102 | wmean=3.341 | wstd=0.169 | score=3.425
# [Epoch 0927] mean=3.358 | std=0.126 | wmean=3.340 | wstd=0.168 | score=3.424
# [Epoch 0928] mean=3.329 | std=0.149 | wmean=3.340 | wstd=0.167 | score=3.423
# [Epoch 0929] mean=3.338 | std=0.251 | wmean=3.340 | wstd=0.172 | score=3.426
# [Epoch 0930] mean=3.364 | std=0.158 | wmean=3.341 | wstd=0.171 | score=3.426
# [Epoch 0931] mean=3.332 | std=0.154 | wmean=3.340 | wstd=0.171 | score=3.426
# 🛑 Early stopping triggered

# %% [markdown]
# # Save last results

# %%
# ---- Always save LAST at end of training ----
last_checkpoint = {
    'epoch': epoch,
    'model_state': net.state_dict(),
    'optimizer_state': optimizer.state_dict(),
    'best_score': best_score,
    'mean_losses': mean_losses,
    'std_losses': std_losses,
    'scores': scores,
    'epochs': epochs,
    'all_epoch_unit_losses': all_epoch_unit_losses,
    "rng_torch": torch.random.get_rng_state(),
    "rng_numpy": np.random.get_state(),
}

torch.save(last_checkpoint, checkpoint_last_path)
print("✓ Final LAST checkpoint saved.")
# Out:
# ✓ Final LAST checkpoint saved.

# %% [markdown]
# ## Plot

# %%
epochs_arr = np.array(epochs)
mean_arr = np.array(mean_losses)
std_arr = np.array(std_losses)
scores_arr = np.array(scores)


# ignore first epochs where score is not valid
best_idx = np.argmin(scores_arr[LOSS_WINDOW-1:]) + (LOSS_WINDOW-1)  
best_epoch = epochs_arr[best_idx]
best_score = scores_arr[best_idx]

plt.figure(figsize=(8, 5))

# Main curves
plt.plot(epochs_arr, mean_arr, linewidth=2, label='mean loss')
plt.plot(epochs_arr, mean_arr+AVERSION*std_arr, linewidth=2, label=f'mean+{AVERSION}std')
plt.plot(epochs_arr, scores_arr, linewidth=2, label='risk score')

ymin, ymax = plt.ylim()
yrange = ymax - ymin

y_offset = 0.5 * yrange      # 8% of axis height
x_offset = -0.05 * (epochs_arr.max() - epochs_arr.min())

# ---- Annotation instead of scatter ----
plt.annotate(
    f"min score = {best_score:.3f}\nepoch = {best_epoch}",
    xy=(best_epoch, best_score),
    xytext=(best_epoch + x_offset, best_score + y_offset),
    textcoords='data',
    arrowprops=dict(arrowstyle="->", linewidth=1),
    fontsize=9,
    bbox=dict(boxstyle="round,pad=0.3", fc="white", alpha=0.8),
)

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title(f'{perform_name} PF network training')
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save figure
fig_path = PERFORM_DIR / "net_training_loss.png"
plt.savefig(fig_path, dpi=300)

# Save raw arrays
np.save(PERFORM_DIR/ "net_training_mean.npy", mean_arr)
np.save(PERFORM_DIR / "net_training_std.npy", std_arr)
np.save(PERFORM_DIR / "net_training_scores.npy", scores_arr)

plt.show()

print(f"✓ Plot saved to {fig_path}")
print(f"✓ Best epoch: {best_epoch} (score={best_score:.4f})")
# Out:
# ✓ Plot saved to experiments/DS03/opcond_q0-1/estimation/gamma/net256x256x128x64x32_leaky0.05_npar2000_aversion0.5_losswin30_losstail5/SmHPC/net_training_loss.png
# ✓ Best epoch: 831 (score=3.2141)
