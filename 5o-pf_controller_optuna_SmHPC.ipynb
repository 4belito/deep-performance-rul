# %% [markdown]
# # Tune the bootstrap-PF gains with Optuna (full 13-parameter search)
#
# The no-network baseline (`use_net=False`) replaces the 13 controller outputs with
# fixed gains. Here we tune **all 13**: one process-noise scale **per state dim** (6),
# one prior-regularization weight **per state dim** (6), and a single likelihood
# temperature (1). Objective = leave-one-unit-out dev tail-NLL (same metric as
# training). Trials are CPU-bound and parallelize across cores via `n_jobs`.

# %%
import json
import os

import numpy as np
import optuna
import pandas as pd
import torch

from experiment_config import SEED, DegModel, dataset_paths, pfnet_paths
from src.helpers.seed import set_global_seed
from src.models.particle_filter.core import ParticleFilter
from src.training.pfnet_hparams import PFNET_ARGS

# %% [markdown]
# ## Configuration

# %%
DATA_NAME = "DS06"
EVAL_REPS = 3
N_TRIALS = 600

perform_name = "SmHPC"

# %%
ARGS_ID = 0

# PF + eval settings come from the shared config so tuning matches the pipeline
_args = PFNET_ARGS[ARGS_ID]
N_PARTICLES = int(_args["PARTICLE_FILTER"]["N_PARTICLES"])
MAX_LIFE = int(_args["PARTICLE_FILTER"]["MAX_LIFE"])
LOSS_TAIL_STEPS = int(_args["TRAINING"]["LOSS_TAIL_STEPS"])
SEED_STRIDE = int(_args["EVALUATION"]["SEED_STRIDE"])

STATE_DIM = DegModel.state_dim()  # 6 -> 13 gains (6 noise + 6 prior + 1 lik)


# one torch thread per Optuna worker so threads do not oversubscribe the cores
torch.set_num_threads(1)
N_JOBS = int(os.environ.get("SLURM_CPUS_PER_TASK") or os.cpu_count() or 1)

ESTIMATION_DIR, DEGR_MODEL_DIR = dataset_paths(
    DATA_NAME, fields=["estimation", "degr_model"]
)
# per-metric folder, mirroring the training layout net_arg{ARGS_ID}/{perform_name}
PFNET_ARGS_DIR, _ = pfnet_paths(ARGS_ID, DATA_NAME)
PERFORM_DIR = PFNET_ARGS_DIR / perform_name
PERFORM_DIR.mkdir(parents=True, exist_ok=True)
set_global_seed(SEED)
print(f"n_jobs={N_JOBS} | output: {PERFORM_DIR}")
# Out:
# n_jobs=8 | output: /lustre/diazgonz/deep-performance-rul/experiments/DS06/opcond_q0.001-0.999_corr0.6_range0.6/estimation_thr0.2/gamma/net_arg0/SmHPC

# %% [markdown]
# ## Load dev data and degradation models (once)

# %%
dev_hi = pd.read_csv(ESTIMATION_DIR / "data_dev.csv")
dev_units = sorted(dev_hi["unit"].astype(int).unique().tolist())
...


def build_tensors(df, name):
    out = {}
    for u in dev_units:
        sub = df[df["unit"] == u]
        out[u] = torch.tensor(
            np.stack([sub["cycle"].values, sub[name].values], axis=1),
            dtype=torch.float32,
        )
    return out


# single-metric tuning: load only the target performance metric
dev_tensors = build_tensors(dev_hi, perform_name)
dev_degmodels = {}
for u in dev_units:
    m = DegModel()
    m.load_state_dict(
        torch.load(
            DEGR_MODEL_DIR / "states" / perform_name / f"unit_{u}" / "best_model.pt"
        )
    )
    dev_degmodels[u] = m

print("dev units:", dev_units, "| metric:", perform_name)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/deep-performance-rul/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'SmHPC'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 18
#      14     return out
#      15
#      16
#      17 # single-metric tuning: load only the target performance metric
# ---> 18 dev_tensors = build_tensors(dev_hi, perform_name)
#      19 dev_degmodels = {}
#      20 for u in dev_units:
#      21     m = DegModel()
#
# Cell In[4], line 11, in build_tensors(df, name)
#       7     out = {}
#       8     for u in dev_units:
#       9         sub = df[df["unit"] == u]
#      10         out[u] = torch.tensor(
# ---> 11             np.stack([sub["cycle"].values, sub[name].values], axis=1),
#      12             dtype=torch.float32,
#      13         )
#      14     return out
#
# File ~/deep-performance-rul/.venv/lib/python3.11/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~/deep-performance-rul/.venv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'SmHPC'

# %% [markdown]
# ## Tail-NLL evaluation with tunable gains

# %%
def tail_nll(pf, t_data, s_data):
    step_losses = []
    for k in range(len(t_data)):
        mixture = pf.step(t_obs=t_data[[k]], s_obs=s_data[[k]])
        start = -LOSS_TAIL_STEPS if LOSS_TAIL_STEPS else k
        dist = mixture.distribution(s=s_data[start:])
        step_losses.append(-dist.log_prob(t_data[start:]).mean())
    return float(torch.stack(step_losses).mean().item())


@torch.no_grad()
def eval_unit(base_models, unit_tensor, seeds, cn, cp, cl):
    t_data, s_data = unit_tensor[:, 0], unit_tensor[:, 1]
    reps = []
    for sd in seeds:
        with torch.random.fork_rng(devices=[]):
            torch.manual_seed(sd)
            pf = ParticleFilter(
                base_models=base_models,
                net=None,
                n_particles=N_PARTICLES,
                max_life=MAX_LIFE,
                use_net=False,
                const_noise=cn,
                const_prior=cp,
                const_lik=cl,
            ).eval()
            reps.append(tail_nll(pf, t_data, s_data))
    return float(np.mean(reps))

# %% [markdown]
# ## Objective: leave-one-unit-out dev tail-NLL for a single metric

# %%
def objective(trial):
    cn = [
        trial.suggest_float(f"noise_{d}", 0.05, 5.0, log=True) for d in range(STATE_DIM)
    ]
    cp = [trial.suggest_float(f"prior_{d}", 0.0, 2.0) for d in range(STATE_DIM)]
    cl = trial.suggest_float("lik", 0.1, 10.0, log=True)
    losses = []
    for u in dev_units:
        base = [dev_degmodels[v] for v in dev_units if v != u]
        seeds = [SEED + u * SEED_STRIDE + r for r in range(EVAL_REPS)]
        losses.append(eval_unit(base, dev_tensors[u], seeds, cn, cp, cl))
    return float(np.mean(losses))

# %% [markdown]
# ## Run the study (parallel, resumable)

# %%
storage = f"sqlite:///{(PERFORM_DIR / 'optuna_pf_gains.db').as_posix()}"
study = optuna.create_study(
    direction="minimize",
    study_name=f"pf_gains_{perform_name}_{DATA_NAME}",
    storage=storage,
    load_if_exists=True,  # resumable + multi-worker safe
    sampler=optuna.samplers.TPESampler(seed=SEED),
)

out_json = PERFORM_DIR / "optuna_best_gains.json"


def _best_gains(study):
    b = study.best_params
    return {
        "NOISE": [round(b[f"noise_{d}"], 4) for d in range(STATE_DIM)],
        "PRIOR": [round(b[f"prior_{d}"], 4) for d in range(STATE_DIM)],
        "LIK": round(b["lik"], 4),
    }


def save_best_gains(study, trial):
    """Write the running-best gains whenever a trial improves (live monitoring)."""
    if study.best_trial.number != trial.number:
        return
    tmp = out_json.with_name(out_json.name + f".{trial.number}.tmp")
    tmp.write_text(json.dumps(_best_gains(study), indent=2))
    os.replace(tmp, out_json)  # atomic swap: readers never see a partial file


# N_TRIALS is the TOTAL target: run only the trials still missing in the db.
# Re-running with the same N_TRIALS just reports; a larger N_TRIALS tops up.
n_done = len(
    study.get_trials(deepcopy=False, states=(optuna.trial.TrialState.COMPLETE,))
)
n_remaining = max(0, N_TRIALS - n_done)
print(
    f"{n_done} completed trials in db; running {n_remaining} more to reach {N_TRIALS}"
)
if n_remaining:
    study.optimize(
        objective,
        n_trials=n_remaining,
        n_jobs=N_JOBS,
        show_progress_bar=True,
        callbacks=[save_best_gains],
    )

b = study.best_params
print(f"best value ({perform_name} mean tail-NLL):", study.best_value)

# final write (also covers resumed runs with no new best during this session)
best_gains = _best_gains(study)
out_json.write_text(json.dumps(best_gains, indent=2))
print("saved:", out_json)

print(f"\n# {perform_name} tuned gains, paste into PFNET_ARGS:")
print(
    f"    gains_=gains(noise={best_gains['NOISE']}, "
    f"prior={best_gains['PRIOR']}, lik={best_gains['LIK']}),"
)
# Out:
# [I 2026-08-06 11:11:46,023] A new study created in RDB with name: pf_gains_SmHPC_DS06
# 0 completed trials in db; running 600 more to reach 600
#   0%|          | 0/600 [00:00<?, ?it/s]
# [W 2026-08-06 11:11:48,112] Trial 0 failed with parameters: {'noise_0': 0.48148849171310776, 'noise_1': 2.379330561764397, 'noise_2': 0.14373270649709544, 'noise_3': 0.07178309335792138, 'noise_4': 1.0852003631889309, 'noise_5': 0.8617698942039976, 'prior_0': 1.0209714291342775, 'prior_1': 1.291681941728596, 'prior_2': 0.7540514103161307, 'prior_3': 1.1481798659957207, 'prior_4': 0.11000431578995484, 'prior_5': 1.2737999436989498, 'lik': 2.2261300523374214} because of the following error: NameError("name 'dev_degmodels' is not defined").
# Traceback (most recent call last):
#   File "/home/diazgonz/deep-performance-rul/.venv/lib/python3.11/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in objective
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in <listcomp>
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#             ^^^^^^^^^^^^^
# NameError: name 'dev_degmodels' is not defined
# [W 2026-08-06 11:11:48,116] Trial 0 failed with value None.
# [W 2026-08-06 11:11:48,245] Trial 1 failed with parameters: {'noise_0': 0.6939175995546438, 'noise_1': 0.13422774218533776, 'noise_2': 0.06837826631707204, 'noise_3': 0.19703814298657477, 'noise_4': 0.6623962349444579, 'noise_5': 4.04329076518735, 'prior_0': 0.4844349461418507, 'prior_1': 1.9797363166152573, 'prior_2': 0.7491932797232508, 'prior_3': 0.2880111892425221, 'prior_4': 0.7784898176621895, 'prior_5': 1.5857062601347978, 'lik': 6.738094218253026} because of the following error: NameError("name 'dev_degmodels' is not defined").
# Traceback (most recent call last):
#   File "/home/diazgonz/deep-performance-rul/.venv/lib/python3.11/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in objective
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in <listcomp>
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#             ^^^^^^^^^^^^^
# NameError: name 'dev_degmodels' is not defined
# [W 2026-08-06 11:11:48,247] Trial 1 failed with value None.
# [W 2026-08-06 11:11:48,333] Trial 3 failed with parameters: {'noise_0': 0.9189901134974272, 'noise_1': 1.0847666866248526, 'noise_2': 0.631189440890443, 'noise_3': 0.11392993936247646, 'noise_4': 0.1926098638218434, 'noise_5': 0.11331603529539984, 'prior_0': 0.5186363744517133, 'prior_1': 1.4913341289779054, 'prior_2': 1.7123050396293715, 'prior_3': 0.6468755634790655, 'prior_4': 0.8008838217114491, 'prior_5': 0.35005865201600206, 'lik': 0.11128611966266737} because of the following error: NameError("name 'dev_degmodels' is not defined").
# Traceback (most recent call last):
#   File "/home/diazgonz/deep-performance-rul/.venv/lib/python3.11/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in objective
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in <listcomp>
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#             ^^^^^^^^^^^^^
# NameError: name 'dev_degmodels' is not defined
# [W 2026-08-06 11:11:48,335] Trial 3 failed with value None.
# [W 2026-08-06 11:11:48,349] Trial 2 failed with parameters: {'noise_0': 0.6919285088585528, 'noise_1': 0.06283161988037077, 'noise_2': 1.7734381179130527, 'noise_3': 0.11406698775838905, 'noise_4': 0.9271720626519541, 'noise_5': 0.8753130090486442, 'prior_0': 1.6565543887781795, 'prior_1': 1.9453309159341632, 'prior_2': 1.7074396665589888, 'prior_3': 0.013412409972443085, 'prior_4': 0.7203221186241333, 'prior_5': 0.6154261305548037, 'lik': 6.392174442237465} because of the following error: NameError("name 'dev_degmodels' is not defined").
# Traceback (most recent call last):
#   File "/home/diazgonz/deep-performance-rul/.venv/lib/python3.11/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in objective
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in <listcomp>
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#             ^^^^^^^^^^^^^
# NameError: name 'dev_degmodels' is not defined
# [W 2026-08-06 11:11:48,350] Trial 2 failed with value None.
# [W 2026-08-06 11:11:48,365] Trial 4 failed with parameters: {'noise_0': 0.05971855452400197, 'noise_1': 0.9212501737075715, 'noise_2': 0.4267491982046815, 'noise_3': 0.06468453591154948, 'noise_4': 0.7781833593204587, 'noise_5': 0.26103744393037903, 'prior_0': 0.5309289543813842, 'prior_1': 1.5500315145697199, 'prior_2': 1.7378850770516667, 'prior_3': 0.0582342204647841, 'prior_4': 0.9274493788979281, 'prior_5': 1.296023380460397, 'lik': 0.80264317457953} because of the following error: NameError("name 'dev_degmodels' is not defined").
# Traceback (most recent call last):
#   File "/home/diazgonz/deep-performance-rul/.venv/lib/python3.11/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in objective
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in <listcomp>
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#             ^^^^^^^^^^^^^
# NameError: name 'dev_degmodels' is not defined
# [W 2026-08-06 11:11:48,366] Trial 4 failed with value None.
# [W 2026-08-06 11:11:48,486] Trial 6 failed with parameters: {'noise_0': 0.23018353791836477, 'noise_1': 1.7635972162249123, 'noise_2': 2.028763399119453, 'noise_3': 0.7914386867957789, 'noise_4': 0.058538755778679986, 'noise_5': 0.4154471021315078, 'prior_0': 0.22413374574013933, 'prior_1': 1.6074331637093182, 'prior_2': 0.33554940587286364, 'prior_3': 0.47450690038998466, 'prior_4': 1.2067176341670083, 'prior_5': 1.7826528994683801, 'lik': 0.8841155495242097} because of the following error: NameError("name 'dev_degmodels' is not defined").
# Traceback (most recent call last):
#   File "/home/diazgonz/deep-performance-rul/.venv/lib/python3.11/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in objective
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in <listcomp>
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#             ^^^^^^^^^^^^^
# NameError: name 'dev_degmodels' is not defined
# [W 2026-08-06 11:11:48,487] Trial 6 failed with value None.
# [W 2026-08-06 11:11:48,508] Trial 5 failed with parameters: {'noise_0': 4.718717172767493, 'noise_1': 0.39793416797721326, 'noise_2': 1.086033833882725, 'noise_3': 0.7361247621376287, 'noise_4': 1.0001055960393692, 'noise_5': 4.312973613503603, 'prior_0': 0.6336314512330041, 'prior_1': 0.29852467201666055, 'prior_2': 0.48378568265911137, 'prior_3': 0.24170617937967265, 'prior_4': 0.563352603005812, 'prior_5': 1.5943062231136984, 'lik': 0.5135950352126043} because of the following error: NameError("name 'dev_degmodels' is not defined").
# Traceback (most recent call last):
#   File "/home/diazgonz/deep-performance-rul/.venv/lib/python3.11/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in objective
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in <listcomp>
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#             ^^^^^^^^^^^^^
# NameError: name 'dev_degmodels' is not defined
# [W 2026-08-06 11:11:48,509] Trial 5 failed with value None.
# [W 2026-08-06 11:11:48,522] Trial 7 failed with parameters: {'noise_0': 0.6525192525529669, 'noise_1': 0.2618796523737953, 'noise_2': 0.2967451890898974, 'noise_3': 1.0417435468173246, 'noise_4': 0.1887656675012199, 'noise_5': 0.24346788075692222, 'prior_0': 1.306048438546273, 'prior_1': 0.7503036845316113, 'prior_2': 0.3736618278049917, 'prior_3': 1.7411814583702756, 'prior_4': 1.3631776806886884, 'prior_5': 1.3066691153055445, 'lik': 0.11577536955334598} because of the following error: NameError("name 'dev_degmodels' is not defined").
# Traceback (most recent call last):
#   File "/home/diazgonz/deep-performance-rul/.venv/lib/python3.11/site-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in objective
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/tmp/ipykernel_3215003/3561507617.py", line 9, in <listcomp>
#     base = [dev_degmodels[v] for v in dev_units if v != u]
#             ^^^^^^^^^^^^^
# NameError: name 'dev_degmodels' is not defined
# [W 2026-08-06 11:11:48,523] Trial 7 failed with value None.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 41
#      37 print(
#      38     f"{n_done} completed trials in db; running {n_remaining} more to reach {N_TRIALS}"
#      39 )
#      40 if n_remaining:
# ---> 41     study.optimize(
#      42         objective,
#      43         n_trials=n_remaining,
#      44         n_jobs=N_JOBS,
#
# File ~/deep-performance-rul/.venv/lib/python3.11/site-packages/optuna/study/study.py:516, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     414 def optimize(
#     415     self,
#     416     func: ObjectiveFuncType,
#    (...)    423     show_progress_bar: bool = False,
#     424 ) -> None:
#     425     """Optimize an objective function.
#     426
#     427     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    514             If nested invocation of this method occurs.
#     515     """
# --> 516     _optimize(
#     517         study=self,
#     518         func=func,
#     519         n_trials=n_trials,
#     520         timeout=timeout,
#     521         n_jobs=n_jobs,
#     522         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     523         callbacks=callbacks,
#     524         gc_after_trial=gc_after_trial,
#     525         show_progress_bar=show_progress_bar,
#     526     )
#
# File ~/deep-performance-rul/.venv/lib/python3.11/site-packages/optuna/study/_optimize.py:105, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     103                     # Raise if exception occurred in executing the completed futures.
#     104                     for f in completed:
# --> 105                         f.result()
#     107                 futures.add(
#     108                     executor.submit(
#     109                         _optimize_sequential,
#    (...)    120                     )
#     121                 )
#     122 finally:
#
# File ~/.local/share/uv/python/cpython-3.11.15-linux-x86_64-gnu/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/.local/share/uv/python/cpython-3.11.15-linux-x86_64-gnu/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~/.local/share/uv/python/cpython-3.11.15-linux-x86_64-gnu/lib/python3.11/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/deep-performance-rul/.venv/lib/python3.11/site-packages/optuna/study/_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File ~/deep-performance-rul/.venv/lib/python3.11/site-packages/optuna/study/_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File ~/deep-performance-rul/.venv/lib/python3.11/site-packages/optuna/study/_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# Cell In[6], line 9, in objective(trial)
#       5     cp = [trial.suggest_float(f"prior_{d}", 0.0, 2.0) for d in range(STATE_DIM)]
#       6     cl = trial.suggest_float("lik", 0.1, 10.0, log=True)
#       7     losses = []
#       8     for u in dev_units:
# ----> 9         base = [dev_degmodels[v] for v in dev_units if v != u]
#      10         seeds = [SEED + u * SEED_STRIDE + r for r in range(EVAL_REPS)]
#      11         losses.append(eval_unit(base, dev_tensors[u], seeds, cn, cp, cl))
#      12     return float(np.mean(losses))
#
# Cell In[6], line 9, in objective.<locals>.<listcomp>(.0)
# ----> 9 def objective(trial):
#      10     cn = [
#      11         trial.suggest_float(f"noise_{d}", 0.05, 5.0, log=True) for d in range(STATE_DIM)
#      12     ]
#
# NameError: name 'dev_degmodels' is not defined

# %% [markdown]
# ## Sanity check: tuned vs default gains

# %%
def dev_score(cn, cp, cl):
    return float(
        np.mean(
            [
                eval_unit(
                    [dev_degmodels[v] for v in dev_units if v != u],
                    dev_tensors[u],
                    [SEED + u * SEED_STRIDE + r for r in range(EVAL_REPS)],
                    cn,
                    cp,
                    cl,
                )
                for u in dev_units
            ]
        )
    )


b = study.best_params
noise_vec = [b[f"noise_{d}"] for d in range(STATE_DIM)]
prior_vec = [b[f"prior_{d}"] for d in range(STATE_DIM)]
lik = b["lik"]
print("default:", dev_score([1.0] * STATE_DIM, [0.0] * STATE_DIM, 1.0))
print("tuned  :", dev_score(noise_vec, prior_vec, lik))
print("best params:", b)
# Out:
# default: 4.154591454399957
# tuned  : 3.5940485397974644
# best params: {'noise_0': 0.1509940279618476, 'noise_1': 2.3521215317034674, 'noise_2': 0.17367744287314962, 'noise_3': 0.06126072947841066, 'noise_4': 0.6060049504238149, 'noise_5': 0.10624430122575133, 'prior_0': 0.10841291763955156, 'prior_1': 0.15500146366679124, 'prior_2': 0.6590605196520979, 'prior_3': 1.6367929608520997, 'prior_4': 1.1593372750972104, 'prior_5': 1.7765065456146418, 'lik': 0.4948052671626285}
