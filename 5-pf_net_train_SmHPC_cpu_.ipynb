# %% [markdown]
# ## Train the PF-Controller Neural Network
#
# For each performance metric, train the corresponding particle-filter (PF) controller neural network.

# %%
import os

# use the CPUs allocated by SLURM (fallback 4); set before numpy/torch import so
# the BLAS/OpenMP backend also honors the thread count
N_CPUS = int(os.environ.get("SLURM_CPUS_PER_TASK") or 4)
os.environ.setdefault("OMP_NUM_THREADS", str(N_CPUS))
os.environ.setdefault("MKL_NUM_THREADS", str(N_CPUS))

import numpy as np  # noqa: E402
import pandas as pd  # noqa: E402
import torch  # noqa: E402
from matplotlib import pyplot as plt  # noqa: E402

from experiment_config import (  # noqa: E402
    SEED,
    DegModel,
    dataset_paths,
)
from src.helpers.seed import set_global_seed  # noqa: E402
from src.models.networks.pf_mlp import ParticleFilterMLP  # noqa: E402
from src.training.pfnet_hparams import PFNET_ARGS  # noqa: E402
from src.training.pfnet_training import train_pf_controller_cv  # noqa: E402

torch.set_num_threads(N_CPUS)
print(f"CPU threads: {torch.get_num_threads()} (N_CPUS={N_CPUS})")
# Out:
# CPU threads: 4 (N_CPUS=4)

# %% [markdown]
# ## Task

# %%
DATA_NAME = "DS01"
perform_name = "SmHPC"
ARGS_ID = 8

# %% [markdown]
# ## Hyper-Parameters

# %%
args = PFNET_ARGS[ARGS_ID]

net_args = args["NETWORK"]

if net_args is None:
    raise SystemExit(
        "This ARGS_ID is a no-network baseline (NETWORK=None): there is no "
        "network to train. Use it only in the test/ablation notebooks."
    )
pf_args = args["PARTICLE_FILTER"]
train_args = args["TRAINING"]
eval_args = args["EVALUATION"]

# %%
set_global_seed(SEED)

ESTIMATION_DIR, DEGR_MODEL_DIR = dataset_paths(
    DATA_NAME, fields=["estimation", "degr_model"]
)

PFNET_ARGS_DIR = DEGR_MODEL_DIR / f"net_arg{ARGS_ID}"
PERFORM_DIR = PFNET_ARGS_DIR / perform_name

checkpoint_best_path = PERFORM_DIR / "checkpoint_best.pt"
checkpoint_last_path = PERFORM_DIR / "checkpoint_last.pt"
checkpoint_best_path.parent.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Import training data

# %%
hi_df = pd.read_csv(ESTIMATION_DIR / "data_dev.csv")
units = hi_df["unit"].astype(int).unique().tolist()
units
# Out:
# [1, 2, 4, 5, 6]

# %% [markdown]
# ### Extract degradation onset

# %%
onsets = {
    unit: hi_df[(hi_df["unit"] == unit) & (hi_df["hs"] == 0)]["cycle"].values[0]
    for unit in units
}
del hi_df["hs"]

# %%
perform_names = [col for col in hi_df.columns if col not in ["unit", "cycle"]]

performs = {
    name: {unit: hi_df[hi_df["unit"] == unit][name].values for unit in units}
    for name in perform_names
}

init_ss = {
    name: {unit: perform[unit].max() for unit in units}
    for name, perform in performs.items()
}
time = {unit: hi_df[hi_df["unit"] == unit]["cycle"].values for unit in units}

# %% [markdown]
# ## Create component (base) models

# %%
dev_data = {}
dev_eol = {}
for unit in units:
    t = time[unit]
    s = performs[perform_name][unit]
    dev_data[unit] = torch.tensor(np.stack([t, s], axis=1), dtype=torch.float32)
    dev_eol[unit] = torch.tensor(t[-1], dtype=torch.float32)

# %%
dev_degmodels = {}
for unit in performs[perform_name]:
    best_model = DegModel(onset=onsets[unit], init_s=init_ss[perform_name][unit])
    best_model.load_state_dict(
        torch.load(
            DEGR_MODEL_DIR / "states" / perform_name / f"unit_{unit}" / "best_model.pt"
        )
    )
    dev_degmodels[unit] = best_model

# %% [markdown]
# ## Train Particle Filter controller Net

# %%
from src.models.networks.pf_mlp import build_activation

net = ParticleFilterMLP(
    state_dim=DegModel.state_dim(),
    hidden_dims=list(net_args["HIDDEN_DIMS"]),
    activation=build_activation(net_args),
    dropout_p=float(net_args["DROPOUT"]),
)

optimizer = torch.optim.Adam(net.parameters(), float(train_args["LR"]))
optimizer.zero_grad()

# %%
best_score = float("inf")
train_epoch_losses = []
eval_epoch_losses = []
scores = []
start_epoch = 0

if checkpoint_last_path.exists():
    ckpt = torch.load(checkpoint_last_path, weights_only=False)

    net.load_state_dict(ckpt["model_state"])
    optimizer.load_state_dict(ckpt["optimizer_state"])

    start_epoch = ckpt["epoch"] + 1
    best_score = ckpt["best_score"]
    scores = ckpt.get("scores", [])
    train_epoch_losses = ckpt.get("train_losses", [])
    eval_epoch_losses = ckpt.get("eval_losses", [])

    torch.random.set_rng_state(ckpt["rng_torch"])
    np.random.set_state(ckpt["rng_numpy"])

    print(f"✓ Resumed from epoch {start_epoch}, best_score={best_score:.3f}")

# %%
train_state = train_pf_controller_cv(
    net=net,
    optimizer=optimizer,
    units=units,
    dev_data=dev_data,
    dev_degmodels=dev_degmodels,
    n_particles=int(pf_args["N_PARTICLES"]),
    max_life=int(pf_args["MAX_LIFE"]),
    loss_tail_steps=int(train_args["LOSS_TAIL_STEPS"]),
    n_epochs=int(train_args["N_EPOCHS"]),
    checkpoint_best_path=checkpoint_best_path,
    checkpoint_last_path=checkpoint_last_path,
    start_epoch=start_epoch,
    best_score=best_score,
    scores=scores,
    train_epoch_losses=train_epoch_losses,
    eval_epoch_losses=eval_epoch_losses,
    seed=SEED,
    eval_repetitions=int(eval_args["REPETITIONS"]),
    eval_seed_stride=int(eval_args["SEED_STRIDE"]),
    eval_initial_interval_epochs=int(eval_args["INITIAL_INTERVAL_EPOCHS"]),
    eval_final_interval_epochs=int(eval_args["FINAL_INTERVAL_EPOCHS"]),
    match_train_eval_prior=bool(train_args.get("MATCH_TRAIN_EVAL_PRIOR", False)),
    verbose=True,
)

best_score = train_state["best_score"]
scores = train_state["scores"]
train_epoch_losses = train_state["train_epoch_losses"]
eval_epoch_losses = train_state["eval_epoch_losses"]
epoch = train_state["epoch"]
best_checkpoint = train_state["best_checkpoint"]

if best_checkpoint is None and checkpoint_best_path.exists():
    best_checkpoint = torch.load(checkpoint_best_path, weights_only=False)
# Out:
# [Epoch 000] train=4.310 | eval=3.959 | score=3.959 (eval_every~12)
#   + saved (score=3.959)
# [Epoch 001] train=3.669 | eval=skipped (eval_every~12)
# [Epoch 002] train=3.540 | eval=skipped (eval_every~12)
# [Epoch 003] train=3.450 | eval=skipped (eval_every~12)
# [Epoch 004] train=3.367 | eval=skipped (eval_every~12)
# [Epoch 005] train=3.361 | eval=skipped (eval_every~12)
# [Epoch 006] train=3.379 | eval=skipped (eval_every~12)
# [Epoch 007] train=3.376 | eval=skipped (eval_every~12)
# [Epoch 008] train=3.328 | eval=skipped (eval_every~12)
# [Epoch 009] train=3.357 | eval=skipped (eval_every~12)
# [Epoch 010] train=3.369 | eval=skipped (eval_every~12)
# [Epoch 011] train=3.346 | eval=skipped (eval_every~12)
# [Epoch 012] train=3.346 | eval=3.293 | score=3.293 (eval_every~12)
#   + saved (score=3.293)
# [Epoch 013] train=3.353 | eval=skipped (eval_every~12)
# [Epoch 014] train=3.336 | eval=skipped (eval_every~11)
# [Epoch 015] train=3.333 | eval=skipped (eval_every~11)
# [Epoch 016] train=3.322 | eval=skipped (eval_every~11)
# [Epoch 017] train=3.326 | eval=skipped (eval_every~11)
# [Epoch 018] train=3.311 | eval=skipped (eval_every~11)
# [Epoch 019] train=3.286 | eval=skipped (eval_every~11)
# [Epoch 020] train=3.286 | eval=skipped (eval_every~11)
# [Epoch 021] train=3.265 | eval=skipped (eval_every~11)
# [Epoch 022] train=3.279 | eval=skipped (eval_every~11)
# [Epoch 023] train=3.226 | eval=skipped (eval_every~11)
# [Epoch 024] train=3.249 | eval=3.201 | score=3.201 (eval_every~11)
#   + saved (score=3.201)
# [Epoch 025] train=3.194 | eval=skipped (eval_every~11)
# [Epoch 026] train=3.250 | eval=skipped (eval_every~11)
# [Epoch 027] train=3.239 | eval=skipped (eval_every~11)
# [Epoch 028] train=3.240 | eval=skipped (eval_every~11)
# [Epoch 029] train=3.206 | eval=skipped (eval_every~11)
# [Epoch 030] train=3.247 | eval=skipped (eval_every~11)
# [Epoch 031] train=3.227 | eval=skipped (eval_every~11)
# [Epoch 032] train=3.211 | eval=skipped (eval_every~11)
# [Epoch 033] train=3.194 | eval=skipped (eval_every~11)
# [Epoch 034] train=3.225 | eval=skipped (eval_every~11)
# [Epoch 035] train=3.180 | eval=3.188 | score=3.188 (eval_every~11)
#   + saved (score=3.188)
# [Epoch 036] train=3.200 | eval=skipped (eval_every~11)
# [Epoch 037] train=3.192 | eval=skipped (eval_every~11)
# [Epoch 038] train=3.184 | eval=skipped (eval_every~11)
# [Epoch 039] train=3.218 | eval=skipped (eval_every~11)
# [Epoch 040] train=3.150 | eval=skipped (eval_every~11)
# [Epoch 041] train=3.206 | eval=skipped (eval_every~10)
# [Epoch 042] train=3.187 | eval=skipped (eval_every~10)
# [Epoch 043] train=3.176 | eval=skipped (eval_every~10)
# [Epoch 044] train=3.204 | eval=skipped (eval_every~10)
# [Epoch 045] train=3.206 | eval=skipped (eval_every~10)
# [Epoch 046] train=3.186 | eval=3.171 | score=3.171 (eval_every~10)
#   + saved (score=3.171)
# [Epoch 047] train=3.187 | eval=skipped (eval_every~10)
# [Epoch 048] train=3.189 | eval=skipped (eval_every~10)
# [Epoch 049] train=3.151 | eval=skipped (eval_every~10)
# [Epoch 050] train=3.154 | eval=skipped (eval_every~10)
# [Epoch 051] train=3.153 | eval=skipped (eval_every~10)
# [Epoch 052] train=3.170 | eval=skipped (eval_every~10)
# [Epoch 053] train=3.154 | eval=skipped (eval_every~10)
# [Epoch 054] train=3.189 | eval=skipped (eval_every~10)
# [Epoch 055] train=3.140 | eval=skipped (eval_every~10)
# [Epoch 056] train=3.118 | eval=3.165 | score=3.165 (eval_every~10)
#   + saved (score=3.165)
# [Epoch 057] train=3.123 | eval=skipped (eval_every~10)
# [Epoch 058] train=3.139 | eval=skipped (eval_every~10)
# [Epoch 059] train=3.186 | eval=skipped (eval_every~10)
# [Epoch 060] train=3.131 | eval=skipped (eval_every~10)
# [Epoch 061] train=3.175 | eval=skipped (eval_every~10)
# [Epoch 062] train=3.140 | eval=skipped (eval_every~10)
# [Epoch 063] train=3.149 | eval=skipped (eval_every~10)
# [Epoch 064] train=3.132 | eval=skipped (eval_every~10)
# [Epoch 065] train=3.150 | eval=skipped (eval_every~10)
# [Epoch 066] train=3.120 | eval=3.130 | score=3.130 (eval_every~10)
#   + saved (score=3.130)
# [Epoch 067] train=3.153 | eval=skipped (eval_every~10)
# [Epoch 068] train=3.116 | eval=skipped (eval_every~9)
# [Epoch 069] train=3.104 | eval=skipped (eval_every~9)
# [Epoch 070] train=3.160 | eval=skipped (eval_every~9)
# [Epoch 071] train=3.130 | eval=skipped (eval_every~9)
# [Epoch 072] train=3.093 | eval=skipped (eval_every~9)
# [Epoch 073] train=3.083 | eval=skipped (eval_every~9)
# [Epoch 074] train=3.107 | eval=skipped (eval_every~9)
# [Epoch 075] train=3.134 | eval=skipped (eval_every~9)
# [Epoch 076] train=3.129 | eval=3.047 | score=3.047 (eval_every~9)
#   + saved (score=3.047)
# [Epoch 077] train=3.137 | eval=skipped (eval_every~9)
# [Epoch 078] train=3.076 | eval=skipped (eval_every~9)
# [Epoch 079] train=3.124 | eval=skipped (eval_every~9)
# [Epoch 080] train=3.102 | eval=skipped (eval_every~9)
# [Epoch 081] train=3.079 | eval=skipped (eval_every~9)
# [Epoch 082] train=3.122 | eval=skipped (eval_every~9)
# [Epoch 083] train=3.122 | eval=skipped (eval_every~9)
# [Epoch 084] train=3.081 | eval=skipped (eval_every~9)
# [Epoch 085] train=3.078 | eval=3.060 | score=3.060 (eval_every~9)
# [Epoch 086] train=3.096 | eval=skipped (eval_every~9)
# [Epoch 087] train=3.128 | eval=skipped (eval_every~9)
# [Epoch 088] train=3.132 | eval=skipped (eval_every~9)
# [Epoch 089] train=3.114 | eval=skipped (eval_every~9)
# [Epoch 090] train=3.110 | eval=skipped (eval_every~9)
# [Epoch 091] train=3.073 | eval=skipped (eval_every~9)
# [Epoch 092] train=3.087 | eval=skipped (eval_every~9)
# [Epoch 093] train=3.088 | eval=skipped (eval_every~9)
# [Epoch 094] train=3.093 | eval=3.073 | score=3.073 (eval_every~9)
# [Epoch 095] train=3.120 | eval=skipped (eval_every~9)
# [Epoch 096] train=3.100 | eval=skipped (eval_every~8)
# [Epoch 097] train=3.107 | eval=skipped (eval_every~8)
# [Epoch 098] train=3.115 | eval=skipped (eval_every~8)
# [Epoch 099] train=3.069 | eval=skipped (eval_every~8)
# [Epoch 100] train=3.084 | eval=skipped (eval_every~8)
# [Epoch 101] train=3.068 | eval=skipped (eval_every~8)
# [Epoch 102] train=3.103 | eval=skipped (eval_every~8)
# [Epoch 103] train=3.083 | eval=3.038 | score=3.038 (eval_every~8)
#   + saved (score=3.038)
# [Epoch 104] train=3.061 | eval=skipped (eval_every~8)
# [Epoch 105] train=3.075 | eval=skipped (eval_every~8)
# [Epoch 106] train=3.087 | eval=skipped (eval_every~8)
# [Epoch 107] train=3.082 | eval=skipped (eval_every~8)
# [Epoch 108] train=3.095 | eval=skipped (eval_every~8)
# [Epoch 109] train=3.107 | eval=skipped (eval_every~8)
# [Epoch 110] train=3.081 | eval=skipped (eval_every~8)
# [Epoch 111] train=3.078 | eval=3.051 | score=3.051 (eval_every~8)
# [Epoch 112] train=3.066 | eval=skipped (eval_every~8)
# [Epoch 113] train=3.046 | eval=skipped (eval_every~8)
# [Epoch 114] train=3.117 | eval=skipped (eval_every~8)
# [Epoch 115] train=3.069 | eval=skipped (eval_every~8)
# [Epoch 116] train=3.097 | eval=skipped (eval_every~8)
# [Epoch 117] train=3.087 | eval=skipped (eval_every~8)
# [Epoch 118] train=3.093 | eval=skipped (eval_every~8)
# [Epoch 119] train=3.076 | eval=3.029 | score=3.029 (eval_every~8)
#   + saved (score=3.029)
# [Epoch 120] train=3.089 | eval=skipped (eval_every~8)
# [Epoch 121] train=3.054 | eval=skipped (eval_every~8)
# [Epoch 122] train=3.064 | eval=skipped (eval_every~8)
# [Epoch 123] train=3.079 | eval=skipped (eval_every~7)
# [Epoch 124] train=3.058 | eval=skipped (eval_every~7)
# [Epoch 125] train=3.043 | eval=skipped (eval_every~7)
# [Epoch 126] train=3.074 | eval=skipped (eval_every~7)
# [Epoch 127] train=3.066 | eval=3.008 | score=3.008 (eval_every~7)
#   + saved (score=3.008)
# [Epoch 128] train=3.078 | eval=skipped (eval_every~7)
# [Epoch 129] train=3.058 | eval=skipped (eval_every~7)
# [Epoch 130] train=3.057 | eval=skipped (eval_every~7)
# [Epoch 131] train=3.051 | eval=skipped (eval_every~7)
# [Epoch 132] train=3.057 | eval=skipped (eval_every~7)
# [Epoch 133] train=3.074 | eval=skipped (eval_every~7)
# [Epoch 134] train=3.055 | eval=3.005 | score=3.005 (eval_every~7)
#   + saved (score=3.005)
# [Epoch 135] train=3.042 | eval=skipped (eval_every~7)
# [Epoch 136] train=3.064 | eval=skipped (eval_every~7)
# [Epoch 137] train=3.043 | eval=skipped (eval_every~7)
# [Epoch 138] train=3.053 | eval=skipped (eval_every~7)
# [Epoch 139] train=3.058 | eval=skipped (eval_every~7)
# [Epoch 140] train=3.025 | eval=skipped (eval_every~7)
# [Epoch 141] train=3.046 | eval=3.022 | score=3.022 (eval_every~7)
# [Epoch 142] train=3.055 | eval=skipped (eval_every~7)
# [Epoch 143] train=3.057 | eval=skipped (eval_every~7)
# [Epoch 144] train=3.056 | eval=skipped (eval_every~7)
# [Epoch 145] train=3.041 | eval=skipped (eval_every~7)
# [Epoch 146] train=3.055 | eval=skipped (eval_every~7)
# [Epoch 147] train=3.033 | eval=skipped (eval_every~7)
# [Epoch 148] train=3.049 | eval=2.977 | score=2.977 (eval_every~7)
#   + saved (score=2.977)
# [Epoch 149] train=3.010 | eval=skipped (eval_every~7)
# [Epoch 150] train=3.040 | eval=skipped (eval_every~6)
# [Epoch 151] train=3.045 | eval=skipped (eval_every~6)
# [Epoch 152] train=3.050 | eval=skipped (eval_every~6)
# [Epoch 153] train=3.036 | eval=skipped (eval_every~6)
# [Epoch 154] train=3.051 | eval=skipped (eval_every~6)
# [Epoch 155] train=3.051 | eval=2.972 | score=2.972 (eval_every~6)
#   + saved (score=2.972)
# [Epoch 156] train=3.050 | eval=skipped (eval_every~6)
# [Epoch 157] train=3.030 | eval=skipped (eval_every~6)
# [Epoch 158] train=3.033 | eval=skipped (eval_every~6)
# [Epoch 159] train=3.026 | eval=skipped (eval_every~6)
# [Epoch 160] train=3.039 | eval=skipped (eval_every~6)
# [Epoch 161] train=3.010 | eval=2.971 | score=2.971 (eval_every~6)
#   + saved (score=2.971)
# [Epoch 162] train=3.030 | eval=skipped (eval_every~6)
# [Epoch 163] train=3.018 | eval=skipped (eval_every~6)
# [Epoch 164] train=3.028 | eval=skipped (eval_every~6)
# [Epoch 165] train=3.064 | eval=skipped (eval_every~6)
# [Epoch 166] train=3.015 | eval=skipped (eval_every~6)
# [Epoch 167] train=3.029 | eval=2.968 | score=2.968 (eval_every~6)
#   + saved (score=2.968)
# [Epoch 168] train=3.022 | eval=skipped (eval_every~6)
# [Epoch 169] train=3.002 | eval=skipped (eval_every~6)
# [Epoch 170] train=3.001 | eval=skipped (eval_every~6)
# [Epoch 171] train=3.003 | eval=skipped (eval_every~6)
# [Epoch 172] train=3.017 | eval=skipped (eval_every~6)
# [Epoch 173] train=3.002 | eval=2.956 | score=2.956 (eval_every~6)
#   + saved (score=2.956)
# [Epoch 174] train=2.980 | eval=skipped (eval_every~6)
# [Epoch 175] train=3.048 | eval=skipped (eval_every~6)
# [Epoch 176] train=2.973 | eval=skipped (eval_every~6)
# [Epoch 177] train=2.988 | eval=skipped (eval_every~5)
# [Epoch 178] train=3.002 | eval=skipped (eval_every~5)
# [Epoch 179] train=3.020 | eval=2.935 | score=2.935 (eval_every~5)
#   + saved (score=2.935)
# [Epoch 180] train=2.988 | eval=skipped (eval_every~5)
# [Epoch 181] train=3.002 | eval=skipped (eval_every~5)
# [Epoch 182] train=2.991 | eval=skipped (eval_every~5)
# [Epoch 183] train=3.000 | eval=skipped (eval_every~5)
# [Epoch 184] train=2.995 | eval=2.929 | score=2.929 (eval_every~5)
#   + saved (score=2.929)
# [Epoch 185] train=3.021 | eval=skipped (eval_every~5)
# [Epoch 186] train=2.993 | eval=skipped (eval_every~5)
# [Epoch 187] train=2.989 | eval=skipped (eval_every~5)
# [Epoch 188] train=3.014 | eval=skipped (eval_every~5)
# [Epoch 189] train=2.990 | eval=2.950 | score=2.950 (eval_every~5)
# [Epoch 190] train=2.987 | eval=skipped (eval_every~5)
# [Epoch 191] train=3.000 | eval=skipped (eval_every~5)
# [Epoch 192] train=3.011 | eval=skipped (eval_every~5)
# [Epoch 193] train=2.993 | eval=skipped (eval_every~5)
# [Epoch 194] train=3.001 | eval=2.965 | score=2.965 (eval_every~5)
# [Epoch 195] train=2.995 | eval=skipped (eval_every~5)
# [Epoch 196] train=2.982 | eval=skipped (eval_every~5)
# [Epoch 197] train=2.980 | eval=skipped (eval_every~5)
# [Epoch 198] train=2.985 | eval=skipped (eval_every~5)
# [Epoch 199] train=2.989 | eval=2.952 | score=2.952 (eval_every~5)
# [Epoch 200] train=3.001 | eval=skipped (eval_every~5)
# [Epoch 201] train=3.004 | eval=skipped (eval_every~5)
# [Epoch 202] train=3.029 | eval=skipped (eval_every~5)
# [Epoch 203] train=3.014 | eval=skipped (eval_every~5)
# [Epoch 204] train=3.018 | eval=2.947 | score=2.947 (eval_every~4)
# [Epoch 205] train=3.023 | eval=skipped (eval_every~4)
# [Epoch 206] train=2.985 | eval=skipped (eval_every~4)
# [Epoch 207] train=2.988 | eval=skipped (eval_every~4)
# [Epoch 208] train=2.979 | eval=2.946 | score=2.946 (eval_every~4)
# [Epoch 209] train=2.988 | eval=skipped (eval_every~4)
# [Epoch 210] train=2.993 | eval=skipped (eval_every~4)
# [Epoch 211] train=3.020 | eval=skipped (eval_every~4)
# [Epoch 212] train=3.021 | eval=2.965 | score=2.965 (eval_every~4)
# [Epoch 213] train=3.005 | eval=skipped (eval_every~4)
# [Epoch 214] train=2.969 | eval=skipped (eval_every~4)
# [Epoch 215] train=3.006 | eval=skipped (eval_every~4)
# [Epoch 216] train=2.982 | eval=2.925 | score=2.925 (eval_every~4)
#   + saved (score=2.925)
# [Epoch 217] train=2.988 | eval=skipped (eval_every~4)
# [Epoch 218] train=3.001 | eval=skipped (eval_every~4)
# [Epoch 219] train=3.001 | eval=skipped (eval_every~4)
# [Epoch 220] train=2.975 | eval=2.930 | score=2.930 (eval_every~4)
# [Epoch 221] train=3.008 | eval=skipped (eval_every~4)
# [Epoch 222] train=2.984 | eval=skipped (eval_every~4)
# [Epoch 223] train=2.969 | eval=skipped (eval_every~4)
# [Epoch 224] train=2.973 | eval=2.935 | score=2.935 (eval_every~4)
# [Epoch 225] train=2.988 | eval=skipped (eval_every~4)
# [Epoch 226] train=2.966 | eval=skipped (eval_every~4)
# [Epoch 227] train=2.979 | eval=skipped (eval_every~4)
# [Epoch 228] train=2.987 | eval=2.930 | score=2.930 (eval_every~4)
# [Epoch 229] train=3.024 | eval=skipped (eval_every~4)
# [Epoch 230] train=2.975 | eval=skipped (eval_every~4)
# [Epoch 231] train=2.996 | eval=skipped (eval_every~4)
# [Epoch 232] train=2.961 | eval=2.916 | score=2.916 (eval_every~3)
#   + saved (score=2.916)
# [Epoch 233] train=2.975 | eval=skipped (eval_every~3)
# [Epoch 234] train=2.973 | eval=skipped (eval_every~3)
# [Epoch 235] train=2.985 | eval=2.923 | score=2.923 (eval_every~3)
# [Epoch 236] train=2.978 | eval=skipped (eval_every~3)
# [Epoch 237] train=2.994 | eval=skipped (eval_every~3)
# [Epoch 238] train=3.018 | eval=2.943 | score=2.943 (eval_every~3)
# [Epoch 239] train=2.987 | eval=skipped (eval_every~3)
# [Epoch 240] train=2.981 | eval=skipped (eval_every~3)
# [Epoch 241] train=2.982 | eval=2.937 | score=2.937 (eval_every~3)
# [Epoch 242] train=2.992 | eval=skipped (eval_every~3)
# [Epoch 243] train=2.972 | eval=skipped (eval_every~3)
# [Epoch 244] train=3.000 | eval=2.916 | score=2.916 (eval_every~3)
# [Epoch 245] train=3.028 | eval=skipped (eval_every~3)
# [Epoch 246] train=3.046 | eval=skipped (eval_every~3)
# [Epoch 247] train=2.969 | eval=2.936 | score=2.936 (eval_every~3)
# [Epoch 248] train=2.955 | eval=skipped (eval_every~3)
# [Epoch 249] train=2.967 | eval=skipped (eval_every~3)
# [Epoch 250] train=3.002 | eval=2.933 | score=2.933 (eval_every~3)
# [Epoch 251] train=2.980 | eval=skipped (eval_every~3)
# [Epoch 252] train=2.993 | eval=skipped (eval_every~3)

# %% [markdown]
# ## Plot

# %%
train_loss_arr = np.array(train_epoch_losses)
eval_loss_arr = np.array(eval_epoch_losses)
score_arr = np.array(scores)
best_epoch = best_checkpoint["epoch"]

epochs = np.arange(len(train_loss_arr))

# best epoch based on score

best_score = score_arr[best_epoch]
best_eval_loss = eval_loss_arr[best_epoch]

plt.figure(figsize=(8, 5))

# Main curves
plt.plot(epochs, train_loss_arr, linewidth=2, label="train loss")
plt.plot(epochs, eval_loss_arr, linewidth=2, label="eval loss")
plt.plot(epochs, score_arr, linewidth=2, linestyle="--", label="score")

ymin, ymax = plt.ylim()
yrange = ymax - ymin

xmin, xmax = plt.xlim()
xrange = xmax - xmin

y_offset = 0.5 * yrange
x_offset = -0.05 * xrange

# Annotation of best score
plt.annotate(
    f"min score = {best_score:.3f}\nepoch = {best_epoch}",
    xy=(best_epoch, best_score),
    xytext=(best_epoch + x_offset, best_score + y_offset),
    textcoords="data",
    arrowprops={"arrowstyle": "->", "linewidth": 1},
    fontsize=9,
    bbox={"boxstyle": "round,pad=0.3", "fc": "white", "alpha": 0.8},
)

plt.xlabel("Epoch")
plt.ylabel("Loss / Score")
plt.title(f"{perform_name} PF network training")

plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save figure
fig_path = PERFORM_DIR / "net_training_loss.png"
plt.savefig(fig_path, dpi=300)

# Save raw arrays
np.save(PERFORM_DIR / "net_training.npy", train_loss_arr)
np.save(PERFORM_DIR / "net_eval.npy", eval_loss_arr)
np.save(PERFORM_DIR / "net_score.npy", score_arr)
np.save(PERFORM_DIR / "net_bestepoch.npy", best_epoch)

plt.show()

print(f"✓ Plot saved to {fig_path}")
print(f"✓ Best epoch: {best_epoch} (score={best_score:.4f})")
# Out:
# ✓ Plot saved to /lustre/diazgonz/deep-performance-rul/experiments/DS05/opcond_q0.001-0.999_corr0.6_range0.6/estimation_thr0.2/gamma/net_arg7/SmLPC/net_training_loss.png
# ✓ Best epoch: 285 (score=3.4214)
