# %% [markdown]
# ## Train the PF-Controller Neural Network
#
# For each performance metric, train the corresponding particle-filter (PF) controller neural network.

# %%
import os

# use the CPUs allocated by SLURM (fallback 4); set before numpy/torch import so
# the BLAS/OpenMP backend also honors the thread count
N_CPUS = int(os.environ.get("SLURM_CPUS_PER_TASK") or 4)
os.environ.setdefault("OMP_NUM_THREADS", str(N_CPUS))
os.environ.setdefault("MKL_NUM_THREADS", str(N_CPUS))

import numpy as np  # noqa: E402
import pandas as pd  # noqa: E402
import torch  # noqa: E402
from matplotlib import pyplot as plt  # noqa: E402

from experiment_config import (  # noqa: E402
    SEED,
    DegModel,
    dataset_paths,
)
from src.helpers.seed import set_global_seed  # noqa: E402
from src.models.networks.pf_mlp import ParticleFilterMLP  # noqa: E402
from src.training.pfnet_hparams import PFNET_ARGS  # noqa: E402
from src.training.pfnet_training import train_pf_controller_cv  # noqa: E402

torch.set_num_threads(N_CPUS)
print(f"CPU threads: {torch.get_num_threads()} (N_CPUS={N_CPUS})")
# Out:
# CPU threads: 4 (N_CPUS=4)

# %% [markdown]
# ## Task

# %%
DATA_NAME = "DS01"
perform_name = "SmLPC"
ARGS_ID = 8

# %% [markdown]
# ## Hyper-Parameters

# %%
args = PFNET_ARGS[ARGS_ID]

net_args = args["NETWORK"]

if net_args is None:
    raise SystemExit(
        "This ARGS_ID is a no-network baseline (NETWORK=None): there is no "
        "network to train. Use it only in the test/ablation notebooks."
    )
pf_args = args["PARTICLE_FILTER"]
train_args = args["TRAINING"]
eval_args = args["EVALUATION"]

# %%
set_global_seed(SEED)

ESTIMATION_DIR, DEGR_MODEL_DIR = dataset_paths(
    DATA_NAME, fields=["estimation", "degr_model"]
)

PFNET_ARGS_DIR = DEGR_MODEL_DIR / f"net_arg{ARGS_ID}"
PERFORM_DIR = PFNET_ARGS_DIR / perform_name

checkpoint_best_path = PERFORM_DIR / "checkpoint_best.pt"
checkpoint_last_path = PERFORM_DIR / "checkpoint_last.pt"
checkpoint_best_path.parent.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Import training data

# %%
hi_df = pd.read_csv(ESTIMATION_DIR / "data_dev.csv")
units = hi_df["unit"].astype(int).unique().tolist()
units
# Out:
# [1, 2, 4, 5, 6]

# %% [markdown]
# ### Extract degradation onset

# %%
onsets = {
    unit: hi_df[(hi_df["unit"] == unit) & (hi_df["hs"] == 0)]["cycle"].values[0]
    for unit in units
}
del hi_df["hs"]

# %%
perform_names = [col for col in hi_df.columns if col not in ["unit", "cycle"]]

performs = {
    name: {unit: hi_df[hi_df["unit"] == unit][name].values for unit in units}
    for name in perform_names
}

init_ss = {
    name: {unit: perform[unit].max() for unit in units}
    for name, perform in performs.items()
}
time = {unit: hi_df[hi_df["unit"] == unit]["cycle"].values for unit in units}

# %% [markdown]
# ## Create component (base) models

# %%
dev_data = {}
dev_eol = {}
for unit in units:
    t = time[unit]
    s = performs[perform_name][unit]
    dev_data[unit] = torch.tensor(np.stack([t, s], axis=1), dtype=torch.float32)
    dev_eol[unit] = torch.tensor(t[-1], dtype=torch.float32)

# %%
dev_degmodels = {}
for unit in performs[perform_name]:
    best_model = DegModel(onset=onsets[unit], init_s=init_ss[perform_name][unit])
    best_model.load_state_dict(
        torch.load(
            DEGR_MODEL_DIR / "states" / perform_name / f"unit_{unit}" / "best_model.pt"
        )
    )
    dev_degmodels[unit] = best_model

# %% [markdown]
# ## Train Particle Filter controller Net

# %%
from src.models.networks.pf_mlp import build_activation

net = ParticleFilterMLP(
    state_dim=DegModel.state_dim(),
    hidden_dims=list(net_args["HIDDEN_DIMS"]),
    activation=build_activation(net_args),
    dropout_p=float(net_args["DROPOUT"]),
)

optimizer = torch.optim.Adam(net.parameters(), float(train_args["LR"]))
optimizer.zero_grad()

# %%
best_score = float("inf")
train_epoch_losses = []
eval_epoch_losses = []
scores = []
start_epoch = 0

if checkpoint_last_path.exists():
    ckpt = torch.load(checkpoint_last_path, weights_only=False)

    net.load_state_dict(ckpt["model_state"])
    optimizer.load_state_dict(ckpt["optimizer_state"])

    start_epoch = ckpt["epoch"] + 1
    best_score = ckpt["best_score"]
    scores = ckpt.get("scores", [])
    train_epoch_losses = ckpt.get("train_losses", [])
    eval_epoch_losses = ckpt.get("eval_losses", [])

    torch.random.set_rng_state(ckpt["rng_torch"])
    np.random.set_state(ckpt["rng_numpy"])

    print(f"✓ Resumed from epoch {start_epoch}, best_score={best_score:.3f}")

# %%
train_state = train_pf_controller_cv(
    net=net,
    optimizer=optimizer,
    units=units,
    dev_data=dev_data,
    dev_degmodels=dev_degmodels,
    n_particles=int(pf_args["N_PARTICLES"]),
    max_life=int(pf_args["MAX_LIFE"]),
    loss_tail_steps=int(train_args["LOSS_TAIL_STEPS"]),
    n_epochs=int(train_args["N_EPOCHS"]),
    checkpoint_best_path=checkpoint_best_path,
    checkpoint_last_path=checkpoint_last_path,
    start_epoch=start_epoch,
    best_score=best_score,
    scores=scores,
    train_epoch_losses=train_epoch_losses,
    eval_epoch_losses=eval_epoch_losses,
    seed=SEED,
    eval_repetitions=int(eval_args["REPETITIONS"]),
    eval_seed_stride=int(eval_args["SEED_STRIDE"]),
    eval_initial_interval_epochs=int(eval_args["INITIAL_INTERVAL_EPOCHS"]),
    eval_final_interval_epochs=int(eval_args["FINAL_INTERVAL_EPOCHS"]),
    match_train_eval_prior=bool(train_args.get("MATCH_TRAIN_EVAL_PRIOR", False)),
    verbose=True,
)

best_score = train_state["best_score"]
scores = train_state["scores"]
train_epoch_losses = train_state["train_epoch_losses"]
eval_epoch_losses = train_state["eval_epoch_losses"]
epoch = train_state["epoch"]
best_checkpoint = train_state["best_checkpoint"]

if best_checkpoint is None and checkpoint_best_path.exists():
    best_checkpoint = torch.load(checkpoint_best_path, weights_only=False)
# Out:
# [Epoch 000] train=9.582 | eval=6.857 | score=6.857 (eval_every~12)
#   + saved (score=6.857)
# [Epoch 001] train=6.105 | eval=skipped (eval_every~12)
# [Epoch 002] train=5.118 | eval=skipped (eval_every~12)
# [Epoch 003] train=4.042 | eval=skipped (eval_every~12)
# [Epoch 004] train=3.869 | eval=skipped (eval_every~12)
# [Epoch 005] train=3.629 | eval=skipped (eval_every~12)
# [Epoch 006] train=3.718 | eval=skipped (eval_every~12)
# [Epoch 007] train=3.589 | eval=skipped (eval_every~12)
# [Epoch 008] train=3.555 | eval=skipped (eval_every~12)
# [Epoch 009] train=3.580 | eval=skipped (eval_every~12)
# [Epoch 010] train=3.541 | eval=skipped (eval_every~12)
# [Epoch 011] train=3.452 | eval=skipped (eval_every~12)
# [Epoch 012] train=3.543 | eval=3.890 | score=3.890 (eval_every~12)
#   + saved (score=3.890)
# [Epoch 013] train=3.453 | eval=skipped (eval_every~12)
# [Epoch 014] train=3.483 | eval=skipped (eval_every~11)
# [Epoch 015] train=3.465 | eval=skipped (eval_every~11)
# [Epoch 016] train=3.436 | eval=skipped (eval_every~11)
# [Epoch 017] train=3.421 | eval=skipped (eval_every~11)
# [Epoch 018] train=3.444 | eval=skipped (eval_every~11)
# [Epoch 019] train=3.408 | eval=skipped (eval_every~11)
# [Epoch 020] train=3.419 | eval=skipped (eval_every~11)
# [Epoch 021] train=3.411 | eval=skipped (eval_every~11)
# [Epoch 022] train=3.411 | eval=skipped (eval_every~11)
# [Epoch 023] train=3.389 | eval=skipped (eval_every~11)
# [Epoch 024] train=3.381 | eval=3.265 | score=3.265 (eval_every~11)
#   + saved (score=3.265)
# [Epoch 025] train=3.380 | eval=skipped (eval_every~11)
# [Epoch 026] train=3.388 | eval=skipped (eval_every~11)
# [Epoch 027] train=3.377 | eval=skipped (eval_every~11)
# [Epoch 028] train=3.377 | eval=skipped (eval_every~11)
# [Epoch 029] train=3.361 | eval=skipped (eval_every~11)
# [Epoch 030] train=3.369 | eval=skipped (eval_every~11)
# [Epoch 031] train=3.361 | eval=skipped (eval_every~11)
# [Epoch 032] train=3.377 | eval=skipped (eval_every~11)
# [Epoch 033] train=3.360 | eval=skipped (eval_every~11)
# [Epoch 034] train=3.383 | eval=skipped (eval_every~11)
# [Epoch 035] train=3.354 | eval=3.270 | score=3.270 (eval_every~11)
# [Epoch 036] train=3.347 | eval=skipped (eval_every~11)
# [Epoch 037] train=3.377 | eval=skipped (eval_every~11)
# [Epoch 038] train=3.374 | eval=skipped (eval_every~11)
# [Epoch 039] train=3.350 | eval=skipped (eval_every~11)
# [Epoch 040] train=3.377 | eval=skipped (eval_every~11)
# [Epoch 041] train=3.356 | eval=skipped (eval_every~10)
# [Epoch 042] train=3.348 | eval=skipped (eval_every~10)
# [Epoch 043] train=3.364 | eval=skipped (eval_every~10)
# [Epoch 044] train=3.352 | eval=skipped (eval_every~10)
# [Epoch 045] train=3.359 | eval=skipped (eval_every~10)
# [Epoch 046] train=3.365 | eval=3.264 | score=3.264 (eval_every~10)
#   + saved (score=3.264)
# [Epoch 047] train=3.352 | eval=skipped (eval_every~10)
# [Epoch 048] train=3.350 | eval=skipped (eval_every~10)
# [Epoch 049] train=3.341 | eval=skipped (eval_every~10)
# [Epoch 050] train=3.359 | eval=skipped (eval_every~10)
# [Epoch 051] train=3.343 | eval=skipped (eval_every~10)
# [Epoch 052] train=3.337 | eval=skipped (eval_every~10)
# [Epoch 053] train=3.330 | eval=skipped (eval_every~10)
# [Epoch 054] train=3.348 | eval=skipped (eval_every~10)
# [Epoch 055] train=3.344 | eval=skipped (eval_every~10)
# [Epoch 056] train=3.327 | eval=3.255 | score=3.255 (eval_every~10)
#   + saved (score=3.255)
# [Epoch 057] train=3.329 | eval=skipped (eval_every~10)
# [Epoch 058] train=3.325 | eval=skipped (eval_every~10)
# [Epoch 059] train=3.324 | eval=skipped (eval_every~10)
# [Epoch 060] train=3.343 | eval=skipped (eval_every~10)
# [Epoch 061] train=3.329 | eval=skipped (eval_every~10)
# [Epoch 062] train=3.332 | eval=skipped (eval_every~10)
# [Epoch 063] train=3.341 | eval=skipped (eval_every~10)
# [Epoch 064] train=3.326 | eval=skipped (eval_every~10)
# [Epoch 065] train=3.319 | eval=skipped (eval_every~10)
# [Epoch 066] train=3.323 | eval=3.246 | score=3.246 (eval_every~10)
#   + saved (score=3.246)
# [Epoch 067] train=3.315 | eval=skipped (eval_every~10)
# [Epoch 068] train=3.315 | eval=skipped (eval_every~9)
# [Epoch 069] train=3.316 | eval=skipped (eval_every~9)
# [Epoch 070] train=3.304 | eval=skipped (eval_every~9)
# [Epoch 071] train=3.296 | eval=skipped (eval_every~9)
# [Epoch 072] train=3.293 | eval=skipped (eval_every~9)
# [Epoch 073] train=3.300 | eval=skipped (eval_every~9)
# [Epoch 074] train=3.272 | eval=skipped (eval_every~9)
# [Epoch 075] train=3.262 | eval=skipped (eval_every~9)
# [Epoch 076] train=3.268 | eval=3.190 | score=3.190 (eval_every~9)
#   + saved (score=3.190)
# [Epoch 077] train=3.281 | eval=skipped (eval_every~9)
# [Epoch 078] train=3.241 | eval=skipped (eval_every~9)
# [Epoch 079] train=3.250 | eval=skipped (eval_every~9)
# [Epoch 080] train=3.242 | eval=skipped (eval_every~9)
# [Epoch 081] train=3.220 | eval=skipped (eval_every~9)
# [Epoch 082] train=3.251 | eval=skipped (eval_every~9)
# [Epoch 083] train=3.225 | eval=skipped (eval_every~9)
# [Epoch 084] train=3.262 | eval=skipped (eval_every~9)
# [Epoch 085] train=3.213 | eval=3.160 | score=3.160 (eval_every~9)
#   + saved (score=3.160)
# [Epoch 086] train=3.209 | eval=skipped (eval_every~9)
# [Epoch 087] train=3.201 | eval=skipped (eval_every~9)
# [Epoch 088] train=3.225 | eval=skipped (eval_every~9)
# [Epoch 089] train=3.203 | eval=skipped (eval_every~9)
# [Epoch 090] train=3.209 | eval=skipped (eval_every~9)
# [Epoch 091] train=3.210 | eval=skipped (eval_every~9)
# [Epoch 092] train=3.202 | eval=skipped (eval_every~9)
# [Epoch 093] train=3.209 | eval=skipped (eval_every~9)
# [Epoch 094] train=3.174 | eval=3.143 | score=3.143 (eval_every~9)
#   + saved (score=3.143)
# [Epoch 095] train=3.173 | eval=skipped (eval_every~9)
# [Epoch 096] train=3.192 | eval=skipped (eval_every~8)
# [Epoch 097] train=3.170 | eval=skipped (eval_every~8)
# [Epoch 098] train=3.190 | eval=skipped (eval_every~8)
# [Epoch 099] train=3.187 | eval=skipped (eval_every~8)
# [Epoch 100] train=3.170 | eval=skipped (eval_every~8)
# [Epoch 101] train=3.163 | eval=skipped (eval_every~8)
# [Epoch 102] train=3.166 | eval=skipped (eval_every~8)
# [Epoch 103] train=3.154 | eval=3.104 | score=3.104 (eval_every~8)
#   + saved (score=3.104)
# [Epoch 104] train=3.158 | eval=skipped (eval_every~8)
# [Epoch 105] train=3.145 | eval=skipped (eval_every~8)
# [Epoch 106] train=3.179 | eval=skipped (eval_every~8)
# [Epoch 107] train=3.159 | eval=skipped (eval_every~8)
# [Epoch 108] train=3.140 | eval=skipped (eval_every~8)
# [Epoch 109] train=3.130 | eval=skipped (eval_every~8)
# [Epoch 110] train=3.163 | eval=skipped (eval_every~8)
# [Epoch 111] train=3.133 | eval=3.084 | score=3.084 (eval_every~8)
#   + saved (score=3.084)
# [Epoch 112] train=3.100 | eval=skipped (eval_every~8)
# [Epoch 113] train=3.126 | eval=skipped (eval_every~8)
# [Epoch 114] train=3.144 | eval=skipped (eval_every~8)
# [Epoch 115] train=3.116 | eval=skipped (eval_every~8)
# [Epoch 116] train=3.112 | eval=skipped (eval_every~8)
# [Epoch 117] train=3.131 | eval=skipped (eval_every~8)
# [Epoch 118] train=3.113 | eval=skipped (eval_every~8)
# [Epoch 119] train=3.100 | eval=3.049 | score=3.049 (eval_every~8)
#   + saved (score=3.049)
# [Epoch 120] train=3.074 | eval=skipped (eval_every~8)
# [Epoch 121] train=3.094 | eval=skipped (eval_every~8)
# [Epoch 122] train=3.089 | eval=skipped (eval_every~8)
# [Epoch 123] train=3.095 | eval=skipped (eval_every~7)
# [Epoch 124] train=3.097 | eval=skipped (eval_every~7)
# [Epoch 125] train=3.065 | eval=skipped (eval_every~7)
# [Epoch 126] train=3.062 | eval=skipped (eval_every~7)
# [Epoch 127] train=3.177 | eval=3.049 | score=3.049 (eval_every~7)
# [Epoch 128] train=3.097 | eval=skipped (eval_every~7)
# [Epoch 129] train=3.037 | eval=skipped (eval_every~7)
# [Epoch 130] train=3.151 | eval=skipped (eval_every~7)
# [Epoch 131] train=3.060 | eval=skipped (eval_every~7)
# [Epoch 132] train=3.086 | eval=skipped (eval_every~7)
# [Epoch 133] train=3.064 | eval=skipped (eval_every~7)
# [Epoch 134] train=3.044 | eval=2.984 | score=2.984 (eval_every~7)
#   + saved (score=2.984)
# [Epoch 135] train=3.042 | eval=skipped (eval_every~7)
# [Epoch 136] train=3.071 | eval=skipped (eval_every~7)
# [Epoch 137] train=3.066 | eval=skipped (eval_every~7)
# [Epoch 138] train=3.082 | eval=skipped (eval_every~7)
# [Epoch 139] train=3.065 | eval=skipped (eval_every~7)
# [Epoch 140] train=3.068 | eval=skipped (eval_every~7)
# [Epoch 141] train=3.043 | eval=3.018 | score=3.018 (eval_every~7)
# [Epoch 142] train=3.033 | eval=skipped (eval_every~7)
# [Epoch 143] train=3.025 | eval=skipped (eval_every~7)
# [Epoch 144] train=3.038 | eval=skipped (eval_every~7)
# [Epoch 145] train=3.021 | eval=skipped (eval_every~7)
# [Epoch 146] train=3.031 | eval=skipped (eval_every~7)
# [Epoch 147] train=3.047 | eval=skipped (eval_every~7)
# [Epoch 148] train=3.047 | eval=2.969 | score=2.969 (eval_every~7)
#   + saved (score=2.969)
# [Epoch 149] train=3.022 | eval=skipped (eval_every~7)
# [Epoch 150] train=3.031 | eval=skipped (eval_every~6)
# [Epoch 151] train=3.017 | eval=skipped (eval_every~6)
# [Epoch 152] train=3.035 | eval=skipped (eval_every~6)
# [Epoch 153] train=3.035 | eval=skipped (eval_every~6)
# [Epoch 154] train=2.987 | eval=skipped (eval_every~6)
# [Epoch 155] train=3.042 | eval=2.936 | score=2.936 (eval_every~6)
#   + saved (score=2.936)
# [Epoch 156] train=3.016 | eval=skipped (eval_every~6)
# [Epoch 157] train=2.996 | eval=skipped (eval_every~6)
# [Epoch 158] train=3.013 | eval=skipped (eval_every~6)
# [Epoch 159] train=2.991 | eval=skipped (eval_every~6)
# [Epoch 160] train=3.018 | eval=skipped (eval_every~6)
# [Epoch 161] train=3.029 | eval=2.946 | score=2.946 (eval_every~6)
# [Epoch 162] train=3.004 | eval=skipped (eval_every~6)
# [Epoch 163] train=3.024 | eval=skipped (eval_every~6)
# [Epoch 164] train=2.999 | eval=skipped (eval_every~6)
# [Epoch 165] train=3.014 | eval=skipped (eval_every~6)
# [Epoch 166] train=3.005 | eval=skipped (eval_every~6)
# [Epoch 167] train=3.013 | eval=2.935 | score=2.935 (eval_every~6)
#   + saved (score=2.935)
# [Epoch 168] train=2.984 | eval=skipped (eval_every~6)
# [Epoch 169] train=3.020 | eval=skipped (eval_every~6)
# [Epoch 170] train=3.012 | eval=skipped (eval_every~6)
# [Epoch 171] train=2.980 | eval=skipped (eval_every~6)
# [Epoch 172] train=2.973 | eval=skipped (eval_every~6)
# [Epoch 173] train=3.025 | eval=2.914 | score=2.914 (eval_every~6)
#   + saved (score=2.914)
# [Epoch 174] train=3.001 | eval=skipped (eval_every~6)
# [Epoch 175] train=2.987 | eval=skipped (eval_every~6)
# [Epoch 176] train=2.970 | eval=skipped (eval_every~6)
# [Epoch 177] train=2.999 | eval=skipped (eval_every~5)
# [Epoch 178] train=2.984 | eval=skipped (eval_every~5)
# [Epoch 179] train=2.975 | eval=2.925 | score=2.925 (eval_every~5)
# [Epoch 180] train=3.006 | eval=skipped (eval_every~5)
# [Epoch 181] train=2.950 | eval=skipped (eval_every~5)
# [Epoch 182] train=2.988 | eval=skipped (eval_every~5)
# [Epoch 183] train=3.017 | eval=skipped (eval_every~5)
# [Epoch 184] train=3.005 | eval=2.980 | score=2.980 (eval_every~5)
# [Epoch 185] train=3.000 | eval=skipped (eval_every~5)
# [Epoch 186] train=2.989 | eval=skipped (eval_every~5)
# [Epoch 187] train=2.962 | eval=skipped (eval_every~5)
# [Epoch 188] train=2.980 | eval=skipped (eval_every~5)
# [Epoch 189] train=3.004 | eval=2.958 | score=2.958 (eval_every~5)
# [Epoch 190] train=2.971 | eval=skipped (eval_every~5)
# [Epoch 191] train=2.979 | eval=skipped (eval_every~5)
# [Epoch 192] train=2.978 | eval=skipped (eval_every~5)
# [Epoch 193] train=2.970 | eval=skipped (eval_every~5)
# [Epoch 194] train=2.978 | eval=2.916 | score=2.916 (eval_every~5)
# [Epoch 195] train=2.982 | eval=skipped (eval_every~5)
# [Epoch 196] train=3.005 | eval=skipped (eval_every~5)
# [Epoch 197] train=3.009 | eval=skipped (eval_every~5)
# [Epoch 198] train=2.945 | eval=skipped (eval_every~5)
# [Epoch 199] train=2.949 | eval=2.902 | score=2.902 (eval_every~5)
#   + saved (score=2.902)
# [Epoch 200] train=3.013 | eval=skipped (eval_every~5)
# [Epoch 201] train=2.980 | eval=skipped (eval_every~5)
# [Epoch 202] train=2.967 | eval=skipped (eval_every~5)
# [Epoch 203] train=2.962 | eval=skipped (eval_every~5)
# [Epoch 204] train=2.952 | eval=2.891 | score=2.891 (eval_every~4)
#   + saved (score=2.891)
# [Epoch 205] train=2.963 | eval=skipped (eval_every~4)
# [Epoch 206] train=3.003 | eval=skipped (eval_every~4)
# [Epoch 207] train=2.974 | eval=skipped (eval_every~4)
# [Epoch 208] train=2.985 | eval=2.885 | score=2.885 (eval_every~4)
#   + saved (score=2.885)
# [Epoch 209] train=2.978 | eval=skipped (eval_every~4)
# [Epoch 210] train=2.957 | eval=skipped (eval_every~4)
# [Epoch 211] train=2.980 | eval=skipped (eval_every~4)
# [Epoch 212] train=2.972 | eval=2.901 | score=2.901 (eval_every~4)
# [Epoch 213] train=2.942 | eval=skipped (eval_every~4)
# [Epoch 214] train=2.968 | eval=skipped (eval_every~4)
# [Epoch 215] train=2.958 | eval=skipped (eval_every~4)
# [Epoch 216] train=2.984 | eval=2.909 | score=2.909 (eval_every~4)
# [Epoch 217] train=2.950 | eval=skipped (eval_every~4)
# [Epoch 218] train=2.995 | eval=skipped (eval_every~4)
# [Epoch 219] train=2.965 | eval=skipped (eval_every~4)
# [Epoch 220] train=2.962 | eval=2.907 | score=2.907 (eval_every~4)
# [Epoch 221] train=2.976 | eval=skipped (eval_every~4)
# [Epoch 222] train=2.940 | eval=skipped (eval_every~4)
# [Epoch 223] train=2.950 | eval=skipped (eval_every~4)
# [Epoch 224] train=2.942 | eval=2.895 | score=2.895 (eval_every~4)
# [Epoch 225] train=2.998 | eval=skipped (eval_every~4)
# [Epoch 226] train=2.940 | eval=skipped (eval_every~4)
# [Epoch 227] train=2.937 | eval=skipped (eval_every~4)
# [Epoch 228] train=2.997 | eval=2.909 | score=2.909 (eval_every~4)
# [Epoch 229] train=2.971 | eval=skipped (eval_every~4)
# [Epoch 230] train=2.959 | eval=skipped (eval_every~4)
# [Epoch 231] train=2.955 | eval=skipped (eval_every~4)
# [Epoch 232] train=2.951 | eval=2.919 | score=2.919 (eval_every~3)
# [Epoch 233] train=2.973 | eval=skipped (eval_every~3)
# [Epoch 234] train=2.960 | eval=skipped (eval_every~3)
# [Epoch 235] train=2.964 | eval=2.901 | score=2.901 (eval_every~3)
# [Epoch 236] train=2.944 | eval=skipped (eval_every~3)
# [Epoch 237] train=2.986 | eval=skipped (eval_every~3)
# [Epoch 238] train=2.987 | eval=2.910 | score=2.910 (eval_every~3)
# [Epoch 239] train=2.963 | eval=skipped (eval_every~3)
# [Epoch 240] train=2.981 | eval=skipped (eval_every~3)
# [Epoch 241] train=2.959 | eval=2.889 | score=2.889 (eval_every~3)
# [Epoch 242] train=2.966 | eval=skipped (eval_every~3)
# [Epoch 243] train=2.937 | eval=skipped (eval_every~3)
# [Epoch 244] train=2.936 | eval=2.893 | score=2.893 (eval_every~3)
# [Epoch 245] train=2.932 | eval=skipped (eval_every~3)
# [Epoch 246] train=2.959 | eval=skipped (eval_every~3)
# [Epoch 247] train=2.927 | eval=2.881 | score=2.881 (eval_every~3)
#   + saved (score=2.881)
# [Epoch 248] train=2.929 | eval=skipped (eval_every~3)
# [Epoch 249] train=2.963 | eval=skipped (eval_every~3)
# [Epoch 250] train=2.963 | eval=2.886 | score=2.886 (eval_every~3)
# [Epoch 251] train=2.962 | eval=skipped (eval_every~3)
# [Epoch 252] train=2.911 | eval=skipped (eval_every~3)
# [Epoch 253] train=2.979 | eval=2.908 | score=2.908 (eval_every~3)

# %% [markdown]
# ## Plot

# %%
train_loss_arr = np.array(train_epoch_losses)
eval_loss_arr = np.array(eval_epoch_losses)
score_arr = np.array(scores)
best_epoch = best_checkpoint["epoch"]

epochs = np.arange(len(train_loss_arr))

# best epoch based on score

best_score = score_arr[best_epoch]
best_eval_loss = eval_loss_arr[best_epoch]

plt.figure(figsize=(8, 5))

# Main curves
plt.plot(epochs, train_loss_arr, linewidth=2, label="train loss")
plt.plot(epochs, eval_loss_arr, linewidth=2, label="eval loss")
plt.plot(epochs, score_arr, linewidth=2, linestyle="--", label="score")

ymin, ymax = plt.ylim()
yrange = ymax - ymin

xmin, xmax = plt.xlim()
xrange = xmax - xmin

y_offset = 0.5 * yrange
x_offset = -0.05 * xrange

# Annotation of best score
plt.annotate(
    f"min score = {best_score:.3f}\nepoch = {best_epoch}",
    xy=(best_epoch, best_score),
    xytext=(best_epoch + x_offset, best_score + y_offset),
    textcoords="data",
    arrowprops={"arrowstyle": "->", "linewidth": 1},
    fontsize=9,
    bbox={"boxstyle": "round,pad=0.3", "fc": "white", "alpha": 0.8},
)

plt.xlabel("Epoch")
plt.ylabel("Loss / Score")
plt.title(f"{perform_name} PF network training")

plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

# Save figure
fig_path = PERFORM_DIR / "net_training_loss.png"
plt.savefig(fig_path, dpi=300)

# Save raw arrays
np.save(PERFORM_DIR / "net_training.npy", train_loss_arr)
np.save(PERFORM_DIR / "net_eval.npy", eval_loss_arr)
np.save(PERFORM_DIR / "net_score.npy", score_arr)
np.save(PERFORM_DIR / "net_bestepoch.npy", best_epoch)

plt.show()

print(f"✓ Plot saved to {fig_path}")
print(f"✓ Best epoch: {best_epoch} (score={best_score:.4f})")
# Out:
# ✓ Plot saved to /lustre/diazgonz/deep-performance-rul/experiments/DS03/opcond_q0.001-0.999_corr0.6_range0.6/estimation_thr0.2/gamma/net_arg7/SmLPC/net_training_loss.png
# ✓ Best epoch: 293 (score=nan)
